# %% [markdown]
# # xprStats

# %%
# lib
from urllib.request import urlopen
import json  
import pandas as pd

# %%
# Récupération des donnée 
# param (date or thirdParty)
param = "1706"

# url
url = "https://experts.huma-num.fr/xpr/statistics/" + param

# enregistrement de la réponse
response = urlopen(url)

# lecture du json
data = json.loads(response.read())
  
# print the json response
#print(data)

# %% [markdown]
# ## Expertises

# %%
expertises = data['expertises']

# %%
print("Nombre total d'expertises : " + str(expertises['total']))
# Out:
# Nombre total d'expertises : 360

# %% [markdown]
# ### Croquis

# %%
sketchesDF = pd.json_normalize(expertises['sketches'])
print(sketchesDF.to_string(index=False))
# Out:
#  expertisesWithoutSketch  expertisesWithSketch
#                      353                     7

# %% [markdown]
# ### Étendue

# %%
extent = expertises['extent']
#print(extent)

print('Nombre de feuillets : ' + str(extent['total']))

print('Moyenne par expertise : ' + str(extent['averageByExpertise']))

#Distribution
print('Distribution :')
keys = []
values = []
for dic in extent['extentDistribution']:
    for key, val in dic.items():
        keys.append(key),
        values.append(val)        

extentDistributionDict = {'nombre de feuillets': keys, 'nombre d’expertises': values,} 
print(pd.DataFrame(extentDistributionDict).to_string(index=False))
# Out:
# Nombre de feuillets : 2801
# Moyenne par expertise : 7.78
# Distribution :
# nombre de feuillets  nombre d’expertises
#                   5                  228
#                  10                   81
#                  15                   14
#                  20                   15
#                  25                    5
#                  30                    5
#                  35                    3
#                  40                    0
#                  45                    0
#                  50                    1
#                  55                    0
#                  60                    0
#                  65                    1
#                  70                    1
#                  75                    1
#                  80                    0
#                  85                    0
#                  90                    0
#                  95                    1
#                 100                    3

# %% [markdown]
# ### Annexes

# %%
appendices = expertises['appendices']
#print(appendices)

print(f"{appendices['total']} annexes")


print(f"{appendices['expertisesWithAppendices']} expertises avec annexes ; {appendices['expertisesWithoutAppendices']} expertises sans annexes")


df=pd.json_normalize(appendices['types'])
print(df.to_string(columns=['label', 'total', 'expertises'], index=False))
# Out:
# 475 annexes
# 312 expertises avec annexes ; 48 expertises sans annexes
#                                       label  total  expertises
# Pouvoir/procuration (acte sous seing privé)     47          42
#                                       Autre    369         298
#          Pouvoir/procuration (acte notarié)     14          14
#                                     Requête     16          15
#                      Plan, coupe, élévation     17          13
#                                   Brouillon      4           3
#                                     Croquis      4           4
#                                      Dessin      4           3

# %% [markdown]
# ### Vacations

# %%
sessions = expertises['sessions']
#print(sessions)

print(f"{sessions['total']} vacations")


print(f"en moyenne {sessions['averageByExpertise']} vacations par expertise")
# Out:
# 751 vacations
# en moyenne 2.09 vacations par expertise

# %% [markdown]
# Nombre de vacation par lieu

# %%
sessionsDf=pd.json_normalize(sessions['places'])
print(sessionsDf.to_string(columns=['label', 'total'], index=False))
# Out:
#    label  total
#    Paris    517
# Banlieue     44
# Province    190

# %% [markdown]
# ### Durée

# %%
duration = expertises['duration']
#print(duration)

# %% [markdown]
# #### Jours

# %%
#Distribution
durationDays = duration['days']
#print(durationDays)
print('Distribution :')
keys = []
values = []
for dic in durationDays['distributionByDays']:
    for key, val in dic.items():
        keys.append(key),
        values.append(val)        

durationDaysDf = {'nombre de jours': keys, 'nombre d’expertises': values,} 
print(pd.DataFrame(durationDaysDf).to_string(index=False))
# Out:
# Distribution :
# nombre de jours  nombre d’expertises
#               5                  296
#              10                   14
#              15                    6
#              20                    9
#              25                    7
#              30                    1
#              35                    1
#              40                    1
#              45                    1
#              50                    2
#              55                    5
#              60                    1
#              65                    3
#              70                    0
#              75                    0
#              80                    0
#              85                    1
#              90                    0
#              95                    1
#             100                   10

# %% [markdown]
# #### Vacations

# %%
#Distribution
durationSessions = duration['sessions']
#print(durationDays)
print(f"{durationSessions['total']} vacations, soit en moyenne {durationSessions['averageByExpertise']} vacations par expertise.")
# Out:
# 751 vacations, soit en moyenne 1.04 vacations par expertise.

# %% [markdown]
# ### Lieux

# %%
places = expertises['places']
#print(places)

placesDf=pd.json_normalize(places)
print(placesDf.to_string(columns=['place', 'total'], index=False))
# Out:
#                        place  total
#                      [paris]    272
#                    [suburbs]     24
#                   [province]     57
#           [[paris, suburbs]]      1
#          [[paris, province]]      4
#        [[suburbs, province]]      1
# [[paris, suburbs, province]]      1

# %% [markdown]
# ### Procédures et cadres

# %%
frameworks = expertises['frameworks']
#print(frameworks)

frameworksDf=pd.json_normalize(frameworks)
print(frameworksDf.to_string(columns=['label', 'framework', 'total'], index=False))
# Out:
#                                                                                                                   label framework  total
#                                                                                               Commun accord des parties         a     93
# L’institution est saisie dans le cadre d’une procédure (les parties nomment chacune leur expert ou un expert en commun)       b2a    107
#                         L’institution est saisie dans le cadre d’une procédure (l’institution nomme un ou deux experts)       b2b     52
#                                                     Requête auprès d’une institution pour qu’elle demande une expertise        b1     31
#                                          Saisie mixte (un expert est nommé par les parties, l'autre est nommé d'office)        b3      6
# L’institution est saisie dans le cadre d’une procédure (les parties nomment chacune leur expert ou un expert en commun)        b2     63
#                                                                                                       Cas problématique         c      6
#                                                                                                                                        2

# %% [markdown]
# ### Catégories

# %%
categories = expertises['categories']

for cat in categories:
    if cat['total'] != 0: print(f"{cat['label']} : {cat['total']} expertises"),
    for framework in cat['frameworks']:
        if framework['total'] != 0: print(f"\t{framework['framework']} : {framework['total']} expertises"),
        for place in framework['places']:
            if place['total'] != 0: print(f"\t\t{place['place']} : {place['total']}"),
            for obj in place['objects']:
                if obj['total'] != 0: print(f"\t\t\t{obj['label']} : {obj['total']}")
        print('\n')
    print('\n')
# Out:
# Recevoir et évaluer le travail réalisé : 75 expertises
# 	a : 23 expertises
# 		['paris'] : 20
# 			Ouvrages de maçonnerie : 7
# 			Maison(s) : 14
# 			Fosse(s) d'aisance : 1
# 		['suburbs'] : 1
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 		['province'] : 2
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
#
#
# 	b2a : 29 expertises
# 		['paris'] : 25
# 			Ouvrages de maçonnerie : 9
# 			Maison(s) : 16
# 		['province'] : 4
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 2
# 			Domaine, terres, fief : 1
#
#
# 	b2b : 5 expertises
# 		['paris'] : 3
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 3
# 		['suburbs'] : 2
# 			Maison(s) : 2
#
#
# 	b1 : 6 expertises
# 		['paris'] : 5
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 5
# 		['suburbs'] : 1
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
#
#
# 	b3 : 2 expertises
# 		['paris'] : 2
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 1
#
#
# 	b2 : 10 expertises
# 		['paris'] : 9
# 			Ouvrages de maçonnerie : 9
# 			Maison(s) : 3
# 		['suburbs'] : 1
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
#
#
#
#
#
#
#
#
# Départager : 82 expertises
# 	a : 37 expertises
# 		['paris'] : 36
# 			Terrain(s) : 1
# 			Mur(s) : 36
# 		['suburbs'] : 1
# 			Mur(s) : 1
#
#
# 	b2a : 24 expertises
# 		['paris'] : 22
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 8
# 			Mur(s) : 14
# 			Fosse(s) d'aisance : 1
# 		['province'] : 2
# 			Ouvrages de maçonnerie : 1
# 			Mur(s) : 1
#
#
# 	b2b : 7 expertises
# 		['paris'] : 7
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 			Mur(s) : 5
# 			Fosse(s) d'aisance : 1
#
#
# 	b1 : 2 expertises
# 		['paris'] : 1
# 			Ouvrages de maçonnerie : 1
# 		['province'] : 1
# 			Maison(s) : 1
#
#
#
#
# 	b2 : 11 expertises
# 		['paris'] : 9
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 4
# 			Mur(s) : 3
# 			Fosse(s) d'aisance : 1
# 			Puits : 2
# 		['suburbs'] : 2
# 			Terrain(s) : 1
# 			Mur(s) : 1
#
#
#
#
# 	 : 1 expertises
# 		['paris'] : 1
# 			Maison(s) : 1
#
#
#
#
# Décrire et évaluer les travaux à venir : 106 expertises
# 	a : 14 expertises
# 		['paris'] : 10
# 			Maison(s) : 3
# 			Mur(s) : 8
# 		['province'] : 4
# 			Ouvrages de maçonnerie : 3
# 			Ensemble de bâtiments (biens immeubles) : 3
# 			Domaine, terres, fief : 1
#
#
# 	b2a : 23 expertises
# 		['paris'] : 18
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 17
# 			Mur(s) : 1
# 		['suburbs'] : 1
# 			Maison(s) : 1
# 		['province'] : 3
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 2
# 		[['paris', 'suburbs', 'province']] : 1
# 			Maison(s) : 1
#
#
# 	b2b : 19 expertises
# 		['paris'] : 14
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 13
# 		['suburbs'] : 1
# 			Maison(s) : 1
# 		['province'] : 4
# 			Ouvrages de maçonnerie : 3
# 			Maison(s) : 1
#
#
# 	b1 : 18 expertises
# 		['paris'] : 10
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 7
# 		['suburbs'] : 3
# 			Maison(s) : 3
# 		['province'] : 4
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 2
# 			Ensemble de bâtiments (biens immeubles) : 1
# 			Domaine, terres, fief : 1
# 		[['paris', 'province']] : 1
# 			Ouvrages de maçonnerie : 1
#
#
# 	b3 : 3 expertises
# 		['paris'] : 3
# 			Maison(s) : 2
#
#
# 	b2 : 25 expertises
# 		['paris'] : 18
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 14
# 			Mur(s) : 2
# 			Fosse(s) d'aisance : 1
# 			Puits : 1
# 		['suburbs'] : 1
# 			Ouvrages de maçonnerie : 1
# 		['province'] : 6
# 			Ouvrages de maçonnerie : 2
# 			Ensemble de bâtiments (biens immeubles) : 3
# 			Domaine, terres, fief : 5
#
#
# 	c : 4 expertises
# 		['paris'] : 3
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 			Mur(s) : 1
# 		['suburbs'] : 1
# 			Maison(s) : 1
#
#
#
#
#
#
# Estimer la valeur des biens : 80 expertises
# 	a : 16 expertises
# 		['paris'] : 12
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 9
# 			Terrain(s) : 2
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		['suburbs'] : 1
# 			Maison(s) : 1
# 		['province'] : 2
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 			Domaine, terres, fief : 1
# 		[['suburbs', 'province']] : 1
# 			Maison(s) : 1
#
#
# 	b2a : 27 expertises
# 		['paris'] : 12
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 10
# 			Ensemble de bâtiments (biens immeubles) : 1
# 			Domaine, terres, fief : 1
# 		['suburbs'] : 2
# 			Maison(s) : 2
# 		['province'] : 12
# 			Maison(s) : 6
# 			Terrain(s) : 5
# 			Domaine, terres, fief : 3
# 		[['paris', 'province']] : 1
# 			Maison(s) : 1
#
#
# 	b2b : 19 expertises
# 		['paris'] : 10
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 8
# 		['suburbs'] : 5
# 			Maison(s) : 4
# 			Terrain(s) : 2
# 		['province'] : 3
# 			Maison(s) : 2
# 			Terrain(s) : 1
# 		[['paris', 'suburbs']] : 1
# 			Maison(s) : 1
#
#
# 	b1 : 4 expertises
# 		['paris'] : 2
# 			Maison(s) : 2
# 		['province'] : 2
# 			Maison(s) : 2
#
#
# 	b3 : 1 expertises
# 		['province'] : 1
# 			Maison(s) : 1
#
#
# 	b2 : 11 expertises
# 		['paris'] : 7
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 7
# 		['suburbs'] : 1
# 			Maison(s) : 1
# 		['province'] : 3
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
# 			Domaine, terres, fief : 1
#
#
# 	c : 2 expertises
# 		['paris'] : 1
# 			Maison(s) : 1
# 		['province'] : 1
# 			Domaine, terres, fief : 1
#
#
#
#
#
#
# Enregistrer : 4 expertises
# 	a : 1 expertises
# 		['paris'] : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
#
#
#
#
# 	b2b : 1 expertises
# 		['paris'] : 1
# 			Maison(s) : 1
#
#
# 	b1 : 1 expertises
# 		['province'] : 1
# 			Ouvrages de maçonnerie : 1
#
#
#
#
# 	b2 : 1 expertises
# 		['paris'] : 1
# 			Maison(s) : 1

# %% [markdown]
# ### Tiers expertises

# %%
thirdParty = expertises['thirdParty']

# %%
thirdPartyDf=pd.json_normalize(thirdParty)
print(thirdPartyDf.to_string(columns=['architectes', 'entrepreneurs', 'total'], index=False))
# Out:
#  architectes  entrepreneurs  total
#           13              5     18

# %% [markdown]
# ### Distribution (hors tiers expertises)

# %%
columnDistrib = expertises['experts']

for column in columnDistrib:
    print(f"{column['totalExperts']} expert(s) : {column['totalExpertises']} expertises"),
    if column['totalExperts']<3: print(pd.json_normalize(column['distribution']).to_string(columns=['label', 'total'], index=False))
    print('\n')
# Out:
# 1 expert(s) : 233 expertises
#        label  total
#   architecte    102
# entrepreneur    123
#
#
# 2 expert(s) : 107 expertises
#                       label  total
#     architecte - architecte     25
#   entrepreneur - architecte     49
# entrepreneur - entrepreneur     21
#
#
# 3 expert(s) : 2 expertises

# %% [markdown]
# ## Experts

# %%
experts = data['experts']
#print(experts)

# %%
print(f"Nombre d’experts : {experts['total']}")
print(f"{experts['architects']} architectes")
print(f"{experts['entrepreneur']} entrepreneurs")
print(f"{experts['surveyor']} arpenteurs")
# Out:
# Nombre d’experts : 62
# 33 architectes
# 22 entrepreneurs
# 7 arpenteurs

# %%
listExperts = experts['list']
listExpertsDf = pd.DataFrame(listExperts)
listExpertsDf.drop('expertises', inplace=True, axis=1)

# %%
print(listExpertsDf.to_string(columns=['id', 'name', 'column', 'age'], index=False))
# Out:
#      id                                  name       column age
# xpr0008                         Aubry, Claude   architecte
# xpr0011                         Baillis, Jean   architecte
# xpr0012                 Bailly, Jean Baptiste entrepreneur  70
# xpr0021                      Bertier, Nicolas entrepreneur  66
# xpr0027                     Boffrand, Germain   architecte  39
# xpr0035              Boulier de Bourges, Jean   architecte
# xpr0048                        Caulle, Martin   architecte  45
# xpr0051           Chastelain, Nicolas Isidore   architecte   4
# xpr0053              Chastelain (Ii), Isidore   architecte  36
# xpr0058                    Collibeuf, Laurent    arpenteur
# xpr0059                        Convers, Louis   architecte  60
# xpr0063                    Cudeville, Jacques    arpenteur
# xpr0077            De Mezerets (Père), Michel   architecte  69
# xpr0086                    Delespine, Nicolas   architecte  64
# xpr0087             Delespine, Pierre Nicolas entrepreneur  44
# xpr0099                     Doussot, François   architecte
# xpr0100                          Dubois, Jean entrepreneur  58
# xpr0105                        Duval, Charles    arpenteur
# xpr0113                      Frosne, Jean Luc   architecte  50
# xpr0115                      Gabriel, Maurice   architecte
# xpr0124                  Gobin, Jean François   architecte  49
# xpr0126               Goujon, Louis Alexandre   architecte  46
# xpr0132                      Guemier, Jacques   architecte
# xpr0133                    Guillain, Philippe    arpenteur
# xpr0138                       Hallot, Etienne    arpenteur
# xpr0139                      Havard, François entrepreneur  60
# xpr0140                        Hequan, Pierre entrepreneur  68
# xpr0141                        Herbet, Michel entrepreneur  44
# xpr0146                      Joubert, Charles entrepreneur  66
# xpr0149                           Ju, Charles entrepreneur  42
# xpr0151             Laisney, François Etienne entrepreneur  23
# xpr0153                       Lajoue, Jacques entrepreneur
# xpr0154                        Lambert, Simon   architecte
# xpr0161                    Le Clerc, François   architecte
# xpr0162                       Le Duc, Gabriel   architecte  83
# xpr0166                      Le Juge, Nicolas   architecte  60
# xpr0167                    Le Maistre, Pierre   architecte  63
# xpr0168                    Le Proust, Rolland   architecte  69
# xpr0170                      Le Roy, Estienne entrepreneur  58
# xpr0172 Le Teilleur De Boncourt, Hélie (Elie)   architecte
# xpr0178          Lepas Dubuisson, Jacques (I)    arpenteur
# xpr0180                          Leve, Pierre entrepreneur  51
# xpr0181                      Lievain, Nicolas entrepreneur  46
# xpr0183                   Loir, Jean Baptiste entrepreneur  41
# xpr0186                Lourdet, Baudouin Paul   architecte  40
# xpr0189                        Marchand, Marc entrepreneur
# xpr0190                Marteau, Jean Baptiste   architecte  52
# xpr0192                          Masson, Noël   architecte  63
# xpr0194                     Mazieres, Jacques   architecte
# xpr0195                    Menessier, Bernard entrepreneur
# xpr0197                        Miche, Jacques entrepreneur  54
# xpr0204                     Pageois, François   architecte  78
# xpr0211                       Perrault, André entrepreneur  49
# xpr0213                       Person, Charles   architecte  53
# xpr0220                        Pipault, Simon   architecte
# xpr0221                    Pirethouy, Jacques   architecte  56
# xpr0225                         Poisson, Jean entrepreneur  57
# xpr0232                        Quirot, Pierre   architecte  44
# xpr0237                          Richer, Jean entrepreneur
# xpr0239                     Rohais, Toussaint    arpenteur
# xpr0244                         Serouge, Jean entrepreneur
# xpr0264                    Vuyet, Jean Robert   architecte  42

# %%
for expert in listExperts:
    print(f"{expert['name']} ; {expert['column']} ; {expert['expertises']['total']} expertises ; {expert['expertises']['thirParty']} expertises en tant que tiers-expert ; {expert['expertises']['collab']['total']} expertises avec d'autres experts (tiers expertises comprises)"),
    print("\n")
    
    collabDF = pd.json_normalize(expert['expertises']['collab']['experts']) 
    if expert['expertises']['collab']['total'] != 0: print(collabDF.to_string(columns=['id', 'name', 'column', 'totalCollab', 'age'], index=False))
    print("\n")
    categoriesDef = pd.json_normalize(expert['expertises']['categories'])
    print(categoriesDef.to_string(columns=['label', 'total'], index=False))

    print("\n")
    print("\n")
# Out:
# Aubry, Claude ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      0
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Baillis, Jean ; architecte ; 7 expertises ; 0 expertises en tant que tiers-expert ; 7 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0180               Leve, Pierre entrepreneur            1  51
# xpr0244              Serouge, Jean entrepreneur            1
# xpr0264         Vuyet, Jean Robert   architecte            1  42
# xpr0086         Delespine, Nicolas   architecte            1  64
# xpr0140             Hequan, Pierre entrepreneur            1  68
# xpr0077 De Mezerets (Père), Michel   architecte            2  69
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      2
#                             Départager      1
# Décrire et évaluer les travaux à venir      2
#            Estimer la valeur des biens      2
#                            Enregistrer      0
#
#
#
#
# Bailly, Jean Baptiste ; entrepreneur ; 8 expertises ; 0 expertises en tant que tiers-expert ; 4 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id               name       column  totalCollab age
# xpr0197     Miche, Jacques entrepreneur            1  54
# xpr0221 Pirethouy, Jacques   architecte            1  56
# xpr0153    Lajoue, Jacques entrepreneur            2
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#                             Départager      2
# Décrire et évaluer les travaux à venir      4
#            Estimer la valeur des biens      1
#                            Enregistrer      0
#
#
#
#
# Bertier, Nicolas ; entrepreneur ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      0
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Boffrand, Germain ; architecte ; 19 expertises ; 5 expertises en tant que tiers-expert ; 9 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0197             Miche, Jacques entrepreneur            1  54
# xpr0058         Collibeuf, Laurent    arpenteur            1
# xpr0211            Perrault, André entrepreneur            1  49
# xpr0151  Laisney, François Etienne entrepreneur            1  23
# xpr0124       Gobin, Jean François   architecte            1  49
# xpr0077 De Mezerets (Père), Michel   architecte            2  69
# xpr0113           Frosne, Jean Luc   architecte            2  50
# xpr0264         Vuyet, Jean Robert   architecte            2  42
# xpr0153            Lajoue, Jacques entrepreneur            2
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      5
#                             Départager      7
# Décrire et évaluer les travaux à venir      4
#            Estimer la valeur des biens      2
#                            Enregistrer      0
#
#
#
#
# Boulier de Bourges, Jean ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      0
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Caulle, Martin ; architecte ; 2 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id            name       column  totalCollab age
# xpr0153 Lajoue, Jacques entrepreneur            1
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      0
# Décrire et évaluer les travaux à venir      1
#            Estimer la valeur des biens      1
#                            Enregistrer      0
#
#
#
#
# Chastelain, Nicolas Isidore ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      0
# Décrire et évaluer les travaux à venir      1
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Chastelain (Ii), Isidore ; architecte ; 20 expertises ; 0 expertises en tant que tiers-expert ; 13 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0168         Le Proust, Rolland   architecte            1  69
# xpr0087  Delespine, Pierre Nicolas entrepreneur            1  44
# xpr0063         Cudeville, Jacques    arpenteur            1
# xpr0153            Lajoue, Jacques entrepreneur            1
# xpr0244              Serouge, Jean entrepreneur            1
# xpr0180               Leve, Pierre entrepreneur            1  51
# xpr0197             Miche, Jacques entrepreneur            1  54
# xpr0221         Pirethouy, Jacques   architecte            1  56
# xpr0077 De Mezerets (Père), Michel   architecte            1  69
# xpr0194          Mazieres, Jacques   architecte            1
# xpr0133         Guillain, Philippe    arpenteur            1
# xpr0181           Lievain, Nicolas entrepreneur            1  46
# xpr0100               Dubois, Jean entrepreneur            1  58
# xpr0124       Gobin, Jean François   architecte            2  49
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      3
#                             Départager      5
# Décrire et évaluer les travaux à venir      8
#            Estimer la valeur des biens      3
#                            Enregistrer      0
#
#
#
#
# Collibeuf, Laurent ; arpenteur ; 2 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id              name       column  totalCollab age
# xpr0027 Boffrand, Germain   architecte            1  39
# xpr0197    Miche, Jacques entrepreneur            1  54
# xpr0244     Serouge, Jean entrepreneur            1
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#                             Départager      1
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Convers, Louis ; architecte ; 7 expertises ; 1 expertises en tant que tiers-expert ; 6 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name     column  totalCollab age
# xpr0194          Mazieres, Jacques architecte            1
# xpr0138            Hallot, Etienne  arpenteur            1
# xpr0264         Vuyet, Jean Robert architecte            1  42
# xpr0221         Pirethouy, Jacques architecte            1  56
# xpr0086         Delespine, Nicolas architecte            2  64
# xpr0077 De Mezerets (Père), Michel architecte            3  69
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      3
#                             Départager      1
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      2
#                            Enregistrer      0
#
#
#
#
# Cudeville, Jacques ; arpenteur ; 4 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name     column  totalCollab age
# xpr0053 Chastelain (Ii), Isidore architecte            1  36
# xpr0086       Delespine, Nicolas architecte            1  64
# xpr0264       Vuyet, Jean Robert architecte            1  42
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#                             Départager      1
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      2
#                            Enregistrer      0
#
#
#
#
# De Mezerets (Père), Michel ; architecte ; 38 expertises ; 2 expertises en tant que tiers-expert ; 26 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0086       Delespine, Nicolas   architecte            1  64
# xpr0053 Chastelain (Ii), Isidore   architecte            1  36
# xpr0168       Le Proust, Rolland   architecte            1  69
# xpr0146         Joubert, Charles entrepreneur            1  66
# xpr0149              Ju, Charles entrepreneur            1  42
# xpr0027        Boffrand, Germain   architecte            2  39
# xpr0197           Miche, Jacques entrepreneur            2  54
# xpr0180             Leve, Pierre entrepreneur            2  51
# xpr0138          Hallot, Etienne    arpenteur            2
# xpr0221       Pirethouy, Jacques   architecte            2  56
# xpr0244            Serouge, Jean entrepreneur            2
# xpr0239        Rohais, Toussaint    arpenteur            2
# xpr0011            Baillis, Jean   architecte            2
# xpr0059           Convers, Louis   architecte            3  60
# xpr0153          Lajoue, Jacques entrepreneur            3
# xpr0113         Frosne, Jean Luc   architecte            4  50
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      5
#                             Départager     19
# Décrire et évaluer les travaux à venir      8
#            Estimer la valeur des biens      6
#                            Enregistrer      0
#
#
#
#
# Delespine, Nicolas ; architecte ; 42 expertises ; 2 expertises en tant que tiers-expert ; 14 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0149                Ju, Charles entrepreneur            1  42
# xpr0077 De Mezerets (Père), Michel   architecte            1  69
# xpr0063         Cudeville, Jacques    arpenteur            1
# xpr0113           Frosne, Jean Luc   architecte            1  50
# xpr0141             Herbet, Michel entrepreneur            1  44
# xpr0264         Vuyet, Jean Robert   architecte            1  42
# xpr0011              Baillis, Jean   architecte            1
# xpr0170           Le Roy, Estienne entrepreneur            1  58
# xpr0124       Gobin, Jean François   architecte            1  49
# xpr0059             Convers, Louis   architecte            2  60
# xpr0138            Hallot, Etienne    arpenteur            2
# xpr0168         Le Proust, Rolland   architecte            4  69
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé     10
#                             Départager     11
# Décrire et évaluer les travaux à venir     14
#            Estimer la valeur des biens      3
#                            Enregistrer      2
#
#
#
#
# Delespine, Pierre Nicolas ; entrepreneur ; 2 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0124     Gobin, Jean François   architecte            1  49
# xpr0053 Chastelain (Ii), Isidore   architecte            1  36
# xpr0181         Lievain, Nicolas entrepreneur            1  46
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      2
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Doussot, François ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      0
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Dubois, Jean ; entrepreneur ; 2 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name     column  totalCollab age
# xpr0053 Chastelain (Ii), Isidore architecte            1  36
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#                             Départager      0
# Décrire et évaluer les travaux à venir      1
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Duval, Charles ; arpenteur ; 2 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id           name       column  totalCollab age
# xpr0140 Hequan, Pierre entrepreneur            1  68
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      0
# Décrire et évaluer les travaux à venir      2
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Frosne, Jean Luc ; architecte ; 15 expertises ; 0 expertises en tant que tiers-expert ; 10 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0181           Lievain, Nicolas entrepreneur            1  46
# xpr0190     Marteau, Jean Baptiste   architecte            1  52
# xpr0086         Delespine, Nicolas   architecte            1  64
# xpr0153            Lajoue, Jacques entrepreneur            1
# xpr0124       Gobin, Jean François   architecte            2  49
# xpr0027          Boffrand, Germain   architecte            2  39
# xpr0077 De Mezerets (Père), Michel   architecte            4  69
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      7
#                             Départager      3
# Décrire et évaluer les travaux à venir      1
#            Estimer la valeur des biens      3
#                            Enregistrer      0
#
#
#
#
# Gabriel, Maurice ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      0
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Gobin, Jean François ; architecte ; 22 expertises ; 0 expertises en tant que tiers-expert ; 13 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                      name       column  totalCollab age
# xpr0087 Delespine, Pierre Nicolas entrepreneur            1  44
# xpr0244             Serouge, Jean entrepreneur            1
# xpr0195        Menessier, Bernard entrepreneur            1
# xpr0211           Perrault, André entrepreneur            1  49
# xpr0126   Goujon, Louis Alexandre   architecte            1  46
# xpr0027         Boffrand, Germain   architecte            1  39
# xpr0086        Delespine, Nicolas   architecte            1  64
# xpr0113          Frosne, Jean Luc   architecte            2  50
# xpr0053  Chastelain (Ii), Isidore   architecte            2  36
# xpr0141            Herbet, Michel entrepreneur            2  44
# xpr0153           Lajoue, Jacques entrepreneur            2
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      8
#                             Départager      4
# Décrire et évaluer les travaux à venir      5
#            Estimer la valeur des biens      3
#                            Enregistrer      0
#
#
#
#
# Goujon, Louis Alexandre ; architecte ; 4 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                 name     column  totalCollab age
# xpr0124 Gobin, Jean François architecte            1  49
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      2
#                             Départager      1
# Décrire et évaluer les travaux à venir      1
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Guemier, Jacques ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      0
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Guillain, Philippe ; arpenteur ; 4 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name     column  totalCollab age
# xpr0053 Chastelain (Ii), Isidore architecte            1  36
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#                             Départager      1
# Décrire et évaluer les travaux à venir      2
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Hallot, Etienne ; arpenteur ; 6 expertises ; 0 expertises en tant que tiers-expert ; 6 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0180               Leve, Pierre entrepreneur            1  51
# xpr0059             Convers, Louis   architecte            1  60
# xpr0239          Rohais, Toussaint    arpenteur            1
# xpr0170           Le Roy, Estienne entrepreneur            1  58
# xpr0153            Lajoue, Jacques entrepreneur            1
# xpr0077 De Mezerets (Père), Michel   architecte            2  69
# xpr0086         Delespine, Nicolas   architecte            2  64
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#                             Départager      3
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      1
#                            Enregistrer      0
#
#
#
#
# Havard, François ; entrepreneur ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      0
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Hequan, Pierre ; entrepreneur ; 5 expertises ; 0 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id             name       column  totalCollab age
# xpr0105   Duval, Charles    arpenteur            1
# xpr0225    Poisson, Jean entrepreneur            1  57
# xpr0153  Lajoue, Jacques entrepreneur            1
# xpr0011    Baillis, Jean   architecte            1
# xpr0170 Le Roy, Estienne entrepreneur            2  58
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      3
#                             Départager      0
# Décrire et évaluer les travaux à venir      1
#            Estimer la valeur des biens      1
#                            Enregistrer      0
#
#
#
#
# Herbet, Michel ; entrepreneur ; 5 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                 name     column  totalCollab age
# xpr0086   Delespine, Nicolas architecte            1  64
# xpr0124 Gobin, Jean François architecte            2  49
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#                             Départager      1
# Décrire et évaluer les travaux à venir      1
#            Estimer la valeur des biens      0
#                            Enregistrer      1
#
#
#
#
# Joubert, Charles ; entrepreneur ; 4 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0153            Lajoue, Jacques entrepreneur            1
# xpr0077 De Mezerets (Père), Michel   architecte            1  69
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      3
# Décrire et évaluer les travaux à venir      1
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Ju, Charles ; entrepreneur ; 7 expertises ; 0 expertises en tant que tiers-expert ; 4 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0086         Delespine, Nicolas   architecte            1  64
# xpr0077 De Mezerets (Père), Michel   architecte            1  69
# xpr0153            Lajoue, Jacques entrepreneur            2
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#                             Départager      2
# Décrire et évaluer les travaux à venir      3
#            Estimer la valeur des biens      1
#                            Enregistrer      0
#
#
#
#
# Laisney, François Etienne ; entrepreneur ; 4 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id              name       column  totalCollab age
# xpr0180      Leve, Pierre entrepreneur            1  51
# xpr0027 Boffrand, Germain   architecte            1  39
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      1
# Décrire et évaluer les travaux à venir      1
#            Estimer la valeur des biens      1
#                            Enregistrer      0
#
#
#
#
# Lajoue, Jacques ; entrepreneur ; 113 expertises ; 3 expertises en tant que tiers-expert ; 32 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0048             Caulle, Martin   architecte            1  45
# xpr0204          Pageois, François   architecte            1  78
# xpr0053   Chastelain (Ii), Isidore   architecte            1  36
# xpr0167         Le Maistre, Pierre   architecte            1  63
# xpr0180               Leve, Pierre entrepreneur            1  51
# xpr0140             Hequan, Pierre entrepreneur            1  68
# xpr0225              Poisson, Jean entrepreneur            1  57
# xpr0170           Le Roy, Estienne entrepreneur            1  58
# xpr0113           Frosne, Jean Luc   architecte            1  50
# xpr0146           Joubert, Charles entrepreneur            1  66
# xpr0239          Rohais, Toussaint    arpenteur            1
# xpr0221         Pirethouy, Jacques   architecte            1  56
# xpr0232             Quirot, Pierre   architecte            1  44
# xpr0138            Hallot, Etienne    arpenteur            1
# xpr0244              Serouge, Jean entrepreneur            1
# xpr0012      Bailly, Jean Baptiste entrepreneur            2  70
# xpr0149                Ju, Charles entrepreneur            2  42
# xpr0027          Boffrand, Germain   architecte            2  39
# xpr0190     Marteau, Jean Baptiste   architecte            2  52
# xpr0181           Lievain, Nicolas entrepreneur            2  46
# xpr0124       Gobin, Jean François   architecte            2  49
# xpr0077 De Mezerets (Père), Michel   architecte            3  69
# xpr0197             Miche, Jacques entrepreneur            4  54
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé     23
#                             Départager     22
# Décrire et évaluer les travaux à venir     30
#            Estimer la valeur des biens     32
#                            Enregistrer      1
#
#
#
#
# Lambert, Simon ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      0
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Le Clerc, François ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      0
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Le Duc, Gabriel ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      0
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Le Juge, Nicolas ; architecte ; 2 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id             name       column  totalCollab age
# xpr0181 Lievain, Nicolas entrepreneur            1  46
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      1
# Décrire et évaluer les travaux à venir      1
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Le Maistre, Pierre ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id            name       column  totalCollab age
# xpr0153 Lajoue, Jacques entrepreneur            1
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      0
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      1
#                            Enregistrer      0
#
#
#
#
# Le Proust, Rolland ; architecte ; 10 expertises ; 0 expertises en tant que tiers-expert ; 7 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0053   Chastelain (Ii), Isidore   architecte            1  36
# xpr0197             Miche, Jacques entrepreneur            1  54
# xpr0077 De Mezerets (Père), Michel   architecte            1  69
# xpr0086         Delespine, Nicolas   architecte            4  64
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      2
#                             Départager      2
# Décrire et évaluer les travaux à venir      5
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Le Roy, Estienne ; entrepreneur ; 8 expertises ; 0 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id               name       column  totalCollab age
# xpr0153    Lajoue, Jacques entrepreneur            1
# xpr0194  Mazieres, Jacques   architecte            1
# xpr0138    Hallot, Etienne    arpenteur            1
# xpr0086 Delespine, Nicolas   architecte            1  64
# xpr0140     Hequan, Pierre entrepreneur            2  68
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      2
#                             Départager      1
# Décrire et évaluer les travaux à venir      1
#            Estimer la valeur des biens      3
#                            Enregistrer      0
#
#
#
#
# Le Teilleur De Boncourt, Hélie (Elie) ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      0
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Lepas Dubuisson, Jacques (I) ; arpenteur ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      0
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Leve, Pierre ; entrepreneur ; 14 expertises ; 0 expertises en tant que tiers-expert ; 8 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0011              Baillis, Jean   architecte            1
# xpr0138            Hallot, Etienne    arpenteur            1
# xpr0153            Lajoue, Jacques entrepreneur            1
# xpr0053   Chastelain (Ii), Isidore   architecte            1  36
# xpr0151  Laisney, François Etienne entrepreneur            1  23
# xpr0244              Serouge, Jean entrepreneur            1
# xpr0077 De Mezerets (Père), Michel   architecte            2  69
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#                             Départager      3
# Décrire et évaluer les travaux à venir      5
#            Estimer la valeur des biens      4
#                            Enregistrer      0
#
#
#
#
# Lievain, Nicolas ; entrepreneur ; 13 expertises ; 1 expertises en tant que tiers-expert ; 8 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                      name       column  totalCollab age
# xpr0113          Frosne, Jean Luc   architecte            1  50
# xpr0197            Miche, Jacques entrepreneur            1  54
# xpr0087 Delespine, Pierre Nicolas entrepreneur            1  44
# xpr0239         Rohais, Toussaint    arpenteur            1
# xpr0166          Le Juge, Nicolas   architecte            1  60
# xpr0053  Chastelain (Ii), Isidore   architecte            1  36
# xpr0153           Lajoue, Jacques entrepreneur            2
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      2
#                             Départager      5
# Décrire et évaluer les travaux à venir      2
#            Estimer la valeur des biens      3
#                            Enregistrer      1
#
#
#
#
# Loir, Jean Baptiste ; entrepreneur ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      0
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Lourdet, Baudouin Paul ; architecte ; 4 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id           name       column  totalCollab age
# xpr0197 Miche, Jacques entrepreneur            1  54
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#                             Départager      0
# Décrire et évaluer les travaux à venir      3
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Marchand, Marc ; entrepreneur ; 2 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#                             Départager      1
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Marteau, Jean Baptiste ; architecte ; 3 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id             name       column  totalCollab age
# xpr0113 Frosne, Jean Luc   architecte            1  50
# xpr0153  Lajoue, Jacques entrepreneur            2
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      3
#                             Départager      0
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Masson, Noël ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      0
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Mazieres, Jacques ; architecte ; 5 expertises ; 2 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0059           Convers, Louis   architecte            1  60
# xpr0170         Le Roy, Estienne entrepreneur            1  58
# xpr0053 Chastelain (Ii), Isidore   architecte            1  36
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#                             Départager      0
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      2
#                            Enregistrer      0
#
#
#
#
# Menessier, Bernard ; entrepreneur ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                 name     column  totalCollab age
# xpr0124 Gobin, Jean François architecte            1  49
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      1
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Miche, Jacques ; entrepreneur ; 18 expertises ; 1 expertises en tant que tiers-expert ; 12 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0181           Lievain, Nicolas entrepreneur            1  46
# xpr0027          Boffrand, Germain   architecte            1  39
# xpr0058         Collibeuf, Laurent    arpenteur            1
# xpr0012      Bailly, Jean Baptiste entrepreneur            1  70
# xpr0053   Chastelain (Ii), Isidore   architecte            1  36
# xpr0168         Le Proust, Rolland   architecte            1  69
# xpr0186     Lourdet, Baudouin Paul   architecte            1  40
# xpr0077 De Mezerets (Père), Michel   architecte            2  69
# xpr0153            Lajoue, Jacques entrepreneur            4
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      3
#                             Départager      6
# Décrire et évaluer les travaux à venir      6
#            Estimer la valeur des biens      3
#                            Enregistrer      0
#
#
#
#
# Pageois, François ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id            name       column  totalCollab age
# xpr0153 Lajoue, Jacques entrepreneur            1
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#                             Départager      0
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Perrault, André ; entrepreneur ; 7 expertises ; 0 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                 name     column  totalCollab age
# xpr0027    Boffrand, Germain architecte            1  39
# xpr0124 Gobin, Jean François architecte            1  49
# xpr0264   Vuyet, Jean Robert architecte            3  42
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      2
#                             Départager      0
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      5
#                            Enregistrer      0
#
#
#
#
# Person, Charles ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      0
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Pipault, Simon ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      0
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Pirethouy, Jacques ; architecte ; 12 expertises ; 1 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0053   Chastelain (Ii), Isidore   architecte            1  36
# xpr0059             Convers, Louis   architecte            1  60
# xpr0153            Lajoue, Jacques entrepreneur            1
# xpr0012      Bailly, Jean Baptiste entrepreneur            1  70
# xpr0244              Serouge, Jean entrepreneur            1
# xpr0077 De Mezerets (Père), Michel   architecte            2  69
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      4
#                             Départager      2
# Décrire et évaluer les travaux à venir      2
#            Estimer la valeur des biens      4
#                            Enregistrer      0
#
#
#
#
# Poisson, Jean ; entrepreneur ; 2 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id            name       column  totalCollab age
# xpr0140  Hequan, Pierre entrepreneur            1  68
# xpr0153 Lajoue, Jacques entrepreneur            1
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#                             Départager      0
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      1
#                            Enregistrer      0
#
#
#
#
# Quirot, Pierre ; architecte ; 6 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id            name       column  totalCollab age
# xpr0153 Lajoue, Jacques entrepreneur            1
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#                             Départager      1
# Décrire et évaluer les travaux à venir      3
#            Estimer la valeur des biens      1
#                            Enregistrer      0
#
#
#
#
# Richer, Jean ; entrepreneur ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      0
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Rohais, Toussaint ; arpenteur ; 6 expertises ; 0 expertises en tant que tiers-expert ; 4 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0181           Lievain, Nicolas entrepreneur            1  46
# xpr0138            Hallot, Etienne    arpenteur            1
# xpr0153            Lajoue, Jacques entrepreneur            1
# xpr0077 De Mezerets (Père), Michel   architecte            2  69
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#                             Départager      4
# Décrire et évaluer les travaux à venir      1
#            Estimer la valeur des biens      0
#                            Enregistrer      0
#
#
#
#
# Serouge, Jean ; entrepreneur ; 16 expertises ; 0 expertises en tant que tiers-expert ; 9 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0011              Baillis, Jean   architecte            1
# xpr0124       Gobin, Jean François   architecte            1  49
# xpr0053   Chastelain (Ii), Isidore   architecte            1  36
# xpr0058         Collibeuf, Laurent    arpenteur            1
# xpr0180               Leve, Pierre entrepreneur            1  51
# xpr0221         Pirethouy, Jacques   architecte            1  56
# xpr0153            Lajoue, Jacques entrepreneur            1
# xpr0077 De Mezerets (Père), Michel   architecte            2  69
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      6
# Décrire et évaluer les travaux à venir      6
#            Estimer la valeur des biens      4
#                            Enregistrer      0
#
#
#
#
# Vuyet, Jean Robert ; architecte ; 15 expertises ; 0 expertises en tant que tiers-expert ; 8 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id               name       column  totalCollab age
# xpr0011      Baillis, Jean   architecte            1
# xpr0086 Delespine, Nicolas   architecte            1  64
# xpr0059     Convers, Louis   architecte            1  60
# xpr0063 Cudeville, Jacques    arpenteur            1
# xpr0027  Boffrand, Germain   architecte            2  39
# xpr0211    Perrault, André entrepreneur            3  49
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      2
#                             Départager      0
# Décrire et évaluer les travaux à venir      6
#            Estimer la valeur des biens      7
#                            Enregistrer      0
