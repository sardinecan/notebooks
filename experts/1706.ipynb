# %% [markdown]
# # xprStats

# %%
# lib
from urllib.request import urlopen
import json  
import pandas as pd

# %%
# Récupération des donnée 
# param (date or thirdParty)
param = "1706"

# url
url = "https://experts.huma-num.fr/xpr/statistics/" + param

# enregistrement de la réponse
response = urlopen(url)

# lecture du json
data = json.loads(response.read())
  
# print the json response
#print(data)

# %% [markdown]
# ## Expertises

# %%
expertises = data['expertises']

# %%
print("Nombre total d'expertises : " + str(expertises['total']))
# Out:
# Nombre total d'expertises : 484

# %% [markdown]
# ### Croquis

# %%
sketchesDF = pd.json_normalize(expertises['sketches'])
print(sketchesDF.to_string(index=False))
# Out:
#  expertisesWithoutSketch  expertisesWithSketch
#                      475                     9

# %% [markdown]
# ### Étendue

# %%
extent = expertises['extent']
#print(extent)

print('Nombre de feuillets : ' + str(extent['total']))

print('Moyenne par expertise : ' + str(extent['averageByExpertise']))

#Distribution
print('Distribution :')
keys = []
values = []
for dic in extent['extentDistribution']:
    for key, val in dic.items():
        keys.append(key),
        values.append(val)        

extentDistributionDict = {'nombre de feuillets': keys, 'nombre d’expertises': values,} 
print(pd.DataFrame(extentDistributionDict).to_string(index=False))
# Out:
# Nombre de feuillets : 3240
# Moyenne par expertise : 6.69
# Distribution :
# nombre de feuillets  nombre d’expertises
#                   5                  316
#                  10                   98
#                  15                   30
#                  20                   15
#                  25                    5
#                  30                    2
#                  35                    5
#                  40                    1
#                  45                    0
#                  50                    1
#                  55                    2
#                  60                    0
#                  65                    1
#                  70                    0
#                  75                    0
#                  80                    0
#                  85                    0
#                  90                    0
#                  95                    0
#                 100                    3

# %% [markdown]
# ### Annexes

# %%
appendices = expertises['appendices']
#print(appendices)

print(f"{appendices['total']} annexes")


print(f"{appendices['expertisesWithAppendices']} expertises avec annexes ; {appendices['expertisesWithoutAppendices']} expertises sans annexes")


df=pd.json_normalize(appendices['types'])
print(df.to_string(columns=['label', 'total', 'expertises'], index=False))
# Out:
# 587 annexes
# 367 expertises avec annexes ; 117 expertises sans annexes
#                                       label  total  expertises
#                                       Autre    396         299
# Pouvoir/procuration (acte sous seing privé)    117          97
#                      Plan, coupe, élévation      9           9
#          Pouvoir/procuration (acte notarié)     20          19
#                                     Requête     26          25
#                                     Croquis      6           6
#                                   Brouillon     10          10
#                                      Dessin      1           1

# %% [markdown]
# ### Vacations

# %%
sessions = expertises['sessions']
#print(sessions)

print(f"{sessions['total']} vacations")


print(f"en moyenne {sessions['averageByExpertise']} vacations par expertise")
# Out:
# 1006 vacations
# en moyenne 2.08 vacations par expertise

# %% [markdown]
# Nombre de vacation par lieu

# %%
sessionsDf=pd.json_normalize(sessions['places'])
print(sessionsDf.to_string(columns=['label', 'total'], index=False))
# Out:
#    label  total
#    Paris    828
# Banlieue     79
# Province     96

# %% [markdown]
# ### Durée

# %%
duration = expertises['duration']
#print(duration)

# %% [markdown]
# #### Jours

# %%
#Distribution
durationDays = duration['days']
#print(durationDays)
print('Distribution :')
keys = []
values = []
for dic in durationDays['distributionByDays']:
    for key, val in dic.items():
        keys.append(key),
        values.append(val)        

durationDaysDf = {'nombre de jours': keys, 'nombre d’expertises': values,} 
print(pd.DataFrame(durationDaysDf).to_string(index=False))
# Out:
# Distribution :
# nombre de jours  nombre d’expertises
#               5                  348
#              10                   36
#              15                   23
#              20                   11
#              25                    8
#              30                    5
#              35                    6
#              40                    5
#              45                    5
#              50                    6
#              55                    4
#              60                    3
#              65                    3
#              70                    0
#              75                    3
#              80                    0
#              85                    1
#              90                    1
#              95                    0
#             100                   15

# %% [markdown]
# #### Vacations

# %%
#Distribution
durationSessions = duration['sessions']
#print(durationDays)
print(f"{durationSessions['total']} vacations, soit en moyenne {durationSessions['averageByExpertise']} vacations par expertise.")
# Out:
# 1006 vacations, soit en moyenne 1.04 vacations par expertise.

# %% [markdown]
# ### Lieux

# %%
places = expertises['places']
#print(places)

placesDf=pd.json_normalize(places)
print(placesDf.to_string(columns=['place', 'total'], index=False))
# Out:
#                        place  total
#                      [paris]    390
#                    [suburbs]     36
#                   [province]     42
#           [[paris, suburbs]]      4
#          [[paris, province]]      9
#        [[suburbs, province]]      0
# [[paris, suburbs, province]]      0

# %% [markdown]
# ### Procédures et cadres

# %%
frameworks = expertises['frameworks']
#print(frameworks)

frameworksDf=pd.json_normalize(frameworks)
print(frameworksDf.to_string(columns=['label', 'framework', 'total'], index=False))
# Out:
#                                                                                                                   label framework  total
#                                                                                               Commun accord des parties         a    129
# L’institution est saisie dans le cadre d’une procédure (les parties nomment chacune leur expert ou un expert en commun)        b2    227
#                                                     Requête auprès d’une institution pour qu’elle demande une expertise        b1     38
# L’institution est saisie dans le cadre d’une procédure (les parties nomment chacune leur expert ou un expert en commun)       b2a     72
#                         L’institution est saisie dans le cadre d’une procédure (l’institution nomme un ou deux experts)       b2b     11
#                                          Saisie mixte (un expert est nommé par les parties, l'autre est nommé d'office)        b3      2
#                                                                                                       Cas problématique         c      2
#                                                                                                                                        3

# %% [markdown]
# ### Catégories

# %%
categories = expertises['categories']

for cat in categories:
    if cat['total'] != 0: print(f"{cat['label']} : {cat['total']} expertises"),
    for framework in cat['frameworks']:
        if framework['total'] != 0: print(f"\t{framework['framework']} : {framework['total']} expertises"),
        for place in framework['places']:
            if place['total'] != 0: print(f"\t\t{place['place']} : {place['total']}"),
            for obj in place['objects']:
                if obj['total'] != 0: print(f"\t\t\t{obj['label']} : {obj['total']}")
        print('\n')
    print('\n')
# Out:
# Estimer la valeur des biens : 117 expertises
# 	a : 18 expertises
# 		['paris'] : 15
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 14
# 			Terrain(s) : 1
# 		['suburbs'] : 1
# 			Terrain(s) : 1
# 		[['paris', 'suburbs']] : 1
# 			Maison(s) : 1
# 		[['paris', 'province']] : 1
# 			Maison(s) : 1
#
#
# 	b2 : 57 expertises
# 		['paris'] : 41
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 33
# 			Terrain(s) : 4
# 			Mur(s) : 2
# 			Fosse(s) d'aisance : 1
# 		['suburbs'] : 6
# 			Maison(s) : 5
# 			Terrain(s) : 2
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		['province'] : 8
# 			Maison(s) : 2
# 			Ensemble de bâtiments (biens immeubles) : 1
# 			Domaine, terres, fief : 4
# 		[['paris', 'province']] : 2
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 2
# 			Terrain(s) : 2
#
#
# 	b1 : 14 expertises
# 		['paris'] : 11
# 			Maison(s) : 9
# 			Terrain(s) : 1
# 		['province'] : 3
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 2
# 			Terrain(s) : 2
#
#
# 	b2a : 20 expertises
# 		['paris'] : 14
# 			Maison(s) : 14
# 		['suburbs'] : 1
# 			Maison(s) : 1
# 		['province'] : 5
# 			Maison(s) : 4
#
#
# 	b2b : 4 expertises
# 		['paris'] : 3
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 2
# 		['province'] : 1
# 			Maison(s) : 1
# 			Terrain(s) : 1
#
#
#
#
# 	c : 1 expertises
# 		['paris'] : 1
# 			Maison(s) : 1
#
#
# 	 : 3 expertises
# 		['paris'] : 2
# 			Maison(s) : 1
#
#
#
#
# Décrire et évaluer les travaux à venir : 108 expertises
# 	a : 9 expertises
# 		['paris'] : 7
# 			Maison(s) : 4
# 			Mur(s) : 3
# 		['suburbs'] : 1
# 			Mur(s) : 1
# 		['province'] : 1
# 			Ouvrages de maçonnerie : 1
#
#
# 	b2 : 65 expertises
# 		['paris'] : 55
# 			Ouvrages de maçonnerie : 17
# 			Maison(s) : 35
# 			Mur(s) : 4
# 			Fosse(s) d'aisance : 1
# 		['suburbs'] : 4
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 3
# 		['province'] : 5
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 4
# 			Mur(s) : 1
# 			Domaine, terres, fief : 1
#
#
# 	b1 : 17 expertises
# 		['paris'] : 9
# 			Ouvrages de maçonnerie : 4
# 			Maison(s) : 6
# 		['suburbs'] : 3
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 2
# 		['province'] : 5
# 			Ouvrages de maçonnerie : 3
# 			Maison(s) : 2
# 			Ensemble de bâtiments (biens immeubles) : 1
#
#
# 	b2a : 17 expertises
# 		['paris'] : 14
# 			Maison(s) : 14
# 		['province'] : 3
# 			Ouvrages de maçonnerie : 2
# 			Terrain(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
# 			Domaine, terres, fief : 1
#
#
#
#
#
#
#
#
#
#
#
#
# Recevoir et évaluer le travail réalisé : 128 expertises
# 	a : 56 expertises
# 		['paris'] : 53
# 			Ouvrages de maçonnerie : 36
# 			Maison(s) : 21
# 		['suburbs'] : 1
# 			Ouvrages de maçonnerie : 1
# 		['province'] : 1
# 			Ouvrages de maçonnerie : 1
#
#
# 	b2 : 52 expertises
# 		['paris'] : 42
# 			Ouvrages de maçonnerie : 37
# 			Maison(s) : 5
# 			Mur(s) : 2
# 			Fosse(s) d'aisance : 1
# 		['suburbs'] : 5
# 			Ouvrages de maçonnerie : 5
# 		['province'] : 2
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 		[['paris', 'suburbs']] : 2
# 			Ouvrages de maçonnerie : 2
# 		[['paris', 'province']] : 1
# 			Ouvrages de maçonnerie : 1
#
#
# 	b1 : 2 expertises
# 		['paris'] : 1
# 			Ouvrages de maçonnerie : 1
# 		['suburbs'] : 1
# 			Ouvrages de maçonnerie : 1
#
#
# 	b2a : 14 expertises
# 		['paris'] : 11
# 			Ouvrages de maçonnerie : 3
# 			Maison(s) : 6
# 			Fosse(s) d'aisance : 1
# 		['suburbs'] : 2
# 			Maison(s) : 2
# 		['province'] : 1
# 			Ouvrages de maçonnerie : 1
#
#
# 	b2b : 4 expertises
# 		['paris'] : 4
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 2
#
#
#
#
#
#
#
#
#
#
# Départager : 107 expertises
# 	a : 38 expertises
# 		['paris'] : 36
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 3
# 			Terrain(s) : 2
# 			Mur(s) : 30
# 			Fosse(s) d'aisance : 2
# 			Puits : 1
# 		['suburbs'] : 1
# 			Mur(s) : 1
# 		['province'] : 1
# 			Maison(s) : 1
# 			Terrain(s) : 1
#
#
# 	b2 : 42 expertises
# 		['paris'] : 30
# 			Ouvrages de maçonnerie : 12
# 			Maison(s) : 5
# 			Mur(s) : 13
# 			Ensemble de bâtiments (biens immeubles) : 1
# 			Fosse(s) d'aisance : 5
# 			Puits : 1
# 		['suburbs'] : 8
# 			Ouvrages de maçonnerie : 4
# 			Terrain(s) : 1
# 			Mur(s) : 2
# 		['province'] : 1
# 			Maison(s) : 1
# 		[['paris', 'suburbs']] : 1
# 			Maison(s) : 1
# 		[['paris', 'province']] : 2
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
#
#
# 	b1 : 1 expertises
# 		['paris'] : 1
# 			Mur(s) : 1
#
#
# 	b2a : 20 expertises
# 		['paris'] : 18
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 6
# 			Terrain(s) : 1
# 			Mur(s) : 10
# 			Fosse(s) d'aisance : 2
# 		['province'] : 1
# 			Mur(s) : 1
# 		[['paris', 'province']] : 1
# 			Mur(s) : 1
#
#
# 	b2b : 3 expertises
# 		['paris'] : 2
# 			Maison(s) : 1
# 			Mur(s) : 1
# 		['province'] : 1
# 			Maison(s) : 1
#
#
# 	b3 : 2 expertises
# 		['paris'] : 1
# 			Mur(s) : 1
# 		['suburbs'] : 1
# 			Maison(s) : 1
#
#
# 	c : 1 expertises
# 		['paris'] : 1
# 			Mur(s) : 1
#
#
#
#
#
#
# Enregistrer : 7 expertises
# 	a : 2 expertises
# 		['paris'] : 2
# 			Maison(s) : 1
# 			Mur(s) : 1
#
#
# 	b2 : 1 expertises
# 		['paris'] : 1
# 			Ouvrages de maçonnerie : 1
#
#
# 	b1 : 3 expertises
# 		['paris'] : 3
# 			Maison(s) : 3
#
#
# 	b2a : 1 expertises
# 		['paris'] : 1
# 			Terrain(s) : 1

# %% [markdown]
# ### Tiers expertises

# %%
thirdParty = expertises['thirdParty']

# %%
thirdPartyDf=pd.json_normalize(thirdParty)
print(thirdPartyDf.to_string(columns=['architectes', 'entrepreneurs', 'total'], index=False))
# Out:
#  architectes  entrepreneurs  total
#           14             11     25

# %% [markdown]
# ### Distribution (hors tiers expertises)

# %%
columnDistrib = expertises['experts']

for column in columnDistrib:
    print(f"{column['totalExperts']} expert(s) : {column['totalExpertises']} expertises"),
    if column['totalExperts']<3: print(pd.json_normalize(column['distribution']).to_string(columns=['label', 'total'], index=False))
    print('\n')
# Out:
# 1 expert(s) : 288 expertises
#        label  total
#   architecte    181
# entrepreneur    103
#
#
# 2 expert(s) : 163 expertises
#                       label  total
#     architecte - architecte     68
#   entrepreneur - architecte     63
# entrepreneur - entrepreneur     25
#
#
# 3 expert(s) : 8 expertises

# %% [markdown]
# ## Experts

# %%
experts = data['experts']
#print(experts)

# %%
print(f"Nombre d’experts : {experts['total']}")
print(f"{experts['architects']} architectes")
print(f"{experts['entrepreneur']} entrepreneurs")
print(f"{experts['surveyor']} arpenteurs")
# Out:
# Nombre d’experts : 43
# 24 architectes
# 17 entrepreneurs
# 2 arpenteurs

# %%
listExperts = experts['list']
listExpertsDf = pd.DataFrame(listExperts)
listExpertsDf.drop('expertises', inplace=True, axis=1)

# %%
print(listExpertsDf.to_string(columns=['id', 'name', 'column', 'age'], index=False))
# Out:
#      id                            name       column age
# xpr0018                Bernard, Charles   architecte  46
# xpr0027               Boffrand, Germain   architecte  49
# xpr0048                  Caulle, Martin   architecte  55
# xpr0053        Chastelain (Ii), Isidore   architecte  46
# xpr0063              Cudeville, Jacques    arpenteur
# xpr0077      De Mezerets (Père), Michel   architecte  79
# xpr0086              Delespine, Nicolas   architecte  74
# xpr0100                    Dubois, Jean entrepreneur  68
# xpr0105                  Duval, Charles    arpenteur
# xpr0111     Fourier, Edme (1668 - 1727) entrepreneur  48
# xpr0113                Frosne, Jean Luc   architecte  60
# xpr0116                Gabriel, Jacques   architecte
# xpr0121              Giraud, Jean Louis   architecte  19
# xpr0124            Gobin, Jean François   architecte  59
# xpr0125                    Gobin, Denis entrepreneur  53
# xpr0126         Goujon, Louis Alexandre   architecte  56
# xpr0140                  Hequan, Pierre entrepreneur  78
# xpr0141                  Herbet, Michel entrepreneur  54
# xpr0146                Joubert, Charles entrepreneur  76
# xpr0149                     Ju, Charles entrepreneur  52
# xpr0151       Laisney, François Etienne entrepreneur  33
# xpr0166                Le Juge, Nicolas   architecte  70
# xpr0168              Le Proust, Rolland   architecte  79
# xpr0170                Le Roy, Estienne entrepreneur  68
# xpr0177 Lepas Dubuisson, Claude Nicolas   architecte
# xpr0181                Lievain, Nicolas entrepreneur  56
# xpr0183             Loir, Jean Baptiste entrepreneur  51
# xpr0185     Loir, Bernard Jean Baptiste   architecte
# xpr0189                  Marchand, Marc entrepreneur
# xpr0190          Marteau, Jean Baptiste   architecte  62
# xpr0193                 Masson, Etienne entrepreneur  34
# xpr0197                  Miche, Jacques entrepreneur  64
# xpr0211                 Perrault, André entrepreneur  59
# xpr0213                 Person, Charles   architecte  63
# xpr0221              Pirethouy, Jacques   architecte  66
# xpr0232                  Quirot, Pierre   architecte  54
# xpr0234         Raymond, Etienne Hubert   architecte
# xpr0244                   Serouge, Jean entrepreneur
# xpr0246                 Simon, Mathurin entrepreneur  50
# xpr0264              Vuyet, Jean Robert   architecte  52
# xpr0278       Bourgeois, Pierre (? - ?)   architecte
# xpr0279        Beuzelin, Martin (? - ?)   architecte
# xpr0280        Saunier, Nicolas (? - ?)   architecte

# %%
for expert in listExperts:
    print(f"{expert['name']} ; {expert['column']} ; {expert['expertises']['total']} expertises ; {expert['expertises']['thirParty']} expertises en tant que tiers-expert ; {expert['expertises']['collab']['total']} expertises avec d'autres experts (tiers expertises comprises)"),
    print("\n")
    
    collabDF = pd.json_normalize(expert['expertises']['collab']['experts']) 
    if expert['expertises']['collab']['total'] != 0: print(collabDF.to_string(columns=['id', 'name', 'column', 'totalCollab', 'age'], index=False))
    print("\n")
    categoriesDef = pd.json_normalize(expert['expertises']['categories'])
    print(categoriesDef.to_string(columns=['label', 'total'], index=False))

    print("\n")
    print("\n")
# Out:
# Bernard, Charles ; architecte ; 3 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name     column  totalCollab age
# xpr0221         Pirethouy, Jacques architecte            1  66
# xpr0077 De Mezerets (Père), Michel architecte            1  79
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      3
# Recevoir et évaluer le travail réalisé      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Boffrand, Germain ; architecte ; 14 expertises ; 1 expertises en tant que tiers-expert ; 9 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                    name       column  totalCollab age
# xpr0048          Caulle, Martin   architecte            1  55
# xpr0197          Miche, Jacques entrepreneur            1  64
# xpr0126 Goujon, Louis Alexandre   architecte            1  56
# xpr0100            Dubois, Jean entrepreneur            1  68
# xpr0124    Gobin, Jean François   architecte            2  59
# xpr0183     Loir, Jean Baptiste entrepreneur            2  51
# xpr0086      Delespine, Nicolas   architecte            3  74
#
#
#                                  label  total
#            Estimer la valeur des biens      3
# Décrire et évaluer les travaux à venir      5
# Recevoir et évaluer le travail réalisé      2
#                             Départager      4
#                            Enregistrer      0
#
#
#
#
# Caulle, Martin ; architecte ; 23 expertises ; 0 expertises en tant que tiers-expert ; 18 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                            name       column  totalCollab age
# xpr0183             Loir, Jean Baptiste entrepreneur            1  51
# xpr0086              Delespine, Nicolas   architecte            1  74
# xpr0027               Boffrand, Germain   architecte            1  49
# xpr0177 Lepas Dubuisson, Claude Nicolas   architecte            1
# xpr0113                Frosne, Jean Luc   architecte            1  60
# xpr0105                  Duval, Charles    arpenteur            1
# xpr0100                    Dubois, Jean entrepreneur            1  68
# xpr0141                  Herbet, Michel entrepreneur            1  54
# xpr0124            Gobin, Jean François   architecte            1  59
# xpr0197                  Miche, Jacques entrepreneur            1  64
# xpr0232                  Quirot, Pierre   architecte           10  54
#
#
#                                  label  total
#            Estimer la valeur des biens      5
# Décrire et évaluer les travaux à venir      2
# Recevoir et évaluer le travail réalisé     12
#                             Départager      3
#                            Enregistrer      0
#
#
#
#
# Chastelain (Ii), Isidore ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
# Recevoir et évaluer le travail réalisé      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Cudeville, Jacques ; arpenteur ; 9 expertises ; 0 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                 name       column  totalCollab age
# xpr0105       Duval, Charles    arpenteur            1
# xpr0124 Gobin, Jean François   architecte            1  59
# xpr0197       Miche, Jacques entrepreneur            1  64
# xpr0244        Serouge, Jean entrepreneur            1
# xpr0221   Pirethouy, Jacques   architecte            1  66
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
# Recevoir et évaluer le travail réalisé      4
#                             Départager      4
#                            Enregistrer      0
#
#
#
#
# De Mezerets (Père), Michel ; architecte ; 88 expertises ; 6 expertises en tant que tiers-expert ; 39 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                            name       column  totalCollab age
# xpr0111     Fourier, Edme (1668 - 1727) entrepreneur            1  48
# xpr0146                Joubert, Charles entrepreneur            1  76
# xpr0140                  Hequan, Pierre entrepreneur            1  78
# xpr0170                Le Roy, Estienne entrepreneur            1  68
# xpr0190          Marteau, Jean Baptiste   architecte            1  62
# xpr0105                  Duval, Charles    arpenteur            1
# xpr0189                  Marchand, Marc entrepreneur            1
# xpr0018                Bernard, Charles   architecte            1  46
# xpr0197                  Miche, Jacques entrepreneur            2  64
# xpr0149                     Ju, Charles entrepreneur            2  52
# xpr0193                 Masson, Etienne entrepreneur            2  34
# xpr0100                    Dubois, Jean entrepreneur            2  68
# xpr0177 Lepas Dubuisson, Claude Nicolas   architecte            2
# xpr0086              Delespine, Nicolas   architecte            2  74
# xpr0124            Gobin, Jean François   architecte            3  59
# xpr0244                   Serouge, Jean entrepreneur            3
# xpr0264              Vuyet, Jean Robert   architecte            3  52
# xpr0232                  Quirot, Pierre   architecte            3  54
# xpr0221              Pirethouy, Jacques   architecte            3  66
# xpr0183             Loir, Jean Baptiste entrepreneur            4  51
# xpr0113                Frosne, Jean Luc   architecte            9  60
#
#
#                                  label  total
#            Estimer la valeur des biens     23
# Décrire et évaluer les travaux à venir     25
# Recevoir et évaluer le travail réalisé     15
#                             Départager     22
#                            Enregistrer      2
#
#
#
#
# Delespine, Nicolas ; architecte ; 30 expertises ; 0 expertises en tant que tiers-expert ; 18 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0146           Joubert, Charles entrepreneur            1  76
# xpr0048             Caulle, Martin   architecte            1  55
# xpr0264         Vuyet, Jean Robert   architecte            1  52
# xpr0170           Le Roy, Estienne entrepreneur            1  68
# xpr0126    Goujon, Louis Alexandre   architecte            1  56
# xpr0100               Dubois, Jean entrepreneur            1  68
# xpr0149                Ju, Charles entrepreneur            1  52
# xpr0168         Le Proust, Rolland   architecte            2  79
# xpr0183        Loir, Jean Baptiste entrepreneur            2  51
# xpr0124       Gobin, Jean François   architecte            2  59
# xpr0077 De Mezerets (Père), Michel   architecte            2  79
# xpr0113           Frosne, Jean Luc   architecte            3  60
# xpr0027          Boffrand, Germain   architecte            3  49
#
#
#                                  label  total
#            Estimer la valeur des biens      7
# Décrire et évaluer les travaux à venir      7
# Recevoir et évaluer le travail réalisé      4
#                             Départager      8
#                            Enregistrer      1
#
#
#
#
# Dubois, Jean ; entrepreneur ; 23 expertises ; 0 expertises en tant que tiers-expert ; 15 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0124       Gobin, Jean François   architecte            1  59
# xpr0244              Serouge, Jean entrepreneur            1
# xpr0140             Hequan, Pierre entrepreneur            1  78
# xpr0183        Loir, Jean Baptiste entrepreneur            1  51
# xpr0048             Caulle, Martin   architecte            1  55
# xpr0027          Boffrand, Germain   architecte            1  49
# xpr0189             Marchand, Marc entrepreneur            1
# xpr0086         Delespine, Nicolas   architecte            1  74
# xpr0190     Marteau, Jean Baptiste   architecte            1  62
# xpr0113           Frosne, Jean Luc   architecte            1  60
# xpr0232             Quirot, Pierre   architecte            2  54
# xpr0077 De Mezerets (Père), Michel   architecte            2  79
# xpr0197             Miche, Jacques entrepreneur            3  64
#
#
#                                  label  total
#            Estimer la valeur des biens      5
# Décrire et évaluer les travaux à venir      4
# Recevoir et évaluer le travail réalisé      4
#                             Départager      8
#                            Enregistrer      0
#
#
#
#
# Duval, Charles ; arpenteur ; 4 expertises ; 0 expertises en tant que tiers-expert ; 4 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                            name     column  totalCollab age
# xpr0063              Cudeville, Jacques  arpenteur            1
# xpr0048                  Caulle, Martin architecte            1  55
# xpr0221              Pirethouy, Jacques architecte            1  66
# xpr0077      De Mezerets (Père), Michel architecte            1  79
# xpr0177 Lepas Dubuisson, Claude Nicolas architecte            1
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      1
# Recevoir et évaluer le travail réalisé      1
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Fourier, Edme (1668 - 1727) ; entrepreneur ; 13 expertises ; 1 expertises en tant que tiers-expert ; 8 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0077 De Mezerets (Père), Michel   architecte            1  79
# xpr0124       Gobin, Jean François   architecte            1  59
# xpr0125               Gobin, Denis entrepreneur            1  53
# xpr0141             Herbet, Michel entrepreneur            1  54
# xpr0170           Le Roy, Estienne entrepreneur            1  68
# xpr0183        Loir, Jean Baptiste entrepreneur            1  51
# xpr0232             Quirot, Pierre   architecte            1  54
# xpr0246            Simon, Mathurin entrepreneur            1  50
# xpr0113           Frosne, Jean Luc   architecte            2  60
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      5
# Recevoir et évaluer le travail réalisé      4
#                             Départager      3
#                            Enregistrer      0
#
#
#
#
# Frosne, Jean Luc ; architecte ; 44 expertises ; 2 expertises en tant que tiers-expert ; 33 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                            name       column  totalCollab age
# xpr0244                   Serouge, Jean entrepreneur            1
# xpr0048                  Caulle, Martin   architecte            1  55
# xpr0181                Lievain, Nicolas entrepreneur            1  56
# xpr0190          Marteau, Jean Baptiste   architecte            1  62
# xpr0100                    Dubois, Jean entrepreneur            1  68
# xpr0177 Lepas Dubuisson, Claude Nicolas   architecte            1
# xpr0189                  Marchand, Marc entrepreneur            1
# xpr0111     Fourier, Edme (1668 - 1727) entrepreneur            2  48
# xpr0197                  Miche, Jacques entrepreneur            2  64
# xpr0151       Laisney, François Etienne entrepreneur            2  33
# xpr0183             Loir, Jean Baptiste entrepreneur            3  51
# xpr0221              Pirethouy, Jacques   architecte            3  66
# xpr0086              Delespine, Nicolas   architecte            3  74
# xpr0124            Gobin, Jean François   architecte            5  59
# xpr0232                  Quirot, Pierre   architecte            6  54
# xpr0077      De Mezerets (Père), Michel   architecte            9  79
#
#
#                                  label  total
#            Estimer la valeur des biens      5
# Décrire et évaluer les travaux à venir     11
# Recevoir et évaluer le travail réalisé     12
#                             Départager     11
#                            Enregistrer      2
#
#
#
#
# Gabriel, Jacques ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      1
# Recevoir et évaluer le travail réalisé      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Giraud, Jean Louis ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
# Recevoir et évaluer le travail réalisé      1
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Gobin, Jean François ; architecte ; 55 expertises ; 1 expertises en tant que tiers-expert ; 35 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                        name       column  totalCollab age
# xpr0166            Le Juge, Nicolas   architecte            1  70
# xpr0170            Le Roy, Estienne entrepreneur            1  68
# xpr0100                Dubois, Jean entrepreneur            1  68
# xpr0146            Joubert, Charles entrepreneur            1  76
# xpr0111 Fourier, Edme (1668 - 1727) entrepreneur            1  48
# xpr0063          Cudeville, Jacques    arpenteur            1
# xpr0125                Gobin, Denis entrepreneur            1  53
# xpr0183         Loir, Jean Baptiste entrepreneur            1  51
# xpr0185 Loir, Bernard Jean Baptiste   architecte            1
# xpr0168          Le Proust, Rolland   architecte            1  79
# xpr0048              Caulle, Martin   architecte            1  55
# xpr0181            Lievain, Nicolas entrepreneur            2  56
# xpr0264          Vuyet, Jean Robert   architecte            2  52
# xpr0027           Boffrand, Germain   architecte            2  49
# xpr0221          Pirethouy, Jacques   architecte            2  66
# xpr0086          Delespine, Nicolas   architecte            2  74
# xpr0197              Miche, Jacques entrepreneur            2  64
# xpr0077  De Mezerets (Père), Michel   architecte            3  79
# xpr0113            Frosne, Jean Luc   architecte            5  60
# xpr0232              Quirot, Pierre   architecte            8  54
#
#
#                                  label  total
#            Estimer la valeur des biens     15
# Décrire et évaluer les travaux à venir      8
# Recevoir et évaluer le travail réalisé     15
#                             Départager     13
#                            Enregistrer      2
#
#
#
#
# Gobin, Denis ; entrepreneur ; 9 expertises ; 0 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                        name       column  totalCollab age
# xpr0183         Loir, Jean Baptiste entrepreneur            1  51
# xpr0111 Fourier, Edme (1668 - 1727) entrepreneur            1  48
# xpr0124        Gobin, Jean François   architecte            1  59
# xpr0140              Hequan, Pierre entrepreneur            1  78
# xpr0197              Miche, Jacques entrepreneur            1  64
#
#
#                                  label  total
#            Estimer la valeur des biens      3
# Décrire et évaluer les travaux à venir      1
# Recevoir et évaluer le travail réalisé      2
#                             Départager      3
#                            Enregistrer      0
#
#
#
#
# Goujon, Louis Alexandre ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id               name     column  totalCollab age
# xpr0086 Delespine, Nicolas architecte            1  74
# xpr0027  Boffrand, Germain architecte            1  49
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      0
# Recevoir et évaluer le travail réalisé      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Hequan, Pierre ; entrepreneur ; 6 expertises ; 0 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0077 De Mezerets (Père), Michel   architecte            1  79
# xpr0100               Dubois, Jean entrepreneur            1  68
# xpr0183        Loir, Jean Baptiste entrepreneur            1  51
# xpr0264         Vuyet, Jean Robert   architecte            1  52
# xpr0125               Gobin, Denis entrepreneur            1  53
# xpr0197             Miche, Jacques entrepreneur            1  64
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      2
# Recevoir et évaluer le travail réalisé      2
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# Herbet, Michel ; entrepreneur ; 6 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                        name       column  totalCollab age
# xpr0111 Fourier, Edme (1668 - 1727) entrepreneur            1  48
# xpr0048              Caulle, Martin   architecte            1  55
# xpr0221          Pirethouy, Jacques   architecte            1  66
#
#
#                                  label  total
#            Estimer la valeur des biens      2
# Décrire et évaluer les travaux à venir      2
# Recevoir et évaluer le travail réalisé      1
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Joubert, Charles ; entrepreneur ; 6 expertises ; 0 expertises en tant que tiers-expert ; 4 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0086         Delespine, Nicolas   architecte            1  74
# xpr0124       Gobin, Jean François   architecte            1  59
# xpr0181           Lievain, Nicolas entrepreneur            1  56
# xpr0077 De Mezerets (Père), Michel   architecte            1  79
# xpr0246            Simon, Mathurin entrepreneur            1  50
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      1
# Recevoir et évaluer le travail réalisé      1
#                             Départager      3
#                            Enregistrer      0
#
#
#
#
# Ju, Charles ; entrepreneur ; 9 expertises ; 0 expertises en tant que tiers-expert ; 7 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0232             Quirot, Pierre   architecte            1  54
# xpr0181           Lievain, Nicolas entrepreneur            1  56
# xpr0168         Le Proust, Rolland   architecte            1  79
# xpr0086         Delespine, Nicolas   architecte            1  74
# xpr0221         Pirethouy, Jacques   architecte            1  66
# xpr0077 De Mezerets (Père), Michel   architecte            2  79
#
#
#                                  label  total
#            Estimer la valeur des biens      3
# Décrire et évaluer les travaux à venir      3
# Recevoir et évaluer le travail réalisé      0
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# Laisney, François Etienne ; entrepreneur ; 3 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id             name       column  totalCollab age
# xpr0244    Serouge, Jean entrepreneur            1
# xpr0113 Frosne, Jean Luc   architecte            2  60
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
# Recevoir et évaluer le travail réalisé      0
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Le Juge, Nicolas ; architecte ; 10 expertises ; 0 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                 name       column  totalCollab age
# xpr0124 Gobin, Jean François   architecte            1  59
# xpr0232       Quirot, Pierre   architecte            1  54
# xpr0221   Pirethouy, Jacques   architecte            1  66
# xpr0197       Miche, Jacques entrepreneur            1  64
# xpr0170     Le Roy, Estienne entrepreneur            1  68
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      4
# Recevoir et évaluer le travail réalisé      4
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Le Proust, Rolland ; architecte ; 7 expertises ; 0 expertises en tant que tiers-expert ; 6 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                        name       column  totalCollab age
# xpr0221          Pirethouy, Jacques   architecte            1  66
# xpr0149                 Ju, Charles entrepreneur            1  52
# xpr0185 Loir, Bernard Jean Baptiste   architecte            1
# xpr0124        Gobin, Jean François   architecte            1  59
# xpr0244               Serouge, Jean entrepreneur            1
# xpr0086          Delespine, Nicolas   architecte            2  74
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      2
# Recevoir et évaluer le travail réalisé      0
#                             Départager      3
#                            Enregistrer      0
#
#
#
#
# Le Roy, Estienne ; entrepreneur ; 17 expertises ; 0 expertises en tant que tiers-expert ; 8 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                        name       column  totalCollab age
# xpr0124        Gobin, Jean François   architecte            1  59
# xpr0077  De Mezerets (Père), Michel   architecte            1  79
# xpr0111 Fourier, Edme (1668 - 1727) entrepreneur            1  48
# xpr0189              Marchand, Marc entrepreneur            1
# xpr0086          Delespine, Nicolas   architecte            1  74
# xpr0264          Vuyet, Jean Robert   architecte            1  52
# xpr0166            Le Juge, Nicolas   architecte            1  70
# xpr0197              Miche, Jacques entrepreneur            1  64
#
#
#                                  label  total
#            Estimer la valeur des biens      9
# Décrire et évaluer les travaux à venir      2
# Recevoir et évaluer le travail réalisé      2
#                             Départager      4
#                            Enregistrer      0
#
#
#
#
# Lepas Dubuisson, Claude Nicolas ; architecte ; 11 expertises ; 0 expertises en tant que tiers-expert ; 6 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0189             Marchand, Marc entrepreneur            1
# xpr0197             Miche, Jacques entrepreneur            1  64
# xpr0048             Caulle, Martin   architecte            1  55
# xpr0105             Duval, Charles    arpenteur            1
# xpr0113           Frosne, Jean Luc   architecte            1  60
# xpr0077 De Mezerets (Père), Michel   architecte            2  79
#
#
#                                  label  total
#            Estimer la valeur des biens      2
# Décrire et évaluer les travaux à venir      2
# Recevoir et évaluer le travail réalisé      5
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Lievain, Nicolas ; entrepreneur ; 11 expertises ; 0 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                 name       column  totalCollab age
# xpr0146     Joubert, Charles entrepreneur            1  76
# xpr0149          Ju, Charles entrepreneur            1  52
# xpr0189       Marchand, Marc entrepreneur            1
# xpr0113     Frosne, Jean Luc   architecte            1  60
# xpr0124 Gobin, Jean François   architecte            2  59
#
#
#                                  label  total
#            Estimer la valeur des biens      2
# Décrire et évaluer les travaux à venir      4
# Recevoir et évaluer le travail réalisé      3
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# Loir, Jean Baptiste ; entrepreneur ; 58 expertises ; 10 expertises en tant que tiers-expert ; 21 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                        name       column  totalCollab age
# xpr0048              Caulle, Martin   architecte            1  55
# xpr0125                Gobin, Denis entrepreneur            1  53
# xpr0246             Simon, Mathurin entrepreneur            1  50
# xpr0190      Marteau, Jean Baptiste   architecte            1  62
# xpr0100                Dubois, Jean entrepreneur            1  68
# xpr0264          Vuyet, Jean Robert   architecte            1  52
# xpr0140              Hequan, Pierre entrepreneur            1  78
# xpr0124        Gobin, Jean François   architecte            1  59
# xpr0111 Fourier, Edme (1668 - 1727) entrepreneur            1  48
# xpr0086          Delespine, Nicolas   architecte            2  74
# xpr0027           Boffrand, Germain   architecte            2  49
# xpr0232              Quirot, Pierre   architecte            3  54
# xpr0113            Frosne, Jean Luc   architecte            3  60
# xpr0077  De Mezerets (Père), Michel   architecte            4  79
# xpr0197              Miche, Jacques entrepreneur            4  64
#
#
#                                  label  total
#            Estimer la valeur des biens     26
# Décrire et évaluer les travaux à venir     11
# Recevoir et évaluer le travail réalisé      9
#                             Départager     11
#                            Enregistrer      0
#
#
#
#
# Loir, Bernard Jean Baptiste ; architecte ; 20 expertises ; 1 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                 name       column  totalCollab age
# xpr0221   Pirethouy, Jacques   architecte            1  66
# xpr0197       Miche, Jacques entrepreneur            1  64
# xpr0168   Le Proust, Rolland   architecte            1  79
# xpr0124 Gobin, Jean François   architecte            1  59
#
#
#                                  label  total
#            Estimer la valeur des biens     12
# Décrire et évaluer les travaux à venir      5
# Recevoir et évaluer le travail réalisé      1
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# Marchand, Marc ; entrepreneur ; 16 expertises ; 0 expertises en tant que tiers-expert ; 10 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                            name       column  totalCollab age
# xpr0177 Lepas Dubuisson, Claude Nicolas   architecte            1
# xpr0232                  Quirot, Pierre   architecte            1  54
# xpr0181                Lievain, Nicolas entrepreneur            1  56
# xpr0170                Le Roy, Estienne entrepreneur            1  68
# xpr0100                    Dubois, Jean entrepreneur            1  68
# xpr0077      De Mezerets (Père), Michel   architecte            1  79
# xpr0113                Frosne, Jean Luc   architecte            1  60
# xpr0221              Pirethouy, Jacques   architecte            1  66
# xpr0197                  Miche, Jacques entrepreneur            3  64
#
#
#                                  label  total
#            Estimer la valeur des biens      2
# Décrire et évaluer les travaux à venir      3
# Recevoir et évaluer le travail réalisé      6
#                             Départager      3
#                            Enregistrer      0
#
#
#
#
# Marteau, Jean Baptiste ; architecte ; 12 expertises ; 0 expertises en tant que tiers-expert ; 6 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0232             Quirot, Pierre   architecte            1  54
# xpr0077 De Mezerets (Père), Michel   architecte            1  79
# xpr0183        Loir, Jean Baptiste entrepreneur            1  51
# xpr0113           Frosne, Jean Luc   architecte            1  60
# xpr0100               Dubois, Jean entrepreneur            1  68
# xpr0221         Pirethouy, Jacques   architecte            3  66
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      0
# Recevoir et évaluer le travail réalisé      5
#                             Départager      5
#                            Enregistrer      1
#
#
#
#
# Masson, Etienne ; entrepreneur ; 10 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name     column  totalCollab age
# xpr0232             Quirot, Pierre architecte            1  54
# xpr0077 De Mezerets (Père), Michel architecte            2  79
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
# Recevoir et évaluer le travail réalisé      7
#                             Départager      3
#                            Enregistrer      0
#
#
#
#
# Miche, Jacques ; entrepreneur ; 35 expertises ; 0 expertises en tant que tiers-expert ; 27 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                            name       column  totalCollab age
# xpr0063              Cudeville, Jacques    arpenteur            1
# xpr0177 Lepas Dubuisson, Claude Nicolas   architecte            1
# xpr0166                Le Juge, Nicolas   architecte            1  70
# xpr0027               Boffrand, Germain   architecte            1  49
# xpr0170                Le Roy, Estienne entrepreneur            1  68
# xpr0125                    Gobin, Denis entrepreneur            1  53
# xpr0140                  Hequan, Pierre entrepreneur            1  78
# xpr0185     Loir, Bernard Jean Baptiste   architecte            1
# xpr0048                  Caulle, Martin   architecte            1  55
# xpr0221              Pirethouy, Jacques   architecte            2  66
# xpr0077      De Mezerets (Père), Michel   architecte            2  79
# xpr0113                Frosne, Jean Luc   architecte            2  60
# xpr0124            Gobin, Jean François   architecte            2  59
# xpr0232                  Quirot, Pierre   architecte            3  54
# xpr0100                    Dubois, Jean entrepreneur            3  68
# xpr0189                  Marchand, Marc entrepreneur            3
# xpr0183             Loir, Jean Baptiste entrepreneur            4  51
#
#
#                                  label  total
#            Estimer la valeur des biens      6
# Décrire et évaluer les travaux à venir      3
# Recevoir et évaluer le travail réalisé     19
#                             Départager      5
#                            Enregistrer      0
#
#
#
#
# Perrault, André ; entrepreneur ; 2 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id               name     column  totalCollab age
# xpr0221 Pirethouy, Jacques architecte            1  66
# xpr0232     Quirot, Pierre architecte            1  54
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
# Recevoir et évaluer le travail réalisé      0
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Person, Charles ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
# Recevoir et évaluer le travail réalisé      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Pirethouy, Jacques ; architecte ; 37 expertises ; 2 expertises en tant que tiers-expert ; 18 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                        name       column  totalCollab age
# xpr0166            Le Juge, Nicolas   architecte            1  70
# xpr0168          Le Proust, Rolland   architecte            1  79
# xpr0105              Duval, Charles    arpenteur            1
# xpr0211             Perrault, André entrepreneur            1  59
# xpr0185 Loir, Bernard Jean Baptiste   architecte            1
# xpr0141              Herbet, Michel entrepreneur            1  54
# xpr0063          Cudeville, Jacques    arpenteur            1
# xpr0189              Marchand, Marc entrepreneur            1
# xpr0149                 Ju, Charles entrepreneur            1  52
# xpr0018            Bernard, Charles   architecte            1  46
# xpr0197              Miche, Jacques entrepreneur            2  64
# xpr0124        Gobin, Jean François   architecte            2  59
# xpr0113            Frosne, Jean Luc   architecte            3  60
# xpr0190      Marteau, Jean Baptiste   architecte            3  62
# xpr0077  De Mezerets (Père), Michel   architecte            3  79
#
#
#                                  label  total
#            Estimer la valeur des biens      4
# Décrire et évaluer les travaux à venir     13
# Recevoir et évaluer le travail réalisé      8
#                             Départager     12
#                            Enregistrer      0
#
#
#
#
# Quirot, Pierre ; architecte ; 54 expertises ; 0 expertises en tant que tiers-expert ; 43 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                        name       column  totalCollab age
# xpr0149                 Ju, Charles entrepreneur            1  52
# xpr0166            Le Juge, Nicolas   architecte            1  70
# xpr0189              Marchand, Marc entrepreneur            1
# xpr0190      Marteau, Jean Baptiste   architecte            1  62
# xpr0193             Masson, Etienne entrepreneur            1  34
# xpr0244               Serouge, Jean entrepreneur            1
# xpr0211             Perrault, André entrepreneur            1  59
# xpr0246             Simon, Mathurin entrepreneur            1  50
# xpr0111 Fourier, Edme (1668 - 1727) entrepreneur            1  48
# xpr0100                Dubois, Jean entrepreneur            2  68
# xpr0183         Loir, Jean Baptiste entrepreneur            3  51
# xpr0197              Miche, Jacques entrepreneur            3  64
# xpr0264          Vuyet, Jean Robert   architecte            3  52
# xpr0077  De Mezerets (Père), Michel   architecte            3  79
# xpr0113            Frosne, Jean Luc   architecte            6  60
# xpr0124        Gobin, Jean François   architecte            8  59
# xpr0048              Caulle, Martin   architecte           10  55
#
#
#                                  label  total
#            Estimer la valeur des biens      7
# Décrire et évaluer les travaux à venir     10
# Recevoir et évaluer le travail réalisé     23
#                             Départager     11
#                            Enregistrer      0
#
#
#
#
# Raymond, Etienne Hubert ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id               name     column  totalCollab age
# xpr0264 Vuyet, Jean Robert architecte            1  52
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
# Recevoir et évaluer le travail réalisé      1
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Serouge, Jean ; entrepreneur ; 15 expertises ; 0 expertises en tant que tiers-expert ; 9 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0113           Frosne, Jean Luc   architecte            1  60
# xpr0151  Laisney, François Etienne entrepreneur            1  33
# xpr0100               Dubois, Jean entrepreneur            1  68
# xpr0264         Vuyet, Jean Robert   architecte            1  52
# xpr0063         Cudeville, Jacques    arpenteur            1
# xpr0232             Quirot, Pierre   architecte            1  54
# xpr0168         Le Proust, Rolland   architecte            1  79
# xpr0077 De Mezerets (Père), Michel   architecte            3  79
#
#
#                                  label  total
#            Estimer la valeur des biens      2
# Décrire et évaluer les travaux à venir      0
# Recevoir et évaluer le travail réalisé      3
#                             Départager      8
#                            Enregistrer      0
#
#
#
#
# Simon, Mathurin ; entrepreneur ; 4 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                        name       column  totalCollab age
# xpr0183         Loir, Jean Baptiste entrepreneur            1  51
# xpr0146            Joubert, Charles entrepreneur            1  76
# xpr0232              Quirot, Pierre   architecte            1  54
# xpr0111 Fourier, Edme (1668 - 1727) entrepreneur            1  48
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
# Recevoir et évaluer le travail réalisé      1
#                             Départager      3
#                            Enregistrer      0
#
#
#
#
# Vuyet, Jean Robert ; architecte ; 26 expertises ; 0 expertises en tant que tiers-expert ; 11 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0086         Delespine, Nicolas   architecte            1  74
# xpr0244              Serouge, Jean entrepreneur            1
# xpr0170           Le Roy, Estienne entrepreneur            1  68
# xpr0183        Loir, Jean Baptiste entrepreneur            1  51
# xpr0140             Hequan, Pierre entrepreneur            1  78
# xpr0234    Raymond, Etienne Hubert   architecte            1
# xpr0124       Gobin, Jean François   architecte            2  59
# xpr0232             Quirot, Pierre   architecte            3  54
# xpr0077 De Mezerets (Père), Michel   architecte            3  79
#
#
#                                  label  total
#            Estimer la valeur des biens      4
# Décrire et évaluer les travaux à venir      5
# Recevoir et évaluer le travail réalisé     10
#                             Départager      5
#                            Enregistrer      1
#
#
#
#
# Bourgeois, Pierre (? - ?) ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name     column  totalCollab age
# xpr0279 Beuzelin, Martin (? - ?) architecte            1
# xpr0280 Saunier, Nicolas (? - ?) architecte            1
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
# Recevoir et évaluer le travail réalisé      0
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Beuzelin, Martin (? - ?) ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                      name     column  totalCollab age
# xpr0278 Bourgeois, Pierre (? - ?) architecte            1
# xpr0280  Saunier, Nicolas (? - ?) architecte            1
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
# Recevoir et évaluer le travail réalisé      0
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Saunier, Nicolas (? - ?) ; architecte ; 1 expertises ; 1 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                      name     column  totalCollab age
# xpr0278 Bourgeois, Pierre (? - ?) architecte            1
# xpr0279  Beuzelin, Martin (? - ?) architecte            1
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
# Recevoir et évaluer le travail réalisé      0
#                             Départager      1
#                            Enregistrer      0
