# %% [markdown]
# # xprStats

# %%
# lib
from urllib.request import urlopen
import json  
import pandas as pd

# %%
# Récupération des donnée 
# param (date or thirdParty)
param = "1776"

# url
url = "https://experts.huma-num.fr/xpr/statistics/" + param

# enregistrement de la réponse
response = urlopen(url)

# lecture du json
data = json.loads(response.read())
  
# print the json response
#print(data)

# %% [markdown]
# ## Expertises

# %%
expertises = data['expertises']

# %%
print("Nombre total d'expertises : " + str(expertises['total']))
# Out:
# Nombre total d'expertises : 724

# %% [markdown]
# ### Croquis

# %%
sketchesDF = pd.json_normalize(expertises['sketches'])
print(sketchesDF.to_string(index=False))
# Out:
#  expertisesWithoutSketch  expertisesWithSketch
#                      718                     6

# %% [markdown]
# ### Étendue

# %%
extent = expertises['extent']
#print(extent)

print('Nombre de feuillets : ' + str(extent['total']))

print('Moyenne par expertise : ' + str(extent['averageByExpertise']))

#Distribution
print('Distribution :')
keys = []
values = []
for dic in extent['extentDistribution']:
    for key, val in dic.items():
        keys.append(key),
        values.append(val)        

extentDistributionDict = {'nombre de feuillets': keys, 'nombre d’expertises': values,} 
print(pd.DataFrame(extentDistributionDict).to_string(index=False))
# Out:
# Nombre de feuillets : 6463
# Moyenne par expertise : 8.93
# Distribution :
# nombre de feuillets  nombre d’expertises
#                   5                  360
#                  10                  228
#                  15                   48
#                  20                   33
#                  25                   13
#                  30                   11
#                  35                    5
#                  40                    8
#                  45                    1
#                  50                    4
#                  55                    2
#                  60                    3
#                  65                    0
#                  70                    0
#                  75                    1
#                  80                    2
#                  85                    1
#                  90                    0
#                  95                    1
#                 100                    2

# %% [markdown]
# ### Annexes

# %%
appendices = expertises['appendices']
#print(appendices)

print(f"{appendices['total']} annexes")


print(f"{appendices['expertisesWithAppendices']} expertises avec annexes ; {appendices['expertisesWithoutAppendices']} expertises sans annexes")


df=pd.json_normalize(appendices['types'])
print(df.to_string(columns=['label', 'total', 'expertises'], index=False))
# Out:
# 719 annexes
# 377 expertises avec annexes ; 347 expertises sans annexes
#                                       label  total  expertises
#                                     Requête    162         156
# Pouvoir/procuration (acte sous seing privé)     80          58
#                                       Autre    195         131
#                      Plan, coupe, élévation    191         120
#                                      Dessin     55          41
#                                   Brouillon      7           7
#          Pouvoir/procuration (acte notarié)     16          14
#                                     Croquis      7           4

# %% [markdown]
# ### Vacations

# %%
sessions = expertises['sessions']
#print(sessions)

print(f"{sessions['total']} vacations")


print(f"en moyenne {sessions['averageByExpertise']} vacations par expertise")
# Out:
# 2641 vacations
# en moyenne 3.65 vacations par expertise

# %% [markdown]
# Nombre de vacation par lieu

# %%
sessionsDf=pd.json_normalize(sessions['places'])
print(sessionsDf.to_string(columns=['label', 'total'], index=False))
# Out:
#    label  total
#    Paris   1968
# Banlieue    321
# Province    348

# %% [markdown]
# ### Durée

# %%
duration = expertises['duration']
#print(duration)

# %% [markdown]
# #### Jours

# %%
#Distribution
durationDays = duration['days']
#print(durationDays)
print('Distribution :')
keys = []
values = []
for dic in durationDays['distributionByDays']:
    for key, val in dic.items():
        keys.append(key),
        values.append(val)        

durationDaysDf = {'nombre de jours': keys, 'nombre d’expertises': values,} 
print(pd.DataFrame(durationDaysDf).to_string(index=False))
# Out:
# Distribution :
# nombre de jours  nombre d’expertises
#               5                  298
#              10                   64
#              15                   36
#              20                   27
#              25                   35
#              30                   21
#              35                   20
#              40                   18
#              45                   10
#              50                   12
#              55                   17
#              60                    6
#              65                   12
#              70                   12
#              75                    6
#              80                   11
#              85                    6
#              90                    8
#              95                    5
#             100                   97

# %% [markdown]
# #### Vacations

# %%
#Distribution
durationSessions = duration['sessions']
#print(durationDays)
print(f"{durationSessions['total']} vacations, soit en moyenne {durationSessions['averageByExpertise']} vacations par expertise.")
# Out:
# 2641 vacations, soit en moyenne 1.82 vacations par expertise.

# %% [markdown]
# ### Lieux

# %%
places = expertises['places']
#print(places)

placesDf=pd.json_normalize(places)
print(placesDf.to_string(columns=['place', 'total'], index=False))
# Out:
#                        place  total
#                      [paris]    466
#                    [suburbs]    100
#                   [province]     91
#           [[paris, suburbs]]     18
#          [[paris, province]]     42
#        [[suburbs, province]]      3
# [[paris, suburbs, province]]      0

# %% [markdown]
# ### Procédures et cadres

# %%
frameworks = expertises['frameworks']
#print(frameworks)

frameworksDf=pd.json_normalize(frameworks)
print(frameworksDf.to_string(columns=['label', 'framework', 'total'], index=False))
# Out:
#                                                                                                                   label framework  total
# L’institution est saisie dans le cadre d’une procédure (les parties nomment chacune leur expert ou un expert en commun)       b2a    222
#                                                     Requête auprès d’une institution pour qu’elle demande une expertise        b1     61
#                         L’institution est saisie dans le cadre d’une procédure (l’institution nomme un ou deux experts)       b2b    280
#                                                                                               Commun accord des parties         a     65
# L’institution est saisie dans le cadre d’une procédure (les parties nomment chacune leur expert ou un expert en commun)        b2     65
#                                                                                                       Cas problématique         c      8
#                                                                                                                                        8
#                                          Saisie mixte (un expert est nommé par les parties, l'autre est nommé d'office)        b3     15

# %% [markdown]
# ### Catégories

# %%
categories = expertises['categories']

for cat in categories:
    if cat['total'] != 0: print(f"{cat['label']} : {cat['total']} expertises"),
    for framework in cat['frameworks']:
        if framework['total'] != 0: print(f"\t{framework['framework']} : {framework['total']} expertises"),
        for place in framework['places']:
            if place['total'] != 0: print(f"\t\t{place['place']} : {place['total']}"),
            for obj in place['objects']:
                if obj['total'] != 0: print(f"\t\t\t{obj['label']} : {obj['total']}")
        print('\n')
    print('\n')
# Out:
# Recevoir et évaluer le travail réalisé : 203 expertises
# 	b2a : 95 expertises
# 		['paris'] : 70
# 			Ouvrages de maçonnerie : 49
# 			Maison(s) : 33
# 			Fosse(s) d'aisance : 1
# 		['suburbs'] : 8
# 			Ouvrages de maçonnerie : 6
# 			Maison(s) : 3
# 		['province'] : 6
# 			Ouvrages de maçonnerie : 4
# 			Maison(s) : 3
# 		[['paris', 'suburbs']] : 4
# 			Ouvrages de maçonnerie : 4
# 		[['paris', 'province']] : 6
# 			Ouvrages de maçonnerie : 3
# 			Maison(s) : 2
#
#
# 	b1 : 10 expertises
# 		['paris'] : 9
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 9
# 		[['paris', 'province']] : 1
# 			Maison(s) : 1
#
#
# 	b2b : 56 expertises
# 		['paris'] : 48
# 			Ouvrages de maçonnerie : 33
# 			Maison(s) : 20
# 		['suburbs'] : 3
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 1
# 		[['paris', 'suburbs']] : 2
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 1
# 		[['paris', 'province']] : 2
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 2
#
#
# 	a : 13 expertises
# 		['paris'] : 10
# 			Ouvrages de maçonnerie : 6
# 			Maison(s) : 5
# 		['suburbs'] : 1
# 			Ouvrages de maçonnerie : 1
# 		['province'] : 1
# 			Ouvrages de maçonnerie : 1
# 		[['paris', 'province']] : 1
# 			Ouvrages de maçonnerie : 1
#
#
# 	b2 : 18 expertises
# 		['paris'] : 10
# 			Ouvrages de maçonnerie : 8
# 			Maison(s) : 3
# 			Terrain(s) : 1
# 		['suburbs'] : 7
# 			Ouvrages de maçonnerie : 6
# 			Maison(s) : 3
# 		['province'] : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
#
#
# 	c : 2 expertises
# 		['paris'] : 2
# 			Ouvrages de maçonnerie : 2
#
#
# 	 : 5 expertises
# 		['paris'] : 5
# 			Ouvrages de maçonnerie : 3
#
#
# 	b3 : 4 expertises
# 		['paris'] : 4
# 			Ouvrages de maçonnerie : 3
# 			Maison(s) : 3
#
#
#
#
# Estimer la valeur des biens : 228 expertises
# 	b2a : 62 expertises
# 		['paris'] : 29
# 			Maison(s) : 28
# 			Terrain(s) : 2
# 		['suburbs'] : 9
# 			Maison(s) : 8
# 			Terrain(s) : 4
# 		['province'] : 15
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 9
# 			Terrain(s) : 2
# 			Ensemble de bâtiments (biens immeubles) : 3
# 			Domaine, terres, fief : 4
# 		[['paris', 'suburbs']] : 1
# 			Maison(s) : 1
# 			Terrain(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		[['paris', 'province']] : 7
# 			Maison(s) : 6
# 			Ensemble de bâtiments (biens immeubles) : 1
# 			Domaine, terres, fief : 2
# 		[['suburbs', 'province']] : 1
# 			Maison(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
#
#
# 	b1 : 6 expertises
# 		['paris'] : 6
# 			Maison(s) : 5
#
#
# 	b2b : 111 expertises
# 		['paris'] : 64
# 			Maison(s) : 57
# 			Terrain(s) : 6
# 			Domaine, terres, fief : 3
# 		['suburbs'] : 14
# 			Maison(s) : 11
# 			Terrain(s) : 4
# 		['province'] : 23
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 18
# 			Terrain(s) : 4
# 			Domaine, terres, fief : 2
# 		[['paris', 'suburbs']] : 2
# 			Maison(s) : 2
# 		[['paris', 'province']] : 7
# 			Maison(s) : 5
# 			Domaine, terres, fief : 2
#
#
# 	a : 10 expertises
# 		['paris'] : 8
# 			Maison(s) : 7
# 			Ensemble de bâtiments (biens immeubles) : 1
# 			Domaine, terres, fief : 2
# 		['suburbs'] : 2
# 			Maison(s) : 2
#
#
# 	b2 : 34 expertises
# 		['paris'] : 15
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 13
# 			Terrain(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		['suburbs'] : 6
# 			Maison(s) : 6
# 			Terrain(s) : 1
# 		['province'] : 7
# 			Maison(s) : 7
# 			Terrain(s) : 2
# 		[['paris', 'suburbs']] : 1
# 			Maison(s) : 1
# 		[['paris', 'province']] : 4
# 			Maison(s) : 4
# 			Terrain(s) : 1
# 			Domaine, terres, fief : 1
# 		[['suburbs', 'province']] : 1
# 			Terrain(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
#
#
#
#
# 	 : 2 expertises
# 		['paris'] : 1
# 			Maison(s) : 1
# 		['province'] : 1
#
#
# 	b3 : 3 expertises
# 		['paris'] : 1
# 			Maison(s) : 1
# 		['suburbs'] : 1
# 			Maison(s) : 1
# 		['province'] : 1
# 			Domaine, terres, fief : 1
#
#
#
#
# Décrire et évaluer les travaux à venir : 134 expertises
# 	b2a : 24 expertises
# 		['paris'] : 14
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 12
# 		['suburbs'] : 2
# 			Maison(s) : 1
# 			Mur(s) : 1
# 		['province'] : 6
# 			Ouvrages de maçonnerie : 4
# 			Maison(s) : 2
# 			Ensemble de bâtiments (biens immeubles) : 2
# 			Domaine, terres, fief : 1
# 		[['paris', 'suburbs']] : 1
# 			Maison(s) : 1
# 		[['paris', 'province']] : 1
# 			Ouvrages de maçonnerie : 1
#
#
# 	b1 : 14 expertises
# 		['paris'] : 9
# 			Maison(s) : 9
# 			Mur(s) : 1
# 			Fosse(s) d'aisance : 1
# 		['suburbs'] : 3
# 			Maison(s) : 3
# 		['province'] : 2
# 			Ouvrages de maçonnerie : 2
#
#
# 	b2b : 77 expertises
# 		['paris'] : 50
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 43
# 			Mur(s) : 2
# 			Fosse(s) d'aisance : 3
# 			Puits : 1
# 		['suburbs'] : 19
# 			Maison(s) : 18
# 			Terrain(s) : 1
# 		['province'] : 5
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 3
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		[['paris', 'suburbs']] : 1
# 			Maison(s) : 1
# 			Terrain(s) : 1
# 		[['paris', 'province']] : 2
# 			Ouvrages de maçonnerie : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
#
#
# 	a : 9 expertises
# 		['paris'] : 7
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 4
# 			Mur(s) : 2
# 		[['paris', 'suburbs']] : 1
# 			Ouvrages de maçonnerie : 1
# 		[['paris', 'province']] : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
#
#
# 	b2 : 1 expertises
# 		['paris'] : 1
# 			Maison(s) : 1
# 			Fosse(s) d'aisance : 1
#
#
# 	c : 4 expertises
# 		['paris'] : 2
# 			Maison(s) : 2
# 		['suburbs'] : 1
# 			Maison(s) : 1
# 		['province'] : 1
# 			Domaine, terres, fief : 1
#
#
#
#
# 	b3 : 5 expertises
# 		['paris'] : 3
# 			Maison(s) : 3
# 		['suburbs'] : 1
# 			Ouvrages de maçonnerie : 1
# 		['province'] : 1
# 			Maison(s) : 1
#
#
#
#
# Départager : 98 expertises
# 	b2a : 30 expertises
# 		['paris'] : 15
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 3
# 			Terrain(s) : 1
# 			Mur(s) : 7
# 			Ensemble de bâtiments (biens immeubles) : 1
# 			Fosse(s) d'aisance : 2
# 			Puits : 1
# 		['suburbs'] : 6
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 			Mur(s) : 5
# 		['province'] : 5
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 			Mur(s) : 4
# 		[['paris', 'province']] : 4
# 			Maison(s) : 1
# 			Mur(s) : 2
#
#
# 	b1 : 5 expertises
# 		['paris'] : 4
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 			Mur(s) : 1
# 			Fosse(s) d'aisance : 1
# 		['suburbs'] : 1
# 			Mur(s) : 1
#
#
# 	b2b : 20 expertises
# 		['paris'] : 9
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 1
# 			Mur(s) : 5
# 			Fosse(s) d'aisance : 3
# 		['suburbs'] : 4
# 			Ouvrages de maçonnerie : 2
# 			Mur(s) : 1
# 		['province'] : 2
# 			Mur(s) : 2
# 		[['paris', 'suburbs']] : 2
# 			Maison(s) : 1
# 			Terrain(s) : 1
# 			Mur(s) : 2
# 		[['paris', 'province']] : 3
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 			Terrain(s) : 1
# 			Mur(s) : 2
#
#
# 	a : 31 expertises
# 		['paris'] : 26
# 			Maison(s) : 3
# 			Terrain(s) : 1
# 			Mur(s) : 22
# 		['suburbs'] : 2
# 			Mur(s) : 2
# 		['province'] : 3
# 			Ouvrages de maçonnerie : 1
# 			Terrain(s) : 1
# 			Mur(s) : 1
#
#
# 	b2 : 8 expertises
# 		['paris'] : 4
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 			Terrain(s) : 1
# 			Mur(s) : 2
# 		['suburbs'] : 1
# 			Ouvrages de maçonnerie : 1
# 		['province'] : 1
# 			Terrain(s) : 1
# 		[['paris', 'suburbs']] : 1
# 			Terrain(s) : 1
# 		[['paris', 'province']] : 1
# 			Ouvrages de maçonnerie : 1
#
#
# 	c : 2 expertises
# 		['paris'] : 2
# 			Mur(s) : 1
# 			Fosse(s) d'aisance : 1
#
#
# 	 : 1 expertises
# 		['province'] : 1
# 			Mur(s) : 1
#
#
# 	b3 : 1 expertises
# 		['paris'] : 1
# 			Mur(s) : 1
#
#
#
#
# Enregistrer : 36 expertises
# 	b2a : 6 expertises
# 		['paris'] : 2
# 			Maison(s) : 1
# 			Mur(s) : 1
# 		['suburbs'] : 1
# 			Maison(s) : 1
# 		['province'] : 3
# 			Maison(s) : 2
# 			Terrain(s) : 1
#
#
# 	b1 : 25 expertises
# 		['paris'] : 16
# 			Maison(s) : 16
# 		['suburbs'] : 6
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 6
# 		['province'] : 1
# 			Maison(s) : 1
# 		[['paris', 'suburbs']] : 1
# 			Maison(s) : 1
# 		[['suburbs', 'province']] : 1
# 			Maison(s) : 1
#
#
# 	b2b : 2 expertises
# 		['paris'] : 2
# 			Maison(s) : 1
# 			Fosse(s) d'aisance : 1
#
#
# 	a : 1 expertises
# 		['province'] : 1
# 			Terrain(s) : 1
#
#
# 	b2 : 2 expertises
# 		['paris'] : 2
# 			Maison(s) : 2

# %% [markdown]
# ### Tiers expertises

# %%
thirdParty = expertises['thirdParty']

# %%
thirdPartyDf=pd.json_normalize(thirdParty)
print(thirdPartyDf.to_string(columns=['architectes', 'entrepreneurs', 'total'], index=False))
# Out:
#  architectes  entrepreneurs  total
#           10              7     17

# %% [markdown]
# ### Distribution (hors tiers expertises)

# %%
columnDistrib = expertises['experts']

for column in columnDistrib:
    print(f"{column['totalExperts']} expert(s) : {column['totalExpertises']} expertises"),
    if column['totalExperts']<3: print(pd.json_normalize(column['distribution']).to_string(columns=['label', 'total'], index=False))
    print('\n')
# Out:
# 1 expert(s) : 512 expertises
#        label  total
#   architecte    410
# entrepreneur    102
#
#
# 2 expert(s) : 192 expertises
#                       label  total
#     architecte - architecte     69
#   entrepreneur - architecte    107
# entrepreneur - entrepreneur     16
#
#
# 3 expert(s) : 3 expertises
#
#
# 4 expert(s) : 0 expertises

# %% [markdown]
# ## Experts

# %%
experts = data['experts']
#print(experts)

# %%
print(f"Nombre d’experts : {experts['total']}")
print(f"{experts['architects']} architectes")
print(f"{experts['entrepreneur']} entrepreneurs")
print(f"{experts['surveyor']} arpenteurs")
# Out:
# Nombre d’experts : 69
# 39 architectes
# 30 entrepreneurs
# 0 arpenteurs

# %%
listExperts = experts['list']
listExpertsDf = pd.DataFrame(listExperts)
listExpertsDf.drop('expertises', inplace=True, axis=1)

# %%
print(listExpertsDf.to_string(columns=['id', 'name', 'column', 'age'], index=False))
# Out:
#      id                                       name       column age
# xpr0002                       André, Jean Baptiste   architecte  41
# xpr0003                         Angot, Jean Pierre entrepreneur  37
# xpr0004                           Antoine, Antoine   architecte  30
# xpr0005                     Antoine, Jacques Denis entrepreneur  43
# xpr0006                            Arnoult, Thomas   architecte  69
# xpr0022               Billard de Bellisard, Claude   architecte  38
# xpr0024                        Blanchard, Jean-Luc   architecte
# xpr0026                          Bleve, Jean Louis   architecte  49
# xpr0031                       Bouchu, Paul Antoine   architecte  36
# xpr0032                Bouillette de Chamly, Raoul entrepreneur  42
# xpr0033            Boullant, Jean Baptiste Vincent   architecte  37
# xpr0037                     Bourgeois, Louis Denis   architecte
# xpr0038                   Bourgeois, Louis Silvain entrepreneur  40
# xpr0039                          Bourgeois, Pierre entrepreneur
# xpr0042                            Buron, François entrepreneur  45
# xpr0043              Le Camus de Mézières, Nicolas   architecte  51
# xpr0047                           Caque, Guillaume entrepreneur
# xpr0049                 Chabouille, Médéric Joseph entrepreneur  34
# xpr0050                    Chasteau, Jean François entrepreneur  42
# xpr0054                 Chauveau, René Bonaventure entrepreneur  83
# xpr0055                     Clavareau, Jean Pierre   architecte  55
# xpr0060                 Coupard Delatouche, Pierre entrepreneur  60
# xpr0065                   Danjan, Pierre Alexandre   architecte  54
# xpr0066                        Danjan, Pierre Paul   architecte  78
# xpr0067                   Dauphin, Antoine Nicolas   architecte  63
# xpr0070                 De Besse, Claude Guillaume   architecte  42
# xpr0081                De Villers, Eustache Robert   architecte  56
# xpr0082                          De Vonges, Michel entrepreneur  62
# xpr0085                     Delespine, Louis Jules   architecte  50
# xpr0089                   Desboeufs, Henri Quentin   architecte  71
# xpr0092               Desmaisons, Jacques François entrepreneur  61
# xpr0095                    Dosmond, Léonard Pierre   architecte  25
# xpr0101                 Duboiscerf, Sébastien Jean entrepreneur  63
# xpr0102                            Ducret, Nicolas   architecte  49
# xpr0104                       Dumont, Jean Charles entrepreneur  48
# xpr0106                        Egresset, Guillaume entrepreneur  65
# xpr0114                 Gabriel, Nicolas Toussaint   architecte  37
# xpr0122                       Giraud, Pierre Marie   architecte  42
# xpr0129                           Goupy Ii, Martin   architecte  42
# xpr0143                       Jacob, Jean François entrepreneur  41
# xpr0155                   Lardant, Pierre François entrepreneur  45
# xpr0163                  Le Foulon, Guillaume Elie entrepreneur  49
# xpr0191                       Martin, Pierre Henry   architecte  62
# xpr0200                             Mouchet, André entrepreneur
# xpr0201                              Neveu, Michel entrepreneur  43
# xpr0205            Parvy De La Renaudiere, Nicolas entrepreneur  42
# xpr0206                   Paulick, Jean Nepomucene   architecte
# xpr0209                     Payen, Jacques Antoine   architecte  66
# xpr0210                   Perrard, Nicolas Antoine entrepreneur  70
# xpr0216                Petit Radel, Louis François   architecte  36
# xpr0226                     Porquet, Claude Joseph   architecte  54
# xpr0228             Poulain, Jean Baptiste Martial   architecte  41
# xpr0229           Pruneau De Montlouis, Jean Louis   architecte  53
# xpr0230                    Puisieux, Jean Baptiste   architecte  86
# xpr0231                              Quirot, Denis   architecte  68
# xpr0235 Regnard De Barentin, Bernard Jean Baptiste entrepreneur  37
# xpr0236                      Richard, Pierre Louis entrepreneur  80
# xpr0247                        Simon, René Auguste entrepreneur  64
# xpr0250                          Taboureur, Pierre   architecte  40
# xpr0252                      Terrier, Martin Marie   architecte  48
# xpr0254                     Thevenin, Jacques-Jean entrepreneur
# xpr0258      Vavasseur Desperriers, Louis Athanase entrepreneur  34
# xpr0259                               Vedy, Julien entrepreneur  79
# xpr0261                         Villetard, Etienne entrepreneur  50
# xpr0268               Leleu, Antoine André (? - ?)   architecte
# xpr0269                     Dubois, Alexis (? - ?)   architecte
# xpr0270                                     Poupée   architecte
# xpr0273                   Lefort, François (? - ?)   architecte
# xpr0276                     Gilbert, Louis (? - ?)   architecte

# %%
for expert in listExperts:
    print(f"{expert['name']} ; {expert['column']} ; {expert['expertises']['total']} expertises ; {expert['expertises']['thirParty']} expertises en tant que tiers-expert ; {expert['expertises']['collab']['total']} expertises avec d'autres experts (tiers expertises comprises)"),
    print("\n")
    
    collabDF = pd.json_normalize(expert['expertises']['collab']['experts']) 
    if expert['expertises']['collab']['total'] != 0: print(collabDF.to_string(columns=['id', 'name', 'column', 'totalCollab', 'age'], index=False))
    print("\n")
    categoriesDef = pd.json_normalize(expert['expertises']['categories'])
    print(categoriesDef.to_string(columns=['label', 'total'], index=False))

    print("\n")
    print("\n")
# Out:
# André, Jean Baptiste ; architecte ; 4 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                      name       column  totalCollab age
# xpr0163 Le Foulon, Guillaume Elie entrepreneur            1  49
# xpr0250         Taboureur, Pierre   architecte            1  40
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      3
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Angot, Jean Pierre ; entrepreneur ; 7 expertises ; 0 expertises en tant que tiers-expert ; 4 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                 name       column  totalCollab age
# xpr0104 Dumont, Jean Charles entrepreneur            1  48
# xpr0082    De Vonges, Michel entrepreneur            1  62
# xpr0250    Taboureur, Pierre   architecte            2  40
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      2
#            Estimer la valeur des biens      2
# Décrire et évaluer les travaux à venir      3
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Antoine, Antoine ; architecte ; 5 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0055   Clavareau, Jean Pierre   architecte            1  55
# xpr0104     Dumont, Jean Charles entrepreneur            1  48
# xpr0210 Perrard, Nicolas Antoine entrepreneur            1  70
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#            Estimer la valeur des biens      2
# Décrire et évaluer les travaux à venir      0
#                             Départager      1
#                            Enregistrer      1
#
#
#
#
# Antoine, Jacques Denis ; entrepreneur ; 2 expertises ; 1 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                   name     column  totalCollab age
# xpr0085 Delespine, Louis Jules architecte            1  50
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      1
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Arnoult, Thomas ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Billard de Bellisard, Claude ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id            name     column  totalCollab age
# xpr0102 Ducret, Nicolas architecte            1  49
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Blanchard, Jean-Luc ; architecte ; 6 expertises ; 0 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0026        Bleve, Jean Louis   architecte            1  49
# xpr0210 Perrard, Nicolas Antoine entrepreneur            1  70
# xpr0250        Taboureur, Pierre   architecte            1  40
# xpr0104     Dumont, Jean Charles entrepreneur            2  48
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      3
#            Estimer la valeur des biens      2
# Décrire et évaluer les travaux à venir      0
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Bleve, Jean Louis ; architecte ; 33 expertises ; 3 expertises en tant que tiers-expert ; 16 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                             name       column  totalCollab age
# xpr0024              Blanchard, Jean-Luc   architecte            1
# xpr0155         Lardant, Pierre François entrepreneur            1  45
# xpr0070       De Besse, Claude Guillaume   architecte            1  42
# xpr0216      Petit Radel, Louis François   architecte            1  36
# xpr0261               Villetard, Etienne entrepreneur            1  50
# xpr0089         Desboeufs, Henri Quentin   architecte            1  71
# xpr0104             Dumont, Jean Charles entrepreneur            1  48
# xpr0229 Pruneau De Montlouis, Jean Louis   architecte            1  53
# xpr0065         Danjan, Pierre Alexandre   architecte            1  54
# xpr0081      De Villers, Eustache Robert   architecte            2  56
# xpr0250                Taboureur, Pierre   architecte            6  40
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé     12
#            Estimer la valeur des biens     10
# Décrire et évaluer les travaux à venir      4
#                             Départager      6
#                            Enregistrer      0
#
#
#
#
# Bouchu, Paul Antoine ; architecte ; 5 expertises ; 0 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                          name       column  totalCollab age
# xpr0210      Perrard, Nicolas Antoine entrepreneur            1  70
# xpr0043 Le Camus de Mézières, Nicolas   architecte            1  51
# xpr0104          Dumont, Jean Charles entrepreneur            1  48
# xpr0250             Taboureur, Pierre   architecte            1  40
# xpr0042               Buron, François entrepreneur            1  45
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      3
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      2
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Bouillette de Chamly, Raoul ; entrepreneur ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Boullant, Jean Baptiste Vincent ; architecte ; 3 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0250        Taboureur, Pierre   architecte            1  40
# xpr0067 Dauphin, Antoine Nicolas   architecte            1  63
# xpr0050  Chasteau, Jean François entrepreneur            1  42
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      1
#
#
#
#
# Bourgeois, Louis Denis ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Bourgeois, Louis Silvain ; entrepreneur ; 4 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id              name     column  totalCollab age
# xpr0250 Taboureur, Pierre architecte            1  40
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      3
# Décrire et évaluer les travaux à venir      1
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Bourgeois, Pierre ; entrepreneur ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0106        Egresset, Guillaume entrepreneur            1  65
# xpr0104       Dumont, Jean Charles entrepreneur            1  48
# xpr0060 Coupard Delatouche, Pierre entrepreneur            1  60
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Buron, François ; entrepreneur ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                 name     column  totalCollab age
# xpr0031 Bouchu, Paul Antoine architecte            1  36
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      1
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Le Camus de Mézières, Nicolas ; architecte ; 9 expertises ; 0 expertises en tant que tiers-expert ; 9 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                             name       column  totalCollab age
# xpr0129                 Goupy Ii, Martin   architecte            1  42
# xpr0210         Perrard, Nicolas Antoine entrepreneur            1  70
# xpr0163        Le Foulon, Guillaume Elie entrepreneur            1  49
# xpr0209           Payen, Jacques Antoine   architecte            1  66
# xpr0031             Bouchu, Paul Antoine   architecte            1  36
# xpr0070       De Besse, Claude Guillaume   architecte            1  42
# xpr0250                Taboureur, Pierre   architecte            1  40
# xpr0229 Pruneau De Montlouis, Jean Louis   architecte            1  53
# xpr0259                     Vedy, Julien entrepreneur            1  79
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      8
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      1
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Caque, Guillaume ; entrepreneur ; 3 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0210 Perrard, Nicolas Antoine entrepreneur            1  70
# xpr0250        Taboureur, Pierre   architecte            1  40
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      0
#                             Départager      1
#                            Enregistrer      1
#
#
#
#
# Chabouille, Médéric Joseph ; entrepreneur ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Chasteau, Jean François ; entrepreneur ; 10 expertises ; 0 expertises en tant que tiers-expert ; 6 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                            name     column  totalCollab age
# xpr0250               Taboureur, Pierre architecte            1  40
# xpr0270                          Poupée architecte            1
# xpr0033 Boullant, Jean Baptiste Vincent architecte            1  37
# xpr0070      De Besse, Claude Guillaume architecte            3  42
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      3
#            Estimer la valeur des biens      4
# Décrire et évaluer les travaux à venir      1
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Chauveau, René Bonaventure ; entrepreneur ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                   name     column  totalCollab age
# xpr0209 Payen, Jacques Antoine architecte            1  66
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Clavareau, Jean Pierre ; architecte ; 6 expertises ; 0 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0004           Antoine, Antoine   architecte            1  30
# xpr0104       Dumont, Jean Charles entrepreneur            1  48
# xpr0070 De Besse, Claude Guillaume   architecte            1  42
# xpr0250          Taboureur, Pierre   architecte            2  40
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      2
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      1
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# Coupard Delatouche, Pierre ; entrepreneur ; 2 expertises ; 1 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                 name       column  totalCollab age
# xpr0106  Egresset, Guillaume entrepreneur            1  65
# xpr0039    Bourgeois, Pierre entrepreneur            1
# xpr0104 Dumont, Jean Charles entrepreneur            2  48
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# Danjan, Pierre Alexandre ; architecte ; 10 expertises ; 1 expertises en tant que tiers-expert ; 7 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                        name       column  totalCollab age
# xpr0200              Mouchet, André entrepreneur            1
# xpr0210    Perrard, Nicolas Antoine entrepreneur            1  70
# xpr0070  De Besse, Claude Guillaume   architecte            1  42
# xpr0250           Taboureur, Pierre   architecte            1  40
# xpr0081 De Villers, Eustache Robert   architecte            1  56
# xpr0026           Bleve, Jean Louis   architecte            1  49
# xpr0085      Delespine, Louis Jules   architecte            3  50
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      3
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      2
#                             Départager      3
#                            Enregistrer      1
#
#
#
#
# Danjan, Pierre Paul ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Dauphin, Antoine Nicolas ; architecte ; 4 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                            name     column  totalCollab age
# xpr0089        Desboeufs, Henri Quentin architecte            1  71
# xpr0033 Boullant, Jean Baptiste Vincent architecte            1  37
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      2
#                             Départager      0
#                            Enregistrer      1
#
#
#
#
# De Besse, Claude Guillaume ; architecte ; 43 expertises ; 1 expertises en tant que tiers-expert ; 38 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                             name       column  totalCollab age
# xpr0081      De Villers, Eustache Robert   architecte            1  56
# xpr0026                Bleve, Jean Louis   architecte            1  49
# xpr0191             Martin, Pierre Henry   architecte            1  62
# xpr0254           Thevenin, Jacques-Jean entrepreneur            1
# xpr0163        Le Foulon, Guillaume Elie entrepreneur            1  49
# xpr0089         Desboeufs, Henri Quentin   architecte            1  71
# xpr0209           Payen, Jacques Antoine   architecte            1  66
# xpr0229 Pruneau De Montlouis, Jean Louis   architecte            1  53
# xpr0043    Le Camus de Mézières, Nicolas   architecte            1  51
# xpr0101       Duboiscerf, Sébastien Jean entrepreneur            1  63
# xpr0065         Danjan, Pierre Alexandre   architecte            1  54
# xpr0055           Clavareau, Jean Pierre   architecte            1  55
# xpr0228   Poulain, Jean Baptiste Martial   architecte            2  41
# xpr0143             Jacob, Jean François entrepreneur            2  41
# xpr0050          Chasteau, Jean François entrepreneur            3  42
# xpr0200                   Mouchet, André entrepreneur            3
# xpr0102                  Ducret, Nicolas   architecte            3  49
# xpr0210         Perrard, Nicolas Antoine entrepreneur            4  70
# xpr0104             Dumont, Jean Charles entrepreneur            6  48
# xpr0250                Taboureur, Pierre   architecte            6  40
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé     22
#            Estimer la valeur des biens      4
# Décrire et évaluer les travaux à venir      3
#                             Départager     11
#                            Enregistrer      0
#
#
#
#
# De Villers, Eustache Robert ; architecte ; 8 expertises ; 0 expertises en tant que tiers-expert ; 7 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0070 De Besse, Claude Guillaume   architecte            1  42
# xpr0250          Taboureur, Pierre   architecte            1  40
# xpr0102            Ducret, Nicolas   architecte            1  49
# xpr0089   Desboeufs, Henri Quentin   architecte            1  71
# xpr0065   Danjan, Pierre Alexandre   architecte            1  54
# xpr0200             Mouchet, André entrepreneur            2
# xpr0026          Bleve, Jean Louis   architecte            2  49
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      6
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# De Vonges, Michel ; entrepreneur ; 8 expertises ; 1 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                   name       column  totalCollab age
# xpr0003     Angot, Jean Pierre entrepreneur            1  37
# xpr0102        Ducret, Nicolas   architecte            1  49
# xpr0250      Taboureur, Pierre   architecte            1  40
# xpr0143   Jacob, Jean François entrepreneur            1  41
# xpr0191   Martin, Pierre Henry   architecte            1  62
# xpr0254 Thevenin, Jacques-Jean entrepreneur            1
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      2
#            Estimer la valeur des biens      3
# Décrire et évaluer les travaux à venir      1
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# Delespine, Louis Jules ; architecte ; 36 expertises ; 0 expertises en tant que tiers-expert ; 8 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0089 Desboeufs, Henri Quentin   architecte            1  71
# xpr0102          Ducret, Nicolas   architecte            1  49
# xpr0005   Antoine, Jacques Denis entrepreneur            1  43
# xpr0250        Taboureur, Pierre   architecte            2  40
# xpr0065 Danjan, Pierre Alexandre   architecte            3  54
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      5
#            Estimer la valeur des biens     15
# Décrire et évaluer les travaux à venir      6
#                             Départager      4
#                            Enregistrer      2
#
#
#
#
# Desboeufs, Henri Quentin ; architecte ; 34 expertises ; 1 expertises en tant que tiers-expert ; 23 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                            name       column  totalCollab age
# xpr0067        Dauphin, Antoine Nicolas   architecte            1  63
# xpr0252           Terrier, Martin Marie   architecte            1  48
# xpr0070      De Besse, Claude Guillaume   architecte            1  42
# xpr0122            Giraud, Pierre Marie   architecte            1  42
# xpr0209          Payen, Jacques Antoine   architecte            1  66
# xpr0205 Parvy De La Renaudiere, Nicolas entrepreneur            1  42
# xpr0085          Delespine, Louis Jules   architecte            1  50
# xpr0026               Bleve, Jean Louis   architecte            1  49
# xpr0254          Thevenin, Jacques-Jean entrepreneur            1
# xpr0081     De Villers, Eustache Robert   architecte            1  56
# xpr0210        Perrard, Nicolas Antoine entrepreneur            2  70
# xpr0106             Egresset, Guillaume entrepreneur            2  65
# xpr0261              Villetard, Etienne entrepreneur            2  50
# xpr0102                 Ducret, Nicolas   architecte            3  49
# xpr0104            Dumont, Jean Charles entrepreneur            3  48
# xpr0250               Taboureur, Pierre   architecte            4  40
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      7
#            Estimer la valeur des biens      8
# Décrire et évaluer les travaux à venir      9
#                             Départager      8
#                            Enregistrer      2
#
#
#
#
# Desmaisons, Jacques François ; entrepreneur ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0210 Perrard, Nicolas Antoine entrepreneur            1  70
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Dosmond, Léonard Pierre ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id               name       column  totalCollab age
# xpr0261 Villetard, Etienne entrepreneur            1  50
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Duboiscerf, Sébastien Jean ; entrepreneur ; 26 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name     column  totalCollab age
# xpr0070 De Besse, Claude Guillaume architecte            1  42
# xpr0250          Taboureur, Pierre architecte            2  40
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      3
#            Estimer la valeur des biens     12
# Décrire et évaluer les travaux à venir      7
#                             Départager      3
#                            Enregistrer      0
#
#
#
#
# Ducret, Nicolas ; architecte ; 34 expertises ; 0 expertises en tant que tiers-expert ; 21 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                         name       column  totalCollab age
# xpr0209       Payen, Jacques Antoine   architecte            1  66
# xpr0200               Mouchet, André entrepreneur            1
# xpr0155     Lardant, Pierre François entrepreneur            1  45
# xpr0082            De Vonges, Michel entrepreneur            1  62
# xpr0085       Delespine, Louis Jules   architecte            1  50
# xpr0143         Jacob, Jean François entrepreneur            1  41
# xpr0022 Billard de Bellisard, Claude   architecte            1  38
# xpr0081  De Villers, Eustache Robert   architecte            1  56
# xpr0247          Simon, René Auguste entrepreneur            1  64
# xpr0104         Dumont, Jean Charles entrepreneur            2  48
# xpr0210     Perrard, Nicolas Antoine entrepreneur            2  70
# xpr0089     Desboeufs, Henri Quentin   architecte            3  71
# xpr0250            Taboureur, Pierre   architecte            3  40
# xpr0070   De Besse, Claude Guillaume   architecte            3  42
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé     16
#            Estimer la valeur des biens      9
# Décrire et évaluer les travaux à venir      3
#                             Départager      5
#                            Enregistrer      0
#
#
#
#
# Dumont, Jean Charles ; entrepreneur ; 42 expertises ; 2 expertises en tant que tiers-expert ; 31 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                  name       column  totalCollab age
# xpr0209                Payen, Jacques Antoine   architecte            1  66
# xpr0039                     Bourgeois, Pierre entrepreneur            1
# xpr0003                    Angot, Jean Pierre entrepreneur            1  37
# xpr0004                      Antoine, Antoine   architecte            1  30
# xpr0055                Clavareau, Jean Pierre   architecte            1  55
# xpr0143                  Jacob, Jean François entrepreneur            1  41
# xpr0031                  Bouchu, Paul Antoine   architecte            1  36
# xpr0226                Porquet, Claude Joseph   architecte            1  54
# xpr0258 Vavasseur Desperriers, Louis Athanase entrepreneur            1  34
# xpr0026                     Bleve, Jean Louis   architecte            1  49
# xpr0102                       Ducret, Nicolas   architecte            2  49
# xpr0106                   Egresset, Guillaume entrepreneur            2  65
# xpr0060            Coupard Delatouche, Pierre entrepreneur            2  60
# xpr0210              Perrard, Nicolas Antoine entrepreneur            2  70
# xpr0024                   Blanchard, Jean-Luc   architecte            2
# xpr0089              Desboeufs, Henri Quentin   architecte            3  71
# xpr0070            De Besse, Claude Guillaume   architecte            6  42
# xpr0250                     Taboureur, Pierre   architecte            7  40
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé     19
#            Estimer la valeur des biens      7
# Décrire et évaluer les travaux à venir      2
#                             Départager      8
#                            Enregistrer      3
#
#
#
#
# Egresset, Guillaume ; entrepreneur ; 9 expertises ; 1 expertises en tant que tiers-expert ; 7 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0209     Payen, Jacques Antoine   architecte            1  66
# xpr0210   Perrard, Nicolas Antoine entrepreneur            1  70
# xpr0039          Bourgeois, Pierre entrepreneur            1
# xpr0060 Coupard Delatouche, Pierre entrepreneur            1  60
# xpr0114 Gabriel, Nicolas Toussaint   architecte            1  37
# xpr0104       Dumont, Jean Charles entrepreneur            2  48
# xpr0089   Desboeufs, Henri Quentin   architecte            2  71
# xpr0250          Taboureur, Pierre   architecte            2  40
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      4
# Décrire et évaluer les travaux à venir      0
#                             Départager      5
#                            Enregistrer      0
#
#
#
#
# Gabriel, Nicolas Toussaint ; architecte ; 3 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                name       column  totalCollab age
# xpr0106 Egresset, Guillaume entrepreneur            1  65
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      2
# Décrire et évaluer les travaux à venir      0
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Giraud, Pierre Marie ; architecte ; 5 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0247      Simon, René Auguste entrepreneur            1  64
# xpr0089 Desboeufs, Henri Quentin   architecte            1  71
# xpr0200           Mouchet, André entrepreneur            2
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#            Estimer la valeur des biens      2
# Décrire et évaluer les travaux à venir      1
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Goupy Ii, Martin ; architecte ; 5 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                          name     column  totalCollab age
# xpr0043 Le Camus de Mézières, Nicolas architecte            1  51
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      2
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      2
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Jacob, Jean François ; entrepreneur ; 11 expertises ; 0 expertises en tant que tiers-expert ; 8 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0210   Perrard, Nicolas Antoine entrepreneur            1  70
# xpr0104       Dumont, Jean Charles entrepreneur            1  48
# xpr0082          De Vonges, Michel entrepreneur            1  62
# xpr0102            Ducret, Nicolas   architecte            1  49
# xpr0070 De Besse, Claude Guillaume   architecte            2  42
# xpr0250          Taboureur, Pierre   architecte            3  40
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      8
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      3
#                            Enregistrer      0
#
#
#
#
# Lardant, Pierre François ; entrepreneur ; 7 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id              name     column  totalCollab age
# xpr0026 Bleve, Jean Louis architecte            1  49
# xpr0102   Ducret, Nicolas architecte            1  49
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      2
#            Estimer la valeur des biens      3
# Décrire et évaluer les travaux à venir      1
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Le Foulon, Guillaume Elie ; entrepreneur ; 9 expertises ; 0 expertises en tant que tiers-expert ; 6 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                  name       column  totalCollab age
# xpr0043         Le Camus de Mézières, Nicolas   architecte            1  51
# xpr0070            De Besse, Claude Guillaume   architecte            1  42
# xpr0002                  André, Jean Baptiste   architecte            1  41
# xpr0258 Vavasseur Desperriers, Louis Athanase entrepreneur            1  34
# xpr0250                     Taboureur, Pierre   architecte            2  40
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      6
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      2
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Martin, Pierre Henry ; architecte ; 2 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0070 De Besse, Claude Guillaume   architecte            1  42
# xpr0082          De Vonges, Michel entrepreneur            1  62
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# Mouchet, André ; entrepreneur ; 20 expertises ; 1 expertises en tant que tiers-expert ; 14 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                        name       column  totalCollab age
# xpr0065    Danjan, Pierre Alexandre   architecte            1  54
# xpr0247         Simon, René Auguste entrepreneur            1  64
# xpr0102             Ducret, Nicolas   architecte            1  49
# xpr0261          Villetard, Etienne entrepreneur            1  50
# xpr0081 De Villers, Eustache Robert   architecte            2  56
# xpr0210    Perrard, Nicolas Antoine entrepreneur            2  70
# xpr0122        Giraud, Pierre Marie   architecte            2  42
# xpr0250           Taboureur, Pierre   architecte            2  40
# xpr0070  De Besse, Claude Guillaume   architecte            3  42
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      9
#            Estimer la valeur des biens      6
# Décrire et évaluer les travaux à venir      2
#                             Départager      3
#                            Enregistrer      0
#
#
#
#
# Neveu, Michel ; entrepreneur ; 1 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Parvy De La Renaudiere, Nicolas ; entrepreneur ; 6 expertises ; 0 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                  name       column  totalCollab age
# xpr0258 Vavasseur Desperriers, Louis Athanase entrepreneur            1  34
# xpr0228        Poulain, Jean Baptiste Martial   architecte            1  41
# xpr0089              Desboeufs, Henri Quentin   architecte            1  71
# xpr0250                     Taboureur, Pierre   architecte            2  40
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#            Estimer la valeur des biens      3
# Décrire et évaluer les travaux à venir      0
#                             Départager      1
#                            Enregistrer      1
#
#
#
#
# Paulick, Jean Nepomucene ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Payen, Jacques Antoine ; architecte ; 23 expertises ; 1 expertises en tant que tiers-expert ; 11 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                          name       column  totalCollab age
# xpr0104          Dumont, Jean Charles entrepreneur            1  48
# xpr0210      Perrard, Nicolas Antoine entrepreneur            1  70
# xpr0106           Egresset, Guillaume entrepreneur            1  65
# xpr0043 Le Camus de Mézières, Nicolas   architecte            1  51
# xpr0102               Ducret, Nicolas   architecte            1  49
# xpr0089      Desboeufs, Henri Quentin   architecte            1  71
# xpr0070    De Besse, Claude Guillaume   architecte            1  42
# xpr0261            Villetard, Etienne entrepreneur            1  50
# xpr0054    Chauveau, René Bonaventure entrepreneur            1  83
# xpr0250             Taboureur, Pierre   architecte            4  40
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      6
#            Estimer la valeur des biens     11
# Décrire et évaluer les travaux à venir      2
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# Perrard, Nicolas Antoine ; entrepreneur ; 46 expertises ; 0 expertises en tant que tiers-expert ; 31 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                             name       column  totalCollab age
# xpr0092     Desmaisons, Jacques François entrepreneur            1  61
# xpr0043    Le Camus de Mézières, Nicolas   architecte            1  51
# xpr0047                 Caque, Guillaume entrepreneur            1
# xpr0209           Payen, Jacques Antoine   architecte            1  66
# xpr0106              Egresset, Guillaume entrepreneur            1  65
# xpr0143             Jacob, Jean François entrepreneur            1  41
# xpr0024              Blanchard, Jean-Luc   architecte            1
# xpr0031             Bouchu, Paul Antoine   architecte            1  36
# xpr0004                 Antoine, Antoine   architecte            1  30
# xpr0216      Petit Radel, Louis François   architecte            1  36
# xpr0065         Danjan, Pierre Alexandre   architecte            1  54
# xpr0089         Desboeufs, Henri Quentin   architecte            2  71
# xpr0200                   Mouchet, André entrepreneur            2
# xpr0102                  Ducret, Nicolas   architecte            2  49
# xpr0104             Dumont, Jean Charles entrepreneur            2  48
# xpr0228   Poulain, Jean Baptiste Martial   architecte            2  41
# xpr0229 Pruneau De Montlouis, Jean Louis   architecte            2  53
# xpr0070       De Besse, Claude Guillaume   architecte            4  42
# xpr0250                Taboureur, Pierre   architecte            7  40
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé     11
#            Estimer la valeur des biens     11
# Décrire et évaluer les travaux à venir      5
#                             Départager     17
#                            Enregistrer      1
#
#
#
#
# Petit Radel, Louis François ; architecte ; 2 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0026        Bleve, Jean Louis   architecte            1  49
# xpr0210 Perrard, Nicolas Antoine entrepreneur            1  70
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Porquet, Claude Joseph ; architecte ; 3 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                 name       column  totalCollab age
# xpr0104 Dumont, Jean Charles entrepreneur            1  48
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      2
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Poulain, Jean Baptiste Martial ; architecte ; 13 expertises ; 0 expertises en tant que tiers-expert ; 7 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                            name       column  totalCollab age
# xpr0250               Taboureur, Pierre   architecte            1  40
# xpr0261              Villetard, Etienne entrepreneur            1  50
# xpr0205 Parvy De La Renaudiere, Nicolas entrepreneur            1  42
# xpr0247             Simon, René Auguste entrepreneur            1  64
# xpr0070      De Besse, Claude Guillaume   architecte            2  42
# xpr0210        Perrard, Nicolas Antoine entrepreneur            2  70
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      4
#            Estimer la valeur des biens      3
# Décrire et évaluer les travaux à venir      1
#                             Départager      3
#                            Enregistrer      0
#
#
#
#
# Pruneau De Montlouis, Jean Louis ; architecte ; 10 expertises ; 0 expertises en tant que tiers-expert ; 6 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                          name       column  totalCollab age
# xpr0070    De Besse, Claude Guillaume   architecte            1  42
# xpr0261            Villetard, Etienne entrepreneur            1  50
# xpr0026             Bleve, Jean Louis   architecte            1  49
# xpr0043 Le Camus de Mézières, Nicolas   architecte            1  51
# xpr0210      Perrard, Nicolas Antoine entrepreneur            2  70
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#            Estimer la valeur des biens      3
# Décrire et évaluer les travaux à venir      2
#                             Départager      4
#                            Enregistrer      0
#
#
#
#
# Puisieux, Jean Baptiste ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Quirot, Denis ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Regnard De Barentin, Bernard Jean Baptiste ; entrepreneur ; 3 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                   name       column  totalCollab age
# xpr0254 Thevenin, Jacques-Jean entrepreneur            1
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#            Estimer la valeur des biens      2
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Richard, Pierre Louis ; entrepreneur ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Simon, René Auguste ; entrepreneur ; 5 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                           name       column  totalCollab age
# xpr0122           Giraud, Pierre Marie   architecte            1  42
# xpr0200                 Mouchet, André entrepreneur            1
# xpr0228 Poulain, Jean Baptiste Martial   architecte            1  41
# xpr0102                Ducret, Nicolas   architecte            1  49
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      2
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      2
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Taboureur, Pierre ; architecte ; 367 expertises ; 3 expertises en tant que tiers-expert ; 71 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                  name       column  totalCollab age
# xpr0038              Bourgeois, Louis Silvain entrepreneur            1  40
# xpr0228        Poulain, Jean Baptiste Martial   architecte            1  41
# xpr0276                Gilbert, Louis (? - ?)   architecte            1
# xpr0033       Boullant, Jean Baptiste Vincent   architecte            1  37
# xpr0050               Chasteau, Jean François entrepreneur            1  42
# xpr0082                     De Vonges, Michel entrepreneur            1  62
# xpr0047                      Caque, Guillaume entrepreneur            1
# xpr0024                   Blanchard, Jean-Luc   architecte            1
# xpr0031                  Bouchu, Paul Antoine   architecte            1  36
# xpr0254                Thevenin, Jacques-Jean entrepreneur            1
# xpr0043         Le Camus de Mézières, Nicolas   architecte            1  51
# xpr0081           De Villers, Eustache Robert   architecte            1  56
# xpr0065              Danjan, Pierre Alexandre   architecte            1  54
# xpr0002                  André, Jean Baptiste   architecte            1  41
# xpr0258 Vavasseur Desperriers, Louis Athanase entrepreneur            2  34
# xpr0163             Le Foulon, Guillaume Elie entrepreneur            2  49
# xpr0085                Delespine, Louis Jules   architecte            2  50
# xpr0055                Clavareau, Jean Pierre   architecte            2  55
# xpr0205       Parvy De La Renaudiere, Nicolas entrepreneur            2  42
# xpr0106                   Egresset, Guillaume entrepreneur            2  65
# xpr0003                    Angot, Jean Pierre entrepreneur            2  37
# xpr0200                        Mouchet, André entrepreneur            2
# xpr0101            Duboiscerf, Sébastien Jean entrepreneur            2  63
# xpr0102                       Ducret, Nicolas   architecte            3  49
# xpr0143                  Jacob, Jean François entrepreneur            3  41
# xpr0261                    Villetard, Etienne entrepreneur            3  50
# xpr0089              Desboeufs, Henri Quentin   architecte            4  71
# xpr0209                Payen, Jacques Antoine   architecte            4  66
# xpr0070            De Besse, Claude Guillaume   architecte            6  42
# xpr0026                     Bleve, Jean Louis   architecte            6  49
# xpr0104                  Dumont, Jean Charles entrepreneur            7  48
# xpr0210              Perrard, Nicolas Antoine entrepreneur            7  70
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé     98
#            Estimer la valeur des biens    112
# Décrire et évaluer les travaux à venir     79
#                             Départager     40
#                            Enregistrer     27
#
#
#
#
# Terrier, Martin Marie ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name     column  totalCollab age
# xpr0089 Desboeufs, Henri Quentin architecte            1  71
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Thevenin, Jacques-Jean ; entrepreneur ; 11 expertises ; 0 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                       name       column  totalCollab age
# xpr0070                 De Besse, Claude Guillaume   architecte            1  42
# xpr0235 Regnard De Barentin, Bernard Jean Baptiste entrepreneur            1  37
# xpr0250                          Taboureur, Pierre   architecte            1  40
# xpr0082                          De Vonges, Michel entrepreneur            1  62
# xpr0089                   Desboeufs, Henri Quentin   architecte            1  71
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      4
#            Estimer la valeur des biens      4
# Décrire et évaluer les travaux à venir      0
#                             Départager      3
#                            Enregistrer      0
#
#
#
#
# Vavasseur Desperriers, Louis Athanase ; entrepreneur ; 9 expertises ; 0 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                            name       column  totalCollab age
# xpr0205 Parvy De La Renaudiere, Nicolas entrepreneur            1  42
# xpr0104            Dumont, Jean Charles entrepreneur            1  48
# xpr0163       Le Foulon, Guillaume Elie entrepreneur            1  49
# xpr0250               Taboureur, Pierre   architecte            2  40
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#            Estimer la valeur des biens      3
# Décrire et évaluer les travaux à venir      3
#                             Départager      0
#                            Enregistrer      2
#
#
#
#
# Vedy, Julien ; entrepreneur ; 3 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                          name     column  totalCollab age
# xpr0043 Le Camus de Mézières, Nicolas architecte            1  51
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      3
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Villetard, Etienne ; entrepreneur ; 13 expertises ; 0 expertises en tant que tiers-expert ; 10 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                             name       column  totalCollab age
# xpr0026                Bleve, Jean Louis   architecte            1  49
# xpr0228   Poulain, Jean Baptiste Martial   architecte            1  41
# xpr0209           Payen, Jacques Antoine   architecte            1  66
# xpr0229 Pruneau De Montlouis, Jean Louis   architecte            1  53
# xpr0200                   Mouchet, André entrepreneur            1
# xpr0095          Dosmond, Léonard Pierre   architecte            1  25
# xpr0089         Desboeufs, Henri Quentin   architecte            2  71
# xpr0250                Taboureur, Pierre   architecte            3  40
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      5
#            Estimer la valeur des biens      4
# Décrire et évaluer les travaux à venir      1
#                             Départager      3
#                            Enregistrer      0
#
#
#
#
# Leleu, Antoine André (? - ?) ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                   name     column  totalCollab age
# xpr0269 Dubois, Alexis (? - ?) architecte            1
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Dubois, Alexis (? - ?) ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                         name     column  totalCollab age
# xpr0268 Leleu, Antoine André (? - ?) architecte            1
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Poupée ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                    name       column  totalCollab age
# xpr0050 Chasteau, Jean François entrepreneur            1  42
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      1
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Lefort, François (? - ?) ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Gilbert, Louis (? - ?) ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id              name     column  totalCollab age
# xpr0250 Taboureur, Pierre architecte            1  40
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      1
#                             Départager      0
#                            Enregistrer      0
