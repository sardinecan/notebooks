# %% [markdown]
# # xprStats

# %%
# lib
from urllib.request import urlopen
import json  
import pandas as pd

# %%
# Récupération des donnée 
# param (date or thirdParty)
param = "1766"

# url
url = "https://experts.huma-num.fr/xpr/statistics/" + param

# enregistrement de la réponse
response = urlopen(url)

# lecture du json
data = json.loads(response.read())
  
# print the json response
#print(data)

# %% [markdown]
# ## Expertises

# %%
expertises = data['expertises']

# %%
print("Nombre total d'expertises : " + str(expertises['total']))
# Out:
# Nombre total d'expertises : 438

# %% [markdown]
# ### Croquis

# %%
sketchesDF = pd.json_normalize(expertises['sketches'])
print(sketchesDF.to_string(index=False))
# Out:
#  expertisesWithoutSketch  expertisesWithSketch
#                      438                     0

# %% [markdown]
# ### Étendue

# %%
extent = expertises['extent']
#print(extent)

print('Nombre de feuillets : ' + str(extent['total']))

print('Moyenne par expertise : ' + str(extent['averageByExpertise']))

#Distribution
print('Distribution :')
keys = []
values = []
for dic in extent['extentDistribution']:
    for key, val in dic.items():
        keys.append(key),
        values.append(val)        

extentDistributionDict = {'nombre de feuillets': keys, 'nombre d’expertises': values,} 
print(pd.DataFrame(extentDistributionDict).to_string(index=False))
# Out:
# Nombre de feuillets : 4546
# Moyenne par expertise : 10.38
# Distribution :
# nombre de feuillets  nombre d’expertises
#                   5                  180
#                  10                  152
#                  15                   43
#                  20                   25
#                  25                   15
#                  30                    2
#                  35                    4
#                  40                    1
#                  45                    2
#                  50                    2
#                  55                    3
#                  60                    1
#                  65                    1
#                  70                    0
#                  75                    0
#                  80                    0
#                  85                    3
#                  90                    1
#                  95                    0
#                 100                    3

# %% [markdown]
# ### Annexes

# %%
appendices = expertises['appendices']
#print(appendices)

print(f"{appendices['total']} annexes")


print(f"{appendices['expertisesWithAppendices']} expertises avec annexes ; {appendices['expertisesWithoutAppendices']} expertises sans annexes")


df=pd.json_normalize(appendices['types'])
print(df.to_string(columns=['label', 'total', 'expertises'], index=False))
# Out:
# 330 annexes
# 197 expertises avec annexes ; 241 expertises sans annexes
#                                       label  total  expertises
#                                       Autre    104          69
# Pouvoir/procuration (acte sous seing privé)     74          59
#                                     Requête     46          44
#                                     Croquis     13          10
#                                   Brouillon      4           3
#                      Plan, coupe, élévation     70          45
#          Pouvoir/procuration (acte notarié)     10           8
#                                      Dessin      9           8

# %% [markdown]
# ### Vacations

# %%
sessions = expertises['sessions']
#print(sessions)

print(f"{sessions['total']} vacations")


print(f"en moyenne {sessions['averageByExpertise']} vacations par expertise")
# Out:
# 1891 vacations
# en moyenne 4.32 vacations par expertise

# %% [markdown]
# Nombre de vacation par lieu

# %%
sessionsDf=pd.json_normalize(sessions['places'])
print(sessionsDf.to_string(columns=['label', 'total'], index=False))
# Out:
#    label  total
#    Paris   1483
# Banlieue    163
# Province    243

# %% [markdown]
# ### Durée

# %%
duration = expertises['duration']
#print(duration)

# %% [markdown]
# #### Jours

# %%
#Distribution
durationDays = duration['days']
#print(durationDays)
print('Distribution :')
keys = []
values = []
for dic in durationDays['distributionByDays']:
    for key, val in dic.items():
        keys.append(key),
        values.append(val)        

durationDaysDf = {'nombre de jours': keys, 'nombre d’expertises': values,} 
print(pd.DataFrame(durationDaysDf).to_string(index=False))
# Out:
# Distribution :
# nombre de jours  nombre d’expertises
#               5                  228
#              10                   39
#              15                   25
#              20                   16
#              25                   10
#              30                   15
#              35                   10
#              40                    5
#              45                    7
#              50                    5
#              55                    8
#              60                    1
#              65                    4
#              70                    3
#              75                    0
#              80                    4
#              85                    2
#              90                    0
#              95                    1
#             100                   50

# %% [markdown]
# #### Vacations

# %%
#Distribution
durationSessions = duration['sessions']
#print(durationDays)
print(f"{durationSessions['total']} vacations, soit en moyenne {durationSessions['averageByExpertise']} vacations par expertise.")
# Out:
# 1891 vacations, soit en moyenne 2.16 vacations par expertise.

# %% [markdown]
# ### Lieux

# %%
places = expertises['places']
#print(places)

placesDf=pd.json_normalize(places)
print(placesDf.to_string(columns=['place', 'total'], index=False))
# Out:
#                        place  total
#                      [paris]    302
#                    [suburbs]     45
#                   [province]     65
#           [[paris, suburbs]]      7
#          [[paris, province]]     17
#        [[suburbs, province]]      0
# [[paris, suburbs, province]]      0

# %% [markdown]
# ### Procédures et cadres

# %%
frameworks = expertises['frameworks']
#print(frameworks)

frameworksDf=pd.json_normalize(frameworks)
print(frameworksDf.to_string(columns=['label', 'framework', 'total'], index=False))
# Out:
#                                                                                                                   label framework  total
# L’institution est saisie dans le cadre d’une procédure (les parties nomment chacune leur expert ou un expert en commun)       b2a    106
# L’institution est saisie dans le cadre d’une procédure (les parties nomment chacune leur expert ou un expert en commun)        b2    180
#                                                                                               Commun accord des parties         a     71
#                                                     Requête auprès d’une institution pour qu’elle demande une expertise        b1     27
#                                                                                                       Cas problématique         c      3
#                         L’institution est saisie dans le cadre d’une procédure (l’institution nomme un ou deux experts)       b2b     41
#                                          Saisie mixte (un expert est nommé par les parties, l'autre est nommé d'office)        b3      8
#                                                                                                                                        2

# %% [markdown]
# ### Catégories

# %%
categories = expertises['categories']

for cat in categories:
    if cat['total'] != 0: print(f"{cat['label']} : {cat['total']} expertises"),
    for framework in cat['frameworks']:
        if framework['total'] != 0: print(f"\t{framework['framework']} : {framework['total']} expertises"),
        for place in framework['places']:
            if place['total'] != 0: print(f"\t\t{place['place']} : {place['total']}"),
            for obj in place['objects']:
                if obj['total'] != 0: print(f"\t\t\t{obj['label']} : {obj['total']}")
        print('\n')
    print('\n')
# Out:
# Estimer la valeur des biens : 152 expertises
# 	b2a : 53 expertises
# 		['paris'] : 25
# 			Maison(s) : 24
# 			Terrain(s) : 1
# 		['suburbs'] : 6
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 6
# 		['province'] : 17
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 14
# 			Terrain(s) : 2
# 			Ensemble de bâtiments (biens immeubles) : 1
# 			Domaine, terres, fief : 5
# 		[['paris', 'suburbs']] : 2
# 			Maison(s) : 1
# 		[['paris', 'province']] : 3
# 			Maison(s) : 3
# 			Domaine, terres, fief : 1
#
#
# 	b2 : 60 expertises
# 		['paris'] : 43
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 41
# 			Terrain(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
# 			Domaine, terres, fief : 1
# 		['suburbs'] : 9
# 			Maison(s) : 9
# 		['province'] : 5
# 			Maison(s) : 5
# 			Terrain(s) : 1
# 			Domaine, terres, fief : 1
# 		[['paris', 'province']] : 3
# 			Maison(s) : 2
# 			Domaine, terres, fief : 1
#
#
# 	a : 9 expertises
# 		['paris'] : 8
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 7
# 		[['paris', 'suburbs']] : 1
# 			Maison(s) : 1
#
#
# 	b1 : 5 expertises
# 		['paris'] : 4
# 			Maison(s) : 4
# 		[['paris', 'province']] : 1
# 			Maison(s) : 1
#
#
# 	c : 1 expertises
# 		['suburbs'] : 1
# 			Maison(s) : 1
#
#
# 	b2b : 24 expertises
# 		['paris'] : 14
# 			Maison(s) : 13
# 			Terrain(s) : 1
# 			Domaine, terres, fief : 1
# 		['suburbs'] : 3
# 			Maison(s) : 2
# 			Terrain(s) : 1
# 		['province'] : 6
# 			Maison(s) : 4
# 			Ensemble de bâtiments (biens immeubles) : 1
# 			Domaine, terres, fief : 2
# 		[['paris', 'province']] : 1
# 			Maison(s) : 1
# 			Domaine, terres, fief : 1
#
#
#
#
#
#
#
#
# Recevoir et évaluer le travail réalisé : 127 expertises
# 	b2a : 24 expertises
# 		['paris'] : 10
# 			Ouvrages de maçonnerie : 7
# 			Maison(s) : 7
# 		['suburbs'] : 5
# 			Ouvrages de maçonnerie : 4
# 			Maison(s) : 2
# 		['province'] : 5
# 			Ouvrages de maçonnerie : 4
# 			Maison(s) : 2
# 		[['paris', 'province']] : 4
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 2
# 			Ensemble de bâtiments (biens immeubles) : 1
#
#
# 	b2 : 54 expertises
# 		['paris'] : 44
# 			Ouvrages de maçonnerie : 36
# 			Maison(s) : 9
# 		['suburbs'] : 5
# 			Ouvrages de maçonnerie : 4
# 			Maison(s) : 1
# 		[['paris', 'suburbs']] : 2
# 			Ouvrages de maçonnerie : 1
# 			Mur(s) : 1
# 		[['paris', 'province']] : 2
# 			Ouvrages de maçonnerie : 2
#
#
# 	a : 37 expertises
# 		['paris'] : 32
# 			Ouvrages de maçonnerie : 13
# 			Maison(s) : 21
# 			Mur(s) : 1
# 			Domaine, terres, fief : 1
# 		['suburbs'] : 1
# 			Maison(s) : 1
# 		['province'] : 2
# 			Ouvrages de maçonnerie : 2
# 		[['paris', 'suburbs']] : 1
# 			Maison(s) : 1
# 		[['paris', 'province']] : 1
# 			Maison(s) : 1
#
#
# 	b1 : 3 expertises
# 		['paris'] : 2
# 			Maison(s) : 2
# 		['suburbs'] : 1
# 			Maison(s) : 1
#
#
#
#
# 	b2b : 4 expertises
# 		['paris'] : 3
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 2
# 		['province'] : 1
# 			Maison(s) : 1
#
#
# 	b3 : 4 expertises
# 		['paris'] : 2
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 2
# 		['suburbs'] : 1
# 			Maison(s) : 1
# 		['province'] : 1
# 			Maison(s) : 1
#
#
# 	 : 1 expertises
# 		['paris'] : 1
# 			Maison(s) : 1
#
#
#
#
# Décrire et évaluer les travaux à venir : 54 expertises
# 	b2a : 11 expertises
# 		['paris'] : 9
# 			Maison(s) : 8
# 			Fosse(s) d'aisance : 1
# 		['province'] : 1
# 			Ouvrages de maçonnerie : 1
# 		[['paris', 'province']] : 1
# 			Maison(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
# 			Domaine, terres, fief : 1
#
#
# 	b2 : 24 expertises
# 		['paris'] : 16
# 			Ouvrages de maçonnerie : 3
# 			Maison(s) : 11
# 			Mur(s) : 1
# 			Fosse(s) d'aisance : 1
# 			Puits : 1
# 		['suburbs'] : 2
# 			Maison(s) : 2
# 		['province'] : 5
# 			Maison(s) : 3
# 			Domaine, terres, fief : 2
#
#
# 	a : 1 expertises
# 		['province'] : 1
# 			Domaine, terres, fief : 1
#
#
# 	b1 : 9 expertises
# 		['paris'] : 7
# 			Maison(s) : 7
# 			Mur(s) : 1
# 		['suburbs'] : 1
# 			Maison(s) : 1
# 			Terrain(s) : 1
# 		['province'] : 1
# 			Maison(s) : 1
#
#
# 	c : 2 expertises
# 		['paris'] : 1
# 			Mur(s) : 1
# 		['suburbs'] : 1
# 			Maison(s) : 1
#
#
# 	b2b : 5 expertises
# 		['paris'] : 2
# 			Maison(s) : 2
# 		['suburbs'] : 1
# 			Maison(s) : 1
# 		['province'] : 2
# 			Maison(s) : 1
# 			Puits : 1
#
#
# 	b3 : 2 expertises
# 		['province'] : 2
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
#
#
#
#
#
#
# Départager : 63 expertises
# 	b2a : 15 expertises
# 		['paris'] : 15
# 			Ouvrages de maçonnerie : 5
# 			Maison(s) : 2
# 			Mur(s) : 8
# 			Fosse(s) d'aisance : 1
# 			Puits : 1
#
#
# 	b2 : 19 expertises
# 		['paris'] : 13
# 			Ouvrages de maçonnerie : 4
# 			Maison(s) : 5
# 			Terrain(s) : 1
# 			Mur(s) : 2
# 			Fosse(s) d'aisance : 2
# 		['suburbs'] : 2
# 			Ouvrages de maçonnerie : 1
# 			Terrain(s) : 2
# 		['province'] : 3
# 			Maison(s) : 3
# 		[['paris', 'suburbs']] : 1
# 			Terrain(s) : 1
#
#
# 	a : 23 expertises
# 		['paris'] : 21
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 2
# 			Terrain(s) : 2
# 			Mur(s) : 16
# 			Domaine, terres, fief : 1
# 		['suburbs'] : 2
# 			Mur(s) : 2
#
#
#
#
#
#
# 	b2b : 4 expertises
# 		['paris'] : 2
# 			Ouvrages de maçonnerie : 1
# 			Mur(s) : 1
# 		['suburbs'] : 1
# 			Maison(s) : 1
# 		['province'] : 1
# 			Mur(s) : 1
#
#
# 	b3 : 2 expertises
# 		['paris'] : 2
# 			Mur(s) : 2
#
#
#
#
#
#
# Enregistrer : 1 expertises
#
#
#
#
# 	a : 1 expertises
# 		['province'] : 1
# 			Ouvrages de maçonnerie : 1

# %% [markdown]
# ### Tiers expertises

# %%
thirdParty = expertises['thirdParty']

# %%
thirdPartyDf=pd.json_normalize(thirdParty)
print(thirdPartyDf.to_string(columns=['architectes', 'entrepreneurs', 'total'], index=False))
# Out:
#  architectes  entrepreneurs  total
#            9              5     14

# %% [markdown]
# ### Distribution (hors tiers expertises)

# %%
columnDistrib = expertises['experts']

for column in columnDistrib:
    print(f"{column['totalExperts']} expert(s) : {column['totalExpertises']} expertises"),
    if column['totalExperts']<3: print(pd.json_normalize(column['distribution']).to_string(columns=['label', 'total'], index=False))
    print('\n')
# Out:
# 1 expert(s) : 287 expertises
#        label  total
#   architecte    154
# entrepreneur    133
#
#
# 2 expert(s) : 132 expertises
#                       label  total
#     architecte - architecte     38
#   entrepreneur - architecte     65
# entrepreneur - entrepreneur     29
#
#
# 3 expert(s) : 5 expertises

# %% [markdown]
# ## Experts

# %%
experts = data['experts']
#print(experts)

# %%
print(f"Nombre d’experts : {experts['total']}")
print(f"{experts['architects']} architectes")
print(f"{experts['entrepreneur']} entrepreneurs")
print(f"{experts['surveyor']} arpenteurs")
# Out:
# Nombre d’experts : 62
# 33 architectes
# 29 entrepreneurs
# 0 arpenteurs

# %%
listExperts = experts['list']
listExpertsDf = pd.DataFrame(listExperts)
listExpertsDf.drop('expertises', inplace=True, axis=1)

# %%
print(listExpertsDf.to_string(columns=['id', 'name', 'column', 'age'], index=False))
# Out:
#      id                                   name       column age
# xpr0001             Adhenet, Thomas (1690 - ?)   architecte  76
# xpr0005                 Antoine, Jacques Denis entrepreneur  33
# xpr0006                        Arnoult, Thomas entrepreneur  59
# xpr0010 Babuty, François Antoine (1716 - 1766) entrepreneur  50
# xpr0024                    Blanchard, Jean-Luc   architecte
# xpr0026                      Bleve, Jean Louis   architecte  39
# xpr0032            Bouillette de Chamly, Raoul entrepreneur  32
# xpr0037                 Bourgeois, Louis Denis   architecte
# xpr0038               Bourgeois, Louis Silvain entrepreneur  30
# xpr0039                      Bourgeois, Pierre entrepreneur
# xpr0040                           Bray, Pierre entrepreneur  48
# xpr0042                        Buron, François entrepreneur  35
# xpr0043          Le Camus de Mézières, Nicolas   architecte  41
# xpr0045                          Caque, Pierre entrepreneur  66
# xpr0047                       Caque, Guillaume entrepreneur
# xpr0050                Chasteau, Jean François entrepreneur  32
# xpr0054             Chauveau, René Bonaventure entrepreneur  73
# xpr0055                 Clavareau, Jean Pierre   architecte  45
# xpr0060             Coupard Delatouche, Pierre entrepreneur  50
# xpr0065               Danjan, Pierre Alexandre   architecte  44
# xpr0066                    Danjan, Pierre Paul   architecte  68
# xpr0067               Dauphin, Antoine Nicolas   architecte  53
# xpr0070             De Besse, Claude Guillaume   architecte  32
# xpr0072                 De Bias Aubry, Mathieu   architecte  48
# xpr0079            De Varenne, Claude Estienne entrepreneur  60
# xpr0081            De Villers, Eustache Robert   architecte  46
# xpr0082                      De Vonges, Michel entrepreneur  52
# xpr0085                 Delespine, Louis Jules   architecte  40
# xpr0088            Delvincourt, André François   architecte
# xpr0089               Desboeufs, Henri Quentin   architecte  61
# xpr0091                     Desmaisons, Pierre   architecte  55
# xpr0092           Desmaisons, Jacques François entrepreneur  51
# xpr0096                 Dosmond, Pierre Marcel   architecte  44
# xpr0102                        Ducret, Nicolas   architecte  39
# xpr0104                   Dumont, Jean Charles entrepreneur  38
# xpr0106                    Egresset, Guillaume entrepreneur  55
# xpr0110                 Fortin, Pierre Jacques entrepreneur  37
# xpr0120          Gillet De La Fontaine, Joseph   architecte
# xpr0121                     Giraud, Jean Louis entrepreneur  69
# xpr0122                   Giraud, Pierre Marie   architecte  32
# xpr0129                       Goupy Ii, Martin   architecte  32
# xpr0131                          Grissot, Jean   architecte
# xpr0136                   Guyon, Jean Baptiste   architecte
# xpr0160                       Le Chauve, Brice   architecte
# xpr0184                            Loir, Denis entrepreneur  46
# xpr0191                   Martin, Pierre Henry   architecte  52
# xpr0200                         Mouchet, André entrepreneur
# xpr0206               Paulick, Jean Nepomucene   architecte
# xpr0209                 Payen, Jacques Antoine   architecte  56
# xpr0210               Perrard, Nicolas Antoine entrepreneur  60
# xpr0219                           Pinard, Jean entrepreneur  61
# xpr0223           Poirin, Jean Baptiste Michel   architecte  69
# xpr0226                 Porquet, Claude Joseph   architecte  44
# xpr0229       Pruneau De Montlouis, Jean Louis   architecte  43
# xpr0230                Puisieux, Jean Baptiste   architecte  76
# xpr0231                          Quirot, Denis   architecte  58
# xpr0234                Raymond, Etienne Hubert entrepreneur
# xpr0236                  Richard, Pierre Louis entrepreneur  70
# xpr0247                    Simon, René Auguste entrepreneur  54
# xpr0250                      Taboureur, Pierre   architecte  30
# xpr0259                           Vedy, Julien entrepreneur  69
# xpr0261                     Villetard, Etienne entrepreneur  40

# %%
for expert in listExperts:
    print(f"{expert['name']} ; {expert['column']} ; {expert['expertises']['total']} expertises ; {expert['expertises']['thirParty']} expertises en tant que tiers-expert ; {expert['expertises']['collab']['total']} expertises avec d'autres experts (tiers expertises comprises)"),
    print("\n")
    
    collabDF = pd.json_normalize(expert['expertises']['collab']['experts']) 
    if expert['expertises']['collab']['total'] != 0: print(collabDF.to_string(columns=['id', 'name', 'column', 'totalCollab', 'age'], index=False))
    print("\n")
    categoriesDef = pd.json_normalize(expert['expertises']['categories'])
    print(categoriesDef.to_string(columns=['label', 'total'], index=False))

    print("\n")
    print("\n")
# Out:
# Adhenet, Thomas (1690 - ?) ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Antoine, Jacques Denis ; entrepreneur ; 6 expertises ; 0 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0066      Danjan, Pierre Paul   architecte            1  68
# xpr0209   Payen, Jacques Antoine   architecte            1  56
# xpr0219             Pinard, Jean entrepreneur            1  61
# xpr0089 Desboeufs, Henri Quentin   architecte            1  61
# xpr0226   Porquet, Claude Joseph   architecte            1  44
# xpr0210 Perrard, Nicolas Antoine entrepreneur            1  60
#
#
#                                  label  total
#            Estimer la valeur des biens      2
# Recevoir et évaluer le travail réalisé      3
# Décrire et évaluer les travaux à venir      0
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Arnoult, Thomas ; entrepreneur ; 3 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id           name       column  totalCollab age
# xpr0200 Mouchet, André entrepreneur            1
# xpr0045  Caque, Pierre entrepreneur            1  66
#
#
#                                  label  total
#            Estimer la valeur des biens      2
# Recevoir et évaluer le travail réalisé      1
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Babuty, François Antoine (1716 - 1766) ; entrepreneur ; 24 expertises ; 0 expertises en tant que tiers-expert ; 9 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0050  Chasteau, Jean François entrepreneur            1  32
# xpr0219             Pinard, Jean entrepreneur            1  61
# xpr0106      Egresset, Guillaume entrepreneur            1  55
# xpr0209   Payen, Jacques Antoine   architecte            1  56
# xpr0261       Villetard, Etienne entrepreneur            1  40
# xpr0230  Puisieux, Jean Baptiste   architecte            1  76
# xpr0184              Loir, Denis entrepreneur            1  46
# xpr0250        Taboureur, Pierre   architecte            1  30
# xpr0065 Danjan, Pierre Alexandre   architecte            2  44
#
#
#                                  label  total
#            Estimer la valeur des biens      7
# Recevoir et évaluer le travail réalisé     12
# Décrire et évaluer les travaux à venir      0
#                             Départager      3
#                            Enregistrer      1
#
#
#
#
# Blanchard, Jean-Luc ; architecte ; 5 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                   name     column  totalCollab age
# xpr0209 Payen, Jacques Antoine architecte            1  56
# xpr0250      Taboureur, Pierre architecte            1  30
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Recevoir et évaluer le travail réalisé      1
# Décrire et évaluer les travaux à venir      1
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Bleve, Jean Louis ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Bouillette de Chamly, Raoul ; entrepreneur ; 11 expertises ; 1 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                    name       column  totalCollab age
# xpr0200          Mouchet, André entrepreneur            1
# xpr0230 Puisieux, Jean Baptiste   architecte            1  76
#
#
#                                  label  total
#            Estimer la valeur des biens      3
# Recevoir et évaluer le travail réalisé      3
# Décrire et évaluer les travaux à venir      1
#                             Départager      3
#                            Enregistrer      0
#
#
#
#
# Bourgeois, Louis Denis ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                          name     column  totalCollab age
# xpr0120 Gillet De La Fontaine, Joseph architecte            1
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Bourgeois, Louis Silvain ; entrepreneur ; 9 expertises ; 0 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                          name       column  totalCollab age
# xpr0230       Puisieux, Jean Baptiste   architecte            1  76
# xpr0261            Villetard, Etienne entrepreneur            1  40
# xpr0043 Le Camus de Mézières, Nicolas   architecte            1  41
# xpr0104          Dumont, Jean Charles entrepreneur            2  38
#
#
#                                  label  total
#            Estimer la valeur des biens      5
# Recevoir et évaluer le travail réalisé      1
# Décrire et évaluer les travaux à venir      2
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Bourgeois, Pierre ; entrepreneur ; 15 expertises ; 1 expertises en tant que tiers-expert ; 9 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0209     Payen, Jacques Antoine   architecte            1  56
# xpr0047           Caque, Guillaume entrepreneur            1
# xpr0184                Loir, Denis entrepreneur            1  46
# xpr0045              Caque, Pierre entrepreneur            1  66
# xpr0200             Mouchet, André entrepreneur            1
# xpr0230    Puisieux, Jean Baptiste   architecte            1  76
# xpr0261         Villetard, Etienne entrepreneur            1  40
# xpr0070 De Besse, Claude Guillaume   architecte            2  32
#
#
#                                  label  total
#            Estimer la valeur des biens      6
# Recevoir et évaluer le travail réalisé      2
# Décrire et évaluer les travaux à venir      2
#                             Départager      5
#                            Enregistrer      0
#
#
#
#
# Bray, Pierre ; entrepreneur ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Buron, François ; entrepreneur ; 2 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                 name       column  totalCollab age
# xpr0104 Dumont, Jean Charles entrepreneur            1  38
# xpr0200       Mouchet, André entrepreneur            1
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Le Camus de Mézières, Nicolas ; architecte ; 13 expertises ; 0 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                          name       column  totalCollab age
# xpr0120 Gillet De La Fontaine, Joseph   architecte            1
# xpr0038      Bourgeois, Louis Silvain entrepreneur            1  30
# xpr0104          Dumont, Jean Charles entrepreneur            1  38
# xpr0055        Clavareau, Jean Pierre   architecte            1  45
# xpr0230       Puisieux, Jean Baptiste   architecte            1  76
#
#
#                                  label  total
#            Estimer la valeur des biens      8
# Recevoir et évaluer le travail réalisé      1
# Décrire et évaluer les travaux à venir      0
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# Caque, Pierre ; entrepreneur ; 20 expertises ; 1 expertises en tant que tiers-expert ; 8 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0236    Richard, Pierre Louis entrepreneur            1  70
# xpr0219             Pinard, Jean entrepreneur            1  61
# xpr0006          Arnoult, Thomas entrepreneur            1  59
# xpr0200           Mouchet, André entrepreneur            1
# xpr0234  Raymond, Etienne Hubert entrepreneur            1
# xpr0104     Dumont, Jean Charles entrepreneur            1  38
# xpr0039        Bourgeois, Pierre entrepreneur            1
# xpr0089 Desboeufs, Henri Quentin   architecte            4  61
#
#
#                                  label  total
#            Estimer la valeur des biens     10
# Recevoir et évaluer le travail réalisé      5
# Décrire et évaluer les travaux à venir      0
#                             Départager      5
#                            Enregistrer      0
#
#
#
#
# Caque, Guillaume ; entrepreneur ; 4 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                             name       column  totalCollab age
# xpr0039                Bourgeois, Pierre entrepreneur            1
# xpr0229 Pruneau De Montlouis, Jean Louis   architecte            1  43
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      1
# Décrire et évaluer les travaux à venir      1
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Chasteau, Jean François ; entrepreneur ; 3 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                   name       column  totalCollab age
# xpr0010 Babuty, François Antoine (1716 - 1766) entrepreneur            1  50
# xpr0209                 Payen, Jacques Antoine   architecte            1  56
# xpr0106                    Egresset, Guillaume entrepreneur            1  55
# xpr0104                   Dumont, Jean Charles entrepreneur            1  38
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Recevoir et évaluer le travail réalisé      1
# Décrire et évaluer les travaux à venir      0
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Chauveau, René Bonaventure ; entrepreneur ; 9 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0089 Desboeufs, Henri Quentin   architecte            1  61
# xpr0236    Richard, Pierre Louis entrepreneur            2  70
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Recevoir et évaluer le travail réalisé      6
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Clavareau, Jean Pierre ; architecte ; 5 expertises ; 0 expertises en tant que tiers-expert ; 4 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                          name       column  totalCollab age
# xpr0089      Desboeufs, Henri Quentin   architecte            1  61
# xpr0209        Payen, Jacques Antoine   architecte            1  56
# xpr0247           Simon, René Auguste entrepreneur            1  54
# xpr0043 Le Camus de Mézières, Nicolas   architecte            1  41
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Recevoir et évaluer le travail réalisé      2
# Décrire et évaluer les travaux à venir      1
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Coupard Delatouche, Pierre ; entrepreneur ; 2 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id               name       column  totalCollab age
# xpr0261 Villetard, Etienne entrepreneur            1  40
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Danjan, Pierre Alexandre ; architecte ; 17 expertises ; 0 expertises en tant que tiers-expert ; 7 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                   name       column  totalCollab age
# xpr0102                        Ducret, Nicolas   architecte            1  39
# xpr0200                         Mouchet, André entrepreneur            1
# xpr0250                      Taboureur, Pierre   architecte            1  30
# xpr0236                  Richard, Pierre Louis entrepreneur            1  70
# xpr0210               Perrard, Nicolas Antoine entrepreneur            1  60
# xpr0010 Babuty, François Antoine (1716 - 1766) entrepreneur            2  50
#
#
#                                  label  total
#            Estimer la valeur des biens      5
# Recevoir et évaluer le travail réalisé      5
# Décrire et évaluer les travaux à venir      1
#                             Départager      3
#                            Enregistrer      0
#
#
#
#
# Danjan, Pierre Paul ; architecte ; 11 expertises ; 0 expertises en tant que tiers-expert ; 7 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0005   Antoine, Jacques Denis entrepreneur            1  33
# xpr0096   Dosmond, Pierre Marcel   architecte            1  44
# xpr0072   De Bias Aubry, Mathieu   architecte            1  48
# xpr0209   Payen, Jacques Antoine   architecte            2  56
# xpr0089 Desboeufs, Henri Quentin   architecte            2  61
# xpr0230  Puisieux, Jean Baptiste   architecte            3  76
#
#
#                                  label  total
#            Estimer la valeur des biens      6
# Recevoir et évaluer le travail réalisé      2
# Décrire et évaluer les travaux à venir      1
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# Dauphin, Antoine Nicolas ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                 name       column  totalCollab age
# xpr0104 Dumont, Jean Charles entrepreneur            1  38
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      1
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# De Besse, Claude Guillaume ; architecte ; 9 expertises ; 0 expertises en tant que tiers-expert ; 8 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                          name       column  totalCollab age
# xpr0219                  Pinard, Jean entrepreneur            1  61
# xpr0236         Richard, Pierre Louis entrepreneur            1  70
# xpr0120 Gillet De La Fontaine, Joseph   architecte            1
# xpr0250             Taboureur, Pierre   architecte            1  30
# xpr0039             Bourgeois, Pierre entrepreneur            2
# xpr0089      Desboeufs, Henri Quentin   architecte            4  61
#
#
#                                  label  total
#            Estimer la valeur des biens      2
# Recevoir et évaluer le travail réalisé      5
# Décrire et évaluer les travaux à venir      0
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# De Bias Aubry, Mathieu ; architecte ; 7 expertises ; 0 expertises en tant que tiers-expert ; 4 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0236    Richard, Pierre Louis entrepreneur            1  70
# xpr0066      Danjan, Pierre Paul   architecte            1  68
# xpr0089 Desboeufs, Henri Quentin   architecte            1  61
# xpr0219             Pinard, Jean entrepreneur            1  61
#
#
#                                  label  total
#            Estimer la valeur des biens      3
# Recevoir et évaluer le travail réalisé      2
# Décrire et évaluer les travaux à venir      1
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# De Varenne, Claude Estienne ; entrepreneur ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# De Villers, Eustache Robert ; architecte ; 7 expertises ; 0 expertises en tant que tiers-expert ; 6 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0209   Payen, Jacques Antoine   architecte            1  56
# xpr0250        Taboureur, Pierre   architecte            1  30
# xpr0210 Perrard, Nicolas Antoine entrepreneur            1  60
# xpr0089 Desboeufs, Henri Quentin   architecte            3  61
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      2
# Décrire et évaluer les travaux à venir      2
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# De Vonges, Michel ; entrepreneur ; 2 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
#            Estimer la valeur des biens      2
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Delespine, Louis Jules ; architecte ; 5 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                             name       column  totalCollab age
# xpr0229 Pruneau De Montlouis, Jean Louis   architecte            1  43
# xpr0209           Payen, Jacques Antoine   architecte            1  56
# xpr0247              Simon, René Auguste entrepreneur            1  54
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      2
# Décrire et évaluer les travaux à venir      1
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Delvincourt, André François ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Desboeufs, Henri Quentin ; architecte ; 65 expertises ; 6 expertises en tant que tiers-expert ; 33 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                             name       column  totalCollab age
# xpr0055           Clavareau, Jean Pierre   architecte            1  45
# xpr0234          Raymond, Etienne Hubert entrepreneur            1
# xpr0184                      Loir, Denis entrepreneur            1  46
# xpr0005           Antoine, Jacques Denis entrepreneur            1  33
# xpr0229 Pruneau De Montlouis, Jean Louis   architecte            1  43
# xpr0072           De Bias Aubry, Mathieu   architecte            1  48
# xpr0259                     Vedy, Julien entrepreneur            1  69
# xpr0054       Chauveau, René Bonaventure entrepreneur            1  73
# xpr0106              Egresset, Guillaume entrepreneur            1  55
# xpr0129                 Goupy Ii, Martin   architecte            1  32
# xpr0210         Perrard, Nicolas Antoine entrepreneur            2  60
# xpr0066              Danjan, Pierre Paul   architecte            2  68
# xpr0236            Richard, Pierre Louis entrepreneur            2  70
# xpr0230          Puisieux, Jean Baptiste   architecte            2  76
# xpr0102                  Ducret, Nicolas   architecte            3  39
# xpr0081      De Villers, Eustache Robert   architecte            3  46
# xpr0200                   Mouchet, André entrepreneur            3
# xpr0070       De Besse, Claude Guillaume   architecte            4  32
# xpr0219                     Pinard, Jean entrepreneur            4  61
# xpr0045                    Caque, Pierre entrepreneur            4  66
#
#
#                                  label  total
#            Estimer la valeur des biens     20
# Recevoir et évaluer le travail réalisé     20
# Décrire et évaluer les travaux à venir      8
#                             Départager     14
#                            Enregistrer      0
#
#
#
#
# Desmaisons, Pierre ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Desmaisons, Jacques François ; entrepreneur ; 6 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                name       column  totalCollab age
# xpr0106 Egresset, Guillaume entrepreneur            1  55
# xpr0250   Taboureur, Pierre   architecte            1  30
#
#
#                                  label  total
#            Estimer la valeur des biens      4
# Recevoir et évaluer le travail réalisé      1
# Décrire et évaluer les travaux à venir      1
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Dosmond, Pierre Marcel ; architecte ; 8 expertises ; 0 expertises en tant que tiers-expert ; 6 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                         name       column  totalCollab age
# xpr0066          Danjan, Pierre Paul   architecte            1  68
# xpr0122         Giraud, Pierre Marie   architecte            1  32
# xpr0219                 Pinard, Jean entrepreneur            1  61
# xpr0223 Poirin, Jean Baptiste Michel   architecte            1  69
# xpr0250            Taboureur, Pierre   architecte            1  30
# xpr0104         Dumont, Jean Charles entrepreneur            1  38
#
#
#                                  label  total
#            Estimer la valeur des biens      2
# Recevoir et évaluer le travail réalisé      4
# Décrire et évaluer les travaux à venir      0
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Ducret, Nicolas ; architecte ; 7 expertises ; 0 expertises en tant que tiers-expert ; 6 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0065 Danjan, Pierre Alexandre   architecte            1  44
# xpr0210 Perrard, Nicolas Antoine entrepreneur            2  60
# xpr0089 Desboeufs, Henri Quentin   architecte            3  61
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Recevoir et évaluer le travail réalisé      3
# Décrire et évaluer les travaux à venir      0
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# Dumont, Jean Charles ; entrepreneur ; 26 expertises ; 0 expertises en tant que tiers-expert ; 16 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                             name       column  totalCollab age
# xpr0210         Perrard, Nicolas Antoine entrepreneur            1  60
# xpr0219                     Pinard, Jean entrepreneur            1  61
# xpr0067         Dauphin, Antoine Nicolas   architecte            1  53
# xpr0247              Simon, René Auguste entrepreneur            1  54
# xpr0042                  Buron, François entrepreneur            1  35
# xpr0229 Pruneau De Montlouis, Jean Louis   architecte            1  43
# xpr0045                    Caque, Pierre entrepreneur            1  66
# xpr0209           Payen, Jacques Antoine   architecte            1  56
# xpr0184                      Loir, Denis entrepreneur            1  46
# xpr0050          Chasteau, Jean François entrepreneur            1  32
# xpr0043    Le Camus de Mézières, Nicolas   architecte            1  41
# xpr0250                Taboureur, Pierre   architecte            1  30
# xpr0096           Dosmond, Pierre Marcel   architecte            1  44
# xpr0038         Bourgeois, Louis Silvain entrepreneur            2  30
# xpr0106              Egresset, Guillaume entrepreneur            2  55
#
#
#                                  label  total
#            Estimer la valeur des biens     12
# Recevoir et évaluer le travail réalisé      4
# Décrire et évaluer les travaux à venir      4
#                             Départager      4
#                            Enregistrer      0
#
#
#
#
# Egresset, Guillaume ; entrepreneur ; 16 expertises ; 0 expertises en tant que tiers-expert ; 8 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                   name       column  totalCollab age
# xpr0120          Gillet De La Fontaine, Joseph   architecte            1
# xpr0010 Babuty, François Antoine (1716 - 1766) entrepreneur            1  50
# xpr0230                Puisieux, Jean Baptiste   architecte            1  76
# xpr0250                      Taboureur, Pierre   architecte            1  30
# xpr0089               Desboeufs, Henri Quentin   architecte            1  61
# xpr0092           Desmaisons, Jacques François entrepreneur            1  51
# xpr0050                Chasteau, Jean François entrepreneur            1  32
# xpr0104                   Dumont, Jean Charles entrepreneur            2  38
#
#
#                                  label  total
#            Estimer la valeur des biens      4
# Recevoir et évaluer le travail réalisé      4
# Décrire et évaluer les travaux à venir      2
#                             Départager      4
#                            Enregistrer      0
#
#
#
#
# Fortin, Pierre Jacques ; entrepreneur ; 3 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id              name     column  totalCollab age
# xpr0250 Taboureur, Pierre architecte            1  30
#
#
#                                  label  total
#            Estimer la valeur des biens      2
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Gillet De La Fontaine, Joseph ; architecte ; 6 expertises ; 0 expertises en tant que tiers-expert ; 6 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                          name       column  totalCollab age
# xpr0037        Bourgeois, Louis Denis   architecte            1
# xpr0236         Richard, Pierre Louis entrepreneur            1  70
# xpr0106           Egresset, Guillaume entrepreneur            1  55
# xpr0043 Le Camus de Mézières, Nicolas   architecte            1  41
# xpr0070    De Besse, Claude Guillaume   architecte            1  32
# xpr0219                  Pinard, Jean entrepreneur            1  61
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Recevoir et évaluer le travail réalisé      2
# Décrire et évaluer les travaux à venir      1
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# Giraud, Jean Louis ; entrepreneur ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Giraud, Pierre Marie ; architecte ; 5 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                   name     column  totalCollab age
# xpr0096 Dosmond, Pierre Marcel architecte            1  44
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Recevoir et évaluer le travail réalisé      2
# Décrire et évaluer les travaux à venir      0
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# Goupy Ii, Martin ; architecte ; 3 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                             name       column  totalCollab age
# xpr0229 Pruneau De Montlouis, Jean Louis   architecte            1  43
# xpr0089         Desboeufs, Henri Quentin   architecte            1  61
# xpr0200                   Mouchet, André entrepreneur            1
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# Grissot, Jean ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Guyon, Jean Baptiste ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Le Chauve, Brice ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Loir, Denis ; entrepreneur ; 10 expertises ; 0 expertises en tant que tiers-expert ; 6 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                   name       column  totalCollab age
# xpr0089               Desboeufs, Henri Quentin   architecte            1  61
# xpr0039                      Bourgeois, Pierre entrepreneur            1
# xpr0010 Babuty, François Antoine (1716 - 1766) entrepreneur            1  50
# xpr0250                      Taboureur, Pierre   architecte            1  30
# xpr0104                   Dumont, Jean Charles entrepreneur            1  38
# xpr0226                 Porquet, Claude Joseph   architecte            1  44
# xpr0200                         Mouchet, André entrepreneur            1
#
#
#                                  label  total
#            Estimer la valeur des biens      5
# Recevoir et évaluer le travail réalisé      2
# Décrire et évaluer les travaux à venir      2
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Martin, Pierre Henry ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Mouchet, André ; entrepreneur ; 16 expertises ; 1 expertises en tant que tiers-expert ; 12 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                        name       column  totalCollab age
# xpr0006             Arnoult, Thomas entrepreneur            1  59
# xpr0045               Caque, Pierre entrepreneur            1  66
# xpr0032 Bouillette de Chamly, Raoul entrepreneur            1  32
# xpr0042             Buron, François entrepreneur            1  35
# xpr0039           Bourgeois, Pierre entrepreneur            1
# xpr0065    Danjan, Pierre Alexandre   architecte            1  44
# xpr0129            Goupy Ii, Martin   architecte            1  32
# xpr0184                 Loir, Denis entrepreneur            1  46
# xpr0089    Desboeufs, Henri Quentin   architecte            3  61
# xpr0230     Puisieux, Jean Baptiste   architecte            4  76
#
#
#                                  label  total
#            Estimer la valeur des biens      2
# Recevoir et évaluer le travail réalisé      7
# Décrire et évaluer les travaux à venir      1
#                             Départager      5
#                            Enregistrer      0
#
#
#
#
# Paulick, Jean Nepomucene ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Payen, Jacques Antoine ; architecte ; 30 expertises ; 1 expertises en tant que tiers-expert ; 17 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                   name       column  totalCollab age
# xpr0055                 Clavareau, Jean Pierre   architecte            1  45
# xpr0005                 Antoine, Jacques Denis entrepreneur            1  33
# xpr0024                    Blanchard, Jean-Luc   architecte            1
# xpr0050                Chasteau, Jean François entrepreneur            1  32
# xpr0085                 Delespine, Louis Jules   architecte            1  40
# xpr0039                      Bourgeois, Pierre entrepreneur            1
# xpr0081            De Villers, Eustache Robert   architecte            1  46
# xpr0010 Babuty, François Antoine (1716 - 1766) entrepreneur            1  50
# xpr0104                   Dumont, Jean Charles entrepreneur            1  38
# xpr0261                     Villetard, Etienne entrepreneur            1  40
# xpr0210               Perrard, Nicolas Antoine entrepreneur            2  60
# xpr0066                    Danjan, Pierre Paul   architecte            2  68
# xpr0229       Pruneau De Montlouis, Jean Louis   architecte            2  43
# xpr0230                Puisieux, Jean Baptiste   architecte            3  76
#
#
#                                  label  total
#            Estimer la valeur des biens      8
# Recevoir et évaluer le travail réalisé      9
# Décrire et évaluer les travaux à venir      2
#                             Départager      6
#                            Enregistrer      0
#
#
#
#
# Perrard, Nicolas Antoine ; entrepreneur ; 31 expertises ; 0 expertises en tant que tiers-expert ; 16 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                             name       column  totalCollab age
# xpr0104             Dumont, Jean Charles entrepreneur            1  38
# xpr0236            Richard, Pierre Louis entrepreneur            1  70
# xpr0230          Puisieux, Jean Baptiste   architecte            1  76
# xpr0229 Pruneau De Montlouis, Jean Louis   architecte            1  43
# xpr0226           Porquet, Claude Joseph   architecte            1  44
# xpr0065         Danjan, Pierre Alexandre   architecte            1  44
# xpr0081      De Villers, Eustache Robert   architecte            1  46
# xpr0005           Antoine, Jacques Denis entrepreneur            1  33
# xpr0209           Payen, Jacques Antoine   architecte            2  56
# xpr0102                  Ducret, Nicolas   architecte            2  39
# xpr0089         Desboeufs, Henri Quentin   architecte            2  61
# xpr0219                     Pinard, Jean entrepreneur            3  61
#
#
#                                  label  total
#            Estimer la valeur des biens     10
# Recevoir et évaluer le travail réalisé     12
# Décrire et évaluer les travaux à venir      3
#                             Départager      4
#                            Enregistrer      0
#
#
#
#
# Pinard, Jean ; entrepreneur ; 26 expertises ; 0 expertises en tant que tiers-expert ; 14 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                   name       column  totalCollab age
# xpr0045                          Caque, Pierre entrepreneur            1  66
# xpr0104                   Dumont, Jean Charles entrepreneur            1  38
# xpr0230                Puisieux, Jean Baptiste   architecte            1  76
# xpr0070             De Besse, Claude Guillaume   architecte            1  32
# xpr0010 Babuty, François Antoine (1716 - 1766) entrepreneur            1  50
# xpr0005                 Antoine, Jacques Denis entrepreneur            1  33
# xpr0072                 De Bias Aubry, Mathieu   architecte            1  48
# xpr0096                 Dosmond, Pierre Marcel   architecte            1  44
# xpr0120          Gillet De La Fontaine, Joseph   architecte            1
# xpr0236                  Richard, Pierre Louis entrepreneur            2  70
# xpr0210               Perrard, Nicolas Antoine entrepreneur            3  60
# xpr0089               Desboeufs, Henri Quentin   architecte            4  61
#
#
#                                  label  total
#            Estimer la valeur des biens      6
# Recevoir et évaluer le travail réalisé     12
# Décrire et évaluer les travaux à venir      3
#                             Départager      3
#                            Enregistrer      0
#
#
#
#
# Poirin, Jean Baptiste Michel ; architecte ; 3 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                   name     column  totalCollab age
# xpr0096 Dosmond, Pierre Marcel architecte            1  44
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Recevoir et évaluer le travail réalisé      1
# Décrire et évaluer les travaux à venir      1
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Porquet, Claude Joseph ; architecte ; 3 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0210 Perrard, Nicolas Antoine entrepreneur            1  60
# xpr0005   Antoine, Jacques Denis entrepreneur            1  33
# xpr0184              Loir, Denis entrepreneur            1  46
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      1
# Décrire et évaluer les travaux à venir      0
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# Pruneau De Montlouis, Jean Louis ; architecte ; 19 expertises ; 0 expertises en tant que tiers-expert ; 9 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0085   Delespine, Louis Jules   architecte            1  40
# xpr0250        Taboureur, Pierre   architecte            1  30
# xpr0210 Perrard, Nicolas Antoine entrepreneur            1  60
# xpr0089 Desboeufs, Henri Quentin   architecte            1  61
# xpr0104     Dumont, Jean Charles entrepreneur            1  38
# xpr0129         Goupy Ii, Martin   architecte            1  32
# xpr0047         Caque, Guillaume entrepreneur            1
# xpr0209   Payen, Jacques Antoine   architecte            2  56
#
#
#                                  label  total
#            Estimer la valeur des biens      8
# Recevoir et évaluer le travail réalisé      5
# Décrire et évaluer les travaux à venir      2
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# Puisieux, Jean Baptiste ; architecte ; 33 expertises ; 1 expertises en tant que tiers-expert ; 18 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                   name       column  totalCollab age
# xpr0219                           Pinard, Jean entrepreneur            1  61
# xpr0261                     Villetard, Etienne entrepreneur            1  40
# xpr0210               Perrard, Nicolas Antoine entrepreneur            1  60
# xpr0032            Bouillette de Chamly, Raoul entrepreneur            1  32
# xpr0038               Bourgeois, Louis Silvain entrepreneur            1  30
# xpr0106                    Egresset, Guillaume entrepreneur            1  55
# xpr0010 Babuty, François Antoine (1716 - 1766) entrepreneur            1  50
# xpr0039                      Bourgeois, Pierre entrepreneur            1
# xpr0236                  Richard, Pierre Louis entrepreneur            1  70
# xpr0043          Le Camus de Mézières, Nicolas   architecte            1  41
# xpr0089               Desboeufs, Henri Quentin   architecte            2  61
# xpr0209                 Payen, Jacques Antoine   architecte            3  56
# xpr0066                    Danjan, Pierre Paul   architecte            3  68
# xpr0200                         Mouchet, André entrepreneur            4
#
#
#                                  label  total
#            Estimer la valeur des biens      4
# Recevoir et évaluer le travail réalisé     16
# Décrire et évaluer les travaux à venir      5
#                             Départager      6
#                            Enregistrer      0
#
#
#
#
# Quirot, Denis ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Raymond, Etienne Hubert ; entrepreneur ; 2 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0045            Caque, Pierre entrepreneur            1  66
# xpr0089 Desboeufs, Henri Quentin   architecte            1  61
# xpr0236    Richard, Pierre Louis entrepreneur            1  70
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Recevoir et évaluer le travail réalisé      1
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Richard, Pierre Louis ; entrepreneur ; 21 expertises ; 1 expertises en tant que tiers-expert ; 11 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                          name       column  totalCollab age
# xpr0045                 Caque, Pierre entrepreneur            1  66
# xpr0210      Perrard, Nicolas Antoine entrepreneur            1  60
# xpr0072        De Bias Aubry, Mathieu   architecte            1  48
# xpr0120 Gillet De La Fontaine, Joseph   architecte            1
# xpr0234       Raymond, Etienne Hubert entrepreneur            1
# xpr0070    De Besse, Claude Guillaume   architecte            1  32
# xpr0065      Danjan, Pierre Alexandre   architecte            1  44
# xpr0230       Puisieux, Jean Baptiste   architecte            1  76
# xpr0219                  Pinard, Jean entrepreneur            2  61
# xpr0054    Chauveau, René Bonaventure entrepreneur            2  73
# xpr0089      Desboeufs, Henri Quentin   architecte            2  61
#
#
#                                  label  total
#            Estimer la valeur des biens      5
# Recevoir et évaluer le travail réalisé      9
# Décrire et évaluer les travaux à venir      3
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# Simon, René Auguste ; entrepreneur ; 4 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                   name       column  totalCollab age
# xpr0104   Dumont, Jean Charles entrepreneur            1  38
# xpr0055 Clavareau, Jean Pierre   architecte            1  45
# xpr0085 Delespine, Louis Jules   architecte            1  40
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      4
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Taboureur, Pierre ; architecte ; 52 expertises ; 1 expertises en tant que tiers-expert ; 11 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                   name       column  totalCollab age
# xpr0229       Pruneau De Montlouis, Jean Louis   architecte            1  43
# xpr0184                            Loir, Denis entrepreneur            1  46
# xpr0010 Babuty, François Antoine (1716 - 1766) entrepreneur            1  50
# xpr0106                    Egresset, Guillaume entrepreneur            1  55
# xpr0065               Danjan, Pierre Alexandre   architecte            1  44
# xpr0081            De Villers, Eustache Robert   architecte            1  46
# xpr0110                 Fortin, Pierre Jacques entrepreneur            1  37
# xpr0104                   Dumont, Jean Charles entrepreneur            1  38
# xpr0092           Desmaisons, Jacques François entrepreneur            1  51
# xpr0070             De Besse, Claude Guillaume   architecte            1  32
# xpr0096                 Dosmond, Pierre Marcel   architecte            1  44
# xpr0024                    Blanchard, Jean-Luc   architecte            1
#
#
#                                  label  total
#            Estimer la valeur des biens     10
# Recevoir et évaluer le travail réalisé     16
# Décrire et évaluer les travaux à venir     13
#                             Départager      5
#                            Enregistrer      0
#
#
#
#
# Vedy, Julien ; entrepreneur ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name     column  totalCollab age
# xpr0089 Desboeufs, Henri Quentin architecte            1  61
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      1
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Villetard, Etienne ; entrepreneur ; 10 expertises ; 0 expertises en tant que tiers-expert ; 6 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                   name       column  totalCollab age
# xpr0230                Puisieux, Jean Baptiste   architecte            1  76
# xpr0010 Babuty, François Antoine (1716 - 1766) entrepreneur            1  50
# xpr0038               Bourgeois, Louis Silvain entrepreneur            1  30
# xpr0039                      Bourgeois, Pierre entrepreneur            1
# xpr0060             Coupard Delatouche, Pierre entrepreneur            1  50
# xpr0209                 Payen, Jacques Antoine   architecte            1  56
#
#
#                                  label  total
#            Estimer la valeur des biens      5
# Recevoir et évaluer le travail réalisé      1
# Décrire et évaluer les travaux à venir      1
#                             Départager      3
#                            Enregistrer      0
