# %% [markdown]
# # xprStats

# %%
# lib
from urllib.request import urlopen
import json  
import pandas as pd

# %%
# Récupération des donnée 
# param (date or thirdParty)
param = "1716"

# url
url = "https://experts.huma-num.fr/xpr/statistics/" + param

# enregistrement de la réponse
response = urlopen(url)

# lecture du json
data = json.loads(response.read())
  
# print the json response
#print(data)

# %% [markdown]
# ## Expertises

# %%
expertises = data['expertises']

# %%
print("Nombre total d'expertises : " + str(expertises['total']))
# Out:
# Nombre total d'expertises : 471

# %% [markdown]
# ### Croquis

# %%
sketchesDF = pd.json_normalize(expertises['sketches'])
print(sketchesDF.to_string(index=False))
# Out:
#  expertisesWithoutSketch  expertisesWithSketch
#                      466                     5

# %% [markdown]
# ### Étendue

# %%
extent = expertises['extent']
#print(extent)

print('Nombre de feuillets : ' + str(extent['total']))

print('Moyenne par expertise : ' + str(extent['averageByExpertise']))

#Distribution
print('Distribution :')
keys = []
values = []
for dic in extent['extentDistribution']:
    for key, val in dic.items():
        keys.append(key),
        values.append(val)        

extentDistributionDict = {'nombre de feuillets': keys, 'nombre d’expertises': values,} 
print(pd.DataFrame(extentDistributionDict).to_string(index=False))
# Out:
# Nombre de feuillets : 5289
# Moyenne par expertise : 11.23
# Distribution :
# nombre de feuillets  nombre d’expertises
#                   5                  158
#                  10                  181
#                  15                   43
#                  20                   39
#                  25                   10
#                  30                   10
#                  35                   10
#                  40                    7
#                  45                    3
#                  50                    2
#                  55                    2
#                  60                    0
#                  65                    0
#                  70                    1
#                  75                    0
#                  80                    0
#                  85                    1
#                  90                    1
#                  95                    0
#                 100                    3

# %% [markdown]
# ### Annexes

# %%
appendices = expertises['appendices']
#print(appendices)

print(f"{appendices['total']} annexes")


print(f"{appendices['expertisesWithAppendices']} expertises avec annexes ; {appendices['expertisesWithoutAppendices']} expertises sans annexes")


df=pd.json_normalize(appendices['types'])
print(df.to_string(columns=['label', 'total', 'expertises'], index=False))
# Out:
# 331 annexes
# 203 expertises avec annexes ; 268 expertises sans annexes
#                                       label  total  expertises
# Pouvoir/procuration (acte sous seing privé)    113          90
#                                       Autre    136          91
#                                     Requête     22          20
#          Pouvoir/procuration (acte notarié)     17          16
#                                      Dessin      3           3
#                      Plan, coupe, élévation     29          23
#                                   Brouillon      4           4
#                                     Croquis      2           2

# %% [markdown]
# ### Vacations

# %%
sessions = expertises['sessions']
#print(sessions)

print(f"{sessions['total']} vacations")


print(f"en moyenne {sessions['averageByExpertise']} vacations par expertise")
# Out:
# 948 vacations
# en moyenne 2.01 vacations par expertise

# %% [markdown]
# Nombre de vacation par lieu

# %%
sessionsDf=pd.json_normalize(sessions['places'])
print(sessionsDf.to_string(columns=['label', 'total'], index=False))
# Out:
#    label  total
#    Paris    716
# Banlieue     94
# Province    138

# %% [markdown]
# ### Durée

# %%
duration = expertises['duration']
#print(duration)

# %% [markdown]
# #### Jours

# %%
#Distribution
durationDays = duration['days']
#print(durationDays)
print('Distribution :')
keys = []
values = []
for dic in durationDays['distributionByDays']:
    for key, val in dic.items():
        keys.append(key),
        values.append(val)        

durationDaysDf = {'nombre de jours': keys, 'nombre d’expertises': values,} 
print(pd.DataFrame(durationDaysDf).to_string(index=False))
# Out:
# Distribution :
# nombre de jours  nombre d’expertises
#               5                  300
#              10                   34
#              15                   16
#              20                    5
#              25                   13
#              30                    7
#              35                    5
#              40                    3
#              45                    4
#              50                    7
#              55                    3
#              60                    3
#              65                    5
#              70                    2
#              75                    3
#              80                    6
#              85                    0
#              90                    1
#              95                    3
#             100                   48

# %% [markdown]
# #### Vacations

# %%
#Distribution
durationSessions = duration['sessions']
#print(durationDays)
print(f"{durationSessions['total']} vacations, soit en moyenne {durationSessions['averageByExpertise']} vacations par expertise.")
# Out:
# 948 vacations, soit en moyenne 1.01 vacations par expertise.

# %% [markdown]
# ### Lieux

# %%
places = expertises['places']
#print(places)

placesDf=pd.json_normalize(places)
print(placesDf.to_string(columns=['place', 'total'], index=False))
# Out:
#                        place  total
#                      [paris]    350
#                    [suburbs]     55
#                   [province]     55
#           [[paris, suburbs]]      2
#          [[paris, province]]      9
#        [[suburbs, province]]      0
# [[paris, suburbs, province]]      0

# %% [markdown]
# ### Procédures et cadres

# %%
frameworks = expertises['frameworks']
#print(frameworks)

frameworksDf=pd.json_normalize(frameworks)
print(frameworksDf.to_string(columns=['label', 'framework', 'total'], index=False))
# Out:
#                                                                                                                   label framework  total
#                                                     Requête auprès d’une institution pour qu’elle demande une expertise        b1     32
#                                                                                               Commun accord des parties         a    106
# L’institution est saisie dans le cadre d’une procédure (les parties nomment chacune leur expert ou un expert en commun)       b2a    179
#                                                                                                                                        1
#                         L’institution est saisie dans le cadre d’une procédure (l’institution nomme un ou deux experts)       b2b      8
#                                          Saisie mixte (un expert est nommé par les parties, l'autre est nommé d'office)        b3      4
#                                                                                                       Cas problématique         c      2
# L’institution est saisie dans le cadre d’une procédure (les parties nomment chacune leur expert ou un expert en commun)        b2    139

# %% [markdown]
# ### Catégories

# %%
categories = expertises['categories']

for cat in categories:
    if cat['total'] != 0: print(f"{cat['label']} : {cat['total']} expertises"),
    for framework in cat['frameworks']:
        if framework['total'] != 0: print(f"\t{framework['framework']} : {framework['total']} expertises"),
        for place in framework['places']:
            if place['total'] != 0: print(f"\t\t{place['place']} : {place['total']}"),
            for obj in place['objects']:
                if obj['total'] != 0: print(f"\t\t\t{obj['label']} : {obj['total']}")
        print('\n')
    print('\n')
# Out:
# Recevoir et évaluer le travail réalisé : 137 expertises
# 	b1 : 4 expertises
# 		['paris'] : 2
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 		['province'] : 2
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
#
#
# 	a : 33 expertises
# 		['paris'] : 29
# 			Ouvrages de maçonnerie : 9
# 			Maison(s) : 22
# 		['suburbs'] : 2
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 		['province'] : 2
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 2
#
#
# 	b2a : 53 expertises
# 		['paris'] : 42
# 			Ouvrages de maçonnerie : 24
# 			Maison(s) : 19
# 			Mur(s) : 1
# 			Fosse(s) d'aisance : 1
# 		['suburbs'] : 6
# 			Ouvrages de maçonnerie : 5
# 			Maison(s) : 1
# 		['province'] : 5
# 			Ouvrages de maçonnerie : 3
# 			Maison(s) : 1
# 			Mur(s) : 1
#
#
#
#
# 	b2b : 3 expertises
# 		['paris'] : 2
# 			Ouvrages de maçonnerie : 2
# 		['suburbs'] : 1
# 			Maison(s) : 1
#
#
# 	b3 : 1 expertises
# 		['paris'] : 1
# 			Maison(s) : 1
#
#
#
#
# 	b2 : 43 expertises
# 		['paris'] : 36
# 			Ouvrages de maçonnerie : 16
# 			Maison(s) : 18
# 			Mur(s) : 1
# 			Fosse(s) d'aisance : 1
# 		['suburbs'] : 2
# 			Maison(s) : 2
# 		['province'] : 4
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 2
# 		[['paris', 'province']] : 1
# 			Maison(s) : 1
#
#
#
#
# Départager : 130 expertises
# 	b1 : 7 expertises
# 		['paris'] : 6
# 			Maison(s) : 3
# 			Mur(s) : 2
# 			Fosse(s) d'aisance : 1
# 		['suburbs'] : 1
# 			Puits : 1
#
#
# 	a : 45 expertises
# 		['paris'] : 43
# 			Maison(s) : 8
# 			Mur(s) : 33
# 			Fosse(s) d'aisance : 2
# 		['suburbs'] : 2
# 			Mur(s) : 2
#
#
# 	b2a : 39 expertises
# 		['paris'] : 28
# 			Ouvrages de maçonnerie : 4
# 			Maison(s) : 11
# 			Mur(s) : 9
# 			Ensemble de bâtiments (biens immeubles) : 1
# 			Fosse(s) d'aisance : 3
# 			Puits : 1
# 		['suburbs'] : 5
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 2
# 			Mur(s) : 2
# 		['province'] : 5
# 			Ouvrages de maçonnerie : 3
# 			Mur(s) : 2
# 		[['paris', 'province']] : 1
# 			Domaine, terres, fief : 1
#
#
#
#
# 	b2b : 2 expertises
# 		['paris'] : 2
# 			Maison(s) : 1
# 			Fosse(s) d'aisance : 1
#
#
# 	b3 : 2 expertises
# 		['paris'] : 1
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 			Mur(s) : 1
# 		['province'] : 1
# 			Maison(s) : 1
# 			Terrain(s) : 1
#
#
# 	c : 2 expertises
# 		['paris'] : 2
# 			Ouvrages de maçonnerie : 2
#
#
# 	b2 : 33 expertises
# 		['paris'] : 24
# 			Ouvrages de maçonnerie : 8
# 			Maison(s) : 8
# 			Mur(s) : 7
# 			Fosse(s) d'aisance : 3
# 			Puits : 1
# 		['suburbs'] : 4
# 			Maison(s) : 1
# 			Terrain(s) : 1
# 			Mur(s) : 2
# 		['province'] : 5
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 2
# 			Terrain(s) : 1
#
#
#
#
# Estimer la valeur des biens : 127 expertises
# 	b1 : 7 expertises
# 		['paris'] : 5
# 			Maison(s) : 5
# 		['province'] : 1
# 			Maison(s) : 1
# 		[['paris', 'province']] : 1
# 			Maison(s) : 1
#
#
# 	a : 19 expertises
# 		['paris'] : 15
# 			Maison(s) : 14
# 			Terrain(s) : 1
# 		['suburbs'] : 1
# 			Maison(s) : 1
# 		['province'] : 1
# 			Domaine, terres, fief : 1
# 		[['paris', 'province']] : 2
# 			Maison(s) : 2
#
#
# 	b2a : 58 expertises
# 		['paris'] : 37
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 34
# 			Terrain(s) : 2
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		['suburbs'] : 11
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 9
# 			Terrain(s) : 3
# 			Ensemble de bâtiments (biens immeubles) : 1
# 			Domaine, terres, fief : 1
# 		['province'] : 8
# 			Maison(s) : 8
# 			Terrain(s) : 2
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		[['paris', 'province']] : 2
# 			Maison(s) : 2
#
#
#
#
# 	b2b : 2 expertises
# 		['suburbs'] : 2
# 			Maison(s) : 1
# 			Terrain(s) : 2
#
#
#
#
#
#
# 	b2 : 41 expertises
# 		['paris'] : 18
# 			Maison(s) : 18
# 			Terrain(s) : 1
# 		['suburbs'] : 11
# 			Maison(s) : 10
# 			Terrain(s) : 1
# 		['province'] : 10
# 			Maison(s) : 9
# 			Terrain(s) : 3
# 			Domaine, terres, fief : 2
# 		[['paris', 'suburbs']] : 1
# 			Maison(s) : 1
# 		[['paris', 'province']] : 1
# 			Maison(s) : 1
#
#
#
#
# Décrire et évaluer les travaux à venir : 66 expertises
# 	b1 : 9 expertises
# 		['paris'] : 9
# 			Maison(s) : 9
#
#
# 	a : 6 expertises
# 		['paris'] : 6
# 			Maison(s) : 5
# 			Mur(s) : 2
#
#
# 	b2a : 27 expertises
# 		['paris'] : 17
# 			Maison(s) : 17
# 		['suburbs'] : 4
# 			Maison(s) : 4
# 		['province'] : 6
# 			Ouvrages de maçonnerie : 4
# 			Maison(s) : 2
#
#
#
#
# 	b2b : 1 expertises
# 		['paris'] : 1
# 			Maison(s) : 1
#
#
# 	b3 : 1 expertises
# 		['suburbs'] : 1
# 			Maison(s) : 1
#
#
#
#
# 	b2 : 22 expertises
# 		['paris'] : 18
# 			Ouvrages de maçonnerie : 3
# 			Maison(s) : 15
# 		['suburbs'] : 1
# 			Maison(s) : 1
# 		['province'] : 2
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 		[['paris', 'province']] : 1
# 			Maison(s) : 1
#
#
#
#
# Enregistrer : 7 expertises
# 	b1 : 4 expertises
# 		['paris'] : 2
# 			Maison(s) : 2
# 		['province'] : 2
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
#
#
# 	a : 2 expertises
# 		['paris'] : 1
# 			Mur(s) : 1
# 		['suburbs'] : 1
# 			Ouvrages de maçonnerie : 1
#
#
# 	b2a : 1 expertises
# 		[['paris', 'suburbs']] : 1
# 			Terrain(s) : 1

# %% [markdown]
# ### Tiers expertises

# %%
thirdParty = expertises['thirdParty']

# %%
thirdPartyDf=pd.json_normalize(thirdParty)
print(thirdPartyDf.to_string(columns=['architectes', 'entrepreneurs', 'total'], index=False))
# Out:
#  architectes  entrepreneurs  total
#           12             21     33

# %% [markdown]
# ### Distribution (hors tiers expertises)

# %%
columnDistrib = expertises['experts']

for column in columnDistrib:
    print(f"{column['totalExperts']} expert(s) : {column['totalExpertises']} expertises"),
    if column['totalExperts']<3: print(pd.json_normalize(column['distribution']).to_string(columns=['label', 'total'], index=False))
    print('\n')
# Out:
# 1 expert(s) : 309 expertises
#        label  total
#   architecte    117
# entrepreneur    186
#
#
# 2 expert(s) : 121 expertises
#                       label  total
#     architecte - architecte     29
#   entrepreneur - architecte     65
# entrepreneur - entrepreneur     21
#
#
# 3 expert(s) : 8 expertises

# %% [markdown]
# ## Experts

# %%
experts = data['experts']
#print(experts)

# %%
print(f"Nombre d’experts : {experts['total']}")
print(f"{experts['architects']} architectes")
print(f"{experts['entrepreneur']} entrepreneurs")
print(f"{experts['surveyor']} arpenteurs")
# Out:
# Nombre d’experts : 41
# 21 architectes
# 18 entrepreneurs
# 2 arpenteurs

# %%
listExperts = experts['list']
listExpertsDf = pd.DataFrame(listExperts)
listExpertsDf.drop('expertises', inplace=True, axis=1)

# %%
print(listExpertsDf.to_string(columns=['id', 'name', 'column', 'age'], index=False))
# Out:
#            id                                  name       column age
#       xpr0015                     Belhomme, Maurice entrepreneur  59
#       xpr0017                        Benoist, Louis   architecte
#       xpr0018                      Bernard, Charles   architecte  56
#       xpr0023            Billaudel, Charles Jacques   architecte  30
#       xpr0048                        Caulle, Martin   architecte  65
#       xpr0051           Chastelain, Nicolas Isidore entrepreneur  24
#       xpr0054            Chauveau, René Bonaventure entrepreneur  33
#       xpr0063                    Cudeville, Jacques    arpenteur
#       xpr0073               De Bias Aubry, François   architecte
#       xpr0074                 De La Croix, Philémon entrepreneur  37
#       xpr0078  De Mezeretz (Fils), Charles Philippe   architecte  61
#       xpr0086                    Delespine, Nicolas   architecte  84
#       xpr0097                       Doucet, Jacques entrepreneur  41
#       xpr0100                          Dubois, Jean entrepreneur  78
#       xpr0105                        Duval, Charles    arpenteur
#       xpr0108                          Fauvel, Jean entrepreneur  32
#       xpr0111           Fourier, Edme (1668 - 1727) entrepreneur  58
#       xpr0112                      Fremiot, Nicolas entrepreneur  61
#       xpr0113                      Frosne, Jean Luc   architecte  70
#       xpr0118 Gerard De Montbrouard, Claude Jacques   architecte  33
#       xpr0145         Jacquot De Villeneuve, Pierre   architecte  45
#       xpr0147                        Joubert, Louis entrepreneur  50
#       xpr0151             Laisney, François Etienne entrepreneur  43
#       xpr0158              Le brun, Jacques Charles   architecte  56
#       xpr0160                      Le Chauve, Brice   architecte
#       xpr0171                      Le Sueur, Adrien   architecte  40
#       xpr0177       Lepas Dubuisson, Claude Nicolas   architecte
#       xpr0179         Lepas Dubuisson, Jacques (II) entrepreneur  50
#       xpr0183                   Loir, Jean Baptiste entrepreneur  61
#       xpr0193                       Masson, Etienne entrepreneur  44
#       xpr0207                      Paumier, Nicolas entrepreneur
#       xpr0221                    Pirethouy, Jacques   architecte  76
#       xpr0222                         Plasnie, Jean entrepreneur  50
#       xpr0223          Poirin, Jean Baptiste Michel   architecte  29
#       xpr0232                        Quirot, Pierre   architecte  64
#       xpr0233                Raymond, Jean François   architecte  38
#       xpr0236                 Richard, Pierre Louis entrepreneur  30
#       xpr0246                       Simon, Mathurin entrepreneur  60
#       xpr0248                      Simonet, Nicolas   architecte  41
#       xpr0264                    Vuyet, Jean Robert   architecte  62
# xprPerson0017               Cochois, Pierre (? - ?)   architecte

# %%
for expert in listExperts:
    print(f"{expert['name']} ; {expert['column']} ; {expert['expertises']['total']} expertises ; {expert['expertises']['thirParty']} expertises en tant que tiers-expert ; {expert['expertises']['collab']['total']} expertises avec d'autres experts (tiers expertises comprises)"),
    print("\n")
    
    collabDF = pd.json_normalize(expert['expertises']['collab']['experts']) 
    if expert['expertises']['collab']['total'] != 0: print(collabDF.to_string(columns=['id', 'name', 'column', 'totalCollab', 'age'], index=False))
    print("\n")
    categoriesDef = pd.json_normalize(expert['expertises']['categories'])
    print(categoriesDef.to_string(columns=['label', 'total'], index=False))

    print("\n")
    print("\n")
# Out:
# Belhomme, Maurice ; entrepreneur ; 11 expertises ; 0 expertises en tant que tiers-expert ; 9 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                name       column  totalCollab age
# xpr0108        Fauvel, Jean entrepreneur            1  32
# xpr0207    Paumier, Nicolas entrepreneur            1
# xpr0017      Benoist, Louis   architecte            1
# xpr0048      Caulle, Martin   architecte            1  65
# xpr0232      Quirot, Pierre   architecte            2  64
# xpr0183 Loir, Jean Baptiste entrepreneur            5  61
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      6
#                             Départager      3
#            Estimer la valeur des biens      2
# Décrire et évaluer les travaux à venir      0
#                            Enregistrer      0
#
#
#
#
# Benoist, Louis ; architecte ; 18 expertises ; 1 expertises en tant que tiers-expert ; 14 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                          name       column  totalCollab age
# xpr0073       De Bias Aubry, François   architecte            1
# xpr0145 Jacquot De Villeneuve, Pierre   architecte            1  45
# xpr0015             Belhomme, Maurice entrepreneur            1  59
# xpr0207              Paumier, Nicolas entrepreneur            4
# xpr0232                Quirot, Pierre   architecte            6  64
# xpr0183           Loir, Jean Baptiste entrepreneur            6  61
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      6
#                             Départager      5
#            Estimer la valeur des biens      2
# Décrire et évaluer les travaux à venir      4
#                            Enregistrer      0
#
#
#
#
# Bernard, Charles ; architecte ; 12 expertises ; 0 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                          name       column  totalCollab age
# xpr0233        Raymond, Jean François   architecte            1  38
# xpr0145 Jacquot De Villeneuve, Pierre   architecte            1  45
# xpr0112              Fremiot, Nicolas entrepreneur            1  61
# xpr0113              Frosne, Jean Luc   architecte            2  70
# xpr0183           Loir, Jean Baptiste entrepreneur            2  61
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      4
#                             Départager      5
#            Estimer la valeur des biens      2
# Décrire et évaluer les travaux à venir      1
#                            Enregistrer      0
#
#
#
#
# Billaudel, Charles Jacques ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                            Enregistrer      0
#
#
#
#
# Caulle, Martin ; architecte ; 18 expertises ; 1 expertises en tant que tiers-expert ; 12 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                          name       column  totalCollab age
# xpr0233        Raymond, Jean François   architecte            1  38
# xpr0145 Jacquot De Villeneuve, Pierre   architecte            1  45
# xpr0246               Simon, Mathurin entrepreneur            1  60
# xpr0015             Belhomme, Maurice entrepreneur            1  59
# xpr0111   Fourier, Edme (1668 - 1727) entrepreneur            1  58
# xpr0100                  Dubois, Jean entrepreneur            2  78
# xpr0232                Quirot, Pierre   architecte            3  64
# xpr0183           Loir, Jean Baptiste entrepreneur            4  61
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      4
#                             Départager      4
#            Estimer la valeur des biens      6
# Décrire et évaluer les travaux à venir      3
#                            Enregistrer      0
#
#
#
#
# Chastelain, Nicolas Isidore ; entrepreneur ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id             name       column  totalCollab age
# xpr0112 Fremiot, Nicolas entrepreneur            1  61
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      0
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      0
#                            Enregistrer      0
#
#
#
#
# Chauveau, René Bonaventure ; entrepreneur ; 9 expertises ; 0 expertises en tant que tiers-expert ; 4 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0193          Masson, Etienne entrepreneur            1  44
# xpr0232           Quirot, Pierre   architecte            1  64
# xpr0158 Le brun, Jacques Charles   architecte            1  56
# xpr0112         Fremiot, Nicolas entrepreneur            1  61
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#                             Départager      3
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      5
#                            Enregistrer      0
#
#
#
#
# Cudeville, Jacques ; arpenteur ; 8 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                    name     column  totalCollab age
# xpr0264      Vuyet, Jean Robert architecte            1  62
# xpr0073 De Bias Aubry, François architecte            2
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#                             Départager      3
#            Estimer la valeur des biens      2
# Décrire et évaluer les travaux à venir      2
#                            Enregistrer      0
#
#
#
#
# De Bias Aubry, François ; architecte ; 14 expertises ; 0 expertises en tant que tiers-expert ; 6 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                        name       column  totalCollab age
# xpr0232              Quirot, Pierre   architecte            1  64
# xpr0017              Benoist, Louis   architecte            1
# xpr0111 Fourier, Edme (1668 - 1727) entrepreneur            1  58
# xpr0183         Loir, Jean Baptiste entrepreneur            2  61
# xpr0063          Cudeville, Jacques    arpenteur            2
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      5
#                             Départager      6
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      2
#                            Enregistrer      0
#
#
#
#
# De La Croix, Philémon ; entrepreneur ; 2 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                name       column  totalCollab age
# xpr0183 Loir, Jean Baptiste entrepreneur            1  61
# xpr0246     Simon, Mathurin entrepreneur            1  60
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#                             Départager      1
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                            Enregistrer      0
#
#
#
#
# De Mezeretz (Fils), Charles Philippe ; architecte ; 14 expertises ; 1 expertises en tant que tiers-expert ; 9 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                        name       column  totalCollab age
# xpr0183         Loir, Jean Baptiste entrepreneur            1  61
# xpr0111 Fourier, Edme (1668 - 1727) entrepreneur            2  58
# xpr0158    Le brun, Jacques Charles   architecte            3  56
# xpr0232              Quirot, Pierre   architecte            5  64
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      7
#                             Départager      3
#            Estimer la valeur des biens      3
# Décrire et évaluer les travaux à venir      1
#                            Enregistrer      0
#
#
#
#
# Delespine, Nicolas ; architecte ; 10 expertises ; 2 expertises en tant que tiers-expert ; 6 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                            name       column  totalCollab age
# xpr0221              Pirethouy, Jacques   architecte            1  76
# xpr0232                  Quirot, Pierre   architecte            1  64
# xpr0246                 Simon, Mathurin entrepreneur            1  60
# xpr0207                Paumier, Nicolas entrepreneur            1
# xpr0177 Lepas Dubuisson, Claude Nicolas   architecte            1
# xpr0183             Loir, Jean Baptiste entrepreneur            1  61
# xpr0158        Le brun, Jacques Charles   architecte            2  56
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      2
#                             Départager      3
#            Estimer la valeur des biens      2
# Décrire et évaluer les travaux à venir      3
#                            Enregistrer      0
#
#
#
#
# Doucet, Jacques ; entrepreneur ; 4 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#                             Départager      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      3
#                            Enregistrer      0
#
#
#
#
# Dubois, Jean ; entrepreneur ; 15 expertises ; 0 expertises en tant que tiers-expert ; 9 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                  name       column  totalCollab age
# xpr0118 Gerard De Montbrouard, Claude Jacques   architecte            1  33
# xpr0147                        Joubert, Louis entrepreneur            1  50
# xpr0193                       Masson, Etienne entrepreneur            1  44
# xpr0048                        Caulle, Martin   architecte            2  65
# xpr0183                   Loir, Jean Baptiste entrepreneur            2  61
# xpr0232                        Quirot, Pierre   architecte            2  64
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      2
#                             Départager      5
#            Estimer la valeur des biens      3
# Décrire et évaluer les travaux à venir      4
#                            Enregistrer      1
#
#
#
#
# Duval, Charles ; arpenteur ; 2 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                name       column  totalCollab age
# xpr0183 Loir, Jean Baptiste entrepreneur            1  61
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#                             Départager      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                            Enregistrer      1
#
#
#
#
# Fauvel, Jean ; entrepreneur ; 6 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id              name       column  totalCollab age
# xpr0015 Belhomme, Maurice entrepreneur            1  59
# xpr0147    Joubert, Louis entrepreneur            1  50
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      3
#                             Départager      2
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      0
#                            Enregistrer      0
#
#
#
#
# Fourier, Edme (1668 - 1727) ; entrepreneur ; 41 expertises ; 4 expertises en tant que tiers-expert ; 15 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                 name       column  totalCollab age
# xpr0248                     Simonet, Nicolas   architecte            1  41
# xpr0177      Lepas Dubuisson, Claude Nicolas   architecte            1
# xpr0246                      Simon, Mathurin entrepreneur            1  60
# xpr0048                       Caulle, Martin   architecte            1  65
# xpr0073              De Bias Aubry, François   architecte            1
# xpr0183                  Loir, Jean Baptiste entrepreneur            2  61
# xpr0078 De Mezeretz (Fils), Charles Philippe   architecte            2  61
# xpr0232                       Quirot, Pierre   architecte            9  64
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      9
#                             Départager     13
#            Estimer la valeur des biens     13
# Décrire et évaluer les travaux à venir      3
#                            Enregistrer      2
#
#
#
#
# Fremiot, Nicolas ; entrepreneur ; 11 expertises ; 2 expertises en tant que tiers-expert ; 6 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                          name       column  totalCollab age
# xpr0179 Lepas Dubuisson, Jacques (II) entrepreneur            1  50
# xpr0158      Le brun, Jacques Charles   architecte            1  56
# xpr0222                 Plasnie, Jean entrepreneur            1  50
# xpr0183           Loir, Jean Baptiste entrepreneur            1  61
# xpr0054    Chauveau, René Bonaventure entrepreneur            1  33
# xpr0051   Chastelain, Nicolas Isidore entrepreneur            1  24
# xpr0018              Bernard, Charles   architecte            1  56
# xpr0232                Quirot, Pierre   architecte            1  64
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      2
#                             Départager      4
#            Estimer la valeur des biens      2
# Décrire et évaluer les travaux à venir      3
#                            Enregistrer      0
#
#
#
#
# Frosne, Jean Luc ; architecte ; 4 expertises ; 0 expertises en tant que tiers-expert ; 4 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                            name     column  totalCollab age
# xpr0158        Le brun, Jacques Charles architecte            1  56
# xpr0145   Jacquot De Villeneuve, Pierre architecte            1  45
# xpr0177 Lepas Dubuisson, Claude Nicolas architecte            1
# xpr0018                Bernard, Charles architecte            2  56
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#                             Départager      2
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      0
#                            Enregistrer      0
#
#
#
#
# Gerard De Montbrouard, Claude Jacques ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id         name       column  totalCollab age
# xpr0100 Dubois, Jean entrepreneur            1  78
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      1
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                            Enregistrer      0
#
#
#
#
# Jacquot De Villeneuve, Pierre ; architecte ; 24 expertises ; 0 expertises en tant que tiers-expert ; 11 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                name       column  totalCollab age
# xpr0017      Benoist, Louis   architecte            1
# xpr0147      Joubert, Louis entrepreneur            1  50
# xpr0113    Frosne, Jean Luc   architecte            1  70
# xpr0018    Bernard, Charles   architecte            1  56
# xpr0048      Caulle, Martin   architecte            1  65
# xpr0207    Paumier, Nicolas entrepreneur            1
# xpr0264  Vuyet, Jean Robert   architecte            2  62
# xpr0232      Quirot, Pierre   architecte            2  64
# xpr0183 Loir, Jean Baptiste entrepreneur            4  61
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      3
#                             Départager      4
#            Estimer la valeur des biens     11
# Décrire et évaluer les travaux à venir      5
#                            Enregistrer      0
#
#
#
#
# Joubert, Louis ; entrepreneur ; 15 expertises ; 1 expertises en tant que tiers-expert ; 8 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                          name       column  totalCollab age
# xpr0145 Jacquot De Villeneuve, Pierre   architecte            1  45
# xpr0100                  Dubois, Jean entrepreneur            1  78
# xpr0108                  Fauvel, Jean entrepreneur            1  32
# xpr0183           Loir, Jean Baptiste entrepreneur            2  61
# xpr0158      Le brun, Jacques Charles   architecte            2  56
# xpr0232                Quirot, Pierre   architecte            2  64
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé     10
#                             Départager      3
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      1
#                            Enregistrer      0
#
#
#
#
# Laisney, François Etienne ; entrepreneur ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                            Enregistrer      0
#
#
#
#
# Le brun, Jacques Charles ; architecte ; 26 expertises ; 1 expertises en tant que tiers-expert ; 19 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                 name       column  totalCollab age
# xpr0113                     Frosne, Jean Luc   architecte            1  70
# xpr0179        Lepas Dubuisson, Jacques (II) entrepreneur            1  50
# xpr0112                     Fremiot, Nicolas entrepreneur            1  61
# xpr0054           Chauveau, René Bonaventure entrepreneur            1  33
# xpr0207                     Paumier, Nicolas entrepreneur            1
# xpr0264                   Vuyet, Jean Robert   architecte            1  62
# xpr0233               Raymond, Jean François   architecte            1  38
# xpr0147                       Joubert, Louis entrepreneur            2  50
# xpr0232                       Quirot, Pierre   architecte            2  64
# xpr0086                   Delespine, Nicolas   architecte            2  84
# xpr0078 De Mezeretz (Fils), Charles Philippe   architecte            3  61
# xpr0183                  Loir, Jean Baptiste entrepreneur            6  61
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé     13
#                             Départager      5
#            Estimer la valeur des biens      4
# Décrire et évaluer les travaux à venir      4
#                            Enregistrer      0
#
#
#
#
# Le Chauve, Brice ; architecte ; 3 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                name       column  totalCollab age
# xpr0264  Vuyet, Jean Robert   architecte            1  62
# xpr0183 Loir, Jean Baptiste entrepreneur            1  61
# xpr0246     Simon, Mathurin entrepreneur            1  60
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      2
#                             Départager      0
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      0
#                            Enregistrer      0
#
#
#
#
# Le Sueur, Adrien ; architecte ; 5 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                name       column  totalCollab age
# xpr0232      Quirot, Pierre   architecte            1  64
# xpr0183 Loir, Jean Baptiste entrepreneur            1  61
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      3
#                             Départager      2
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                            Enregistrer      0
#
#
#
#
# Lepas Dubuisson, Claude Nicolas ; architecte ; 10 expertises ; 0 expertises en tant que tiers-expert ; 6 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                        name       column  totalCollab age
# xpr0113            Frosne, Jean Luc   architecte            1  70
# xpr0111 Fourier, Edme (1668 - 1727) entrepreneur            1  58
# xpr0086          Delespine, Nicolas   architecte            1  84
# xpr0232              Quirot, Pierre   architecte            1  64
# xpr0183         Loir, Jean Baptiste entrepreneur            3  61
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      2
#                             Départager      4
#            Estimer la valeur des biens      2
# Décrire et évaluer les travaux à venir      2
#                            Enregistrer      0
#
#
#
#
# Lepas Dubuisson, Jacques (II) ; entrepreneur ; 9 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0112         Fremiot, Nicolas entrepreneur            1  61
# xpr0158 Le brun, Jacques Charles   architecte            1  56
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      2
#                             Départager      6
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      1
#                            Enregistrer      0
#
#
#
#
# Loir, Jean Baptiste ; entrepreneur ; 171 expertises ; 14 expertises en tant que tiers-expert ; 54 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                 name       column  totalCollab age
# xpr0074                De La Croix, Philémon entrepreneur            1  37
# xpr0112                     Fremiot, Nicolas entrepreneur            1  61
# xpr0222                        Plasnie, Jean entrepreneur            1  50
# xpr0078 De Mezeretz (Fils), Charles Philippe   architecte            1  61
# xpr0160                     Le Chauve, Brice   architecte            1
# xpr0086                   Delespine, Nicolas   architecte            1  84
# xpr0105                       Duval, Charles    arpenteur            1
# xpr0236                Richard, Pierre Louis entrepreneur            1  30
# xpr0171                     Le Sueur, Adrien   architecte            1  40
# xpr0264                   Vuyet, Jean Robert   architecte            1  62
# xpr0073              De Bias Aubry, François   architecte            2
# xpr0233               Raymond, Jean François   architecte            2  38
# xpr0018                     Bernard, Charles   architecte            2  56
# xpr0147                       Joubert, Louis entrepreneur            2  50
# xpr0111          Fourier, Edme (1668 - 1727) entrepreneur            2  58
# xpr0100                         Dubois, Jean entrepreneur            2  78
# xpr0207                     Paumier, Nicolas entrepreneur            3
# xpr0177      Lepas Dubuisson, Claude Nicolas   architecte            3
# xpr0048                       Caulle, Martin   architecte            4  65
# xpr0145        Jacquot De Villeneuve, Pierre   architecte            4  45
# xpr0015                    Belhomme, Maurice entrepreneur            5  59
# xpr0017                       Benoist, Louis   architecte            6
# xpr0158             Le brun, Jacques Charles   architecte            6  56
# xpr0232                       Quirot, Pierre   architecte           11  64
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé     32
#                             Départager     47
#            Estimer la valeur des biens     67
# Décrire et évaluer les travaux à venir     23
#                            Enregistrer      1
#
#
#
#
# Masson, Etienne ; entrepreneur ; 7 expertises ; 0 expertises en tant que tiers-expert ; 4 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0054 Chauveau, René Bonaventure entrepreneur            1  33
# xpr0100               Dubois, Jean entrepreneur            1  78
# xpr0232             Quirot, Pierre   architecte            2  64
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      2
#                             Départager      1
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      3
#                            Enregistrer      1
#
#
#
#
# Paumier, Nicolas ; entrepreneur ; 15 expertises ; 0 expertises en tant que tiers-expert ; 10 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                          name       column  totalCollab age
# xpr0222                 Plasnie, Jean entrepreneur            1  50
# xpr0145 Jacquot De Villeneuve, Pierre   architecte            1  45
# xpr0015             Belhomme, Maurice entrepreneur            1  59
# xpr0158      Le brun, Jacques Charles   architecte            1  56
# xpr0086            Delespine, Nicolas   architecte            1  84
# xpr0232                Quirot, Pierre   architecte            2  64
# xpr0183           Loir, Jean Baptiste entrepreneur            3  61
# xpr0017                Benoist, Louis   architecte            4
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      4
#                             Départager      4
#            Estimer la valeur des biens      4
# Décrire et évaluer les travaux à venir      2
#                            Enregistrer      0
#
#
#
#
# Pirethouy, Jacques ; architecte ; 5 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id               name     column  totalCollab age
# xpr0086 Delespine, Nicolas architecte            1  84
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      2
#            Estimer la valeur des biens      2
# Décrire et évaluer les travaux à venir      1
#                            Enregistrer      0
#
#
#
#
# Plasnie, Jean ; entrepreneur ; 6 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                name       column  totalCollab age
# xpr0207    Paumier, Nicolas entrepreneur            1
# xpr0112    Fremiot, Nicolas entrepreneur            1  61
# xpr0183 Loir, Jean Baptiste entrepreneur            1  61
# xpr0232      Quirot, Pierre   architecte            1  64
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      4
#                             Départager      1
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      0
#                            Enregistrer      0
#
#
#
#
# Poirin, Jean Baptiste Michel ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      1
#                            Enregistrer      0
#
#
#
#
# Quirot, Pierre ; architecte ; 97 expertises ; 5 expertises en tant que tiers-expert ; 51 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                 name       column  totalCollab age
# xpr0073              De Bias Aubry, François   architecte            1
# xpr0054           Chauveau, René Bonaventure entrepreneur            1  33
# xpr0222                        Plasnie, Jean entrepreneur            1  50
# xpr0086                   Delespine, Nicolas   architecte            1  84
# xpr0236                Richard, Pierre Louis entrepreneur            1  30
# xpr0177      Lepas Dubuisson, Claude Nicolas   architecte            1
# xpr0171                     Le Sueur, Adrien   architecte            1  40
# xpr0112                     Fremiot, Nicolas entrepreneur            1  61
# xpr0246                      Simon, Mathurin entrepreneur            2  60
# xpr0015                    Belhomme, Maurice entrepreneur            2  59
# xpr0207                     Paumier, Nicolas entrepreneur            2
# xpr0193                      Masson, Etienne entrepreneur            2  44
# xpr0158             Le brun, Jacques Charles   architecte            2  56
# xpr0264                   Vuyet, Jean Robert   architecte            2  62
# xpr0145        Jacquot De Villeneuve, Pierre   architecte            2  45
# xpr0147                       Joubert, Louis entrepreneur            2  50
# xpr0100                         Dubois, Jean entrepreneur            2  78
# xpr0048                       Caulle, Martin   architecte            3  65
# xpr0078 De Mezeretz (Fils), Charles Philippe   architecte            5  61
# xpr0017                       Benoist, Louis   architecte            6
# xpr0111          Fourier, Edme (1668 - 1727) entrepreneur            9  58
# xpr0183                  Loir, Jean Baptiste entrepreneur           11  61
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé     52
#                             Départager     29
#            Estimer la valeur des biens     14
# Décrire et évaluer les travaux à venir      1
#                            Enregistrer      0
#
#
#
#
# Raymond, Jean François ; architecte ; 4 expertises ; 1 expertises en tant que tiers-expert ; 4 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0048           Caulle, Martin   architecte            1  65
# xpr0018         Bernard, Charles   architecte            1  56
# xpr0264       Vuyet, Jean Robert   architecte            1  62
# xpr0158 Le brun, Jacques Charles   architecte            1  56
# xpr0183      Loir, Jean Baptiste entrepreneur            2  61
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#                             Départager      2
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      1
#                            Enregistrer      0
#
#
#
#
# Richard, Pierre Louis ; entrepreneur ; 3 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                name       column  totalCollab age
# xpr0232      Quirot, Pierre   architecte            1  64
# xpr0183 Loir, Jean Baptiste entrepreneur            1  61
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#                             Départager      1
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      1
#                            Enregistrer      0
#
#
#
#
# Simon, Mathurin ; entrepreneur ; 12 expertises ; 0 expertises en tant que tiers-expert ; 6 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                        name       column  totalCollab age
# xpr0111 Fourier, Edme (1668 - 1727) entrepreneur            1  58
# xpr0086          Delespine, Nicolas   architecte            1  84
# xpr0074       De La Croix, Philémon entrepreneur            1  37
# xpr0048              Caulle, Martin   architecte            1  65
# xpr0160            Le Chauve, Brice   architecte            1
# xpr0232              Quirot, Pierre   architecte            2  64
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      3
#                             Départager      5
#            Estimer la valeur des biens      4
# Décrire et évaluer les travaux à venir      0
#                            Enregistrer      0
#
#
#
#
# Simonet, Nicolas ; architecte ; 2 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                        name       column  totalCollab age
# xpr0111 Fourier, Edme (1668 - 1727) entrepreneur            1  58
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#                             Départager      1
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      1
#                            Enregistrer      0
#
#
#
#
# Vuyet, Jean Robert ; architecte ; 13 expertises ; 0 expertises en tant que tiers-expert ; 7 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                          name       column  totalCollab age
# xpr0160              Le Chauve, Brice   architecte            1
# xpr0158      Le brun, Jacques Charles   architecte            1  56
# xpr0233        Raymond, Jean François   architecte            1  38
# xpr0063            Cudeville, Jacques    arpenteur            1
# xpr0183           Loir, Jean Baptiste entrepreneur            1  61
# xpr0145 Jacquot De Villeneuve, Pierre   architecte            2  45
# xpr0232                Quirot, Pierre   architecte            2  64
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      5
#                             Départager      4
#            Estimer la valeur des biens      3
# Décrire et évaluer les travaux à venir      0
#                            Enregistrer      0
#
#
#
#
# Cochois, Pierre (? - ?) ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [23], line 6
#       3 print("\n")
#       5 collabDF = pd.json_normalize(expert['expertises']['collab']['experts'])
# ----> 6 if expert['expertises']['collab']['total'] != 0: print(collabDF.to_string(columns=['id', 'name', 'column', 'totalCollab', 'age'], index=False))
#       7 print("\n")
#       8 categoriesDef = pd.json_normalize(expert['expertises']['categories'])
#
# File /srv/jy/env/python38_default/lib/python3.8/site-packages/pandas/core/frame.py:1174, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1171 from pandas import option_context
#    1173 with option_context("display.max_colwidth", max_colwidth):
# -> 1174     formatter = fmt.DataFrameFormatter(
#    1175         self,
#    1176         columns=columns,
#    1177         col_space=col_space,
#    1178         na_rep=na_rep,
#    1179         formatters=formatters,
#    1180         float_format=float_format,
#    1181         sparsify=sparsify,
#    1182         justify=justify,
#    1183         index_names=index_names,
#    1184         header=header,
#    1185         index=index,
#    1186         min_rows=min_rows,
#    1187         max_rows=max_rows,
#    1188         max_cols=max_cols,
#    1189         show_dimensions=show_dimensions,
#    1190         decimal=decimal,
#    1191     )
#    1192     return fmt.DataFrameRenderer(formatter).to_string(
#    1193         buf=buf,
#    1194         encoding=encoding,
#    1195         line_width=line_width,
#    1196     )
#
# File /srv/jy/env/python38_default/lib/python3.8/site-packages/pandas/io/formats/format.py:582, in DataFrameFormatter.__init__(self, frame, columns, col_space, header, index, na_rep, formatters, justify, float_format, sparsify, index_names, max_rows, min_rows, max_cols, show_dimensions, decimal, bold_rows, escape)
#     560 def __init__(
#     561     self,
#     562     frame: DataFrame,
#    (...)
#     579     escape: bool = True,
#     580 ):
#     581     self.frame = frame
# --> 582     self.columns = self._initialize_columns(columns)
#     583     self.col_space = self._initialize_colspace(col_space)
#     584     self.header = header
#
# File /srv/jy/env/python38_default/lib/python3.8/site-packages/pandas/io/formats/format.py:688, in DataFrameFormatter._initialize_columns(self, columns)
#     686 if columns is not None:
#     687     cols = ensure_index(columns)
# --> 688     self.frame = self.frame[cols]
#     689     return cols
#     690 else:
#
# File /srv/jy/env/python38_default/lib/python3.8/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File /srv/jy/env/python38_default/lib/python3.8/site-packages/pandas/core/indexes/base.py:5796, in Index._get_indexer_strict(self, key, axis_name)
#    5793 else:
#    5794     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5796 self._raise_if_missing(keyarr, indexer, axis_name)
#    5798 keyarr = self.take(indexer)
#    5799 if isinstance(key, Index):
#    5800     # GH 42790 - Preserve name from an Index
#
# File /srv/jy/env/python38_default/lib/python3.8/site-packages/pandas/core/indexes/base.py:5856, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5854     if use_interval_msg:
#    5855         key = list(key)
# -> 5856     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5858 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5859 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['id', 'name', 'column', 'totalCollab', 'age'], dtype='object')] are in the [columns]"
