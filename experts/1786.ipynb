# %% [markdown]
# # xprStats

# %%
# lib
from urllib.request import urlopen
import json  
import pandas as pd

# %%
# Récupération des donnée 
# param (date or thirdParty)
param = "1786"

# url
url = "https://experts.huma-num.fr/xpr/statistics/" + param

# enregistrement de la réponse
response = urlopen(url)

# lecture du json
data = json.loads(response.read())
  
# print the json response
#print(data)

# %% [markdown]
# ## Expertises

# %%
expertises = data['expertises']

# %%
print("Nombre total d'expertises : " + str(expertises['total']))
# Out:
# Nombre total d'expertises : 753

# %% [markdown]
# ### Croquis

# %%
sketchesDF = pd.json_normalize(expertises['sketches'])
print(sketchesDF.to_string(index=False))

# %% [markdown]
# ### Étendue

# %%
extent = expertises['extent']
#print(extent)

print('Nombre de feuillets : ' + str(extent['total']))

print('Moyenne par expertise : ' + str(extent['averageByExpertise']))

#Distribution
print('Distribution :')
keys = []
values = []
for dic in extent['extentDistribution']:
    for key, val in dic.items():
        keys.append(key),
        values.append(val)        

extentDistributionDict = {'nombre de feuillets': keys, 'nombre d’expertises': values,} 
print(pd.DataFrame(extentDistributionDict).to_string(index=False))
# Out:
# Nombre de feuillets : 7011
# Moyenne par expertise : 9.31
# Distribution :
# nombre de feuillets  nombre d’expertises
#                   5                  336
#                  10                  253
#                  15                   63
#                  20                   28
#                  25                   21
#                  30                   14
#                  35                    6
#                  40                    5
#                  45                    2
#                  50                    5
#                  55                    1
#                  60                    0
#                  65                    1
#                  70                    1
#                  75                    0
#                  80                    1
#                  85                    1
#                  90                    0
#                  95                    0
#                 100                    6

# %% [markdown]
# ### Annexes

# %%
appendices = expertises['appendices']
#print(appendices)

print(f"{appendices['total']} annexes")


print(f"{appendices['expertisesWithAppendices']} expertises avec annexes ; {appendices['expertisesWithoutAppendices']} expertises sans annexes")


df=pd.json_normalize(appendices['types'])
print(df.to_string(columns=['label', 'total', 'expertises'], index=False))
# Out:
# 648 annexes
# 332 expertises avec annexes ; 421 expertises sans annexes
#                                       label  total  expertises
#                                   Brouillon     52          47
#                                     Requête    113         105
#                                       Autre    200         126
#                      Plan, coupe, élévation    196          88
# Pouvoir/procuration (acte sous seing privé)     49          42
#          Pouvoir/procuration (acte notarié)     23          16
#                                     Croquis     13           6

# %% [markdown]
# ### Vacations

# %%
sessions = expertises['sessions']
#print(sessions)

print(f"{sessions['total']} vacations")


print(f"en moyenne {sessions['averageByExpertise']} vacations par expertise")
# Out:
# 4061 vacations
# en moyenne 5.39 vacations par expertise

# %% [markdown]
# Nombre de vacation par lieu

# %%
sessionsDf=pd.json_normalize(sessions['places'])
print(sessionsDf.to_string(columns=['label', 'total'], index=False))
# Out:
#    label  total
#    Paris   3392
# Banlieue    243
# Province    423

# %% [markdown]
# ### Durée

# %%
duration = expertises['duration']
#print(duration)

# %% [markdown]
# #### Jours

# %%
#Distribution
durationDays = duration['days']
#print(durationDays)
print('Distribution :')
keys = []
values = []
for dic in durationDays['distributionByDays']:
    for key, val in dic.items():
        keys.append(key),
        values.append(val)        

durationDaysDf = {'nombre de jours': keys, 'nombre d’expertises': values,} 
print(pd.DataFrame(durationDaysDf).to_string(index=False))
# Out:
# Distribution :
# nombre de jours  nombre d’expertises
#               5                  276
#              10                   61
#              15                   44
#              20                   41
#              25                   24
#              30                   32
#              35                   14
#              40                   30
#              45                   16
#              50                   16
#              55                   10
#              60                    6
#              65                   12
#              70                    7
#              75                    6
#              80                    6
#              85                    7
#              90                    3
#              95                    3
#             100                  135

# %% [markdown]
# #### Vacations

# %%
#Distribution
durationSessions = duration['sessions']
#print(durationDays)
print(f"{durationSessions['total']} vacations, soit en moyenne {durationSessions['averageByExpertise']} vacations par expertise.")
# Out:
# 4061 vacations, soit en moyenne 2.7 vacations par expertise.

# %% [markdown]
# ### Lieux

# %%
places = expertises['places']
#print(places)

placesDf=pd.json_normalize(places)
print(placesDf.to_string(columns=['place', 'total'], index=False))
# Out:
#                        place  total
#                      [paris]    505
#                    [suburbs]     61
#                   [province]     68
#           [[paris, suburbs]]     28
#          [[paris, province]]     84
#        [[suburbs, province]]      2
# [[paris, suburbs, province]]      2

# %% [markdown]
# ### Procédures et cadres

# %%
frameworks = expertises['frameworks']
#print(frameworks)

frameworksDf=pd.json_normalize(frameworks)
print(frameworksDf.to_string(columns=['label', 'framework', 'total'], index=False))
# Out:
#                                                                                                                   label framework  total
# L’institution est saisie dans le cadre d’une procédure (les parties nomment chacune leur expert ou un expert en commun)        b2    445
#                         L’institution est saisie dans le cadre d’une procédure (l’institution nomme un ou deux experts)       b2b     83
# L’institution est saisie dans le cadre d’une procédure (les parties nomment chacune leur expert ou un expert en commun)       b2a     55
#                                          Saisie mixte (un expert est nommé par les parties, l'autre est nommé d'office)        b3     13
#                                                                                               Commun accord des parties         a     30
#                                                                                                       Cas problématique         c      7
#                                                     Requête auprès d’une institution pour qu’elle demande une expertise        b1    118
#                                                                                                                                        2

# %% [markdown]
# ### Catégories

# %%
categories = expertises['categories']

for cat in categories:
    if cat['total'] != 0: print(f"{cat['label']} : {cat['total']} expertises"),
    for framework in cat['frameworks']:
        if framework['total'] != 0: print(f"\t{framework['framework']} : {framework['total']} expertises"),
        for place in framework['places']:
            if place['total'] != 0: print(f"\t\t{place['place']} : {place['total']}"),
            for obj in place['objects']:
                if obj['total'] != 0: print(f"\t\t\t{obj['label']} : {obj['total']}")
        print('\n')
    print('\n')
# Out:
# Recevoir et évaluer le travail réalisé : 203 expertises
# 	b2 : 126 expertises
# 		['paris'] : 88
# 			Ouvrages de maçonnerie : 85
# 			Mur(s) : 1
# 			Fosse(s) d'aisance : 1
# 		['suburbs'] : 11
# 			Ouvrages de maçonnerie : 11
# 		['province'] : 4
# 			Ouvrages de maçonnerie : 4
# 		[['paris', 'suburbs']] : 6
# 			Ouvrages de maçonnerie : 6
# 		[['paris', 'province']] : 17
# 			Ouvrages de maçonnerie : 17
#
#
# 	b2b : 13 expertises
# 		['paris'] : 10
# 			Ouvrages de maçonnerie : 8
# 			Maison(s) : 3
# 		['suburbs'] : 2
# 			Ouvrages de maçonnerie : 2
# 		['province'] : 1
# 			Maison(s) : 1
#
#
# 	b2a : 30 expertises
# 		['paris'] : 22
# 			Ouvrages de maçonnerie : 21
# 			Maison(s) : 1
# 		['suburbs'] : 2
# 			Ouvrages de maçonnerie : 2
# 		['province'] : 2
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 		[['paris', 'province']] : 2
# 			Ensemble de bâtiments (biens immeubles) : 2
#
#
# 	b3 : 4 expertises
# 		['paris'] : 4
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
#
#
# 	a : 7 expertises
# 		['paris'] : 3
# 			Ouvrages de maçonnerie : 3
# 		['province'] : 2
# 			Ouvrages de maçonnerie : 2
# 		[['paris', 'suburbs']] : 2
# 			Ouvrages de maçonnerie : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
#
#
# 	c : 4 expertises
# 		['paris'] : 4
# 			Ouvrages de maçonnerie : 4
#
#
# 	b1 : 19 expertises
# 		['paris'] : 14
# 			Ouvrages de maçonnerie : 14
# 		[['paris', 'suburbs']] : 3
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 1
# 		[['paris', 'province']] : 2
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
#
#
#
#
#
#
# Estimer la valeur des biens : 276 expertises
# 	b2 : 156 expertises
# 		['paris'] : 104
# 			Ouvrages de maçonnerie : 18
# 			Maison(s) : 85
# 			Terrain(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
# 			Domaine, terres, fief : 1
# 			Fosse(s) d'aisance : 1
# 		['suburbs'] : 8
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 7
# 			Terrain(s) : 2
# 		['province'] : 22
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 19
# 			Terrain(s) : 8
# 			Ensemble de bâtiments (biens immeubles) : 1
# 			Domaine, terres, fief : 1
# 		[['paris', 'suburbs']] : 2
# 			Maison(s) : 2
# 		[['paris', 'province']] : 17
# 			Ouvrages de maçonnerie : 3
# 			Maison(s) : 12
# 			Terrain(s) : 6
# 			Domaine, terres, fief : 4
# 		[['suburbs', 'province']] : 2
# 			Maison(s) : 2
# 			Terrain(s) : 2
# 		[['paris', 'suburbs', 'province']] : 1
# 			Maison(s) : 1
#
#
# 	b2b : 45 expertises
# 		['paris'] : 25
# 			Ouvrages de maçonnerie : 3
# 			Maison(s) : 20
# 			Terrain(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		['suburbs'] : 4
# 			Maison(s) : 2
# 			Terrain(s) : 2
# 			Domaine, terres, fief : 1
# 		['province'] : 7
# 			Maison(s) : 7
# 			Terrain(s) : 4
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		[['paris', 'suburbs']] : 3
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 2
# 			Terrain(s) : 2
# 		[['paris', 'province']] : 6
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 			Terrain(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 4
# 			Domaine, terres, fief : 4
#
#
# 	b2a : 13 expertises
# 		['paris'] : 6
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 4
# 		['suburbs'] : 1
# 			Ouvrages de maçonnerie : 1
# 		['province'] : 3
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 2
# 			Ensemble de bâtiments (biens immeubles) : 2
# 		[['paris', 'province']] : 3
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 2
# 			Ensemble de bâtiments (biens immeubles) : 1
# 			Domaine, terres, fief : 2
#
#
# 	b3 : 5 expertises
# 		['suburbs'] : 1
# 			Terrain(s) : 1
# 		['province'] : 3
# 			Maison(s) : 3
# 			Terrain(s) : 3
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		[['paris', 'province']] : 1
# 			Ouvrages de maçonnerie : 1
# 			Domaine, terres, fief : 1
#
#
# 	a : 7 expertises
# 		['paris'] : 4
# 			Maison(s) : 3
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		['suburbs'] : 1
# 			Terrain(s) : 1
# 		[['paris', 'province']] : 2
# 			Ouvrages de maçonnerie : 1
# 			Terrain(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
#
#
# 	c : 2 expertises
# 		['paris'] : 2
# 			Maison(s) : 2
#
#
# 	b1 : 47 expertises
# 		['paris'] : 29
# 			Maison(s) : 26
# 			Terrain(s) : 3
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		['suburbs'] : 7
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 5
# 			Terrain(s) : 3
# 		['province'] : 2
# 			Maison(s) : 1
# 			Terrain(s) : 1
# 		[['paris', 'suburbs']] : 1
# 			Maison(s) : 1
# 			Terrain(s) : 1
# 		[['paris', 'province']] : 8
# 			Maison(s) : 4
# 			Terrain(s) : 3
# 			Ensemble de bâtiments (biens immeubles) : 1
# 			Domaine, terres, fief : 5
#
#
# 	 : 1 expertises
# 		['paris'] : 1
# 			Maison(s) : 1
#
#
#
#
# Décrire et évaluer les travaux à venir : 132 expertises
# 	b2 : 84 expertises
# 		['paris'] : 48
# 			Ouvrages de maçonnerie : 46
# 			Maison(s) : 2
# 			Fosse(s) d'aisance : 2
# 			Puits : 1
# 		['suburbs'] : 6
# 			Ouvrages de maçonnerie : 5
# 			Maison(s) : 1
# 			Terrain(s) : 1
# 			Mur(s) : 1
# 		['province'] : 14
# 			Ouvrages de maçonnerie : 12
# 			Terrain(s) : 1
# 		[['paris', 'suburbs']] : 4
# 			Ouvrages de maçonnerie : 4
# 			Terrain(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		[['paris', 'province']] : 12
# 			Ouvrages de maçonnerie : 12
# 			Maison(s) : 3
#
#
# 	b2b : 15 expertises
# 		['paris'] : 11
# 			Ouvrages de maçonnerie : 3
# 			Maison(s) : 6
# 			Terrain(s) : 4
# 		['suburbs'] : 1
# 			Maison(s) : 1
# 		['province'] : 1
# 			Maison(s) : 1
# 		[['paris', 'province']] : 2
# 			Maison(s) : 2
#
#
# 	b2a : 4 expertises
# 		['paris'] : 3
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 2
# 			Mur(s) : 1
# 		['province'] : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
#
#
# 	b3 : 3 expertises
# 		['paris'] : 3
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 2
#
#
# 	a : 5 expertises
# 		['paris'] : 4
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 2
# 		[['paris', 'suburbs']] : 1
# 			Maison(s) : 1
#
#
# 	c : 1 expertises
# 		['paris'] : 1
# 			Ouvrages de maçonnerie : 1
#
#
# 	b1 : 19 expertises
# 		['paris'] : 14
# 			Ouvrages de maçonnerie : 9
# 			Maison(s) : 5
# 			Fosse(s) d'aisance : 1
# 		['suburbs'] : 2
# 			Ouvrages de maçonnerie : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		['province'] : 2
# 			Ouvrages de maçonnerie : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		[['paris', 'province']] : 1
# 			Ouvrages de maçonnerie : 1
#
#
# 	 : 1 expertises
# 		['paris'] : 1
#
#
#
#
# Départager : 85 expertises
# 	b2 : 62 expertises
# 		['paris'] : 45
# 			Ouvrages de maçonnerie : 26
# 			Maison(s) : 3
# 			Terrain(s) : 1
# 			Mur(s) : 14
# 			Fosse(s) d'aisance : 4
# 		['suburbs'] : 7
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 1
# 			Terrain(s) : 3
# 			Mur(s) : 1
# 			Fosse(s) d'aisance : 1
# 			Puits : 1
# 		['province'] : 2
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 		[['paris', 'suburbs']] : 2
# 			Ouvrages de maçonnerie : 1
# 			Mur(s) : 1
# 		[['paris', 'province']] : 6
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 			Terrain(s) : 2
# 			Mur(s) : 4
# 			Domaine, terres, fief : 1
#
#
# 	b2b : 7 expertises
# 		['paris'] : 5
# 			Ouvrages de maçonnerie : 4
# 			Maison(s) : 2
# 		['suburbs'] : 1
# 			Ouvrages de maçonnerie : 1
# 		[['paris', 'province']] : 1
# 			Mur(s) : 1
#
#
# 	b2a : 7 expertises
# 		['paris'] : 5
# 			Ouvrages de maçonnerie : 2
# 			Mur(s) : 3
# 			Ensemble de bâtiments (biens immeubles) : 1
# 			Fosse(s) d'aisance : 1
# 		['suburbs'] : 1
# 			Ouvrages de maçonnerie : 1
# 			Terrain(s) : 1
# 		[['paris', 'province']] : 1
# 			Mur(s) : 1
#
#
# 	b3 : 1 expertises
# 		['paris'] : 1
# 			Maison(s) : 1
#
#
# 	a : 8 expertises
# 		['paris'] : 8
# 			Ouvrages de maçonnerie : 3
# 			Mur(s) : 6
#
#
#
#
#
#
#
#
#
#
# Enregistrer : 40 expertises
# 	b2 : 4 expertises
# 		['paris'] : 4
# 			Ouvrages de maçonnerie : 3
# 			Maison(s) : 1
#
#
# 	b2b : 3 expertises
# 		['paris'] : 1
# 			Maison(s) : 1
# 			Terrain(s) : 1
# 		['suburbs'] : 2
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 			Terrain(s) : 1
#
#
#
#
#
#
# 	a : 2 expertises
# 		['paris'] : 2
# 			Mur(s) : 2
#
#
#
#
# 	b1 : 31 expertises
# 		['paris'] : 24
# 			Ouvrages de maçonnerie : 24
# 			Maison(s) : 4
# 			Terrain(s) : 14
# 		['suburbs'] : 3
# 			Ouvrages de maçonnerie : 3
# 			Maison(s) : 1
# 			Terrain(s) : 2
# 		['province'] : 1
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 			Terrain(s) : 1
# 		[['paris', 'suburbs']] : 1
# 			Maison(s) : 1
# 		[['paris', 'province']] : 1
# 			Ouvrages de maçonnerie : 1

# %% [markdown]
# ### Tiers expertises

# %%
thirdParty = expertises['thirdParty']

# %%
thirdPartyDf=pd.json_normalize(thirdParty)
print(thirdPartyDf.to_string(columns=['architectes', 'entrepreneurs', 'total'], index=False))
# Out:
#  architectes  entrepreneurs  total
#            7              4     11

# %% [markdown]
# ### Distribution (hors tiers expertises)

# %%
columnDistrib = expertises['experts']

for column in columnDistrib:
    print(f"{column['totalExperts']} expert(s) : {column['totalExpertises']} expertises"),
    if column['totalExperts']<3: print(pd.json_normalize(column['distribution']).to_string(columns=['label', 'total'], index=False))
    print('\n')
# Out:
# 1 expert(s) : 493 expertises
#        label  total
#   architecte    303
# entrepreneur    190
#
#
# 2 expert(s) : 235 expertises
#                       label  total
#     architecte - architecte     70
#   entrepreneur - architecte    113
# entrepreneur - entrepreneur     51
#
#
# 3 expert(s) : 14 expertises

# %% [markdown]
# ## Experts

# %%
experts = data['experts']
#print(experts)

# %%
print(f"Nombre d’experts : {experts['total']}")
print(f"{experts['architects']} architectes")
print(f"{experts['entrepreneur']} entrepreneurs")
print(f"{experts['surveyor']} arpenteurs")
# Out:
# Nombre d’experts : 70
# 43 architectes
# 27 entrepreneurs
# 0 arpenteurs

# %%
listExperts = experts['list']
listExpertsDf = pd.DataFrame(listExperts)
listExpertsDf.drop('expertises', inplace=True, axis=1)

# %%
print(listExpertsDf.to_string(columns=['id', 'name', 'column', 'age'], index=False))
# Out:
#      id                                                                     name       column age
# xpr0002                                                     André, Jean Baptiste   architecte  51
# xpr0003                                                       Angot, Jean Pierre entrepreneur  47
# xpr0004                                                         Antoine, Antoine   architecte  40
# xpr0005                                                   Antoine, Jacques Denis   architecte  53
# xpr0007                                                            Aubert, André entrepreneur  41
# xpr0016                                    Bellanger, Guillaume François Gabriel entrepreneur
# xpr0024                                                      Blanchard, Jean-Luc   architecte
# xpr0026                                                        Bleve, Jean Louis   architecte  59
# xpr0031                                                     Bouchu, Paul Antoine   architecte  46
# xpr0033                                          Boullant, Jean Baptiste Vincent   architecte  47
# xpr0038                                                 Bourgeois, Louis Silvain entrepreneur  50
# xpr0042                                                          Buron, François entrepreneur  55
# xpr0043                                            Le Camus de Mézières, Nicolas   architecte  61
# xpr0044                                                   Capron, Charles Martin entrepreneur  56
# xpr0049                                               Chabouille, Médéric Joseph entrepreneur  44
# xpr0050                                                  Chasteau, Jean François entrepreneur  52
# xpr0055                                                   Clavareau, Jean Pierre   architecte  65
# xpr0064                                             D'herbelot, Francois-Charles   architecte
# xpr0065                                                 Danjan, Pierre Alexandre   architecte  64
# xpr0068                                          Dauvergne, Nicolas Rémy Gabriel   architecte  38
# xpr0079                                              De Varenne, Claude Estienne   architecte  80
# xpr0081                                              De Villers, Eustache Robert   architecte  66
# xpr0082                                                        De Vonges, Michel   architecte  72
# xpr0085                                                   Delespine, Louis Jules   architecte  60
# xpr0090 Desjardins, Jean Baptiste Guillaume Alexandre Georges Balthazard Auguste   architecte  32
# xpr0091                                                       Desmaisons, Pierre   architecte  75
# xpr0092                                             Desmaisons, Jacques François   architecte  71
# xpr0095                                                  Dosmond, Léonard Pierre   architecte  35
# xpr0101                                               Duboiscerf, Sébastien Jean entrepreneur  73
# xpr0102                                                          Ducret, Nicolas   architecte  59
# xpr0104                                                     Dumont, Jean Charles entrepreneur  58
# xpr0106                                                      Egresset, Guillaume entrepreneur  75
# xpr0114                                               Gabriel, Nicolas Toussaint   architecte  47
# xpr0122                                                     Giraud, Pierre Marie   architecte  52
# xpr0127                                                          Goulet, Nicolas entrepreneur  41
# xpr0129                                                         Goupy Ii, Martin   architecte  52
# xpr0137                                                  Hallet, Etienne-Sulpice   architecte
# xpr0143                                                     Jacob, Jean François entrepreneur  51
# xpr0144                                                          Jacob, François   architecte
# xpr0155                                                 Lardant, Pierre François entrepreneur  55
# xpr0159                                                Le brun, Charles François   architecte  78
# xpr0163                                                Le Foulon, Guillaume Elie entrepreneur  59
# xpr0169                                                            Le Roux, Jean   architecte
# xpr0176                                                             Lemit, Louis   architecte  41
# xpr0187                                                     Mangin, Jean Charles   architecte  37
# xpr0199                                                 Mouchelet, Georges Louis   architecte
# xpr0200                                                           Mouchet, André entrepreneur
# xpr0201                                                            Neveu, Michel entrepreneur  53
# xpr0203                                                         Normand, Nicolas   architecte  43
# xpr0205                                          Parvy De La Renaudiere, Nicolas entrepreneur  52
# xpr0215                                                            Petit, Pierre entrepreneur  42
# xpr0216                                              Petit Radel, Louis François   architecte  46
# xpr0226                                                   Porquet, Claude Joseph   architecte  64
# xpr0228                                           Poulain, Jean Baptiste Martial   architecte  51
# xpr0229                                         Pruneau De Montlouis, Jean Louis   architecte  63
# xpr0235                               Regnard De Barentin, Bernard Jean Baptiste entrepreneur  47
# xpr0238                                                    Roche, Honoré Jacques   architecte  44
# xpr0245                                                             Siguy, Louis entrepreneur  48
# xpr0247                                                      Simon, René Auguste entrepreneur  74
# xpr0249                                                 Soisson, Charles Nicolas entrepreneur
# xpr0250                                                        Taboureur, Pierre   architecte  50
# xpr0252                                                    Terrier, Martin Marie   architecte  58
# xpr0254                                                   Thevenin, Jacques-Jean entrepreneur
# xpr0256                                                    Varin, Bénigne Joseph entrepreneur  28
# xpr0258                                    Vavasseur Desperriers, Louis Athanase entrepreneur  44
# xpr0260                                                  Villetard, Jean Etienne   architecte
# xpr0261                                                       Villetard, Etienne entrepreneur  60
# xpr0273                                                 Lefort, François (? - ?)   architecte
# xpr0274                                                   Lomet, Quentin (? - ?)   architecte
# xpr0277                                                Jamain, Sébastien (? - ?)   architecte   0

# %%
for expert in listExperts:
    print(f"{expert['name']} ; {expert['column']} ; {expert['expertises']['total']} expertises ; {expert['expertises']['thirParty']} expertises en tant que tiers-expert ; {expert['expertises']['collab']['total']} expertises avec d'autres experts (tiers expertises comprises)"),
    print("\n")
    
    collabDF = pd.json_normalize(expert['expertises']['collab']['experts']) 
    if expert['expertises']['collab']['total'] != 0: print(collabDF.to_string(columns=['id', 'name', 'column', 'totalCollab', 'age'], index=False))
    print("\n")
    categoriesDef = pd.json_normalize(expert['expertises']['categories'])
    print(categoriesDef.to_string(columns=['label', 'total'], index=False))

    print("\n")
    print("\n")
# Out:
# André, Jean Baptiste ; architecte ; 2 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                    name       column  totalCollab age
# xpr0102         Ducret, Nicolas   architecte            1  59
# xpr0095 Dosmond, Léonard Pierre   architecte            1  35
# xpr0261      Villetard, Etienne entrepreneur            1  60
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Angot, Jean Pierre ; entrepreneur ; 7 expertises ; 0 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                        name       column  totalCollab age
# xpr0187        Mangin, Jean Charles   architecte            1  37
# xpr0216 Petit Radel, Louis François   architecte            1  46
# xpr0215               Petit, Pierre entrepreneur            1  42
# xpr0250           Taboureur, Pierre   architecte            2  50
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      4
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Antoine, Antoine ; architecte ; 7 expertises ; 0 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                            name       column  totalCollab age
# xpr0250               Taboureur, Pierre   architecte            1  50
# xpr0104            Dumont, Jean Charles entrepreneur            1  58
# xpr0102                 Ducret, Nicolas   architecte            1  59
# xpr0033 Boullant, Jean Baptiste Vincent   architecte            1  47
# xpr0199        Mouchelet, Georges Louis   architecte            1
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      5
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# Antoine, Jacques Denis ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Aubert, André ; entrepreneur ; 5 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id              name     column  totalCollab age
# xpr0203  Normand, Nicolas architecte            1  43
# xpr0250 Taboureur, Pierre architecte            2  50
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      3
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      1
#
#
#
#
# Bellanger, Guillaume François Gabriel ; entrepreneur ; 5 expertises ; 0 expertises en tant que tiers-expert ; 4 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                           name       column  totalCollab age
# xpr0215                  Petit, Pierre entrepreneur            1  42
# xpr0049     Chabouille, Médéric Joseph entrepreneur            1  44
# xpr0228 Poulain, Jean Baptiste Martial   architecte            1  51
# xpr0260        Villetard, Jean Etienne   architecte            1
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#            Estimer la valeur des biens      4
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Blanchard, Jean-Luc ; architecte ; 6 expertises ; 0 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                       name       column  totalCollab age
# xpr0127                            Goulet, Nicolas entrepreneur            1  41
# xpr0049                 Chabouille, Médéric Joseph entrepreneur            1  44
# xpr0235 Regnard De Barentin, Bernard Jean Baptiste entrepreneur            1  47
# xpr0215                              Petit, Pierre entrepreneur            2  42
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      2
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      4
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Bleve, Jean Louis ; architecte ; 20 expertises ; 0 expertises en tant que tiers-expert ; 14 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                                                     name       column  totalCollab age
# xpr0102                                                          Ducret, Nicolas   architecte            1  59
# xpr0090 Desjardins, Jean Baptiste Guillaume Alexandre Georges Balthazard Auguste   architecte            1  32
# xpr0050                                                  Chasteau, Jean François entrepreneur            1  52
# xpr0095                                                  Dosmond, Léonard Pierre   architecte            1  35
# xpr0104                                                     Dumont, Jean Charles entrepreneur            1  58
# xpr0101                                               Duboiscerf, Sébastien Jean entrepreneur            1  73
# xpr0228                                           Poulain, Jean Baptiste Martial   architecte            1  51
# xpr0187                                                     Mangin, Jean Charles   architecte            2  37
# xpr0215                                                            Petit, Pierre entrepreneur            2  42
# xpr0261                                                       Villetard, Etienne entrepreneur            2  60
# xpr0250                                                        Taboureur, Pierre   architecte            2  50
# xpr0031                                                     Bouchu, Paul Antoine   architecte            2  46
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      9
#            Estimer la valeur des biens      5
# Décrire et évaluer les travaux à venir      4
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# Bouchu, Paul Antoine ; architecte ; 15 expertises ; 0 expertises en tant que tiers-expert ; 10 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0143       Jacob, Jean François entrepreneur            1  51
# xpr0101 Duboiscerf, Sébastien Jean entrepreneur            1  73
# xpr0203           Normand, Nicolas   architecte            1  43
# xpr0187       Mangin, Jean Charles   architecte            1  37
# xpr0065   Danjan, Pierre Alexandre   architecte            1  64
# xpr0104       Dumont, Jean Charles entrepreneur            1  58
# xpr0260    Villetard, Jean Etienne   architecte            1
# xpr0137    Hallet, Etienne-Sulpice   architecte            1
# xpr0026          Bleve, Jean Louis   architecte            2  59
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      8
#            Estimer la valeur des biens      2
# Décrire et évaluer les travaux à venir      3
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# Boullant, Jean Baptiste Vincent ; architecte ; 27 expertises ; 0 expertises en tant que tiers-expert ; 11 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                           name       column  totalCollab age
# xpr0044         Capron, Charles Martin entrepreneur            1  56
# xpr0065       Danjan, Pierre Alexandre   architecte            1  64
# xpr0216    Petit Radel, Louis François   architecte            1  46
# xpr0004               Antoine, Antoine   architecte            1  40
# xpr0199       Mouchelet, Georges Louis   architecte            1
# xpr0085         Delespine, Louis Jules   architecte            1  60
# xpr0228 Poulain, Jean Baptiste Martial   architecte            1  51
# xpr0095        Dosmond, Léonard Pierre   architecte            1  35
# xpr0215                  Petit, Pierre entrepreneur            2  42
# xpr0250              Taboureur, Pierre   architecte            3  50
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      5
#            Estimer la valeur des biens      5
# Décrire et évaluer les travaux à venir      5
#                             Départager      8
#                            Enregistrer      4
#
#
#
#
# Bourgeois, Louis Silvain ; entrepreneur ; 2 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                 name       column  totalCollab age
# xpr0102      Ducret, Nicolas   architecte            1  59
# xpr0104 Dumont, Jean Charles entrepreneur            1  58
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      1
#
#
#
#
# Buron, François ; entrepreneur ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Le Camus de Mézières, Nicolas ; architecte ; 5 expertises ; 0 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                            name       column  totalCollab age
# xpr0205 Parvy De La Renaudiere, Nicolas entrepreneur            1  52
# xpr0101      Duboiscerf, Sébastien Jean entrepreneur            1  73
# xpr0261              Villetard, Etienne entrepreneur            1  60
# xpr0203                Normand, Nicolas   architecte            1  43
# xpr0228  Poulain, Jean Baptiste Martial   architecte            1  51
# xpr0143            Jacob, Jean François entrepreneur            1  51
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      3
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      1
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Capron, Charles Martin ; entrepreneur ; 8 expertises ; 0 expertises en tant que tiers-expert ; 4 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                            name     column  totalCollab age
# xpr0033 Boullant, Jean Baptiste Vincent architecte            1  47
# xpr0068 Dauvergne, Nicolas Rémy Gabriel architecte            1  38
# xpr0250               Taboureur, Pierre architecte            2  50
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      2
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      3
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Chabouille, Médéric Joseph ; entrepreneur ; 3 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                  name       column  totalCollab age
# xpr0250                     Taboureur, Pierre   architecte            1  50
# xpr0024                   Blanchard, Jean-Luc   architecte            1
# xpr0016 Bellanger, Guillaume François Gabriel entrepreneur            1
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      2
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Chasteau, Jean François ; entrepreneur ; 7 expertises ; 1 expertises en tant que tiers-expert ; 6 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                           name       column  totalCollab age
# xpr0250              Taboureur, Pierre   architecte            1  50
# xpr0104           Dumont, Jean Charles entrepreneur            1  58
# xpr0176                   Lemit, Louis   architecte            1  41
# xpr0261             Villetard, Etienne entrepreneur            1  60
# xpr0228 Poulain, Jean Baptiste Martial   architecte            1  51
# xpr0026              Bleve, Jean Louis   architecte            1  59
# xpr0095        Dosmond, Léonard Pierre   architecte            1  35
# xpr0101     Duboiscerf, Sébastien Jean entrepreneur            1  73
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      3
#            Estimer la valeur des biens      4
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Clavareau, Jean Pierre ; architecte ; 6 expertises ; 0 expertises en tant que tiers-expert ; 6 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                       name       column  totalCollab age
# xpr0102                            Ducret, Nicolas   architecte            1  59
# xpr0235 Regnard De Barentin, Bernard Jean Baptiste entrepreneur            1  47
# xpr0228             Poulain, Jean Baptiste Martial   architecte            1  51
# xpr0250                          Taboureur, Pierre   architecte            1  50
# xpr0101                 Duboiscerf, Sébastien Jean entrepreneur            2  73
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#            Estimer la valeur des biens      3
# Décrire et évaluer les travaux à venir      1
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# D'herbelot, Francois-Charles ; architecte ; 2 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                           name     column  totalCollab age
# xpr0228 Poulain, Jean Baptiste Martial architecte            1  51
# xpr0102                Ducret, Nicolas architecte            1  59
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      1
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Danjan, Pierre Alexandre ; architecte ; 11 expertises ; 0 expertises en tant que tiers-expert ; 10 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                            name       column  totalCollab age
# xpr0143            Jacob, Jean François entrepreneur            1  51
# xpr0104            Dumont, Jean Charles entrepreneur            1  58
# xpr0261              Villetard, Etienne entrepreneur            1  60
# xpr0033 Boullant, Jean Baptiste Vincent   architecte            1  47
# xpr0106             Egresset, Guillaume entrepreneur            1  75
# xpr0250               Taboureur, Pierre   architecte            1  50
# xpr0031            Bouchu, Paul Antoine   architecte            1  46
# xpr0215                   Petit, Pierre entrepreneur            4  42
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      4
#            Estimer la valeur des biens      2
# Décrire et évaluer les travaux à venir      2
#                             Départager      3
#                            Enregistrer      0
#
#
#
#
# Dauvergne, Nicolas Rémy Gabriel ; architecte ; 8 expertises ; 1 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0187       Mangin, Jean Charles   architecte            1  37
# xpr0101 Duboiscerf, Sébastien Jean entrepreneur            1  73
# xpr0044     Capron, Charles Martin entrepreneur            1  56
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      2
#            Estimer la valeur des biens      2
# Décrire et évaluer les travaux à venir      1
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# De Varenne, Claude Estienne ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      1
#
#
#
#
# De Villers, Eustache Robert ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# De Vonges, Michel ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Delespine, Louis Jules ; architecte ; 23 expertises ; 0 expertises en tant que tiers-expert ; 8 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                            name       column  totalCollab age
# xpr0261              Villetard, Etienne entrepreneur            1  60
# xpr0199        Mouchelet, Georges Louis   architecte            1
# xpr0250               Taboureur, Pierre   architecte            1  50
# xpr0033 Boullant, Jean Baptiste Vincent   architecte            1  47
# xpr0114      Gabriel, Nicolas Toussaint   architecte            1  47
# xpr0104            Dumont, Jean Charles entrepreneur            3  58
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#            Estimer la valeur des biens      7
# Décrire et évaluer les travaux à venir      9
#                             Départager      4
#                            Enregistrer      1
#
#
#
#
# Desjardins, Jean Baptiste Guillaume Alexandre Georges Balthazard Auguste ; architecte ; 4 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id              name     column  totalCollab age
# xpr0102   Ducret, Nicolas architecte            1  59
# xpr0026 Bleve, Jean Louis architecte            1  59
# xpr0250 Taboureur, Pierre architecte            1  50
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      3
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Desmaisons, Pierre ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Desmaisons, Jacques François ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Dosmond, Léonard Pierre ; architecte ; 14 expertises ; 1 expertises en tant que tiers-expert ; 9 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                            name       column  totalCollab age
# xpr0102                 Ducret, Nicolas   architecte            1  59
# xpr0002            André, Jean Baptiste   architecte            1  51
# xpr0215                   Petit, Pierre entrepreneur            1  42
# xpr0050         Chasteau, Jean François entrepreneur            1  52
# xpr0026               Bleve, Jean Louis   architecte            1  59
# xpr0250               Taboureur, Pierre   architecte            1  50
# xpr0033 Boullant, Jean Baptiste Vincent   architecte            1  47
# xpr0104            Dumont, Jean Charles entrepreneur            2  58
# xpr0228  Poulain, Jean Baptiste Martial   architecte            2  51
# xpr0261              Villetard, Etienne entrepreneur            2  60
# xpr0101      Duboiscerf, Sébastien Jean entrepreneur            2  73
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      6
#            Estimer la valeur des biens      2
# Décrire et évaluer les travaux à venir      4
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# Duboiscerf, Sébastien Jean ; entrepreneur ; 165 expertises ; 2 expertises en tant que tiers-expert ; 54 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                            name       column  totalCollab age
# xpr0260         Villetard, Jean Etienne   architecte            1
# xpr0205 Parvy De La Renaudiere, Nicolas entrepreneur            1  52
# xpr0043   Le Camus de Mézières, Nicolas   architecte            1  61
# xpr0254          Thevenin, Jacques-Jean entrepreneur            1
# xpr0114      Gabriel, Nicolas Toussaint   architecte            1  47
# xpr0031            Bouchu, Paul Antoine   architecte            1  46
#                                                                 1
# xpr0068 Dauvergne, Nicolas Rémy Gabriel   architecte            1  38
# xpr0050         Chasteau, Jean François entrepreneur            1  52
# xpr0026               Bleve, Jean Louis   architecte            1  59
# xpr0106             Egresset, Guillaume entrepreneur            1  75
# xpr0203                Normand, Nicolas   architecte            1  43
# xpr0102                 Ducret, Nicolas   architecte            1  59
# xpr0187            Mangin, Jean Charles   architecte            1  37
# xpr0104            Dumont, Jean Charles entrepreneur            2  58
# xpr0055          Clavareau, Jean Pierre   architecte            2  65
# xpr0228  Poulain, Jean Baptiste Martial   architecte            2  51
# xpr0143            Jacob, Jean François entrepreneur            2  51
# xpr0095         Dosmond, Léonard Pierre   architecte            2  35
# xpr0250               Taboureur, Pierre   architecte            3  50
# xpr0215                   Petit, Pierre entrepreneur            3  42
# xpr0261              Villetard, Etienne entrepreneur           31  60
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé     19
#            Estimer la valeur des biens    117
# Décrire et évaluer les travaux à venir     11
#                             Départager     12
#                            Enregistrer      5
#
#
#
#
# Ducret, Nicolas ; architecte ; 43 expertises ; 0 expertises en tant que tiers-expert ; 24 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                                                     name       column  totalCollab age
# xpr0002                                                     André, Jean Baptiste   architecte            1  51
# xpr0095                                                  Dosmond, Léonard Pierre   architecte            1  35
# xpr0155                                                 Lardant, Pierre François entrepreneur            1  55
# xpr0038                                                 Bourgeois, Louis Silvain entrepreneur            1  50
# xpr0200                                                           Mouchet, André entrepreneur            1
# xpr0090 Desjardins, Jean Baptiste Guillaume Alexandre Georges Balthazard Auguste   architecte            1  32
# xpr0055                                                   Clavareau, Jean Pierre   architecte            1  65
# xpr0004                                                         Antoine, Antoine   architecte            1  40
# xpr0114                                               Gabriel, Nicolas Toussaint   architecte            1  47
# xpr0026                                                        Bleve, Jean Louis   architecte            1  59
# xpr0064                                             D'herbelot, Francois-Charles   architecte            1
# xpr0261                                                       Villetard, Etienne entrepreneur            1  60
# xpr0101                                               Duboiscerf, Sébastien Jean entrepreneur            1  73
# xpr0104                                                     Dumont, Jean Charles entrepreneur            2  58
# xpr0228                                           Poulain, Jean Baptiste Martial   architecte            2  51
# xpr0235                               Regnard De Barentin, Bernard Jean Baptiste entrepreneur            2  47
# xpr0203                                                         Normand, Nicolas   architecte            3  43
# xpr0250                                                        Taboureur, Pierre   architecte            5  50
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé     17
#            Estimer la valeur des biens     15
# Décrire et évaluer les travaux à venir      4
#                             Départager      4
#                            Enregistrer      3
#
#
#
#
# Dumont, Jean Charles ; entrepreneur ; 53 expertises ; 0 expertises en tant que tiers-expert ; 33 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                           name       column  totalCollab age
# xpr0215                  Petit, Pierre entrepreneur            1  42
# xpr0216    Petit Radel, Louis François   architecte            1  46
# xpr0065       Danjan, Pierre Alexandre   architecte            1  64
# xpr0050        Chasteau, Jean François entrepreneur            1  52
# xpr0004               Antoine, Antoine   architecte            1  40
# xpr0114     Gabriel, Nicolas Toussaint   architecte            1  47
# xpr0260        Villetard, Jean Etienne   architecte            1
# xpr0026              Bleve, Jean Louis   architecte            1  59
# xpr0245                   Siguy, Louis entrepreneur            1  48
# xpr0038       Bourgeois, Louis Silvain entrepreneur            1  50
# xpr0031           Bouchu, Paul Antoine   architecte            1  46
# xpr0203               Normand, Nicolas   architecte            1  43
# xpr0095        Dosmond, Léonard Pierre   architecte            2  35
# xpr0102                Ducret, Nicolas   architecte            2  59
# xpr0101     Duboiscerf, Sébastien Jean entrepreneur            2  73
# xpr0085         Delespine, Louis Jules   architecte            3  60
# xpr0187           Mangin, Jean Charles   architecte            3  37
# xpr0261             Villetard, Etienne entrepreneur            3  60
# xpr0250              Taboureur, Pierre   architecte            5  50
# xpr0228 Poulain, Jean Baptiste Martial   architecte            5  51
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé     20
#            Estimer la valeur des biens     11
# Décrire et évaluer les travaux à venir      5
#                             Départager     14
#                            Enregistrer      2
#
#
#
#
# Egresset, Guillaume ; entrepreneur ; 3 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0065   Danjan, Pierre Alexandre   architecte            1  64
# xpr0101 Duboiscerf, Sébastien Jean entrepreneur            1  73
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      1
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Gabriel, Nicolas Toussaint ; architecte ; 14 expertises ; 0 expertises en tant que tiers-expert ; 11 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                  name       column  totalCollab age
# xpr0101            Duboiscerf, Sébastien Jean entrepreneur            1  73
# xpr0104                  Dumont, Jean Charles entrepreneur            1  58
# xpr0102                       Ducret, Nicolas   architecte            1  59
# xpr0261                    Villetard, Etienne entrepreneur            1  60
# xpr0250                     Taboureur, Pierre   architecte            1  50
# xpr0245                          Siguy, Louis entrepreneur            1  48
# xpr0258 Vavasseur Desperriers, Louis Athanase entrepreneur            1  44
# xpr0085                Delespine, Louis Jules   architecte            1  60
# xpr0203                      Normand, Nicolas   architecte            1  43
# xpr0215                         Petit, Pierre entrepreneur            2  42
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      8
#            Estimer la valeur des biens      5
# Décrire et évaluer les travaux à venir      0
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Giraud, Pierre Marie ; architecte ; 11 expertises ; 0 expertises en tant que tiers-expert ; 6 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                       name       column  totalCollab age
# xpr0163                  Le Foulon, Guillaume Elie entrepreneur            1  59
# xpr0143                       Jacob, Jean François entrepreneur            1  51
# xpr0235 Regnard De Barentin, Bernard Jean Baptiste entrepreneur            2  47
# xpr0250                          Taboureur, Pierre   architecte            2  50
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      7
#            Estimer la valeur des biens      2
# Décrire et évaluer les travaux à venir      1
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Goulet, Nicolas ; entrepreneur ; 2 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                           name     column  totalCollab age
# xpr0024            Blanchard, Jean-Luc architecte            1
# xpr0228 Poulain, Jean Baptiste Martial architecte            1  51
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      1
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Goupy Ii, Martin ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Hallet, Etienne-Sulpice ; architecte ; 9 expertises ; 1 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                           name     column  totalCollab age
# xpr0228 Poulain, Jean Baptiste Martial architecte            1  51
# xpr0031           Bouchu, Paul Antoine architecte            1  46
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      3
# Décrire et évaluer les travaux à venir      4
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# Jacob, Jean François ; entrepreneur ; 11 expertises ; 0 expertises en tant que tiers-expert ; 8 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                           name       column  totalCollab age
# xpr0031           Bouchu, Paul Antoine   architecte            1  46
# xpr0065       Danjan, Pierre Alexandre   architecte            1  64
# xpr0250              Taboureur, Pierre   architecte            1  50
# xpr0228 Poulain, Jean Baptiste Martial   architecte            1  51
# xpr0122           Giraud, Pierre Marie   architecte            1  52
# xpr0043  Le Camus de Mézières, Nicolas   architecte            1  61
# xpr0101     Duboiscerf, Sébastien Jean entrepreneur            2  73
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      7
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      2
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Jacob, François ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                   name     column  totalCollab age
# xpr0226 Porquet, Claude Joseph architecte            1  64
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Lardant, Pierre François ; entrepreneur ; 2 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                           name     column  totalCollab age
# xpr0228 Poulain, Jean Baptiste Martial architecte            1  51
# xpr0102                Ducret, Nicolas architecte            1  59
# xpr0250              Taboureur, Pierre architecte            1  50
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      1
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Le brun, Charles François ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Le Foulon, Guillaume Elie ; entrepreneur ; 5 expertises ; 0 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                 name       column  totalCollab age
# xpr0203     Normand, Nicolas   architecte            1  43
# xpr0122 Giraud, Pierre Marie   architecte            1  52
# xpr0245         Siguy, Louis entrepreneur            1  48
# xpr0250    Taboureur, Pierre   architecte            1  50
# xpr0261   Villetard, Etienne entrepreneur            1  60
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      2
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Le Roux, Jean ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id              name     column  totalCollab age
# xpr0250 Taboureur, Pierre architecte            1  50
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Lemit, Louis ; architecte ; 3 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                    name       column  totalCollab age
# xpr0050 Chasteau, Jean François entrepreneur            1  52
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      2
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Mangin, Jean Charles ; architecte ; 36 expertises ; 0 expertises en tant que tiers-expert ; 12 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                            name       column  totalCollab age
# xpr0003              Angot, Jean Pierre entrepreneur            1  47
# xpr0250               Taboureur, Pierre   architecte            1  50
# xpr0068 Dauvergne, Nicolas Rémy Gabriel   architecte            1  38
# xpr0031            Bouchu, Paul Antoine   architecte            1  46
# xpr0215                   Petit, Pierre entrepreneur            1  42
# xpr0261              Villetard, Etienne entrepreneur            1  60
# xpr0101      Duboiscerf, Sébastien Jean entrepreneur            1  73
# xpr0026               Bleve, Jean Louis   architecte            2  59
# xpr0228  Poulain, Jean Baptiste Martial   architecte            2  51
# xpr0104            Dumont, Jean Charles entrepreneur            3  58
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé     11
#            Estimer la valeur des biens      6
# Décrire et évaluer les travaux à venir     16
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Mouchelet, Georges Louis ; architecte ; 4 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                            name     column  totalCollab age
# xpr0004                Antoine, Antoine architecte            1  40
# xpr0033 Boullant, Jean Baptiste Vincent architecte            1  47
# xpr0085          Delespine, Louis Jules architecte            1  60
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      2
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      1
#                            Enregistrer      1
#
#
#
#
# Mouchet, André ; entrepreneur ; 8 expertises ; 0 expertises en tant que tiers-expert ; 4 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                           name     column  totalCollab age
# xpr0102                Ducret, Nicolas architecte            1  59
# xpr0228 Poulain, Jean Baptiste Martial architecte            1  51
# xpr0250              Taboureur, Pierre architecte            2  50
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      2
#            Estimer la valeur des biens      3
# Décrire et évaluer les travaux à venir      0
#                             Départager      3
#                            Enregistrer      0
#
#
#
#
# Neveu, Michel ; entrepreneur ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Normand, Nicolas ; architecte ; 17 expertises ; 0 expertises en tant que tiers-expert ; 13 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                           name       column  totalCollab age
# xpr0228 Poulain, Jean Baptiste Martial   architecte            1  51
# xpr0215                  Petit, Pierre entrepreneur            1  42
# xpr0031           Bouchu, Paul Antoine   architecte            1  46
# xpr0007                  Aubert, André entrepreneur            1  41
# xpr0043  Le Camus de Mézières, Nicolas   architecte            1  61
# xpr0250              Taboureur, Pierre   architecte            1  50
# xpr0163      Le Foulon, Guillaume Elie entrepreneur            1  59
# xpr0101     Duboiscerf, Sébastien Jean entrepreneur            1  73
# xpr0104           Dumont, Jean Charles entrepreneur            1  58
# xpr0114     Gabriel, Nicolas Toussaint   architecte            1  47
# xpr0102                Ducret, Nicolas   architecte            3  59
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      9
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      5
#                             Départager      1
#                            Enregistrer      1
#
#
#
#
# Parvy De La Renaudiere, Nicolas ; entrepreneur ; 6 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                           name       column  totalCollab age
# xpr0101     Duboiscerf, Sébastien Jean entrepreneur            1  73
# xpr0043  Le Camus de Mézières, Nicolas   architecte            1  61
# xpr0228 Poulain, Jean Baptiste Martial   architecte            1  51
# xpr0261             Villetard, Etienne entrepreneur            1  60
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      2
#            Estimer la valeur des biens      3
# Décrire et évaluer les travaux à venir      1
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Petit, Pierre ; entrepreneur ; 60 expertises ; 1 expertises en tant que tiers-expert ; 31 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                       name       column  totalCollab age
# xpr0016      Bellanger, Guillaume François Gabriel entrepreneur            1
# xpr0104                       Dumont, Jean Charles entrepreneur            1  58
# xpr0095                    Dosmond, Léonard Pierre   architecte            1  35
# xpr0203                           Normand, Nicolas   architecte            1  43
# xpr0235 Regnard De Barentin, Bernard Jean Baptiste entrepreneur            1  47
# xpr0261                         Villetard, Etienne entrepreneur            1  60
# xpr0003                         Angot, Jean Pierre entrepreneur            1  47
# xpr0187                       Mangin, Jean Charles   architecte            1  37
# xpr0024                        Blanchard, Jean-Luc   architecte            2
# xpr0033            Boullant, Jean Baptiste Vincent   architecte            2  47
# xpr0026                          Bleve, Jean Louis   architecte            2  59
# xpr0114                 Gabriel, Nicolas Toussaint   architecte            2  47
# xpr0101                 Duboiscerf, Sébastien Jean entrepreneur            3  73
# xpr0065                   Danjan, Pierre Alexandre   architecte            4  64
# xpr0258      Vavasseur Desperriers, Louis Athanase entrepreneur            5  44
# xpr0250                          Taboureur, Pierre   architecte            6  50
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé     25
#            Estimer la valeur des biens     18
# Décrire et évaluer les travaux à venir     12
#                             Départager      4
#                            Enregistrer      1
#
#
#
#
# Petit Radel, Louis François ; architecte ; 11 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                            name       column  totalCollab age
# xpr0104            Dumont, Jean Charles entrepreneur            1  58
# xpr0003              Angot, Jean Pierre entrepreneur            1  47
# xpr0033 Boullant, Jean Baptiste Vincent   architecte            1  47
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      8
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      0
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# Porquet, Claude Joseph ; architecte ; 2 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id            name     column  totalCollab age
# xpr0144 Jacob, François architecte            1
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Poulain, Jean Baptiste Martial ; architecte ; 46 expertises ; 0 expertises en tant que tiers-expert ; 37 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                       name       column  totalCollab age
# xpr0155                   Lardant, Pierre François entrepreneur            1  55
# xpr0137                    Hallet, Etienne-Sulpice   architecte            1
# xpr0203                           Normand, Nicolas   architecte            1  43
# xpr0064               D'herbelot, Francois-Charles   architecte            1
# xpr0235 Regnard De Barentin, Bernard Jean Baptiste entrepreneur            1  47
# xpr0258      Vavasseur Desperriers, Louis Athanase entrepreneur            1  44
# xpr0205            Parvy De La Renaudiere, Nicolas entrepreneur            1  52
# xpr0200                             Mouchet, André entrepreneur            1
# xpr0050                    Chasteau, Jean François entrepreneur            1  52
# xpr0127                            Goulet, Nicolas entrepreneur            1  41
# xpr0247                        Simon, René Auguste entrepreneur            1  74
# xpr0143                       Jacob, Jean François entrepreneur            1  51
# xpr0016      Bellanger, Guillaume François Gabriel entrepreneur            1
# xpr0043              Le Camus de Mézières, Nicolas   architecte            1  61
# xpr0055                     Clavareau, Jean Pierre   architecte            1  65
# xpr0026                          Bleve, Jean Louis   architecte            1  59
# xpr0033            Boullant, Jean Baptiste Vincent   architecte            1  47
# xpr0102                            Ducret, Nicolas   architecte            2  59
# xpr0095                    Dosmond, Léonard Pierre   architecte            2  35
# xpr0261                         Villetard, Etienne entrepreneur            2  60
# xpr0101                 Duboiscerf, Sébastien Jean entrepreneur            2  73
# xpr0187                       Mangin, Jean Charles   architecte            2  37
# xpr0104                       Dumont, Jean Charles entrepreneur            5  58
# xpr0250                          Taboureur, Pierre   architecte            7  50
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé     19
#            Estimer la valeur des biens     11
# Décrire et évaluer les travaux à venir      6
#                             Départager     10
#                            Enregistrer      0
#
#
#
#
# Pruneau De Montlouis, Jean Louis ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Regnard De Barentin, Bernard Jean Baptiste ; entrepreneur ; 8 expertises ; 0 expertises en tant que tiers-expert ; 8 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                           name       column  totalCollab age
# xpr0228 Poulain, Jean Baptiste Martial   architecte            1  51
# xpr0055         Clavareau, Jean Pierre   architecte            1  65
# xpr0215                  Petit, Pierre entrepreneur            1  42
# xpr0024            Blanchard, Jean-Luc   architecte            1
# xpr0122           Giraud, Pierre Marie   architecte            2  52
# xpr0102                Ducret, Nicolas   architecte            2  59
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      5
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      2
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Roche, Honoré Jacques ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id              name     column  totalCollab age
# xpr0250 Taboureur, Pierre architecte            1  50
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Siguy, Louis ; entrepreneur ; 6 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0104       Dumont, Jean Charles entrepreneur            1  58
# xpr0114 Gabriel, Nicolas Toussaint   architecte            1  47
# xpr0163  Le Foulon, Guillaume Elie entrepreneur            1  59
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#            Estimer la valeur des biens      2
# Décrire et évaluer les travaux à venir      1
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# Simon, René Auguste ; entrepreneur ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                           name     column  totalCollab age
# xpr0228 Poulain, Jean Baptiste Martial architecte            1  51
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Soisson, Charles Nicolas ; entrepreneur ; 1 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Taboureur, Pierre ; architecte ; 225 expertises ; 4 expertises en tant que tiers-expert ; 61 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                                                     name       column  totalCollab age
# xpr0155                                                 Lardant, Pierre François entrepreneur            1  55
# xpr0004                                                         Antoine, Antoine   architecte            1  40
# xpr0049                                               Chabouille, Médéric Joseph entrepreneur            1  44
# xpr0050                                                  Chasteau, Jean François entrepreneur            1  52
# xpr0187                                                     Mangin, Jean Charles   architecte            1  37
# xpr0238                                                    Roche, Honoré Jacques   architecte            1  44
# xpr0203                                                         Normand, Nicolas   architecte            1  43
# xpr0169                                                            Le Roux, Jean   architecte            1
# xpr0095                                                  Dosmond, Léonard Pierre   architecte            1  35
# xpr0143                                                     Jacob, Jean François entrepreneur            1  51
# xpr0114                                               Gabriel, Nicolas Toussaint   architecte            1  47
# xpr0065                                                 Danjan, Pierre Alexandre   architecte            1  64
# xpr0085                                                   Delespine, Louis Jules   architecte            1  60
# xpr0163                                                Le Foulon, Guillaume Elie entrepreneur            1  59
# xpr0055                                                   Clavareau, Jean Pierre   architecte            1  65
# xpr0090 Desjardins, Jean Baptiste Guillaume Alexandre Georges Balthazard Auguste   architecte            1  32
# xpr0003                                                       Angot, Jean Pierre entrepreneur            2  47
# xpr0007                                                            Aubert, André entrepreneur            2  41
# xpr0044                                                   Capron, Charles Martin entrepreneur            2  56
# xpr0026                                                        Bleve, Jean Louis   architecte            2  59
# xpr0200                                                           Mouchet, André entrepreneur            2
# xpr0122                                                     Giraud, Pierre Marie   architecte            2  52
# xpr0033                                          Boullant, Jean Baptiste Vincent   architecte            3  47
# xpr0101                                               Duboiscerf, Sébastien Jean entrepreneur            3  73
# xpr0104                                                     Dumont, Jean Charles entrepreneur            5  58
# xpr0102                                                          Ducret, Nicolas   architecte            5  59
# xpr0261                                                       Villetard, Etienne entrepreneur            6  60
# xpr0215                                                            Petit, Pierre entrepreneur            6  42
# xpr0228                                           Poulain, Jean Baptiste Martial   architecte            7  51
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé     63
#            Estimer la valeur des biens     55
# Décrire et évaluer les travaux à venir     47
#                             Départager     32
#                            Enregistrer     22
#
#
#
#
# Terrier, Martin Marie ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Thevenin, Jacques-Jean ; entrepreneur ; 3 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0101 Duboiscerf, Sébastien Jean entrepreneur            1  73
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      3
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Varin, Bénigne Joseph ; entrepreneur ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Vavasseur Desperriers, Louis Athanase ; entrepreneur ; 9 expertises ; 0 expertises en tant que tiers-expert ; 7 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                           name       column  totalCollab age
# xpr0228 Poulain, Jean Baptiste Martial   architecte            1  51
# xpr0114     Gabriel, Nicolas Toussaint   architecte            1  47
# xpr0215                  Petit, Pierre entrepreneur            5  42
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      6
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      1
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Villetard, Jean Etienne ; architecte ; 5 expertises ; 0 expertises en tant que tiers-expert ; 4 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                  name       column  totalCollab age
# xpr0101            Duboiscerf, Sébastien Jean entrepreneur            1  73
# xpr0104                  Dumont, Jean Charles entrepreneur            1  58
# xpr0016 Bellanger, Guillaume François Gabriel entrepreneur            1
# xpr0031                  Bouchu, Paul Antoine   architecte            1  46
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      2
#            Estimer la valeur des biens      2
# Décrire et évaluer les travaux à venir      1
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Villetard, Etienne ; entrepreneur ; 54 expertises ; 0 expertises en tant que tiers-expert ; 50 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                            name       column  totalCollab age
# xpr0065        Danjan, Pierre Alexandre   architecte            1  64
# xpr0043   Le Camus de Mézières, Nicolas   architecte            1  61
# xpr0002            André, Jean Baptiste   architecte            1  51
# xpr0114      Gabriel, Nicolas Toussaint   architecte            1  47
# xpr0050         Chasteau, Jean François entrepreneur            1  52
# xpr0085          Delespine, Louis Jules   architecte            1  60
# xpr0215                   Petit, Pierre entrepreneur            1  42
# xpr0102                 Ducret, Nicolas   architecte            1  59
# xpr0205 Parvy De La Renaudiere, Nicolas entrepreneur            1  52
# xpr0187            Mangin, Jean Charles   architecte            1  37
# xpr0163       Le Foulon, Guillaume Elie entrepreneur            1  59
# xpr0228  Poulain, Jean Baptiste Martial   architecte            2  51
# xpr0026               Bleve, Jean Louis   architecte            2  59
# xpr0095         Dosmond, Léonard Pierre   architecte            2  35
# xpr0104            Dumont, Jean Charles entrepreneur            3  58
# xpr0250               Taboureur, Pierre   architecte            6  50
# xpr0101      Duboiscerf, Sébastien Jean entrepreneur           31  73
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens     48
# Décrire et évaluer les travaux à venir      1
#                             Départager      5
#                            Enregistrer      0
#
#
#
#
# Lefort, François (? - ?) ; architecte ; 3 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                      name     column  totalCollab age
# xpr0274    Lomet, Quentin (? - ?) architecte            1
# xpr0277 Jamain, Sébastien (? - ?) architecte            1   0
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Lomet, Quentin (? - ?) ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name     column  totalCollab age
# xpr0273 Lefort, François (? - ?) architecte            1
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      0
#            Estimer la valeur des biens      1
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Jamain, Sébastien (? - ?) ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name     column  totalCollab age
# xpr0273 Lefort, François (? - ?) architecte            1
#
#
#                                  label  total
# Recevoir et évaluer le travail réalisé      1
#            Estimer la valeur des biens      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
