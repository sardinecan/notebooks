# %% [markdown]
# # xprStats

# %%
# lib
from urllib.request import urlopen
import json  
import pandas as pd

# %%
# Récupération des donnée 
# param (date or thirdParty)
param = "1756"

# url
url = "https://experts.huma-num.fr/xpr/statistics/" + param

# enregistrement de la réponse
response = urlopen(url)

# lecture du json
data = json.loads(response.read())
  
# print the json response
#print(data)

# %% [markdown]
# ## Expertises

# %%
expertises = data['expertises']

# %%
print("Nombre total d'expertises : " + str(expertises['total']))
# Out:
# Nombre total d'expertises : 459

# %% [markdown]
# ### Croquis

# %%
sketchesDF = pd.json_normalize(expertises['sketches'])
print(sketchesDF.to_string(index=False))
# Out:
#  expertisesWithoutSketch  expertisesWithSketch
#                      458                     1

# %% [markdown]
# ### Étendue

# %%
extent = expertises['extent']
#print(extent)

print('Nombre de feuillets : ' + str(extent['total']))

print('Moyenne par expertise : ' + str(extent['averageByExpertise']))

#Distribution
print('Distribution :')
keys = []
values = []
for dic in extent['extentDistribution']:
    for key, val in dic.items():
        keys.append(key),
        values.append(val)        

extentDistributionDict = {'nombre de feuillets': keys, 'nombre d’expertises': values,} 
print(pd.DataFrame(extentDistributionDict).to_string(index=False))
# Out:
# Nombre de feuillets : 5120
# Moyenne par expertise : 11.15
# Distribution :
# nombre de feuillets  nombre d’expertises
#                   5                  165
#                  10                  166
#                  15                   50
#                  20                   34
#                  25                   13
#                  30                    5
#                  35                    6
#                  40                    4
#                  45                    2
#                  50                    6
#                  55                    0
#                  60                    2
#                  65                    3
#                  70                    0
#                  75                    0
#                  80                    0
#                  85                    0
#                  90                    1
#                  95                    1
#                 100                    1

# %% [markdown]
# ### Annexes

# %%
appendices = expertises['appendices']
#print(appendices)

print(f"{appendices['total']} annexes")


print(f"{appendices['expertisesWithAppendices']} expertises avec annexes ; {appendices['expertisesWithoutAppendices']} expertises sans annexes")


df=pd.json_normalize(appendices['types'])
print(df.to_string(columns=['label', 'total', 'expertises'], index=False))
# Out:
# 363 annexes
# 197 expertises avec annexes ; 262 expertises sans annexes
#                                       label  total  expertises
#                                       Autre    190         114
# Pouvoir/procuration (acte sous seing privé)     82          62
#                      Plan, coupe, élévation     38          30
#          Pouvoir/procuration (acte notarié)     16          16
#                                   Brouillon     12          10
#                                     Requête     15          15
#                                     Croquis     10           9
#                                      Dessin      2           2

# %% [markdown]
# ### Vacations

# %%
sessions = expertises['sessions']
#print(sessions)

print(f"{sessions['total']} vacations")


print(f"en moyenne {sessions['averageByExpertise']} vacations par expertise")
# Out:
# 1856 vacations
# en moyenne 4.04 vacations par expertise

# %% [markdown]
# Nombre de vacation par lieu

# %%
sessionsDf=pd.json_normalize(sessions['places'])
print(sessionsDf.to_string(columns=['label', 'total'], index=False))
# Out:
#    label  total
#    Paris   1373
# Banlieue    232
# Province    246

# %% [markdown]
# ### Durée

# %%
duration = expertises['duration']
#print(duration)

# %% [markdown]
# #### Jours

# %%
#Distribution
durationDays = duration['days']
#print(durationDays)
print('Distribution :')
keys = []
values = []
for dic in durationDays['distributionByDays']:
    for key, val in dic.items():
        keys.append(key),
        values.append(val)        

durationDaysDf = {'nombre de jours': keys, 'nombre d’expertises': values,} 
print(pd.DataFrame(durationDaysDf).to_string(index=False))
# Out:
# Distribution :
# nombre de jours  nombre d’expertises
#               5                  246
#              10                   31
#              15                   28
#              20                   12
#              25                   13
#              30                   17
#              35                   12
#              40                    3
#              45                    9
#              50                    8
#              55                    4
#              60                    5
#              65                    3
#              70                    3
#              75                    1
#              80                    1
#              85                    5
#              90                    4
#              95                    2
#             100                   51

# %% [markdown]
# #### Vacations

# %%
#Distribution
durationSessions = duration['sessions']
#print(durationDays)
print(f"{durationSessions['total']} vacations, soit en moyenne {durationSessions['averageByExpertise']} vacations par expertise.")
# Out:
# 1856 vacations, soit en moyenne 2.02 vacations par expertise.

# %% [markdown]
# ### Lieux

# %%
places = expertises['places']
#print(places)

placesDf=pd.json_normalize(places)
print(placesDf.to_string(columns=['place', 'total'], index=False))
# Out:
#                        place  total
#                      [paris]    276
#                    [suburbs]     61
#                   [province]     73
#           [[paris, suburbs]]     13
#          [[paris, province]]     27
#        [[suburbs, province]]      4
# [[paris, suburbs, province]]      2

# %% [markdown]
# ### Procédures et cadres

# %%
frameworks = expertises['frameworks']
#print(frameworks)

frameworksDf=pd.json_normalize(frameworks)
print(frameworksDf.to_string(columns=['label', 'framework', 'total'], index=False))
# Out:
#                                                                                                                   label framework  total
# L’institution est saisie dans le cadre d’une procédure (les parties nomment chacune leur expert ou un expert en commun)        b2    124
#                                                                                               Commun accord des parties         a     80
#                         L’institution est saisie dans le cadre d’une procédure (l’institution nomme un ou deux experts)       b2b     76
#                                                                                                       Cas problématique         c     12
# L’institution est saisie dans le cadre d’une procédure (les parties nomment chacune leur expert ou un expert en commun)       b2a    151
#                                                                                                                                        2
#                                                     Requête auprès d’une institution pour qu’elle demande une expertise        b1     12
#                                          Saisie mixte (un expert est nommé par les parties, l'autre est nommé d'office)        b3      2

# %% [markdown]
# ### Catégories

# %%
categories = expertises['categories']

for cat in categories:
    if cat['total'] != 0: print(f"{cat['label']} : {cat['total']} expertises"),
    for framework in cat['frameworks']:
        if framework['total'] != 0: print(f"\t{framework['framework']} : {framework['total']} expertises"),
        for place in framework['places']:
            if place['total'] != 0: print(f"\t\t{place['place']} : {place['total']}"),
            for obj in place['objects']:
                if obj['total'] != 0: print(f"\t\t\t{obj['label']} : {obj['total']}")
        print('\n')
    print('\n')
# Out:
# Estimer la valeur des biens : 165 expertises
# 	b2 : 41 expertises
# 		['paris'] : 18
# 			Maison(s) : 18
# 		['suburbs'] : 6
# 			Maison(s) : 5
# 			Terrain(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		['province'] : 9
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 4
# 			Domaine, terres, fief : 4
# 		[['paris', 'suburbs']] : 4
# 			Maison(s) : 4
# 			Terrain(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		[['paris', 'province']] : 4
# 			Maison(s) : 4
# 			Terrain(s) : 2
# 			Domaine, terres, fief : 1
#
#
# 	a : 10 expertises
# 		['paris'] : 4
# 			Maison(s) : 3
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		['suburbs'] : 3
# 			Maison(s) : 2
# 			Terrain(s) : 1
# 		['province'] : 2
# 			Maison(s) : 2
# 		[['paris', 'suburbs']] : 1
# 			Maison(s) : 1
#
#
# 	b2b : 48 expertises
# 		['paris'] : 28
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 24
# 			Terrain(s) : 2
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		['suburbs'] : 6
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 5
# 			Terrain(s) : 1
# 		['province'] : 10
# 			Maison(s) : 9
# 			Terrain(s) : 2
# 			Ensemble de bâtiments (biens immeubles) : 1
# 			Domaine, terres, fief : 2
# 		[['paris', 'province']] : 2
# 			Maison(s) : 2
# 		[['suburbs', 'province']] : 1
# 			Maison(s) : 1
# 			Domaine, terres, fief : 1
# 		[['paris', 'suburbs', 'province']] : 1
# 			Maison(s) : 1
#
#
# 	c : 4 expertises
# 		['suburbs'] : 1
# 			Terrain(s) : 1
# 		['province'] : 2
# 			Maison(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
# 			Domaine, terres, fief : 2
#
#
# 	b2a : 58 expertises
# 		['paris'] : 31
# 			Ouvrages de maçonnerie : 6
# 			Maison(s) : 25
# 			Terrain(s) : 2
# 			Ensemble de bâtiments (biens immeubles) : 4
# 		['suburbs'] : 8
# 			Maison(s) : 7
# 			Terrain(s) : 2
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		['province'] : 10
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 7
# 			Terrain(s) : 1
# 			Domaine, terres, fief : 2
# 		[['paris', 'suburbs']] : 1
# 			Maison(s) : 1
# 		[['paris', 'province']] : 5
# 			Maison(s) : 3
# 			Terrain(s) : 2
# 			Ensemble de bâtiments (biens immeubles) : 3
# 			Domaine, terres, fief : 1
# 		[['suburbs', 'province']] : 2
# 			Maison(s) : 2
# 			Ensemble de bâtiments (biens immeubles) : 2
# 		[['paris', 'suburbs', 'province']] : 1
# 			Maison(s) : 1
# 			Terrain(s) : 1
#
#
#
#
# 	b1 : 2 expertises
# 		['paris'] : 2
# 			Maison(s) : 2
#
#
# 	b3 : 2 expertises
# 		['paris'] : 1
# 			Maison(s) : 1
# 		['suburbs'] : 1
# 			Maison(s) : 1
#
#
#
#
# Recevoir et évaluer le travail réalisé : 133 expertises
# 	b2 : 37 expertises
# 		['paris'] : 20
# 			Ouvrages de maçonnerie : 15
# 			Maison(s) : 6
# 			Mur(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		['suburbs'] : 6
# 			Ouvrages de maçonnerie : 4
# 			Maison(s) : 4
# 		['province'] : 5
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 2
# 			Ensemble de bâtiments (biens immeubles) : 2
# 		[['paris', 'suburbs']] : 4
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 2
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		[['paris', 'province']] : 2
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 1
#
#
# 	a : 35 expertises
# 		['paris'] : 28
# 			Ouvrages de maçonnerie : 8
# 			Maison(s) : 23
# 		['suburbs'] : 2
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 2
# 		['province'] : 3
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 1
# 		[['paris', 'suburbs']] : 1
# 			Maison(s) : 1
# 		[['paris', 'province']] : 1
# 			Maison(s) : 1
#
#
# 	b2b : 11 expertises
# 		['paris'] : 7
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 5
# 		['province'] : 4
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 1
#
#
# 	c : 2 expertises
# 		['paris'] : 2
# 			Maison(s) : 2
#
#
# 	b2a : 44 expertises
# 		['paris'] : 28
# 			Ouvrages de maçonnerie : 8
# 			Maison(s) : 18
# 			Mur(s) : 1
# 		['suburbs'] : 6
# 			Maison(s) : 4
# 		['province'] : 4
# 			Maison(s) : 4
# 		[['paris', 'province']] : 5
# 			Maison(s) : 4
# 			Domaine, terres, fief : 1
#
#
# 	 : 2 expertises
# 		['paris'] : 2
# 			Maison(s) : 2
#
#
# 	b1 : 2 expertises
# 		['paris'] : 1
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 		['province'] : 1
# 			Ouvrages de maçonnerie : 1
#
#
#
#
#
#
# Décrire et évaluer les travaux à venir : 67 expertises
# 	b2 : 18 expertises
# 		['paris'] : 12
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 10
# 			Mur(s) : 1
# 			Fosse(s) d'aisance : 2
# 		['suburbs'] : 1
# 			Mur(s) : 1
# 		['province'] : 5
# 			Maison(s) : 4
# 			Ensemble de bâtiments (biens immeubles) : 1
#
#
# 	a : 10 expertises
# 		['paris'] : 4
# 			Maison(s) : 1
# 			Mur(s) : 3
# 		['suburbs'] : 4
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 			Mur(s) : 2
# 		['province'] : 2
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
#
#
# 	b2b : 13 expertises
# 		['paris'] : 8
# 			Maison(s) : 8
# 		['suburbs'] : 2
# 			Maison(s) : 1
# 		['province'] : 3
# 			Maison(s) : 3
#
#
# 	c : 2 expertises
# 		['paris'] : 1
# 			Maison(s) : 1
# 			Terrain(s) : 1
# 		['suburbs'] : 1
# 			Maison(s) : 1
# 			Terrain(s) : 1
#
#
# 	b2a : 18 expertises
# 		['paris'] : 8
# 			Maison(s) : 8
# 		['suburbs'] : 3
# 			Maison(s) : 2
# 			Terrain(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		['province'] : 6
# 			Maison(s) : 6
# 		[['paris', 'province']] : 1
# 			Ouvrages de maçonnerie : 1
#
#
#
#
# 	b1 : 6 expertises
# 		['paris'] : 6
# 			Maison(s) : 6
#
#
#
#
#
#
# Départager : 58 expertises
# 	b2 : 10 expertises
# 		['paris'] : 5
# 			Maison(s) : 1
# 			Terrain(s) : 1
# 			Mur(s) : 3
# 		['suburbs'] : 2
# 			Terrain(s) : 1
# 			Mur(s) : 1
# 		['province'] : 2
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 2
# 			Terrain(s) : 1
# 		[['paris', 'province']] : 1
# 			Ouvrages de maçonnerie : 1
#
#
# 	a : 18 expertises
# 		['paris'] : 15
# 			Maison(s) : 1
# 			Mur(s) : 13
# 			Fosse(s) d'aisance : 1
# 			Puits : 1
# 		['suburbs'] : 3
# 			Terrain(s) : 1
# 			Mur(s) : 3
#
#
# 	b2b : 4 expertises
# 		['paris'] : 3
# 			Mur(s) : 2
# 			Fosse(s) d'aisance : 1
# 		['suburbs'] : 1
# 			Ouvrages de maçonnerie : 1
#
#
# 	c : 3 expertises
# 		['paris'] : 1
# 			Mur(s) : 1
# 		[['paris', 'province']] : 2
# 			Mur(s) : 2
#
#
# 	b2a : 23 expertises
# 		['paris'] : 19
# 			Ouvrages de maçonnerie : 5
# 			Maison(s) : 1
# 			Terrain(s) : 1
# 			Mur(s) : 12
# 			Ensemble de bâtiments (biens immeubles) : 1
# 			Fosse(s) d'aisance : 1
# 			Puits : 1
# 		['province'] : 3
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 2
# 			Mur(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
#
#
#
#
#
#
#
#
#
#
# Enregistrer : 2 expertises
#
#
# 	a : 2 expertises
# 		['paris'] : 2
# 			Maison(s) : 1
# 			Terrain(s) : 1

# %% [markdown]
# ### Tiers expertises

# %%
thirdParty = expertises['thirdParty']

# %%
thirdPartyDf=pd.json_normalize(thirdParty)
print(thirdPartyDf.to_string(columns=['architectes', 'entrepreneurs', 'total'], index=False))
# Out:
#  architectes  entrepreneurs  total
#           12              4     16

# %% [markdown]
# ### Distribution (hors tiers expertises)

# %%
columnDistrib = expertises['experts']

for column in columnDistrib:
    print(f"{column['totalExperts']} expert(s) : {column['totalExpertises']} expertises"),
    if column['totalExperts']<3: print(pd.json_normalize(column['distribution']).to_string(columns=['label', 'total'], index=False))
    print('\n')
# Out:
# 1 expert(s) : 300 expertises
#        label  total
#   architecte    218
# entrepreneur     82
#
#
# 2 expert(s) : 137 expertises
#                       label  total
#     architecte - architecte     45
#   entrepreneur - architecte     70
# entrepreneur - entrepreneur     22
#
#
# 3 expert(s) : 5 expertises
#
#
# 4 expert(s) : 1 expertises

# %% [markdown]
# ## Experts

# %%
experts = data['experts']
#print(experts)

# %%
print(f"Nombre d’experts : {experts['total']}")
print(f"{experts['architects']} architectes")
print(f"{experts['entrepreneur']} entrepreneurs")
print(f"{experts['surveyor']} arpenteurs")
# Out:
# Nombre d’experts : 57
# 30 architectes
# 27 entrepreneurs
# 0 arpenteurs

# %%
listExperts = experts['list']
listExpertsDf = pd.DataFrame(listExperts)
listExpertsDf.drop('expertises', inplace=True, axis=1)

# %%
print(listExpertsDf.to_string(columns=['id', 'name', 'column', 'age'], index=False))
# Out:
#      id                                   name       column age
# xpr0001             Adhenet, Thomas (1690 - ?)   architecte  66
# xpr0006                        Arnoult, Thomas entrepreneur  49
# xpr0010 Babuty, François Antoine (1716 - 1766) entrepreneur  40
# xpr0025                        Blavet, Jacques   architecte  41
# xpr0034                  Boullée, Louis Claude   architecte  57
# xpr0037                 Bourgeois, Louis Denis entrepreneur
# xpr0039                      Bourgeois, Pierre entrepreneur
# xpr0040                           Bray, Pierre entrepreneur  38
# xpr0043          Le Camus de Mézières, Nicolas   architecte  31
# xpr0045                          Caque, Pierre entrepreneur  56
# xpr0046               Caque, Jean Louis Pierre entrepreneur  30
# xpr0054             Chauveau, René Bonaventure entrepreneur  63
# xpr0056            Cochois, Jacques Richard de   architecte  56
# xpr0060             Coupard Delatouche, Pierre entrepreneur  40
# xpr0062             Coustillier, Pierre Gilles entrepreneur  43
# xpr0065               Danjan, Pierre Alexandre   architecte  34
# xpr0066                    Danjan, Pierre Paul   architecte  58
# xpr0067               Dauphin, Antoine Nicolas   architecte  43
# xpr0071                 De Bey, Louis François entrepreneur  39
# xpr0072                 De Bias Aubry, Mathieu   architecte  38
# xpr0079            De Varenne, Claude Estienne entrepreneur  50
# xpr0081            De Villers, Eustache Robert   architecte  36
# xpr0082                      De Vonges, Michel entrepreneur  42
# xpr0083             Delcourt, Nicolas François   architecte
# xpr0084              Delespine, Pierre Charles   architecte
# xpr0088            Delvincourt, André François   architecte
# xpr0089               Desboeufs, Henri Quentin   architecte  51
# xpr0091                     Desmaisons, Pierre   architecte  45
# xpr0092           Desmaisons, Jacques François entrepreneur  41
# xpr0104                   Dumont, Jean Charles entrepreneur  28
# xpr0106                    Egresset, Guillaume entrepreneur  45
# xpr0108                           Fauvel, Jean entrepreneur  62
# xpr0118  Gerard De Montbrouard, Claude Jacques   architecte  63
# xpr0119                       Gillet, François   architecte  44
# xpr0120          Gillet De La Fontaine, Joseph   architecte
# xpr0121                     Giraud, Jean Louis entrepreneur  59
# xpr0122                   Giraud, Pierre Marie entrepreneur  22
# xpr0128                        Goupy I, Martin   architecte  64
# xpr0136                   Guyon, Jean Baptiste   architecte
# xpr0147                         Joubert, Louis entrepreneur  80
# xpr0160                       Le Chauve, Brice   architecte
# xpr0171                       Le Sueur, Adrien   architecte  70
# xpr0174                    Le Tordeur, Jacques   architecte
# xpr0184                            Loir, Denis entrepreneur  36
# xpr0191                   Martin, Pierre Henry   architecte  42
# xpr0200                         Mouchet, André entrepreneur
# xpr0209                 Payen, Jacques Antoine   architecte  46
# xpr0219                           Pinard, Jean entrepreneur  51
# xpr0223           Poirin, Jean Baptiste Michel   architecte  59
# xpr0227                      Pothenot, Gabriel   architecte  60
# xpr0229       Pruneau De Montlouis, Jean Louis   architecte  33
# xpr0230                Puisieux, Jean Baptiste   architecte  66
# xpr0231                          Quirot, Denis   architecte  48
# xpr0234                Raymond, Etienne Hubert entrepreneur
# xpr0236                  Richard, Pierre Louis entrepreneur  60
# xpr0247                    Simon, René Auguste entrepreneur  44
# xpr0259                           Vedy, Julien entrepreneur  59

# %%
for expert in listExperts:
    print(f"{expert['name']} ; {expert['column']} ; {expert['expertises']['total']} expertises ; {expert['expertises']['thirParty']} expertises en tant que tiers-expert ; {expert['expertises']['collab']['total']} expertises avec d'autres experts (tiers expertises comprises)"),
    print("\n")
    
    collabDF = pd.json_normalize(expert['expertises']['collab']['experts']) 
    if expert['expertises']['collab']['total'] != 0: print(collabDF.to_string(columns=['id', 'name', 'column', 'totalCollab', 'age'], index=False))
    print("\n")
    categoriesDef = pd.json_normalize(expert['expertises']['categories'])
    print(categoriesDef.to_string(columns=['label', 'total'], index=False))

    print("\n")
    print("\n")
# Out:
# Adhenet, Thomas (1690 - ?) ; architecte ; 3 expertises ; 1 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                        name       column  totalCollab age
# xpr0006             Arnoult, Thomas entrepreneur            1  49
# xpr0089    Desboeufs, Henri Quentin   architecte            1  51
# xpr0128             Goupy I, Martin   architecte            1  64
# xpr0056 Cochois, Jacques Richard de   architecte            1  56
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Recevoir et évaluer le travail réalisé      1
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Arnoult, Thomas ; entrepreneur ; 8 expertises ; 0 expertises en tant que tiers-expert ; 7 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0001 Adhenet, Thomas (1690 - ?)   architecte            1  66
# xpr0045              Caque, Pierre entrepreneur            1  56
# xpr0219               Pinard, Jean entrepreneur            1  51
# xpr0037     Bourgeois, Louis Denis entrepreneur            2
# xpr0236      Richard, Pierre Louis entrepreneur            2  60
#
#
#                                  label  total
#            Estimer la valeur des biens      3
# Recevoir et évaluer le travail réalisé      2
# Décrire et évaluer les travaux à venir      2
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Babuty, François Antoine (1716 - 1766) ; entrepreneur ; 13 expertises ; 1 expertises en tant que tiers-expert ; 8 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                    name       column  totalCollab age
# xpr0128         Goupy I, Martin   architecte            1  64
# xpr0171        Le Sueur, Adrien   architecte            1  70
# xpr0219            Pinard, Jean entrepreneur            1  51
# xpr0071  De Bey, Louis François entrepreneur            1  39
# xpr0230 Puisieux, Jean Baptiste   architecte            1  66
# xpr0209  Payen, Jacques Antoine   architecte            1  46
# xpr0066     Danjan, Pierre Paul   architecte            1  58
# xpr0104    Dumont, Jean Charles entrepreneur            1  28
# xpr0231           Quirot, Denis   architecte            1  48
#
#
#                                  label  total
#            Estimer la valeur des biens      2
# Recevoir et évaluer le travail réalisé      7
# Décrire et évaluer les travaux à venir      3
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Blavet, Jacques ; architecte ; 3 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name     column  totalCollab age
# xpr0065 Danjan, Pierre Alexandre architecte            1  34
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Recevoir et évaluer le travail réalisé      1
# Décrire et évaluer les travaux à venir      1
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Boullée, Louis Claude ; architecte ; 13 expertises ; 0 expertises en tant que tiers-expert ; 6 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                         name     column  totalCollab age
# xpr0072       De Bias Aubry, Mathieu architecte            1  38
# xpr0128              Goupy I, Martin architecte            1  64
# xpr0171             Le Sueur, Adrien architecte            1  70
# xpr0119             Gillet, François architecte            1  44
# xpr0056  Cochois, Jacques Richard de architecte            1  56
# xpr0223 Poirin, Jean Baptiste Michel architecte            1  59
#
#
#                                  label  total
#            Estimer la valeur des biens      3
# Recevoir et évaluer le travail réalisé      4
# Décrire et évaluer les travaux à venir      1
#                             Départager      3
#                            Enregistrer      0
#
#
#
#
# Bourgeois, Louis Denis ; entrepreneur ; 19 expertises ; 0 expertises en tant que tiers-expert ; 14 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                          name       column  totalCollab age
# xpr0120 Gillet De La Fontaine, Joseph   architecte            1
# xpr0209        Payen, Jacques Antoine   architecte            1  46
# xpr0200                Mouchet, André entrepreneur            1
# xpr0065      Danjan, Pierre Alexandre   architecte            1  34
# xpr0060    Coupard Delatouche, Pierre entrepreneur            1  40
# xpr0234       Raymond, Etienne Hubert entrepreneur            1
# xpr0230       Puisieux, Jean Baptiste   architecte            1  66
# xpr0084     Delespine, Pierre Charles   architecte            1
# xpr0160              Le Chauve, Brice   architecte            1
# xpr0006               Arnoult, Thomas entrepreneur            2  49
# xpr0045                 Caque, Pierre entrepreneur            3  56
#
#
#                                  label  total
#            Estimer la valeur des biens      4
# Recevoir et évaluer le travail réalisé      5
# Décrire et évaluer les travaux à venir      3
#                             Départager      4
#                            Enregistrer      1
#
#
#
#
# Bourgeois, Pierre ; entrepreneur ; 6 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                          name     column  totalCollab age
# xpr0089      Desboeufs, Henri Quentin architecte            1  51
# xpr0174           Le Tordeur, Jacques architecte            1
# xpr0120 Gillet De La Fontaine, Joseph architecte            1
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Recevoir et évaluer le travail réalisé      3
# Décrire et évaluer les travaux à venir      1
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Bray, Pierre ; entrepreneur ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Le Camus de Mézières, Nicolas ; architecte ; 5 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                          name     column  totalCollab age
# xpr0120 Gillet De La Fontaine, Joseph architecte            1
# xpr0091            Desmaisons, Pierre architecte            1  45
# xpr0056   Cochois, Jacques Richard de architecte            1  56
#
#
#                                  label  total
#            Estimer la valeur des biens      3
# Recevoir et évaluer le travail réalisé      1
# Décrire et évaluer les travaux à venir      1
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Caque, Pierre ; entrepreneur ; 16 expertises ; 1 expertises en tant que tiers-expert ; 10 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                        name       column  totalCollab age
# xpr0006             Arnoult, Thomas entrepreneur            1  49
# xpr0200              Mouchet, André entrepreneur            1
# xpr0067    Dauphin, Antoine Nicolas   architecte            1  43
# xpr0056 Cochois, Jacques Richard de   architecte            1  56
# xpr0230     Puisieux, Jean Baptiste   architecte            1  66
# xpr0184                 Loir, Denis entrepreneur            1  36
# xpr0089    Desboeufs, Henri Quentin   architecte            2  51
# xpr0071      De Bey, Louis François entrepreneur            2  39
# xpr0037      Bourgeois, Louis Denis entrepreneur            3
#
#
#                                  label  total
#            Estimer la valeur des biens      6
# Recevoir et évaluer le travail réalisé      4
# Décrire et évaluer les travaux à venir      1
#                             Départager      3
#                            Enregistrer      1
#
#
#
#
# Caque, Jean Louis Pierre ; entrepreneur ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Chauveau, René Bonaventure ; entrepreneur ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Cochois, Jacques Richard de ; architecte ; 76 expertises ; 3 expertises en tant que tiers-expert ; 19 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                          name       column  totalCollab age
# xpr0120 Gillet De La Fontaine, Joseph   architecte            1
# xpr0091            Desmaisons, Pierre   architecte            1  45
# xpr0043 Le Camus de Mézières, Nicolas   architecte            1  31
# xpr0200                Mouchet, André entrepreneur            1
# xpr0034         Boullée, Louis Claude   architecte            1  57
# xpr0209        Payen, Jacques Antoine   architecte            1  46
# xpr0121            Giraud, Jean Louis entrepreneur            1  59
# xpr0081   De Villers, Eustache Robert   architecte            1  36
# xpr0230       Puisieux, Jean Baptiste   architecte            1  66
# xpr0227             Pothenot, Gabriel   architecte            1  60
# xpr0106           Egresset, Guillaume entrepreneur            1  45
# xpr0045                 Caque, Pierre entrepreneur            1  56
# xpr0092  Desmaisons, Jacques François entrepreneur            1  41
# xpr0082             De Vonges, Michel entrepreneur            1  42
# xpr0001    Adhenet, Thomas (1690 - ?)   architecte            1  66
# xpr0128               Goupy I, Martin   architecte            1  64
# xpr0236         Richard, Pierre Louis entrepreneur            2  60
# xpr0089      Desboeufs, Henri Quentin   architecte            5  51
#
#
#                                  label  total
#            Estimer la valeur des biens     43
# Recevoir et évaluer le travail réalisé     11
# Décrire et évaluer les travaux à venir     10
#                             Départager      5
#                            Enregistrer      0
#
#
#
#
# Coupard Delatouche, Pierre ; entrepreneur ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                   name       column  totalCollab age
# xpr0037 Bourgeois, Louis Denis entrepreneur            1
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Coustillier, Pierre Gilles ; entrepreneur ; 6 expertises ; 0 expertises en tant que tiers-expert ; 4 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                        name       column  totalCollab age
# xpr0171            Le Sueur, Adrien   architecte            1  70
# xpr0236       Richard, Pierre Louis entrepreneur            1  60
# xpr0089    Desboeufs, Henri Quentin   architecte            1  51
# xpr0088 Delvincourt, André François   architecte            1
# xpr0227           Pothenot, Gabriel   architecte            1  60
#
#
#                                  label  total
#            Estimer la valeur des biens      3
# Recevoir et évaluer le travail réalisé      3
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Danjan, Pierre Alexandre ; architecte ; 3 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                   name       column  totalCollab age
# xpr0025        Blavet, Jacques   architecte            1  41
# xpr0037 Bourgeois, Louis Denis entrepreneur            1
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      2
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Danjan, Pierre Paul ; architecte ; 12 expertises ; 0 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                   name       column  totalCollab age
# xpr0171                       Le Sueur, Adrien   architecte            1  70
# xpr0200                         Mouchet, André entrepreneur            1
# xpr0104                   Dumont, Jean Charles entrepreneur            1  28
# xpr0010 Babuty, François Antoine (1716 - 1766) entrepreneur            1  40
# xpr0081            De Villers, Eustache Robert   architecte            2  36
#
#
#                                  label  total
#            Estimer la valeur des biens      7
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      3
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Dauphin, Antoine Nicolas ; architecte ; 5 expertises ; 0 expertises en tant que tiers-expert ; 4 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                  name       column  totalCollab age
# xpr0118 Gerard De Montbrouard, Claude Jacques   architecte            1  63
# xpr0045                         Caque, Pierre entrepreneur            1  56
# xpr0089              Desboeufs, Henri Quentin   architecte            2  51
#
#
#                                  label  total
#            Estimer la valeur des biens      2
# Recevoir et évaluer le travail réalisé      2
# Décrire et évaluer les travaux à venir      0
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# De Bey, Louis François ; entrepreneur ; 18 expertises ; 0 expertises en tant que tiers-expert ; 13 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                   name       column  totalCollab age
# xpr0092           Desmaisons, Jacques François entrepreneur            1  41
# xpr0219                           Pinard, Jean entrepreneur            1  51
# xpr0010 Babuty, François Antoine (1716 - 1766) entrepreneur            1  40
# xpr0091                     Desmaisons, Pierre   architecte            1  45
# xpr0209                 Payen, Jacques Antoine   architecte            1  46
# xpr0160                       Le Chauve, Brice   architecte            1
# xpr0184                            Loir, Denis entrepreneur            1  36
# xpr0136                   Guyon, Jean Baptiste   architecte            2
# xpr0089               Desboeufs, Henri Quentin   architecte            2  51
# xpr0171                       Le Sueur, Adrien   architecte            2  70
# xpr0045                          Caque, Pierre entrepreneur            2  56
# xpr0230                Puisieux, Jean Baptiste   architecte            4  66
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Recevoir et évaluer le travail réalisé      9
# Décrire et évaluer les travaux à venir      4
#                             Départager      3
#                            Enregistrer      1
#
#
#
#
# De Bias Aubry, Mathieu ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                  name     column  totalCollab age
# xpr0034 Boullée, Louis Claude architecte            1  57
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# De Varenne, Claude Estienne ; entrepreneur ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# De Villers, Eustache Robert ; architecte ; 11 expertises ; 0 expertises en tant que tiers-expert ; 10 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                          name       column  totalCollab age
# xpr0209        Payen, Jacques Antoine   architecte            1  46
# xpr0136          Guyon, Jean Baptiste   architecte            1
# xpr0056   Cochois, Jacques Richard de   architecte            1  56
# xpr0120 Gillet De La Fontaine, Joseph   architecte            1
# xpr0236         Richard, Pierre Louis entrepreneur            2  60
# xpr0066           Danjan, Pierre Paul   architecte            2  58
# xpr0089      Desboeufs, Henri Quentin   architecte            4  51
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Recevoir et évaluer le travail réalisé      3
# Décrire et évaluer les travaux à venir      2
#                             Départager      3
#                            Enregistrer      0
#
#
#
#
# De Vonges, Michel ; entrepreneur ; 4 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                        name       column  totalCollab age
# xpr0259                Vedy, Julien entrepreneur            1  59
# xpr0056 Cochois, Jacques Richard de   architecte            1  56
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Recevoir et évaluer le travail réalisé      2
# Décrire et évaluer les travaux à venir      0
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Delcourt, Nicolas François ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Delespine, Pierre Charles ; architecte ; 13 expertises ; 0 expertises en tant que tiers-expert ; 9 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                          name       column  totalCollab age
# xpr0209        Payen, Jacques Antoine   architecte            1  46
# xpr0160              Le Chauve, Brice   architecte            1
# xpr0120 Gillet De La Fontaine, Joseph   architecte            1
# xpr0128               Goupy I, Martin   architecte            1  64
# xpr0121            Giraud, Jean Louis entrepreneur            1  59
# xpr0037        Bourgeois, Louis Denis entrepreneur            1
# xpr0230       Puisieux, Jean Baptiste   architecte            1  66
# xpr0219                  Pinard, Jean entrepreneur            1  51
# xpr0171              Le Sueur, Adrien   architecte            2  70
#
#
#                                  label  total
#            Estimer la valeur des biens      2
# Recevoir et évaluer le travail réalisé      6
# Décrire et évaluer les travaux à venir      1
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# Delvincourt, André François ; architecte ; 2 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0062 Coustillier, Pierre Gilles entrepreneur            1  43
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      2
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Desboeufs, Henri Quentin ; architecte ; 76 expertises ; 3 expertises en tant que tiers-expert ; 31 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                             name       column  totalCollab age
# xpr0230          Puisieux, Jean Baptiste   architecte            1  66
# xpr0184                      Loir, Denis entrepreneur            1  36
# xpr0174              Le Tordeur, Jacques   architecte            1
# xpr0121               Giraud, Jean Louis entrepreneur            1  59
# xpr0062       Coustillier, Pierre Gilles entrepreneur            1  43
# xpr0229 Pruneau De Montlouis, Jean Louis   architecte            1  33
# xpr0001       Adhenet, Thomas (1690 - ?)   architecte            1  66
# xpr0039                Bourgeois, Pierre entrepreneur            1
# xpr0128                  Goupy I, Martin   architecte            2  64
# xpr0120    Gillet De La Fontaine, Joseph   architecte            2
# xpr0071           De Bey, Louis François entrepreneur            2  39
# xpr0171                 Le Sueur, Adrien   architecte            2  70
# xpr0067         Dauphin, Antoine Nicolas   architecte            2  43
# xpr0045                    Caque, Pierre entrepreneur            2  56
# xpr0219                     Pinard, Jean entrepreneur            3  51
# xpr0236            Richard, Pierre Louis entrepreneur            4  60
# xpr0081      De Villers, Eustache Robert   architecte            4  36
# xpr0056      Cochois, Jacques Richard de   architecte            5  56
#
#
#                                  label  total
#            Estimer la valeur des biens     37
# Recevoir et évaluer le travail réalisé     19
# Décrire et évaluer les travaux à venir      8
#                             Départager      7
#                            Enregistrer      0
#
#
#
#
# Desmaisons, Pierre ; architecte ; 6 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                          name       column  totalCollab age
# xpr0120 Gillet De La Fontaine, Joseph   architecte            1
# xpr0043 Le Camus de Mézières, Nicolas   architecte            1  31
# xpr0056   Cochois, Jacques Richard de   architecte            1  56
# xpr0108                  Fauvel, Jean entrepreneur            1  62
# xpr0209        Payen, Jacques Antoine   architecte            1  46
# xpr0071        De Bey, Louis François entrepreneur            1  39
# xpr0136          Guyon, Jean Baptiste   architecte            1
#
#
#                                  label  total
#            Estimer la valeur des biens      3
# Recevoir et évaluer le travail réalisé      2
# Décrire et évaluer les travaux à venir      1
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Desmaisons, Jacques François ; entrepreneur ; 10 expertises ; 0 expertises en tant que tiers-expert ; 7 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                        name       column  totalCollab age
# xpr0184                 Loir, Denis entrepreneur            1  36
# xpr0071      De Bey, Louis François entrepreneur            1  39
# xpr0219                Pinard, Jean entrepreneur            1  51
# xpr0236       Richard, Pierre Louis entrepreneur            1  60
# xpr0056 Cochois, Jacques Richard de   architecte            1  56
# xpr0171            Le Sueur, Adrien   architecte            2  70
#
#
#                                  label  total
#            Estimer la valeur des biens      3
# Recevoir et évaluer le travail réalisé      1
# Décrire et évaluer les travaux à venir      1
#                             Départager      5
#                            Enregistrer      0
#
#
#
#
# Dumont, Jean Charles ; entrepreneur ; 3 expertises ; 1 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                   name       column  totalCollab age
# xpr0066                    Danjan, Pierre Paul   architecte            1  58
# xpr0010 Babuty, François Antoine (1716 - 1766) entrepreneur            1  40
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      1
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Egresset, Guillaume ; entrepreneur ; 4 expertises ; 0 expertises en tant que tiers-expert ; 4 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                        name       column  totalCollab age
# xpr0174         Le Tordeur, Jacques   architecte            1
# xpr0219                Pinard, Jean entrepreneur            1  51
# xpr0160            Le Chauve, Brice   architecte            1
# xpr0056 Cochois, Jacques Richard de   architecte            1  56
# xpr0209      Payen, Jacques Antoine   architecte            1  46
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Recevoir et évaluer le travail réalisé      2
# Décrire et évaluer les travaux à venir      0
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Fauvel, Jean ; entrepreneur ; 7 expertises ; 0 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                    name       column  totalCollab age
# xpr0236   Richard, Pierre Louis entrepreneur            1  60
# xpr0091      Desmaisons, Pierre   architecte            1  45
# xpr0230 Puisieux, Jean Baptiste   architecte            3  66
#
#
#                                  label  total
#            Estimer la valeur des biens      2
# Recevoir et évaluer le travail réalisé      2
# Décrire et évaluer les travaux à venir      0
#                             Départager      3
#                            Enregistrer      0
#
#
#
#
# Gerard De Montbrouard, Claude Jacques ; architecte ; 9 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0247      Simon, René Auguste entrepreneur            1  44
# xpr0067 Dauphin, Antoine Nicolas   architecte            1  43
# xpr0230  Puisieux, Jean Baptiste   architecte            1  66
#
#
#                                  label  total
#            Estimer la valeur des biens      2
# Recevoir et évaluer le travail réalisé      5
# Décrire et évaluer les travaux à venir      0
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Gillet, François ; architecte ; 4 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                  name       column  totalCollab age
# xpr0174   Le Tordeur, Jacques   architecte            1
# xpr0200        Mouchet, André entrepreneur            1
# xpr0034 Boullée, Louis Claude   architecte            1  57
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      2
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Gillet De La Fontaine, Joseph ; architecte ; 12 expertises ; 1 expertises en tant que tiers-expert ; 8 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                          name       column  totalCollab age
# xpr0091            Desmaisons, Pierre   architecte            1  45
# xpr0043 Le Camus de Mézières, Nicolas   architecte            1  31
# xpr0056   Cochois, Jacques Richard de   architecte            1  56
# xpr0128               Goupy I, Martin   architecte            1  64
# xpr0037        Bourgeois, Louis Denis entrepreneur            1
# xpr0084     Delespine, Pierre Charles   architecte            1
# xpr0200                Mouchet, André entrepreneur            1
# xpr0081   De Villers, Eustache Robert   architecte            1  36
# xpr0039             Bourgeois, Pierre entrepreneur            1
# xpr0089      Desboeufs, Henri Quentin   architecte            2  51
# xpr0171              Le Sueur, Adrien   architecte            2  70
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Recevoir et évaluer le travail réalisé      2
# Décrire et évaluer les travaux à venir      3
#                             Départager      5
#                            Enregistrer      0
#
#
#
#
# Giraud, Jean Louis ; entrepreneur ; 5 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                        name     column  totalCollab age
# xpr0056 Cochois, Jacques Richard de architecte            1  56
# xpr0089    Desboeufs, Henri Quentin architecte            1  51
# xpr0084   Delespine, Pierre Charles architecte            1
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      2
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Giraud, Pierre Marie ; entrepreneur ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Goupy I, Martin ; architecte ; 17 expertises ; 0 expertises en tant que tiers-expert ; 9 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                   name       column  totalCollab age
# xpr0120          Gillet De La Fontaine, Joseph   architecte            1
# xpr0034                  Boullée, Louis Claude   architecte            1  57
# xpr0010 Babuty, François Antoine (1716 - 1766) entrepreneur            1  40
# xpr0084              Delespine, Pierre Charles   architecte            1
# xpr0229       Pruneau De Montlouis, Jean Louis   architecte            1  33
# xpr0219                           Pinard, Jean entrepreneur            1  51
# xpr0200                         Mouchet, André entrepreneur            1
# xpr0001             Adhenet, Thomas (1690 - ?)   architecte            1  66
# xpr0056            Cochois, Jacques Richard de   architecte            1  56
# xpr0089               Desboeufs, Henri Quentin   architecte            2  51
#
#
#                                  label  total
#            Estimer la valeur des biens      5
# Recevoir et évaluer le travail réalisé      6
# Décrire et évaluer les travaux à venir      2
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# Guyon, Jean Baptiste ; architecte ; 6 expertises ; 0 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                             name       column  totalCollab age
# xpr0229 Pruneau De Montlouis, Jean Louis   architecte            1  33
# xpr0081      De Villers, Eustache Robert   architecte            1  36
# xpr0091               Desmaisons, Pierre   architecte            1  45
# xpr0209           Payen, Jacques Antoine   architecte            1  46
# xpr0236            Richard, Pierre Louis entrepreneur            1  60
# xpr0071           De Bey, Louis François entrepreneur            2  39
#
#
#                                  label  total
#            Estimer la valeur des biens      3
# Recevoir et évaluer le travail réalisé      2
# Décrire et évaluer les travaux à venir      1
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Joubert, Louis ; entrepreneur ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Le Chauve, Brice ; architecte ; 7 expertises ; 0 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                      name       column  totalCollab age
# xpr0106       Egresset, Guillaume entrepreneur            1  45
# xpr0219              Pinard, Jean entrepreneur            1  51
# xpr0084 Delespine, Pierre Charles   architecte            1
# xpr0037    Bourgeois, Louis Denis entrepreneur            1
# xpr0071    De Bey, Louis François entrepreneur            1  39
# xpr0230   Puisieux, Jean Baptiste   architecte            1  66
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Recevoir et évaluer le travail réalisé      4
# Décrire et évaluer les travaux à venir      1
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Le Sueur, Adrien ; architecte ; 19 expertises ; 0 expertises en tant que tiers-expert ; 15 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                   name       column  totalCollab age
# xpr0066                    Danjan, Pierre Paul   architecte            1  58
# xpr0034                  Boullée, Louis Claude   architecte            1  57
# xpr0227                      Pothenot, Gabriel   architecte            1  60
# xpr0062             Coustillier, Pierre Gilles entrepreneur            1  43
# xpr0010 Babuty, François Antoine (1716 - 1766) entrepreneur            1  40
# xpr0230                Puisieux, Jean Baptiste   architecte            1  66
# xpr0219                           Pinard, Jean entrepreneur            1  51
# xpr0092           Desmaisons, Jacques François entrepreneur            2  41
# xpr0120          Gillet De La Fontaine, Joseph   architecte            2
# xpr0084              Delespine, Pierre Charles   architecte            2
# xpr0089               Desboeufs, Henri Quentin   architecte            2  51
# xpr0071                 De Bey, Louis François entrepreneur            2  39
#
#
#                                  label  total
#            Estimer la valeur des biens      2
# Recevoir et évaluer le travail réalisé      6
# Décrire et évaluer les travaux à venir      4
#                             Départager      7
#                            Enregistrer      0
#
#
#
#
# Le Tordeur, Jacques ; architecte ; 16 expertises ; 0 expertises en tant que tiers-expert ; 4 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0119         Gillet, François   architecte            1  44
# xpr0219             Pinard, Jean entrepreneur            1  51
# xpr0106      Egresset, Guillaume entrepreneur            1  45
# xpr0089 Desboeufs, Henri Quentin   architecte            1  51
# xpr0039        Bourgeois, Pierre entrepreneur            1
#
#
#                                  label  total
#            Estimer la valeur des biens      5
# Recevoir et évaluer le travail réalisé      7
# Décrire et évaluer les travaux à venir      3
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Loir, Denis ; entrepreneur ; 5 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                         name       column  totalCollab age
# xpr0092 Desmaisons, Jacques François entrepreneur            1  41
# xpr0089     Desboeufs, Henri Quentin   architecte            1  51
# xpr0045                Caque, Pierre entrepreneur            1  56
# xpr0071       De Bey, Louis François entrepreneur            1  39
#
#
#                                  label  total
#            Estimer la valeur des biens      2
# Recevoir et évaluer le travail réalisé      2
# Décrire et évaluer les travaux à venir      0
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Martin, Pierre Henry ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      1
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Mouchet, André ; entrepreneur ; 14 expertises ; 0 expertises en tant que tiers-expert ; 11 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                             name       column  totalCollab age
# xpr0230          Puisieux, Jean Baptiste   architecte            1  66
# xpr0229 Pruneau De Montlouis, Jean Louis   architecte            1  33
# xpr0056      Cochois, Jacques Richard de   architecte            1  56
# xpr0119                 Gillet, François   architecte            1  44
# xpr0066              Danjan, Pierre Paul   architecte            1  58
# xpr0120    Gillet De La Fontaine, Joseph   architecte            1
# xpr0045                    Caque, Pierre entrepreneur            1  56
# xpr0209           Payen, Jacques Antoine   architecte            1  46
# xpr0037           Bourgeois, Louis Denis entrepreneur            1
# xpr0231                    Quirot, Denis   architecte            1  48
# xpr0128                  Goupy I, Martin   architecte            1  64
#
#
#                                  label  total
#            Estimer la valeur des biens      3
# Recevoir et évaluer le travail réalisé      6
# Décrire et évaluer les travaux à venir      1
#                             Départager      4
#                            Enregistrer      0
#
#
#
#
# Payen, Jacques Antoine ; architecte ; 17 expertises ; 0 expertises en tant que tiers-expert ; 9 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                   name       column  totalCollab age
# xpr0084              Delespine, Pierre Charles   architecte            1
# xpr0219                           Pinard, Jean entrepreneur            1  51
# xpr0081            De Villers, Eustache Robert   architecte            1  36
# xpr0056            Cochois, Jacques Richard de   architecte            1  56
# xpr0091                     Desmaisons, Pierre   architecte            1  45
# xpr0071                 De Bey, Louis François entrepreneur            1  39
# xpr0136                   Guyon, Jean Baptiste   architecte            1
# xpr0037                 Bourgeois, Louis Denis entrepreneur            1
# xpr0200                         Mouchet, André entrepreneur            1
# xpr0010 Babuty, François Antoine (1716 - 1766) entrepreneur            1  40
# xpr0106                    Egresset, Guillaume entrepreneur            1  45
#
#
#                                  label  total
#            Estimer la valeur des biens      3
# Recevoir et évaluer le travail réalisé      6
# Décrire et évaluer les travaux à venir      3
#                             Départager      4
#                            Enregistrer      0
#
#
#
#
# Pinard, Jean ; entrepreneur ; 31 expertises ; 0 expertises en tant que tiers-expert ; 17 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                   name       column  totalCollab age
# xpr0209                 Payen, Jacques Antoine   architecte            1  46
# xpr0174                    Le Tordeur, Jacques   architecte            1
# xpr0106                    Egresset, Guillaume entrepreneur            1  45
# xpr0071                 De Bey, Louis François entrepreneur            1  39
# xpr0160                       Le Chauve, Brice   architecte            1
# xpr0010 Babuty, François Antoine (1716 - 1766) entrepreneur            1  40
# xpr0092           Desmaisons, Jacques François entrepreneur            1  41
# xpr0231                          Quirot, Denis   architecte            1  48
# xpr0084              Delespine, Pierre Charles   architecte            1
# xpr0128                        Goupy I, Martin   architecte            1  64
# xpr0171                       Le Sueur, Adrien   architecte            1  70
# xpr0006                        Arnoult, Thomas entrepreneur            1  49
# xpr0089               Desboeufs, Henri Quentin   architecte            3  51
# xpr0230                Puisieux, Jean Baptiste   architecte            3  66
#
#
#                                  label  total
#            Estimer la valeur des biens     11
# Recevoir et évaluer le travail réalisé     11
# Décrire et évaluer les travaux à venir      4
#                             Départager      5
#                            Enregistrer      0
#
#
#
#
# Poirin, Jean Baptiste Michel ; architecte ; 3 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                  name     column  totalCollab age
# xpr0034 Boullée, Louis Claude architecte            1  57
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      2
# Décrire et évaluer les travaux à venir      1
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Pothenot, Gabriel ; architecte ; 12 expertises ; 1 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                             name       column  totalCollab age
# xpr0171                 Le Sueur, Adrien   architecte            1  70
# xpr0056      Cochois, Jacques Richard de   architecte            1  56
# xpr0062       Coustillier, Pierre Gilles entrepreneur            1  43
# xpr0229 Pruneau De Montlouis, Jean Louis   architecte            2  33
#
#
#                                  label  total
#            Estimer la valeur des biens      4
# Recevoir et évaluer le travail réalisé      5
# Décrire et évaluer les travaux à venir      2
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Pruneau De Montlouis, Jean Louis ; architecte ; 17 expertises ; 0 expertises en tant que tiers-expert ; 7 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0200           Mouchet, André entrepreneur            1
# xpr0236    Richard, Pierre Louis entrepreneur            1  60
# xpr0136     Guyon, Jean Baptiste   architecte            1
# xpr0089 Desboeufs, Henri Quentin   architecte            1  51
# xpr0128          Goupy I, Martin   architecte            1  64
# xpr0227        Pothenot, Gabriel   architecte            2  60
#
#
#                                  label  total
#            Estimer la valeur des biens      7
# Recevoir et évaluer le travail réalisé      5
# Décrire et évaluer les travaux à venir      3
#                             Départager      2
#                            Enregistrer      0
#
#
#
#
# Puisieux, Jean Baptiste ; architecte ; 42 expertises ; 3 expertises en tant que tiers-expert ; 18 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                   name       column  totalCollab age
# xpr0089               Desboeufs, Henri Quentin   architecte            1  51
# xpr0200                         Mouchet, André entrepreneur            1
# xpr0056            Cochois, Jacques Richard de   architecte            1  56
# xpr0010 Babuty, François Antoine (1716 - 1766) entrepreneur            1  40
# xpr0171                       Le Sueur, Adrien   architecte            1  70
# xpr0045                          Caque, Pierre entrepreneur            1  56
# xpr0236                  Richard, Pierre Louis entrepreneur            1  60
# xpr0118  Gerard De Montbrouard, Claude Jacques   architecte            1  63
# xpr0037                 Bourgeois, Louis Denis entrepreneur            1
# xpr0084              Delespine, Pierre Charles   architecte            1
# xpr0160                       Le Chauve, Brice   architecte            1
# xpr0108                           Fauvel, Jean entrepreneur            3  62
# xpr0219                           Pinard, Jean entrepreneur            3  51
# xpr0071                 De Bey, Louis François entrepreneur            4  39
#
#
#                                  label  total
#            Estimer la valeur des biens      5
# Recevoir et évaluer le travail réalisé     18
# Décrire et évaluer les travaux à venir      7
#                             Départager     10
#                            Enregistrer      0
#
#
#
#
# Quirot, Denis ; architecte ; 3 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                   name       column  totalCollab age
# xpr0219                           Pinard, Jean entrepreneur            1  51
# xpr0200                         Mouchet, André entrepreneur            1
# xpr0010 Babuty, François Antoine (1716 - 1766) entrepreneur            1  40
#
#
#                                  label  total
#            Estimer la valeur des biens      1
# Recevoir et évaluer le travail réalisé      1
# Décrire et évaluer les travaux à venir      0
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Raymond, Etienne Hubert ; entrepreneur ; 8 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                   name       column  totalCollab age
# xpr0037 Bourgeois, Louis Denis entrepreneur            1
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      3
# Décrire et évaluer les travaux à venir      3
#                             Départager      1
#                            Enregistrer      0
#
#
#
#
# Richard, Pierre Louis ; entrepreneur ; 32 expertises ; 0 expertises en tant que tiers-expert ; 14 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                             name       column  totalCollab age
# xpr0229 Pruneau De Montlouis, Jean Louis   architecte            1  33
# xpr0108                     Fauvel, Jean entrepreneur            1  62
# xpr0062       Coustillier, Pierre Gilles entrepreneur            1  43
# xpr0092     Desmaisons, Jacques François entrepreneur            1  41
# xpr0230          Puisieux, Jean Baptiste   architecte            1  66
# xpr0136             Guyon, Jean Baptiste   architecte            1
# xpr0081      De Villers, Eustache Robert   architecte            2  36
# xpr0056      Cochois, Jacques Richard de   architecte            2  56
# xpr0006                  Arnoult, Thomas entrepreneur            2  49
# xpr0089         Desboeufs, Henri Quentin   architecte            4  51
#
#
#                                  label  total
#            Estimer la valeur des biens     10
# Recevoir et évaluer le travail réalisé      5
# Décrire et évaluer les travaux à venir      5
#                             Départager      7
#                            Enregistrer      0
#
#
#
#
# Simon, René Auguste ; entrepreneur ; 3 expertises ; 1 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                  name     column  totalCollab age
# xpr0118 Gerard De Montbrouard, Claude Jacques architecte            1  63
#
#
#                                  label  total
#            Estimer la valeur des biens      2
# Recevoir et évaluer le travail réalisé      0
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
#
#
#
#
# Vedy, Julien ; entrepreneur ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id              name       column  totalCollab age
# xpr0082 De Vonges, Michel entrepreneur            1  42
#
#
#                                  label  total
#            Estimer la valeur des biens      0
# Recevoir et évaluer le travail réalisé      1
# Décrire et évaluer les travaux à venir      0
#                             Départager      0
#                            Enregistrer      0
