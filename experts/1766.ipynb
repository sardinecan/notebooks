# %% [markdown]
# # xprStats

# %%
# lib
from urllib.request import urlopen
import json  
import pandas as pd

# %%
# Récupération des donnée 
# param (date or thirdParty)
param = "1766"

# url
url = "https://experts.huma-num.fr/xpr/statistics/" + param

# enregistrement de la réponse
response = urlopen(url)

# lecture du json
data = json.loads(response.read())
  
# print the json response
#print(data)

# %% [markdown]
# ## Expertises

# %%
expertises = data['expertises']

# %%
print("Nombre total d'expertises : " + str(expertises['total']))
# Out:
# Nombre total d'expertises : 466

# %% [markdown]
# ### Croquis

# %%
sketchesDF = pd.json_normalize(expertises['sketches'])
print(sketchesDF.to_string(index=False))
# Out:
#  expertisesWithoutSketch  expertisesWithSketch
#                      446                    20

# %% [markdown]
# ### Étendue

# %%
extent = expertises['extent']
#print(extent)

print('Nombre de feuillets : ' + str(extent['total']))

print('Moyenne par expertise : ' + str(extent['averageByExpertise']))

#Distribution
print('Distribution :')
keys = []
values = []
for dic in extent['extentDistribution']:
    for key, val in dic.items():
        keys.append(key),
        values.append(val)        

extentDistributionDict = {'nombre de feuillets': keys, 'nombre d’expertises': values,} 
print(pd.DataFrame(extentDistributionDict).to_string(index=False))
# Out:
# Nombre de feuillets : 2531
# Moyenne par expertise : 5.43
# Distribution :
# nombre de feuillets  nombre d’expertises
#                   5                  307
#                  10                  108
#                  15                   26
#                  20                    9
#                  25                    6
#                  30                    1
#                  35                    2
#                  40                    1
#                  45                    0
#                  50                    1
#                  55                    0
#                  60                    0
#                  65                    1
#                  70                    0
#                  75                    0
#                  80                    0
#                  85                    0
#                  90                    0
#                  95                    0
#                 100                    0

# %% [markdown]
# ### Annexes

# %%
appendices = expertises['appendices']
#print(appendices)

print(f"{appendices['total']} annexes")


print(f"{appendices['expertisesWithAppendices']} expertises avec annexes ; {appendices['expertisesWithoutAppendices']} expertises sans annexes")


df=pd.json_normalize(appendices['types'])
print(df.to_string(columns=['label', 'total', 'expertises'], index=False))
# Out:
# 342 annexes
# 213 expertises avec annexes ; 253 expertises sans annexes
#                                       label  total  expertises
#          Pouvoir/procuration (acte notarié)     11          11
#                                   Brouillon      4           4
#                                       Autre    159         104
#                                     Requête     17          16
#                                     Croquis     12          12
# Pouvoir/procuration (acte sous seing privé)    118         101
#                      Plan, coupe, élévation     20          17
#                                      Dessin      2           2

# %% [markdown]
# ### Vacations

# %%
sessions = expertises['sessions']
#print(sessions)

print(f"{sessions['total']} vacations")


print(f"en moyenne {sessions['averageByExpertise']} vacations par expertise")
# Out:
# 887 vacations
# en moyenne 1.9 vacations par expertise

# %% [markdown]
# Nombre de vacation par lieu

# %%
sessionsDf=pd.json_normalize(sessions['places'])
print(sessionsDf.to_string(columns=['label', 'total'], index=False))
# Out:
#    label  total
#    Paris    724
# Banlieue     63
# Province     94

# %% [markdown]
# ### Durée

# %%
duration = expertises['duration']
#print(duration)

# %% [markdown]
# #### Jours

# %%
#Distribution
durationDays = duration['days']
#print(durationDays)
print('Distribution :')
keys = []
values = []
for dic in durationDays['distributionByDays']:
    for key, val in dic.items():
        keys.append(key),
        values.append(val)        

durationDaysDf = {'nombre de jours': keys, 'nombre d’expertises': values,} 
print(pd.DataFrame(durationDaysDf).to_string(index=False))
# Out:
# Distribution :
# nombre de jours  nombre d’expertises
#               5                  360
#              10                   26
#              15                   13
#              20                    6
#              25                   11
#              30                    6
#              35                    3
#              40                    1
#              45                    5
#              50                    1
#              55                    3
#              60                    3
#              65                    1
#              70                    3
#              75                    1
#              80                    0
#              85                    3
#              90                    0
#              95                    2
#             100                   18

# %% [markdown]
# #### Vacations

# %%
#Distribution
durationSessions = duration['sessions']
#print(durationDays)
print(f"{durationSessions['total']} vacations, soit en moyenne {durationSessions['averageByExpertise']} vacations par expertise.")
# Out:
# 887 vacations, soit en moyenne 0.95 vacations par expertise.

# %% [markdown]
# ### Lieux

# %%
places = expertises['places']
#print(places)

placesDf=pd.json_normalize(places)
print(placesDf.to_string(columns=['place', 'total'], index=False))
# Out:
#                        place  total
#                      [paris]    369
#                    [suburbs]     36
#                   [province]     43
#           [[paris, suburbs]]      5
#          [[paris, province]]      7
#        [[suburbs, province]]      0
# [[paris, suburbs, province]]      0

# %% [markdown]
# ### Procédures et cadres

# %%
frameworks = expertises['frameworks']
#print(frameworks)

frameworksDf=pd.json_normalize(frameworks)
print(frameworksDf.to_string(columns=['label', 'framework', 'total'], index=False))
# Out:
#                                                                                                                   label framework  total
# L’institution est saisie dans le cadre d’une procédure (les parties nomment chacune leur expert ou un expert en commun)        b2     37
#                                                                                               Commun accord des parties         a    161
#                                                     Requête auprès d’une institution pour qu’elle demande une expertise        b1     21
# L’institution est saisie dans le cadre d’une procédure (les parties nomment chacune leur expert ou un expert en commun)       b2a    138
#                         L’institution est saisie dans le cadre d’une procédure (l’institution nomme un ou deux experts)       b2b     93
#                                                                                                                                        8
#                                                                                                       Cas problématique         c      5
#                                          Saisie mixte (un expert est nommé par les parties, l'autre est nommé d'office)        b3      3

# %% [markdown]
# ### Catégories

# %%
categories = expertises['categories']

for cat in categories:
    if cat['total'] != 0: print(f"{cat['label']} : {cat['total']} expertises"),
    for framework in cat['frameworks']:
        if framework['total'] != 0: print(f"\t{framework['framework']} : {framework['total']} expertises"),
        for place in framework['places']:
            if place['total'] != 0: print(f"\t\t{place['place']} : {place['total']}"),
            for obj in place['objects']:
                if obj['total'] != 0: print(f"\t\t\t{obj['label']} : {obj['total']}")
        print('\n')
    print('\n')
# Out:
# Décrire et évaluer les travaux à venir : 101 expertises
# 	b2 : 10 expertises
# 		['paris'] : 7
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 5
# 		['suburbs'] : 1
# 			Ouvrages de maçonnerie : 1
# 		['province'] : 2
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 			Terrain(s) : 1
#
#
# 	a : 16 expertises
# 		['paris'] : 15
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 5
# 			Mur(s) : 10
# 		['province'] : 1
# 			Ouvrages de maçonnerie : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
#
#
# 	b1 : 11 expertises
# 		['paris'] : 8
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 6
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		['province'] : 3
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 2
#
#
# 	b2a : 30 expertises
# 		['paris'] : 18
# 			Ouvrages de maçonnerie : 3
# 			Maison(s) : 16
# 			Terrain(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		['suburbs'] : 3
# 			Maison(s) : 3
# 		['province'] : 7
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 5
# 			Terrain(s) : 1
# 			Domaine, terres, fief : 1
# 		[['paris', 'province']] : 2
# 			Maison(s) : 1
# 			Terrain(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
# 			Domaine, terres, fief : 1
#
#
# 	b2b : 33 expertises
# 		['paris'] : 25
# 			Maison(s) : 25
# 			Terrain(s) : 1
# 		['suburbs'] : 2
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 2
# 		['province'] : 6
# 			Maison(s) : 3
# 			Domaine, terres, fief : 2
#
#
#
#
# 	c : 1 expertises
# 		['province'] : 1
# 			Maison(s) : 1
# 			Terrain(s) : 1
#
#
#
#
#
#
# Estimer la valeur des biens : 80 expertises
# 	b2 : 8 expertises
# 		['paris'] : 3
# 			Maison(s) : 3
# 		['suburbs'] : 4
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 3
# 			Terrain(s) : 2
# 		['province'] : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
#
#
# 	a : 16 expertises
# 		['paris'] : 10
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 9
# 		['province'] : 3
# 			Maison(s) : 3
# 		[['paris', 'suburbs']] : 2
# 			Maison(s) : 2
# 			Terrain(s) : 1
# 		[['paris', 'province']] : 1
# 			Maison(s) : 1
#
#
# 	b1 : 3 expertises
# 		['paris'] : 1
# 			Maison(s) : 1
# 		['suburbs'] : 1
# 			Maison(s) : 1
# 			Terrain(s) : 1
# 		[['paris', 'province']] : 1
# 			Maison(s) : 1
#
#
# 	b2a : 35 expertises
# 		['paris'] : 25
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 24
# 		['suburbs'] : 6
# 			Maison(s) : 5
# 			Terrain(s) : 1
# 		['province'] : 3
# 			Maison(s) : 1
# 			Terrain(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 2
# 			Domaine, terres, fief : 2
# 		[['paris', 'province']] : 1
# 			Maison(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
#
#
# 	b2b : 15 expertises
# 		['paris'] : 10
# 			Maison(s) : 9
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		['suburbs'] : 2
# 			Maison(s) : 2
# 			Terrain(s) : 1
# 		['province'] : 2
# 			Maison(s) : 1
# 			Terrain(s) : 1
# 			Domaine, terres, fief : 1
# 		[['paris', 'suburbs']] : 1
# 			Maison(s) : 1
#
#
#
#
#
#
# 	b3 : 3 expertises
# 		['paris'] : 2
# 			Maison(s) : 2
# 		['province'] : 1
# 			Terrain(s) : 1
#
#
#
#
# Départager : 91 expertises
# 	b2 : 8 expertises
# 		['paris'] : 7
# 			Ouvrages de maçonnerie : 2
# 			Terrain(s) : 1
# 			Mur(s) : 4
# 			Fosse(s) d'aisance : 1
# 		['suburbs'] : 1
# 			Terrain(s) : 1
#
#
# 	a : 52 expertises
# 		['paris'] : 51
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 3
# 			Mur(s) : 45
# 			Ensemble de bâtiments (biens immeubles) : 1
# 			Fosse(s) d'aisance : 1
#
#
#
#
# 	b2a : 22 expertises
# 		['paris'] : 20
# 			Ouvrages de maçonnerie : 6
# 			Maison(s) : 6
# 			Mur(s) : 8
# 			Fosse(s) d'aisance : 2
# 			Puits : 2
# 		['province'] : 1
# 			Ouvrages de maçonnerie : 1
#
#
# 	b2b : 7 expertises
# 		['paris'] : 4
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 2
# 		['suburbs'] : 2
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 			Mur(s) : 1
# 		['province'] : 1
# 			Maison(s) : 1
# 			Terrain(s) : 1
#
#
# 	 : 1 expertises
# 		['paris'] : 1
# 			Mur(s) : 1
#
#
# 	c : 1 expertises
# 		['paris'] : 1
# 			Mur(s) : 1
#
#
#
#
#
#
# Enregistrer : 9 expertises
#
#
# 	a : 1 expertises
# 		['paris'] : 1
# 			Mur(s) : 1
#
#
# 	b1 : 6 expertises
# 		['paris'] : 2
# 			Maison(s) : 2
# 		['suburbs'] : 1
# 			Maison(s) : 1
# 		['province'] : 3
# 			Maison(s) : 3
#
#
# 	b2a : 2 expertises
# 		['paris'] : 1
# 			Maison(s) : 1
# 		['suburbs'] : 1
# 			Terrain(s) : 1
#
#
#
#
#
#
#
#
#
#
#
#
# Recevoir et évaluer le travail réalisé : 119 expertises
# 	b2 : 11 expertises
# 		['paris'] : 10
# 			Ouvrages de maçonnerie : 10
# 			Maison(s) : 2
# 		['suburbs'] : 1
# 			Ouvrages de maçonnerie : 1
#
#
# 	a : 52 expertises
# 		['paris'] : 47
# 			Ouvrages de maçonnerie : 28
# 			Maison(s) : 31
# 			Mur(s) : 2
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		['suburbs'] : 1
# 			Ouvrages de maçonnerie : 1
# 		['province'] : 2
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 		[['paris', 'province']] : 1
# 			Maison(s) : 1
#
#
#
#
# 	b2a : 40 expertises
# 		['paris'] : 36
# 			Ouvrages de maçonnerie : 22
# 			Maison(s) : 21
# 			Puits : 1
# 		['suburbs'] : 1
# 			Maison(s) : 1
# 		['province'] : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		[['paris', 'suburbs']] : 1
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
#
#
# 	b2b : 16 expertises
# 		['paris'] : 14
# 			Ouvrages de maçonnerie : 10
# 			Maison(s) : 9
# 			Mur(s) : 1
# 		[['paris', 'province']] : 1
# 			Ensemble de bâtiments (biens immeubles) : 1

# %% [markdown]
# ### Tiers expertises

# %%
thirdParty = expertises['thirdParty']

# %%
thirdPartyDf=pd.json_normalize(thirdParty)
print(thirdPartyDf.to_string(columns=['architectes', 'entrepreneurs', 'total'], index=False))
# Out:
#  architectes  entrepreneurs  total
#           21              6     27

# %% [markdown]
# ### Distribution (hors tiers expertises)

# %%
columnDistrib = expertises['experts']

for column in columnDistrib:
    print(f"{column['totalExperts']} expert(s) : {column['totalExpertises']} expertises"),
    if column['totalExperts']<3: print(pd.json_normalize(column['distribution']).to_string(columns=['label', 'total'], index=False))
    print('\n')
# Out:
# 1 expert(s) : 302 expertises
#        label  total
#   architecte    169
# entrepreneur    108
#
#
# 2 expert(s) : 127 expertises
#                       label  total
#     architecte - architecte     29
#   entrepreneur - architecte     61
# entrepreneur - entrepreneur     20
#
#
# 3 expert(s) : 9 expertises
#
#
# 4 expert(s) : 1 expertises

# %% [markdown]
# ## Experts

# %%
experts = data['experts']
#print(experts)

# %%
print(f"Nombre d’experts : {experts['total']}")
print(f"{experts['architects']} architectes")
print(f"{experts['entrepreneur']} entrepreneurs")
print(f"{experts['surveyor']} arpenteurs")
# Out:
# Nombre d’experts : 60
# 29 architectes
# 22 entrepreneurs
# 9 arpenteurs

# %%
listExperts = experts['list']
listExpertsDf = pd.DataFrame(listExperts)
listExpertsDf.drop('expertises', inplace=True, axis=1)

# %%
print(listExpertsDf.to_string(columns=['id', 'name', 'column', 'age'], index=False))
# Out:
#      id                                  name       column age
# xpr0008                         Aubry, Claude entrepreneur
# xpr0011                         Baillis, Jean   architecte
# xpr0021                      Bertier, Nicolas entrepreneur  56
# xpr0035              Boulier de Bourges, Jean   architecte
# xpr0048                        Caulle, Martin entrepreneur  35
# xpr0058                    Collibeuf, Laurent    arpenteur
# xpr0059                        Convers, Louis   architecte  50
# xpr0063                    Cudeville, Jacques    arpenteur
# xpr0077            De Mezerets (Père), Michel   architecte  59
# xpr0084             Delespine, Pierre Charles   architecte
# xpr0085                Delespine, Louis Jules   architecte -30
# xpr0086                    Delespine, Nicolas   architecte  54
# xpr0087             Delespine, Pierre Nicolas entrepreneur  34
# xpr0094                          Dorbay, Jean entrepreneur  60
# xpr0099                     Doussot, François   architecte
# xpr0100                          Dubois, Jean   architecte  48
# xpr0105                        Duval, Charles    arpenteur
# xpr0115                      Gabriel, Maurice entrepreneur
# xpr0116                      Gabriel, Jacques entrepreneur
# xpr0124                  Gobin, Jean François   architecte  39
# xpr0125                          Gobin, Denis   architecte  33
# xpr0126               Goujon, Louis Alexandre   architecte  36
# xpr0132                      Guemier, Jacques entrepreneur
# xpr0133                    Guillain, Philippe    arpenteur
# xpr0138                       Hallot, Etienne    arpenteur
# xpr0139                      Havard, François entrepreneur  50
# xpr0140                        Hequan, Pierre entrepreneur  58
# xpr0141                        Herbet, Michel   architecte  34
# xpr0146                      Joubert, Charles entrepreneur  56
# xpr0151             Laisney, François Etienne   architecte  13
# xpr0152                       Laisney, Gilles entrepreneur
# xpr0153                       Lajoue, Jacques entrepreneur
# xpr0157                   Le Boutteux, Michel   architecte  74
# xpr0161                    Le Clerc, François   architecte
# xpr0162                       Le Duc, Gabriel   architecte  73
# xpr0166                      Le Juge, Nicolas   architecte  50
# xpr0167                    Le Maistre, Pierre   architecte  53
# xpr0168                    Le Proust, Rolland   architecte  59
# xpr0170                      Le Roy, Estienne entrepreneur  48
# xpr0172 Le Teilleur De Boncourt, Hélie (Elie)    arpenteur
# xpr0178          Lepas Dubuisson, Jacques (I)    arpenteur
# xpr0189                        Marchand, Marc   architecte
# xpr0190                Marteau, Jean Baptiste   architecte  42
# xpr0192                          Masson, Noël entrepreneur  53
# xpr0193                       Masson, Etienne   architecte  14
# xpr0194                     Mazieres, Jacques   architecte
# xpr0195                    Menessier, Bernard entrepreneur
# xpr0197                        Miche, Jacques entrepreneur  44
# xpr0204                     Pageois, François   architecte  68
# xpr0211                       Perrault, André entrepreneur  39
# xpr0213                       Person, Charles   architecte  43
# xpr0214                        Petit, Antoine    arpenteur
# xpr0218                       Philipest, Jean entrepreneur  55
# xpr0220                        Pipault, Simon entrepreneur
# xpr0221                    Pirethouy, Jacques   architecte  46
# xpr0225                         Poisson, Jean entrepreneur  47
# xpr0239                     Rohais, Toussaint    arpenteur
# xpr0244                         Serouge, Jean entrepreneur
# xpr0271                       Jomard François   architecte
# xpr0272           Le Berton, François (? - ?)   architecte

# %%
for expert in listExperts:
    print(f"{expert['name']} ; {expert['column']} ; {expert['expertises']['total']} expertises ; {expert['expertises']['thirParty']} expertises en tant que tiers-expert ; {expert['expertises']['collab']['total']} expertises avec d'autres experts (tiers expertises comprises)"),
    print("\n")
    
    collabDF = pd.json_normalize(expert['expertises']['collab']['experts']) 
    if expert['expertises']['collab']['total'] != 0: print(collabDF.to_string(columns=['id', 'name', 'column', 'totalCollab', 'age'], index=False))
    print("\n")
    categoriesDef = pd.json_normalize(expert['expertises']['categories'])
    print(categoriesDef.to_string(columns=['label', 'total'], index=False))

    print("\n")
    print("\n")
# Out:
# Aubry, Claude ; entrepreneur ; 27 expertises ; 2 expertises en tant que tiers-expert ; 18 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0124       Gobin, Jean François   architecte            1  39
# xpr0146           Joubert, Charles entrepreneur            1  56
# xpr0132           Guemier, Jacques entrepreneur            1
# xpr0077 De Mezerets (Père), Michel   architecte            1  59
# xpr0211            Perrault, André entrepreneur            1  39
# xpr0161         Le Clerc, François   architecte            1
# xpr0105             Duval, Charles    arpenteur            1
# xpr0218            Philipest, Jean entrepreneur            1  55
# xpr0139           Havard, François entrepreneur            1  50
# xpr0086         Delespine, Nicolas   architecte            1  54
# xpr0213            Person, Charles   architecte            1  43
# xpr0100               Dubois, Jean   architecte            1  48
# xpr0035   Boulier de Bourges, Jean   architecte            2
# xpr0048             Caulle, Martin entrepreneur            2  35
# xpr0152            Laisney, Gilles entrepreneur            2
# xpr0204          Pageois, François   architecte            3  68
# xpr0195         Menessier, Bernard entrepreneur            3
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      6
#            Estimer la valeur des biens      8
#                             Départager      4
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      6
#
#
#
#
# Baillis, Jean ; architecte ; 9 expertises ; 0 expertises en tant que tiers-expert ; 4 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id               name       column  totalCollab age
# xpr0225      Poisson, Jean entrepreneur            1  47
# xpr0133 Guillain, Philippe    arpenteur            1
# xpr0189     Marchand, Marc   architecte            1
# xpr0021   Bertier, Nicolas entrepreneur            1  56
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      2
#            Estimer la valeur des biens      1
#                             Départager      2
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      1
#
#
#
#
# Bertier, Nicolas ; entrepreneur ; 11 expertises ; 0 expertises en tant que tiers-expert ; 8 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                         name       column  totalCollab age
# xpr0152              Laisney, Gilles entrepreneur            1
# xpr0086           Delespine, Nicolas   architecte            1  54
# xpr0077   De Mezerets (Père), Michel   architecte            1  59
# xpr0239            Rohais, Toussaint    arpenteur            1
# xpr0190       Marteau, Jean Baptiste   architecte            1  42
# xpr0204            Pageois, François   architecte            1  68
# xpr0244                Serouge, Jean entrepreneur            1
# xpr0178 Lepas Dubuisson, Jacques (I)    arpenteur            1
# xpr0011                Baillis, Jean   architecte            1
# xpr0194            Mazieres, Jacques   architecte            2
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      4
#            Estimer la valeur des biens      2
#                             Départager      2
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      2
#
#
#
#
# Boulier de Bourges, Jean ; architecte ; 22 expertises ; 2 expertises en tant que tiers-expert ; 13 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0218            Philipest, Jean entrepreneur            1  55
# xpr0161         Le Clerc, François   architecte            1
# xpr0152            Laisney, Gilles entrepreneur            1
# xpr0105             Duval, Charles    arpenteur            1
# xpr0194          Mazieres, Jacques   architecte            1
# xpr0077 De Mezerets (Père), Michel   architecte            1  59
# xpr0166           Le Juge, Nicolas   architecte            1  50
# xpr0239          Rohais, Toussaint    arpenteur            1
# xpr0008              Aubry, Claude entrepreneur            2
# xpr0204          Pageois, François   architecte            2  68
# xpr0063         Cudeville, Jacques    arpenteur            2
# xpr0168         Le Proust, Rolland   architecte            4  59
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      4
#            Estimer la valeur des biens      5
#                             Départager      3
#                            Enregistrer      1
# Recevoir et évaluer le travail réalisé      5
#
#
#
#
# Caulle, Martin ; entrepreneur ; 4 expertises ; 0 expertises en tant que tiers-expert ; 4 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                      name       column  totalCollab age
# xpr0151 Laisney, François Etienne   architecte            1  13
# xpr0213           Person, Charles   architecte            1  43
# xpr0146          Joubert, Charles entrepreneur            1  56
# xpr0008             Aubry, Claude entrepreneur            2
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      1
#            Estimer la valeur des biens      0
#                             Départager      1
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      2
#
#
#
#
# Collibeuf, Laurent ; arpenteur ; 2 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id               name     column  totalCollab age
# xpr0086 Delespine, Nicolas architecte            1  54
# xpr0168 Le Proust, Rolland architecte            1  59
# xpr0204  Pageois, François architecte            1  68
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      1
#                             Départager      1
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      0
#
#
#
#
# Convers, Louis ; architecte ; 2 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id               name     column  totalCollab age
# xpr0168 Le Proust, Rolland architecte            1  59
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                             Départager      1
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      0
#
#
#
#
# Cudeville, Jacques ; arpenteur ; 6 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0192             Masson, Noël entrepreneur            1  53
# xpr0239        Rohais, Toussaint    arpenteur            1
# xpr0035 Boulier de Bourges, Jean   architecte            2
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      4
#            Estimer la valeur des biens      1
#                             Départager      0
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      1
#
#
#
#
# De Mezerets (Père), Michel ; architecte ; 59 expertises ; 1 expertises en tant que tiers-expert ; 28 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                        name       column  totalCollab age
# xpr0218             Philipest, Jean entrepreneur            1  55
# xpr0225               Poisson, Jean entrepreneur            1  47
# xpr0132            Guemier, Jacques entrepreneur            1
# xpr0021            Bertier, Nicolas entrepreneur            1  56
# xpr0008               Aubry, Claude entrepreneur            1
# xpr0153             Lajoue, Jacques entrepreneur            1
# xpr0146            Joubert, Charles entrepreneur            1  56
# xpr0035    Boulier de Bourges, Jean   architecte            1
# xpr0239           Rohais, Toussaint    arpenteur            1
# xpr0272 Le Berton, François (? - ?)   architecte            1
# xpr0140              Hequan, Pierre entrepreneur            1  58
# xpr0141              Herbet, Michel   architecte            1  34
# xpr0100                Dubois, Jean   architecte            1  48
# xpr0166            Le Juge, Nicolas   architecte            1  50
# xpr0086          Delespine, Nicolas   architecte            2  54
# xpr0094                Dorbay, Jean entrepreneur            2  60
# xpr0168          Le Proust, Rolland   architecte            2  59
# xpr0220              Pipault, Simon entrepreneur            2
# xpr0124        Gobin, Jean François   architecte            3  39
# xpr0170            Le Roy, Estienne entrepreneur            3  48
# xpr0194           Mazieres, Jacques   architecte            3
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir     14
#            Estimer la valeur des biens      9
#                             Départager      8
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé     17
#
#
#
#
# Delespine, Pierre Charles ; architecte ; 1 expertises ; 1 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      1
#                             Départager      0
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      0
#
#
#
#
# Delespine, Louis Jules ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id               name     column  totalCollab age
# xpr0168 Le Proust, Rolland architecte            1  59
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                             Départager      1
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      0
#
#
#
#
# Delespine, Nicolas ; architecte ; 58 expertises ; 5 expertises en tant que tiers-expert ; 23 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                         name       column  totalCollab age
# xpr0178 Lepas Dubuisson, Jacques (I)    arpenteur            1
# xpr0058           Collibeuf, Laurent    arpenteur            1
# xpr0168           Le Proust, Rolland   architecte            1  59
# xpr0167           Le Maistre, Pierre   architecte            1  53
# xpr0021             Bertier, Nicolas entrepreneur            1  56
# xpr0153              Lajoue, Jacques entrepreneur            1
# xpr0197               Miche, Jacques entrepreneur            1  44
# xpr0190       Marteau, Jean Baptiste   architecte            1  42
# xpr0008                Aubry, Claude entrepreneur            1
# xpr0139             Havard, François entrepreneur            1  50
# xpr0100                 Dubois, Jean   architecte            1  48
# xpr0218              Philipest, Jean entrepreneur            1  55
# xpr0087    Delespine, Pierre Nicolas entrepreneur            1  34
# xpr0162              Le Duc, Gabriel   architecte            1  73
# xpr0077   De Mezerets (Père), Michel   architecte            2  59
# xpr0220               Pipault, Simon entrepreneur            2
# xpr0140               Hequan, Pierre entrepreneur            2  58
# xpr0204            Pageois, François   architecte            2  68
# xpr0152              Laisney, Gilles entrepreneur            3
# xpr0146             Joubert, Charles entrepreneur            4  56
# xpr0194            Mazieres, Jacques   architecte            4
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      6
#            Estimer la valeur des biens      6
#                             Départager     15
#                            Enregistrer      1
# Recevoir et évaluer le travail réalisé     23
#
#
#
#
# Delespine, Pierre Nicolas ; entrepreneur ; 11 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id               name     column  totalCollab age
# xpr0193    Masson, Etienne architecte            1  14
# xpr0086 Delespine, Nicolas architecte            1  54
# xpr0194  Mazieres, Jacques architecte            2
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      2
#            Estimer la valeur des biens      3
#                             Départager      1
#                            Enregistrer      1
# Recevoir et évaluer le travail réalisé      3
#
#
#
#
# Dorbay, Jean ; entrepreneur ; 14 expertises ; 1 expertises en tant que tiers-expert ; 4 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0195         Menessier, Bernard entrepreneur            1
# xpr0211            Perrault, André entrepreneur            1  39
# xpr0105             Duval, Charles    arpenteur            1
# xpr0077 De Mezerets (Père), Michel   architecte            2  59
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      2
#            Estimer la valeur des biens      2
#                             Départager      3
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      4
#
#
#
#
# Doussot, François ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id              name     column  totalCollab age
# xpr0204 Pageois, François architecte            1  68
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                             Départager      0
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      1
#
#
#
#
# Dubois, Jean ; architecte ; 13 expertises ; 0 expertises en tant que tiers-expert ; 6 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0146           Joubert, Charles entrepreneur            1  56
# xpr0194          Mazieres, Jacques   architecte            1
# xpr0086         Delespine, Nicolas   architecte            1  54
# xpr0077 De Mezerets (Père), Michel   architecte            1  59
# xpr0008              Aubry, Claude entrepreneur            1
# xpr0140             Hequan, Pierre entrepreneur            2  58
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      2
#            Estimer la valeur des biens      1
#                             Départager      1
#                            Enregistrer      2
# Recevoir et évaluer le travail réalisé      2
#
#
#
#
# Duval, Charles ; arpenteur ; 4 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0035 Boulier de Bourges, Jean   architecte            1
# xpr0008            Aubry, Claude entrepreneur            1
# xpr0211          Perrault, André entrepreneur            1  39
# xpr0094             Dorbay, Jean entrepreneur            1  60
# xpr0218          Philipest, Jean entrepreneur            1  55
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      2
#            Estimer la valeur des biens      1
#                             Départager      0
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      0
#
#
#
#
# Gabriel, Maurice ; entrepreneur ; 2 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      1
#            Estimer la valeur des biens      0
#                             Départager      1
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      0
#
#
#
#
# Gabriel, Jacques ; entrepreneur ; 3 expertises ; 1 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id              name       column  totalCollab age
# xpr0244     Serouge, Jean entrepreneur            1
# xpr0239 Rohais, Toussaint    arpenteur            1
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      2
#                             Départager      1
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      0
#
#
#
#
# Gobin, Jean François ; architecte ; 14 expertises ; 1 expertises en tant que tiers-expert ; 8 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0008              Aubry, Claude entrepreneur            1
# xpr0204          Pageois, François   architecte            1  68
# xpr0239          Rohais, Toussaint    arpenteur            1
# xpr0194          Mazieres, Jacques   architecte            1
# xpr0139           Havard, François entrepreneur            2  50
# xpr0077 De Mezerets (Père), Michel   architecte            3  59
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      1
#            Estimer la valeur des biens      5
#                             Départager      1
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      3
#
#
#
#
# Gobin, Denis ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id              name     column  totalCollab age
# xpr0204 Pageois, François architecte            1  68
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                             Départager      0
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      1
#
#
#
#
# Goujon, Louis Alexandre ; architecte ; 5 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id            name     column  totalCollab age
# xpr0213 Person, Charles architecte            1  43
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                             Départager      1
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      4
#
#
#
#
# Guemier, Jacques ; entrepreneur ; 6 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0008              Aubry, Claude entrepreneur            1
# xpr0077 De Mezerets (Père), Michel   architecte            1  59
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      1
#            Estimer la valeur des biens      1
#                             Départager      0
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      2
#
#
#
#
# Guillain, Philippe ; arpenteur ; 7 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id          name     column  totalCollab age
# xpr0011 Baillis, Jean architecte            1
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      2
#            Estimer la valeur des biens      0
#                             Départager      2
#                            Enregistrer      1
# Recevoir et évaluer le travail réalisé      1
#
#
#
#
# Hallot, Etienne ; arpenteur ; 5 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id            name       column  totalCollab age
# xpr0218 Philipest, Jean entrepreneur            1  55
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      1
#            Estimer la valeur des biens      0
#                             Départager      1
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      3
#
#
#
#
# Havard, François ; entrepreneur ; 9 expertises ; 0 expertises en tant que tiers-expert ; 8 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                 name       column  totalCollab age
# xpr0157  Le Boutteux, Michel   architecte            1  74
# xpr0008        Aubry, Claude entrepreneur            1
# xpr0086   Delespine, Nicolas   architecte            1  54
# xpr0124 Gobin, Jean François   architecte            2  39
# xpr0218      Philipest, Jean entrepreneur            2  55
# xpr0161   Le Clerc, François   architecte            2
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      1
#                             Départager      1
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      6
#
#
#
#
# Hequan, Pierre ; entrepreneur ; 7 expertises ; 0 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0077 De Mezerets (Père), Michel   architecte            1  59
# xpr0218            Philipest, Jean entrepreneur            1  55
# xpr0086         Delespine, Nicolas   architecte            2  54
# xpr0100               Dubois, Jean   architecte            2  48
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      1
#            Estimer la valeur des biens      0
#                             Départager      1
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      2
#
#
#
#
# Herbet, Michel ; architecte ; 2 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name     column  totalCollab age
# xpr0189             Marchand, Marc architecte            1
# xpr0077 De Mezerets (Père), Michel architecte            1  59
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      1
#                             Départager      1
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      0
#
#
#
#
# Joubert, Charles ; entrepreneur ; 19 expertises ; 0 expertises en tant que tiers-expert ; 13 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0008              Aubry, Claude entrepreneur            1
# xpr0100               Dubois, Jean   architecte            1  48
# xpr0077 De Mezerets (Père), Michel   architecte            1  59
# xpr0220             Pipault, Simon entrepreneur            1
# xpr0195         Menessier, Bernard entrepreneur            1
# xpr0244              Serouge, Jean entrepreneur            1
# xpr0048             Caulle, Martin entrepreneur            1  35
# xpr0204          Pageois, François   architecte            2  68
# xpr0218            Philipest, Jean entrepreneur            2  55
# xpr0086         Delespine, Nicolas   architecte            4  54
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      2
#            Estimer la valeur des biens      2
#                             Départager      3
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      8
#
#
#
#
# Laisney, François Etienne ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id           name       column  totalCollab age
# xpr0048 Caulle, Martin entrepreneur            1  35
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                             Départager      1
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      0
#
#
#
#
# Laisney, Gilles ; entrepreneur ; 16 expertises ; 0 expertises en tant que tiers-expert ; 10 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0035 Boulier de Bourges, Jean   architecte            1
# xpr0194        Mazieres, Jacques   architecte            1
# xpr0021         Bertier, Nicolas entrepreneur            1  56
# xpr0244            Serouge, Jean entrepreneur            1
# xpr0195       Menessier, Bernard entrepreneur            1
# xpr0008            Aubry, Claude entrepreneur            2
# xpr0086       Delespine, Nicolas   architecte            3  54
# xpr0204        Pageois, François   architecte            4  68
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      5
#            Estimer la valeur des biens      4
#                             Départager      4
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      1
#
#
#
#
# Lajoue, Jacques ; entrepreneur ; 12 expertises ; 0 expertises en tant que tiers-expert ; 6 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0211            Perrault, André entrepreneur            1  39
# xpr0086         Delespine, Nicolas   architecte            1  54
# xpr0077 De Mezerets (Père), Michel   architecte            1  59
# xpr0204          Pageois, François   architecte            1  68
# xpr0244              Serouge, Jean entrepreneur            1
# xpr0194          Mazieres, Jacques   architecte            1
# xpr0189             Marchand, Marc   architecte            1
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      2
#            Estimer la valeur des biens      1
#                             Départager      2
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      3
#
#
#
#
# Le Boutteux, Michel ; architecte ; 4 expertises ; 0 expertises en tant que tiers-expert ; 2 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id             name       column  totalCollab age
# xpr0139 Havard, François entrepreneur            1  50
# xpr0225    Poisson, Jean entrepreneur            1  47
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      1
#                             Départager      2
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      0
#
#
#
#
# Le Clerc, François ; architecte ; 8 expertises ; 0 expertises en tant que tiers-expert ; 4 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0218          Philipest, Jean entrepreneur            1  55
# xpr0035 Boulier de Bourges, Jean   architecte            1
# xpr0204        Pageois, François   architecte            1  68
# xpr0008            Aubry, Claude entrepreneur            1
# xpr0139         Havard, François entrepreneur            2  50
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      3
#            Estimer la valeur des biens      1
#                             Départager      1
#                            Enregistrer      1
# Recevoir et évaluer le travail réalisé      2
#
#
#
#
# Le Duc, Gabriel ; architecte ; 4 expertises ; 1 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id               name     column  totalCollab age
# xpr0086 Delespine, Nicolas architecte            1  54
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                             Départager      2
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      1
#
#
#
#
# Le Juge, Nicolas ; architecte ; 13 expertises ; 1 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                         name       column  totalCollab age
# xpr0178 Lepas Dubuisson, Jacques (I)    arpenteur            1
# xpr0218              Philipest, Jean entrepreneur            1  55
# xpr0035     Boulier de Bourges, Jean   architecte            1
# xpr0225                Poisson, Jean entrepreneur            1  47
# xpr0077   De Mezerets (Père), Michel   architecte            1  59
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      4
#            Estimer la valeur des biens      3
#                             Départager      0
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      3
#
#
#
#
# Le Maistre, Pierre ; architecte ; 3 expertises ; 2 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id               name     column  totalCollab age
# xpr0194  Mazieres, Jacques architecte            1
# xpr0086 Delespine, Nicolas architecte            1  54
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      1
#                             Départager      1
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      1
#
#
#
#
# Le Proust, Rolland ; architecte ; 26 expertises ; 1 expertises en tant que tiers-expert ; 11 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0086         Delespine, Nicolas   architecte            1  54
# xpr0058         Collibeuf, Laurent    arpenteur            1
# xpr0059             Convers, Louis   architecte            1  50
# xpr0194          Mazieres, Jacques   architecte            1
# xpr0085     Delespine, Louis Jules   architecte            1 -30
# xpr0218            Philipest, Jean entrepreneur            1  55
# xpr0211            Perrault, André entrepreneur            1  39
# xpr0077 De Mezerets (Père), Michel   architecte            2  59
# xpr0035   Boulier de Bourges, Jean   architecte            4
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      5
#            Estimer la valeur des biens      6
#                             Départager      8
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      4
#
#
#
#
# Le Roy, Estienne ; entrepreneur ; 11 expertises ; 1 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name     column  totalCollab age
# xpr0204          Pageois, François architecte            1  68
# xpr0194          Mazieres, Jacques architecte            1
# xpr0077 De Mezerets (Père), Michel architecte            3  59
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      3
#            Estimer la valeur des biens      1
#                             Départager      2
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      3
#
#
#
#
# Le Teilleur De Boncourt, Hélie (Elie) ; arpenteur ; 4 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id            name       column  totalCollab age
# xpr0197  Miche, Jacques entrepreneur            1  44
# xpr0211 Perrault, André entrepreneur            2  39
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      1
#                             Départager      2
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      1
#
#
#
#
# Lepas Dubuisson, Jacques (I) ; arpenteur ; 7 expertises ; 0 expertises en tant que tiers-expert ; 4 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id               name       column  totalCollab age
# xpr0086 Delespine, Nicolas   architecte            1  54
# xpr0166   Le Juge, Nicolas   architecte            1  50
#                                                    1
# xpr0225      Poisson, Jean entrepreneur            1  47
# xpr0021   Bertier, Nicolas entrepreneur            1  56
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      3
#            Estimer la valeur des biens      0
#                             Départager      2
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      2
#
#
#
#
# Marchand, Marc ; architecte ; 5 expertises ; 0 expertises en tant que tiers-expert ; 4 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id              name       column  totalCollab age
# xpr0011     Baillis, Jean   architecte            1
# xpr0141    Herbet, Michel   architecte            1  34
# xpr0204 Pageois, François   architecte            1  68
# xpr0194 Mazieres, Jacques   architecte            1
# xpr0153   Lajoue, Jacques entrepreneur            1
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      2
#            Estimer la valeur des biens      1
#                             Départager      1
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      1
#
#
#
#
# Marteau, Jean Baptiste ; architecte ; 12 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id               name       column  totalCollab age
# xpr0086 Delespine, Nicolas   architecte            1  54
# xpr0021   Bertier, Nicolas entrepreneur            1  56
# xpr0220     Pipault, Simon entrepreneur            1
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      2
#            Estimer la valeur des biens      1
#                             Départager      3
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      5
#
#
#
#
# Masson, Noël ; entrepreneur ; 3 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id               name    column  totalCollab age
# xpr0063 Cudeville, Jacques arpenteur            1
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      1
#            Estimer la valeur des biens      0
#                             Départager      1
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      0
#
#
#
#
# Masson, Etienne ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                      name       column  totalCollab age
# xpr0087 Delespine, Pierre Nicolas entrepreneur            1  34
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                             Départager      0
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      1
#
#
#
#
# Mazieres, Jacques ; architecte ; 24 expertises ; 5 expertises en tant que tiers-expert ; 13 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0167         Le Maistre, Pierre   architecte            1  53
# xpr0152            Laisney, Gilles entrepreneur            1
# xpr0035   Boulier de Bourges, Jean   architecte            1
# xpr0168         Le Proust, Rolland   architecte            1  59
# xpr0153            Lajoue, Jacques entrepreneur            1
# xpr0189             Marchand, Marc   architecte            1
# xpr0170           Le Roy, Estienne entrepreneur            1  48
# xpr0100               Dubois, Jean   architecte            1  48
# xpr0124       Gobin, Jean François   architecte            1  39
# xpr0220             Pipault, Simon entrepreneur            1
# xpr0021           Bertier, Nicolas entrepreneur            2  56
# xpr0087  Delespine, Pierre Nicolas entrepreneur            2  34
# xpr0077 De Mezerets (Père), Michel   architecte            3  59
# xpr0086         Delespine, Nicolas   architecte            4  54
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      6
#            Estimer la valeur des biens      4
#                             Départager      2
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      8
#
#
#
#
# Menessier, Bernard ; entrepreneur ; 7 expertises ; 0 expertises en tant que tiers-expert ; 6 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id              name       column  totalCollab age
# xpr0094      Dorbay, Jean entrepreneur            1  60
# xpr0146  Joubert, Charles entrepreneur            1  56
# xpr0204 Pageois, François   architecte            1  68
# xpr0152   Laisney, Gilles entrepreneur            1
# xpr0008     Aubry, Claude entrepreneur            3
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      1
#            Estimer la valeur des biens      1
#                             Départager      2
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      1
#
#
#
#
# Miche, Jacques ; entrepreneur ; 6 expertises ; 0 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                  name       column  totalCollab age
# xpr0172 Le Teilleur De Boncourt, Hélie (Elie)    arpenteur            1
# xpr0086                    Delespine, Nicolas   architecte            1  54
# xpr0244                         Serouge, Jean entrepreneur            1
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      2
#                             Départager      2
#                            Enregistrer      1
# Recevoir et évaluer le travail réalisé      0
#
#
#
#
# Pageois, François ; architecte ; 41 expertises ; 0 expertises en tant que tiers-expert ; 21 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                     name       column  totalCollab age
# xpr0124     Gobin, Jean François   architecte            1  39
# xpr0161       Le Clerc, François   architecte            1
# xpr0099        Doussot, François   architecte            1
# xpr0170         Le Roy, Estienne entrepreneur            1  48
# xpr0195       Menessier, Bernard entrepreneur            1
# xpr0153          Lajoue, Jacques entrepreneur            1
# xpr0244            Serouge, Jean entrepreneur            1
# xpr0021         Bertier, Nicolas entrepreneur            1  56
# xpr0058       Collibeuf, Laurent    arpenteur            1
# xpr0125             Gobin, Denis   architecte            1  33
# xpr0189           Marchand, Marc   architecte            1
# xpr0218          Philipest, Jean entrepreneur            2  55
# xpr0035 Boulier de Bourges, Jean   architecte            2
# xpr0146         Joubert, Charles entrepreneur            2  56
# xpr0086       Delespine, Nicolas   architecte            2  54
# xpr0008            Aubry, Claude entrepreneur            3
# xpr0152          Laisney, Gilles entrepreneur            4
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      7
#            Estimer la valeur des biens      6
#                             Départager     12
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      9
#
#
#
#
# Perrault, André ; entrepreneur ; 12 expertises ; 0 expertises en tant que tiers-expert ; 7 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                                  name       column  totalCollab age
# xpr0218                       Philipest, Jean entrepreneur            1  55
# xpr0153                       Lajoue, Jacques entrepreneur            1
# xpr0008                         Aubry, Claude entrepreneur            1
# xpr0168                    Le Proust, Rolland   architecte            1  59
# xpr0105                        Duval, Charles    arpenteur            1
# xpr0094                          Dorbay, Jean entrepreneur            1  60
# xpr0172 Le Teilleur De Boncourt, Hélie (Elie)    arpenteur            2
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      2
#            Estimer la valeur des biens      2
#                             Départager      2
#                            Enregistrer      1
# Recevoir et évaluer le travail réalisé      3
#
#
#
#
# Person, Charles ; architecte ; 6 expertises ; 1 expertises en tant que tiers-expert ; 3 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                    name       column  totalCollab age
# xpr0008           Aubry, Claude entrepreneur            1
# xpr0048          Caulle, Martin entrepreneur            1  35
# xpr0126 Goujon, Louis Alexandre   architecte            1  36
# xpr0244           Serouge, Jean entrepreneur            1
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      1
#            Estimer la valeur des biens      1
#                             Départager      0
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      4
#
#
#
#
# Petit, Antoine ; arpenteur ; 1 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      0
#                             Départager      0
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      1
#
#
#
#
# Philipest, Jean ; entrepreneur ; 36 expertises ; 1 expertises en tant que tiers-expert ; 13 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0211            Perrault, André entrepreneur            1  39
# xpr0077 De Mezerets (Père), Michel   architecte            1  59
# xpr0035   Boulier de Bourges, Jean   architecte            1
# xpr0161         Le Clerc, François   architecte            1
# xpr0138            Hallot, Etienne    arpenteur            1
# xpr0166           Le Juge, Nicolas   architecte            1  50
# xpr0008              Aubry, Claude entrepreneur            1
# xpr0168         Le Proust, Rolland   architecte            1  59
# xpr0105             Duval, Charles    arpenteur            1
# xpr0086         Delespine, Nicolas   architecte            1  54
# xpr0140             Hequan, Pierre entrepreneur            1  58
# xpr0204          Pageois, François   architecte            2  68
# xpr0146           Joubert, Charles entrepreneur            2  56
# xpr0139           Havard, François entrepreneur            2  50
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir     14
#            Estimer la valeur des biens      8
#                             Départager      7
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      5
#
#
#
#
# Pipault, Simon ; entrepreneur ; 10 expertises ; 0 expertises en tant que tiers-expert ; 6 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0244              Serouge, Jean entrepreneur            1
# xpr0146           Joubert, Charles entrepreneur            1  56
# xpr0190     Marteau, Jean Baptiste   architecte            1  42
# xpr0194          Mazieres, Jacques   architecte            1
# xpr0077 De Mezerets (Père), Michel   architecte            2  59
# xpr0086         Delespine, Nicolas   architecte            2  54
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      2
#            Estimer la valeur des biens      1
#                             Départager      1
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      4
#
#
#
#
# Pirethouy, Jacques ; architecte ; 4 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      1
#            Estimer la valeur des biens      2
#                             Départager      0
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      0
#
#
#
#
# Poisson, Jean ; entrepreneur ; 8 expertises ; 0 expertises en tant que tiers-expert ; 5 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                         name     column  totalCollab age
# xpr0011                Baillis, Jean architecte            1
# xpr0077   De Mezerets (Père), Michel architecte            1  59
# xpr0178 Lepas Dubuisson, Jacques (I)  arpenteur            1
#                                                            1
# xpr0166             Le Juge, Nicolas architecte            1  50
# xpr0157          Le Boutteux, Michel architecte            1  74
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      1
#            Estimer la valeur des biens      2
#                             Départager      2
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      2
#
#
#
#
# Rohais, Toussaint ; arpenteur ; 10 expertises ; 0 expertises en tant que tiers-expert ; 6 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name       column  totalCollab age
# xpr0021           Bertier, Nicolas entrepreneur            1  56
#                                                            1
# xpr0077 De Mezerets (Père), Michel   architecte            1  59
# xpr0124       Gobin, Jean François   architecte            1  39
# xpr0116           Gabriel, Jacques entrepreneur            1
# xpr0035   Boulier de Bourges, Jean   architecte            1
# xpr0063         Cudeville, Jacques    arpenteur            1
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      2
#            Estimer la valeur des biens      4
#                             Départager      3
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      1
#
#
#
#
# Serouge, Jean ; entrepreneur ; 13 expertises ; 0 expertises en tant que tiers-expert ; 8 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id              name       column  totalCollab age
# xpr0220    Pipault, Simon entrepreneur            1
# xpr0116  Gabriel, Jacques entrepreneur            1
# xpr0152   Laisney, Gilles entrepreneur            1
# xpr0197    Miche, Jacques entrepreneur            1  44
# xpr0204 Pageois, François   architecte            1  68
# xpr0021  Bertier, Nicolas entrepreneur            1  56
# xpr0153   Lajoue, Jacques entrepreneur            1
# xpr0146  Joubert, Charles entrepreneur            1  56
# xpr0213   Person, Charles   architecte            1  43
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      3
#            Estimer la valeur des biens      3
#                             Départager      4
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      3
#
#
#
#
# Jomard François ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 0 expertises avec d'autres experts (tiers expertises comprises)
#
#
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      0
#            Estimer la valeur des biens      1
#                             Départager      0
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      0
#
#
#
#
# Le Berton, François (? - ?) ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 expertises avec d'autres experts (tiers expertises comprises)
#
#
#      id                       name     column  totalCollab age
# xpr0077 De Mezerets (Père), Michel architecte            1  59
#
#
#                                  label  total
# Décrire et évaluer les travaux à venir      1
#            Estimer la valeur des biens      0
#                             Départager      0
#                            Enregistrer      0
# Recevoir et évaluer le travail réalisé      0
