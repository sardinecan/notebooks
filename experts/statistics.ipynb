# %% [markdown]
# # xprStats

# %%
# lib
from urllib.request import urlopen
import json  
import pandas as pd

# %%
# Récupération des donnée 
# param (date or thirdParty)
param = "1786"

# url
url = "https://experts.huma-num.fr/xpr/statistics/" + param

# enregistrement de la réponse
response = urlopen(url)

# lecture du json
data = json.loads(response.read())
  
# print the json response
#print(data)

# %% [markdown]
# ## Expertises

# %%
expertises = data['expertises']

# %%
print("Nombre total d'expertises : " + str(expertises['total']))
# Out:
# Nombre total d'expertises : 753

# %% [markdown]
# ### Croquis

# %%
sketchesDF = pd.json_normalize(expertises['sketches'])
print(sketchesDF.to_string(index=False))
# Out:
#  expertisesWithoutSketch  expertisesWithSketch
#                      748                     5

# %% [markdown]
# ### Étendue

# %%
extent = expertises['extent']
#print(extent)

print('Nombre de feuillets : ' + str(extent['total']))

print('Moyenne par expertise : ' + str(extent['averageByExpertise']))

#Distribution
print('Distribution :')
keys = []
values = []
for dic in extent['extentDistribution']:
    for key, val in dic.items():
        keys.append(key),
        values.append(val)        

extentDistributionDict = {'nombre de feuillets': keys, 'nombre d’expertises': values,} 
print(pd.DataFrame(extentDistributionDict).to_string(index=False))
# Out:
# Nombre de feuillets : 7011
# Moyenne par expertise : 9.31
# Distribution :
# nombre de feuillets  nombre d’expertises
#                   5                  336
#                  10                  253
#                  15                   63
#                  20                   28
#                  25                   21
#                  30                   14
#                  35                    6
#                  40                    5
#                  45                    2
#                  50                    5
#                  55                    1
#                  60                    0
#                  65                    1
#                  70                    1
#                  75                    0
#                  80                    1
#                  85                    1
#                  90                    0
#                  95                    0
#                 100                    6

# %% [markdown]
# ### Annexes

# %%
appendices = expertises['appendices']
#print(appendices)

print(f"{appendices['total']} annexes")


print(f"{appendices['expertisesWithAppendices']} expertises avec annexes ; {appendices['expertisesWithoutAppendices']} expertises sans annexes")


df=pd.json_normalize(appendices['types'])
print(df.to_string(columns=['label', 'total', 'expertises'], index=False))
# Out:
# 648 annexes
# 332 expertises avec annexes ; 421 expertises sans annexes
#                                       label  total  expertises
#                                   Brouillon     52          47
#                                     Requête    113         105
#                                       Autre    200         126
#                      Plan, coupe, élévation    196          88
# Pouvoir/procuration (acte sous seing privé)     49          42
#          Pouvoir/procuration (acte notarié)     23          16
#                                     Croquis     13           6

# %% [markdown]
# ### Vacations

# %%
sessions = expertises['sessions']
#print(sessions)

print(f"{sessions['total']} vacations")


print(f"en moyenne {sessions['averageByExpertise']} vacations par expertise")
# Out:
# 4061 vacations
# en moyenne 5.39 vacations par expertise

# %% [markdown]
# Nombre de vacation par lieu

# %%
sessionsDf=pd.json_normalize(sessions['places'])
print(sessionsDf.to_string(columns=['label', 'total'], index=False))
# Out:
#    label  total
#    Paris   3392
# Banlieue    243
# Province    423

# %% [markdown]
# ### Durée

# %%
duration = expertises['duration']
#print(duration)

# %% [markdown]
# #### Jours

# %%
#Distribution
durationDays = duration['days']
#print(durationDays)
print('Distribution :')
keys = []
values = []
for dic in durationDays['distributionByDays']:
    for key, val in dic.items():
        keys.append(key),
        values.append(val)        

durationDaysDf = {'nombre de jours': keys, 'nombre d’expertises': values,} 
print(pd.DataFrame(durationDaysDf).to_string(index=False))
# Out:
# Distribution :
# nombre de jours  nombre d’expertises
#               5                  276
#              10                   61
#              15                   44
#              20                   41
#              25                   24
#              30                   32
#              35                   14
#              40                   30
#              45                   16
#              50                   16
#              55                   10
#              60                    6
#              65                   12
#              70                    7
#              75                    6
#              80                    6
#              85                    7
#              90                    3
#              95                    3
#             100                  135

# %% [markdown]
# #### Vacations

# %%
#Distribution
durationSessions = duration['sessions']
#print(durationDays)
print(f"{durationSessions['total']} vacations, soit en moyenne {durationSessions['averageByExpertise']} vacations par expertise.")
# Out:
# 4061 vacations, soit en moyenne 2.7 vacations par expertise.

# %% [markdown]
# ### Lieux

# %%
places = expertises['places']
#print(places)

placesDf=pd.json_normalize(places)
print(placesDf.to_string(columns=['place', 'total'], index=False))
# Out:
#                        place  total
#                      [paris]    505
#                    [suburbs]     61
#                   [province]     68
#           [[paris, suburbs]]     28
#          [[paris, province]]     84
#        [[suburbs, province]]      2
# [[paris, suburbs, province]]      2

# %% [markdown]
# ### Procédures et cadres

# %%
frameworks = expertises['frameworks']
#print(frameworks)

frameworksDf=pd.json_normalize(frameworks)
print(frameworksDf.to_string(columns=['label', 'framework', 'total'], index=False))
# Out:
#                                                                                                                   label framework  total
# L’institution est saisie dans le cadre d’une procédure (les parties nomment chacune leur expert ou un expert en commun)        b2    445
#                         L’institution est saisie dans le cadre d’une procédure (l’institution nomme un ou deux experts)       b2b     83
# L’institution est saisie dans le cadre d’une procédure (les parties nomment chacune leur expert ou un expert en commun)       b2a     55
#                                          Saisie mixte (un expert est nommé par les parties, l'autre est nommé d'office)        b3     13
#                                                                                               Commun accord des parties         a     30
#                                                                                                       Cas problématique         c      7
#                                                     Requête auprès d’une institution pour qu’elle demande une expertise        b1    118
#                                                                                                                                        2

# %% [markdown]
# ### Catégories

# %%
categories = expertises['categories']

for cat in categories:
    if cat['total'] != 0: print(f"{cat['label']} : {cat['total']} experties"),
    for framework in cat['frameworks']:
        if framework['total'] != 0: print(f"\t{framework['framework']} : {framework['total']} expertises"),
        for place in framework['places']:
            if place['total'] != 0: print(f"\t\t{place['place']} : {place['total']}"),
            for obj in place['objects']:
                if obj['total'] != 0: print(f"\t\t\t{obj['label']} : {obj['total']}")
# Out:
# Recevoir et évaluer le travail réalisé : 203 experties
# 	b2 : 126 expertises
# 		['paris'] : 88
# 			Ouvrages de maçonnerie : 85
# 			Mur(s) : 1
# 			Fosse(s) d'aisance : 1
# 		['suburbs'] : 11
# 			Ouvrages de maçonnerie : 11
# 		['province'] : 4
# 			Ouvrages de maçonnerie : 4
# 		[['paris', 'suburbs']] : 6
# 			Ouvrages de maçonnerie : 6
# 		[['paris', 'province']] : 17
# 			Ouvrages de maçonnerie : 17
# 	b2b : 13 expertises
# 		['paris'] : 10
# 			Ouvrages de maçonnerie : 8
# 			Maison(s) : 3
# 		['suburbs'] : 2
# 			Ouvrages de maçonnerie : 2
# 		['province'] : 1
# 			Maison(s) : 1
# 	b2a : 30 expertises
# 		['paris'] : 22
# 			Ouvrages de maçonnerie : 21
# 			Maison(s) : 1
# 		['suburbs'] : 2
# 			Ouvrages de maçonnerie : 2
# 		['province'] : 2
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 		[['paris', 'province']] : 2
# 			Ensemble de bâtiments (biens immeubles) : 2
# 	b3 : 4 expertises
# 		['paris'] : 4
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
# 	a : 7 expertises
# 		['paris'] : 3
# 			Ouvrages de maçonnerie : 3
# 		['province'] : 2
# 			Ouvrages de maçonnerie : 2
# 		[['paris', 'suburbs']] : 2
# 			Ouvrages de maçonnerie : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
# 	c : 4 expertises
# 		['paris'] : 4
# 			Ouvrages de maçonnerie : 4
# 	b1 : 19 expertises
# 		['paris'] : 14
# 			Ouvrages de maçonnerie : 14
# 		[['paris', 'suburbs']] : 3
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 1
# 		[['paris', 'province']] : 2
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# Estimer la valeur des biens : 276 experties
# 	b2 : 156 expertises
# 		['paris'] : 104
# 			Ouvrages de maçonnerie : 18
# 			Maison(s) : 85
# 			Terrain(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
# 			Domaine, terres, fief : 1
# 			Fosse(s) d'aisance : 1
# 		['suburbs'] : 8
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 7
# 			Terrain(s) : 2
# 		['province'] : 22
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 19
# 			Terrain(s) : 8
# 			Ensemble de bâtiments (biens immeubles) : 1
# 			Domaine, terres, fief : 1
# 		[['paris', 'suburbs']] : 2
# 			Maison(s) : 2
# 		[['paris', 'province']] : 17
# 			Ouvrages de maçonnerie : 3
# 			Maison(s) : 12
# 			Terrain(s) : 6
# 			Domaine, terres, fief : 4
# 		[['suburbs', 'province']] : 2
# 			Maison(s) : 2
# 			Terrain(s) : 2
# 		[['paris', 'suburbs', 'province']] : 1
# 			Maison(s) : 1
# 	b2b : 45 expertises
# 		['paris'] : 25
# 			Ouvrages de maçonnerie : 3
# 			Maison(s) : 20
# 			Terrain(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		['suburbs'] : 4
# 			Maison(s) : 2
# 			Terrain(s) : 2
# 			Domaine, terres, fief : 1
# 		['province'] : 7
# 			Maison(s) : 7
# 			Terrain(s) : 4
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		[['paris', 'suburbs']] : 3
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 2
# 			Terrain(s) : 2
# 		[['paris', 'province']] : 6
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 			Terrain(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 4
# 			Domaine, terres, fief : 4
# 	b2a : 13 expertises
# 		['paris'] : 6
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 4
# 		['suburbs'] : 1
# 			Ouvrages de maçonnerie : 1
# 		['province'] : 3
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 2
# 			Ensemble de bâtiments (biens immeubles) : 2
# 		[['paris', 'province']] : 3
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 2
# 			Ensemble de bâtiments (biens immeubles) : 1
# 			Domaine, terres, fief : 2
# 	b3 : 5 expertises
# 		['suburbs'] : 1
# 			Terrain(s) : 1
# 		['province'] : 3
# 			Maison(s) : 3
# 			Terrain(s) : 3
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		[['paris', 'province']] : 1
# 			Ouvrages de maçonnerie : 1
# 			Domaine, terres, fief : 1
# 	a : 7 expertises
# 		['paris'] : 4
# 			Maison(s) : 3
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		['suburbs'] : 1
# 			Terrain(s) : 1
# 		[['paris', 'province']] : 2
# 			Ouvrages de maçonnerie : 1
# 			Terrain(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
# 	c : 2 expertises
# 		['paris'] : 2
# 			Maison(s) : 2
# 	b1 : 47 expertises
# 		['paris'] : 29
# 			Maison(s) : 26
# 			Terrain(s) : 3
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		['suburbs'] : 7
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 5
# 			Terrain(s) : 3
# 		['province'] : 2
# 			Maison(s) : 1
# 			Terrain(s) : 1
# 		[['paris', 'suburbs']] : 1
# 			Maison(s) : 1
# 			Terrain(s) : 1
# 		[['paris', 'province']] : 8
# 			Maison(s) : 4
# 			Terrain(s) : 3
# 			Ensemble de bâtiments (biens immeubles) : 1
# 			Domaine, terres, fief : 5
# 	 : 1 expertises
# 		['paris'] : 1
# 			Maison(s) : 1
# Décrire et évaluer les travaux à venir : 132 experties
# 	b2 : 84 expertises
# 		['paris'] : 48
# 			Ouvrages de maçonnerie : 46
# 			Maison(s) : 2
# 			Fosse(s) d'aisance : 2
# 			Puits : 1
# 		['suburbs'] : 6
# 			Ouvrages de maçonnerie : 5
# 			Maison(s) : 1
# 			Terrain(s) : 1
# 			Mur(s) : 1
# 		['province'] : 14
# 			Ouvrages de maçonnerie : 12
# 			Terrain(s) : 1
# 		[['paris', 'suburbs']] : 4
# 			Ouvrages de maçonnerie : 4
# 			Terrain(s) : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		[['paris', 'province']] : 12
# 			Ouvrages de maçonnerie : 12
# 			Maison(s) : 3
# 	b2b : 15 expertises
# 		['paris'] : 11
# 			Ouvrages de maçonnerie : 3
# 			Maison(s) : 6
# 			Terrain(s) : 4
# 		['suburbs'] : 1
# 			Maison(s) : 1
# 		['province'] : 1
# 			Maison(s) : 1
# 		[['paris', 'province']] : 2
# 			Maison(s) : 2
# 	b2a : 4 expertises
# 		['paris'] : 3
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 2
# 			Mur(s) : 1
# 		['province'] : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
# 	b3 : 3 expertises
# 		['paris'] : 3
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 2
# 	a : 5 expertises
# 		['paris'] : 4
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 2
# 		[['paris', 'suburbs']] : 1
# 			Maison(s) : 1
# 	c : 1 expertises
# 		['paris'] : 1
# 			Ouvrages de maçonnerie : 1
# 	b1 : 19 expertises
# 		['paris'] : 14
# 			Ouvrages de maçonnerie : 9
# 			Maison(s) : 5
# 			Fosse(s) d'aisance : 1
# 		['suburbs'] : 2
# 			Ouvrages de maçonnerie : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		['province'] : 2
# 			Ouvrages de maçonnerie : 1
# 			Ensemble de bâtiments (biens immeubles) : 1
# 		[['paris', 'province']] : 1
# 			Ouvrages de maçonnerie : 1
# 	 : 1 expertises
# 		['paris'] : 1
# Départager : 85 experties
# 	b2 : 62 expertises
# 		['paris'] : 45
# 			Ouvrages de maçonnerie : 26
# 			Maison(s) : 3
# 			Terrain(s) : 1
# 			Mur(s) : 14
# 			Fosse(s) d'aisance : 4
# 		['suburbs'] : 7
# 			Ouvrages de maçonnerie : 2
# 			Maison(s) : 1
# 			Terrain(s) : 3
# 			Mur(s) : 1
# 			Fosse(s) d'aisance : 1
# 			Puits : 1
# 		['province'] : 2
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 		[['paris', 'suburbs']] : 2
# 			Ouvrages de maçonnerie : 1
# 			Mur(s) : 1
# 		[['paris', 'province']] : 6
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 			Terrain(s) : 2
# 			Mur(s) : 4
# 			Domaine, terres, fief : 1
# 	b2b : 7 expertises
# 		['paris'] : 5
# 			Ouvrages de maçonnerie : 4
# 			Maison(s) : 2
# 		['suburbs'] : 1
# 			Ouvrages de maçonnerie : 1
# 		[['paris', 'province']] : 1
# 			Mur(s) : 1
# 	b2a : 7 expertises
# 		['paris'] : 5
# 			Ouvrages de maçonnerie : 2
# 			Mur(s) : 3
# 			Ensemble de bâtiments (biens immeubles) : 1
# 			Fosse(s) d'aisance : 1
# 		['suburbs'] : 1
# 			Ouvrages de maçonnerie : 1
# 			Terrain(s) : 1
# 		[['paris', 'province']] : 1
# 			Mur(s) : 1
# 	b3 : 1 expertises
# 		['paris'] : 1
# 			Maison(s) : 1
# 	a : 8 expertises
# 		['paris'] : 8
# 			Ouvrages de maçonnerie : 3
# 			Mur(s) : 6
# Enregistrer : 40 experties
# 	b2 : 4 expertises
# 		['paris'] : 4
# 			Ouvrages de maçonnerie : 3
# 			Maison(s) : 1
# 	b2b : 3 expertises
# 		['paris'] : 1
# 			Maison(s) : 1
# 			Terrain(s) : 1
# 		['suburbs'] : 2
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 			Terrain(s) : 1
# 	a : 2 expertises
# 		['paris'] : 2
# 			Mur(s) : 2
# 	b1 : 31 expertises
# 		['paris'] : 24
# 			Ouvrages de maçonnerie : 24
# 			Maison(s) : 4
# 			Terrain(s) : 14
# 		['suburbs'] : 3
# 			Ouvrages de maçonnerie : 3
# 			Maison(s) : 1
# 			Terrain(s) : 2
# 		['province'] : 1
# 			Ouvrages de maçonnerie : 1
# 			Maison(s) : 1
# 			Terrain(s) : 1
# 		[['paris', 'suburbs']] : 1
# 			Maison(s) : 1
# 		[['paris', 'province']] : 1
# 			Ouvrages de maçonnerie : 1

# %% [markdown]
# ### Tiers expertises

# %%
thirdParty = expertises['thirdParty']

# %%
thirdPartyDf=pd.json_normalize(thirdParty)
print(thirdPartyDf.to_string(columns=['architectes', 'entrepreneurs', 'total'], index=False))
# Out:
#  architectes  entrepreneurs  total
#            7              4     11

# %% [markdown]
# ## Experts

# %%
experts = data['experts']
#print(experts)

# %%
print(f"Nombre d’experts : {experts['total']}")
print(f"{experts['architects']} architectes")
print(f"{experts['entrepreneur']} entrepreneurs")
print(f"{experts['surveyor']} arpenteurs")
# Out:
# Nombre d’experts : 70
# 43 architectes
# 27 entrepreneurs
# 0 arpenteurs

# %%
listExperts = experts['list']
listExpertsDf = pd.DataFrame(listExperts)
listExpertsDf.drop('expertises', inplace=True, axis=1)

# %%
print(listExpertsDf.to_string(columns=['id', 'name', 'column', 'age'], index=False))
# Out:
#      id                                                                     name       column age
# xpr0002                                                     André, Jean Baptiste   architecte  51
# xpr0003                                                       Angot, Jean Pierre entrepreneur  47
# xpr0004                                                         Antoine, Antoine   architecte  40
# xpr0005                                                   Antoine, Jacques Denis   architecte  53
# xpr0007                                                            Aubert, André entrepreneur  41
# xpr0016                                    Bellanger, Guillaume François Gabriel entrepreneur
# xpr0024                                                      Blanchard, Jean-Luc   architecte
# xpr0026                                                        Bleve, Jean Louis   architecte  59
# xpr0031                                                     Bouchu, Paul Antoine   architecte  46
# xpr0033                                          Boullant, Jean Baptiste Vincent   architecte  47
# xpr0038                                                 Bourgeois, Louis Silvain entrepreneur  50
# xpr0042                                                          Buron, François entrepreneur  55
# xpr0043                                            Le Camus de Mézières, Nicolas   architecte  61
# xpr0044                                                   Capron, Charles Martin entrepreneur  56
# xpr0049                                               Chabouille, Médéric Joseph entrepreneur  44
# xpr0050                                                  Chasteau, Jean François entrepreneur  52
# xpr0055                                                   Clavareau, Jean Pierre   architecte  65
# xpr0064                                             D'herbelot, Francois-Charles   architecte
# xpr0065                                                 Danjan, Pierre Alexandre   architecte  64
# xpr0068                                          Dauvergne, Nicolas Rémy Gabriel   architecte  38
# xpr0079                                              De Varenne, Claude Estienne   architecte  80
# xpr0081                                              De Villers, Eustache Robert   architecte  66
# xpr0082                                                        De Vonges, Michel   architecte  72
# xpr0085                                                   Delespine, Louis Jules   architecte  60
# xpr0090 Desjardins, Jean Baptiste Guillaume Alexandre Georges Balthazard Auguste   architecte  32
# xpr0091                                                       Desmaisons, Pierre   architecte  75
# xpr0092                                             Desmaisons, Jacques François   architecte  71
# xpr0095                                                  Dosmond, Léonard Pierre   architecte  35
# xpr0101                                               Duboiscerf, Sébastien Jean entrepreneur  73
# xpr0102                                                          Ducret, Nicolas   architecte  59
# xpr0104                                                     Dumont, Jean Charles entrepreneur  58
# xpr0106                                                      Egresset, Guillaume entrepreneur  75
# xpr0114                                               Gabriel, Nicolas Toussaint   architecte  47
# xpr0122                                                     Giraud, Pierre Marie   architecte  52
# xpr0127                                                          Goulet, Nicolas entrepreneur  41
# xpr0129                                                         Goupy Ii, Martin   architecte  52
# xpr0137                                                  Hallet, Etienne-Sulpice   architecte
# xpr0143                                                     Jacob, Jean François entrepreneur  51
# xpr0144                                                          Jacob, François   architecte
# xpr0155                                                 Lardant, Pierre François entrepreneur  55
# xpr0159                                                Le brun, Charles François   architecte  78
# xpr0163                                                Le Foulon, Guillaume Elie entrepreneur  59
# xpr0169                                                            Le Roux, Jean   architecte
# xpr0176                                                             Lemit, Louis   architecte  41
# xpr0187                                                     Mangin, Jean Charles   architecte  37
# xpr0199                                                 Mouchelet, Georges Louis   architecte
# xpr0200                                                           Mouchet, André entrepreneur
# xpr0201                                                            Neveu, Michel entrepreneur  53
# xpr0203                                                         Normand, Nicolas   architecte  43
# xpr0205                                          Parvy De La Renaudiere, Nicolas entrepreneur  52
# xpr0215                                                            Petit, Pierre entrepreneur  42
# xpr0216                                              Petit Radel, Louis François   architecte  46
# xpr0226                                                   Porquet, Claude Joseph   architecte  64
# xpr0228                                           Poulain, Jean Baptiste Martial   architecte  51
# xpr0229                                         Pruneau De Montlouis, Jean Louis   architecte  63
# xpr0235                               Regnard De Barentin, Bernard Jean Baptiste entrepreneur  47
# xpr0238                                                    Roche, Honoré Jacques   architecte  44
# xpr0245                                                             Siguy, Louis entrepreneur  48
# xpr0247                                                      Simon, René Auguste entrepreneur  74
# xpr0249                                                 Soisson, Charles Nicolas entrepreneur
# xpr0250                                                        Taboureur, Pierre   architecte  50
# xpr0252                                                    Terrier, Martin Marie   architecte  58
# xpr0254                                                   Thevenin, Jacques-Jean entrepreneur
# xpr0256                                                    Varin, Bénigne Joseph entrepreneur  28
# xpr0258                                    Vavasseur Desperriers, Louis Athanase entrepreneur  44
# xpr0260                                                  Villetard, Jean Etienne   architecte
# xpr0261                                                       Villetard, Etienne entrepreneur  60
# xpr0273                                                 Lefort, François (? - ?)   architecte
# xpr0274                                                   Lomet, Quentin (? - ?)   architecte
# xpr0277                                                Jamain, Sébastien (? - ?)   architecte   0

# %%
for expert in listExperts:
    print(f"
          {expert['name']} ; 
          {expert['column']} ;
          {expert['expertises']['total']} expertises ;
          {expert['expertises']['thirParty']} expertises en tant que tiers-expert ;
          {expert['expertises']['collab']['total']} collaborations
    "),
    
          collabDF = pd.json_normalize(expert['expertises']['collab']['experts']) 
    print(collabDF)
# Out:
# André, Jean Baptiste ; architecte ; 2 expertises ; 0 expertises en tant que tiers-expert ; 2 collaborations
#                       name  totalCollab        column       id age
# 0          Ducret, Nicolas            1    architecte  xpr0102  59
# 1  Dosmond, Léonard Pierre            1    architecte  xpr0095  35
# 2       Villetard, Etienne            1  entrepreneur  xpr0261  60
# Angot, Jean Pierre ; entrepreneur ; 7 expertises ; 0 expertises en tant que tiers-expert ; 5 collaborations
#                           name  totalCollab        column       id age
# 0            Taboureur, Pierre            2    architecte  xpr0250  50
# 1         Mangin, Jean Charles            1    architecte  xpr0187  37
# 2  Petit Radel, Louis François            1    architecte  xpr0216  46
# 3                Petit, Pierre            1  entrepreneur  xpr0215  42
# Antoine, Antoine ; architecte ; 7 expertises ; 0 expertises en tant que tiers-expert ; 5 collaborations
#                               name  totalCollab        column       id age
# 0                Taboureur, Pierre            1    architecte  xpr0250  50
# 1             Dumont, Jean Charles            1  entrepreneur  xpr0104  58
# 2                  Ducret, Nicolas            1    architecte  xpr0102  59
# 3  Boullant, Jean Baptiste Vincent            1    architecte  xpr0033  47
# 4         Mouchelet, Georges Louis            1    architecte  xpr0199
# Antoine, Jacques Denis ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 collaborations
# Empty DataFrame
# Columns: []
# Index: []
# Aubert, André ; entrepreneur ; 5 expertises ; 0 expertises en tant que tiers-expert ; 3 collaborations
#                 name  totalCollab      column       id age
# 0  Taboureur, Pierre            2  architecte  xpr0250  50
# 1   Normand, Nicolas            1  architecte  xpr0203  43
# Bellanger, Guillaume François Gabriel ; entrepreneur ; 5 expertises ; 0 expertises en tant que tiers-expert ; 4 collaborations
#                              name  totalCollab        column       id age
# 0                   Petit, Pierre            1  entrepreneur  xpr0215  42
# 1      Chabouille, Médéric Joseph            1  entrepreneur  xpr0049  44
# 2  Poulain, Jean Baptiste Martial            1    architecte  xpr0228  51
# 3         Villetard, Jean Etienne            1    architecte  xpr0260
# Blanchard, Jean-Luc ; architecte ; 6 expertises ; 0 expertises en tant que tiers-expert ; 5 collaborations
#                                          name  totalCollab        column  \
# 0                               Petit, Pierre            2  entrepreneur
# 1                             Goulet, Nicolas            1  entrepreneur
# 2                  Chabouille, Médéric Joseph            1  entrepreneur
# 3  Regnard De Barentin, Bernard Jean Baptiste            1  entrepreneur
#
#         id age
# 0  xpr0215  42
# 1  xpr0127  41
# 2  xpr0049  44
# 3  xpr0235  47
# Bleve, Jean Louis ; architecte ; 20 expertises ; 0 expertises en tant que tiers-expert ; 14 collaborations
#                                                  name  totalCollab  \
# 0                                Mangin, Jean Charles            2
# 1                                       Petit, Pierre            2
# 2                                  Villetard, Etienne            2
# 3                                     Ducret, Nicolas            1
# 4                                   Taboureur, Pierre            2
# 5                                Bouchu, Paul Antoine            2
# 6   Desjardins, Jean Baptiste Guillaume Alexandre ...            1
# 7                             Chasteau, Jean François            1
# 8                             Dosmond, Léonard Pierre            1
# 9                                Dumont, Jean Charles            1
# 10                         Duboiscerf, Sébastien Jean            1
# 11                     Poulain, Jean Baptiste Martial            1
#
#           column       id age
# 0     architecte  xpr0187  37
# 1   entrepreneur  xpr0215  42
# 2   entrepreneur  xpr0261  60
# 3     architecte  xpr0102  59
# 4     architecte  xpr0250  50
# 5     architecte  xpr0031  46
# 6     architecte  xpr0090  32
# 7   entrepreneur  xpr0050  52
# 8     architecte  xpr0095  35
# 9   entrepreneur  xpr0104  58
# 10  entrepreneur  xpr0101  73
# 11    architecte  xpr0228  51
# Bouchu, Paul Antoine ; architecte ; 15 expertises ; 0 expertises en tant que tiers-expert ; 10 collaborations
#                          name  totalCollab        column       id age
# 0        Jacob, Jean François            1  entrepreneur  xpr0143  51
# 1  Duboiscerf, Sébastien Jean            1  entrepreneur  xpr0101  73
# 2            Normand, Nicolas            1    architecte  xpr0203  43
# 3           Bleve, Jean Louis            2    architecte  xpr0026  59
# 4        Mangin, Jean Charles            1    architecte  xpr0187  37
# 5    Danjan, Pierre Alexandre            1    architecte  xpr0065  64
# 6        Dumont, Jean Charles            1  entrepreneur  xpr0104  58
# 7     Villetard, Jean Etienne            1    architecte  xpr0260
# 8     Hallet, Etienne-Sulpice            1    architecte  xpr0137
# Boullant, Jean Baptiste Vincent ; architecte ; 27 expertises ; 0 expertises en tant que tiers-expert ; 11 collaborations
#                              name  totalCollab        column       id age
# 0          Capron, Charles Martin            1  entrepreneur  xpr0044  56
# 1               Taboureur, Pierre            3    architecte  xpr0250  50
# 2                   Petit, Pierre            2  entrepreneur  xpr0215  42
# 3        Danjan, Pierre Alexandre            1    architecte  xpr0065  64
# 4     Petit Radel, Louis François            1    architecte  xpr0216  46
# 5                Antoine, Antoine            1    architecte  xpr0004  40
# 6        Mouchelet, Georges Louis            1    architecte  xpr0199
# 7          Delespine, Louis Jules            1    architecte  xpr0085  60
# 8  Poulain, Jean Baptiste Martial            1    architecte  xpr0228  51
# 9         Dosmond, Léonard Pierre            1    architecte  xpr0095  35
# Bourgeois, Louis Silvain ; entrepreneur ; 2 expertises ; 0 expertises en tant que tiers-expert ; 2 collaborations
#                    name  totalCollab        column       id age
# 0       Ducret, Nicolas            1    architecte  xpr0102  59
# 1  Dumont, Jean Charles            1  entrepreneur  xpr0104  58
# Buron, François ; entrepreneur ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 collaborations
# Empty DataFrame
# Columns: []
# Index: []
# Le Camus de Mézières, Nicolas ; architecte ; 5 expertises ; 0 expertises en tant que tiers-expert ; 5 collaborations
#                               name  totalCollab        column       id age
# 0  Parvy De La Renaudiere, Nicolas            1  entrepreneur  xpr0205  52
# 1       Duboiscerf, Sébastien Jean            1  entrepreneur  xpr0101  73
# 2               Villetard, Etienne            1  entrepreneur  xpr0261  60
# 3                 Normand, Nicolas            1    architecte  xpr0203  43
# 4   Poulain, Jean Baptiste Martial            1    architecte  xpr0228  51
# 5             Jacob, Jean François            1  entrepreneur  xpr0143  51
# Capron, Charles Martin ; entrepreneur ; 8 expertises ; 0 expertises en tant que tiers-expert ; 4 collaborations
#                               name  totalCollab      column       id age
# 0  Boullant, Jean Baptiste Vincent            1  architecte  xpr0033  47
# 1                Taboureur, Pierre            2  architecte  xpr0250  50
# 2  Dauvergne, Nicolas Rémy Gabriel            1  architecte  xpr0068  38
# Chabouille, Médéric Joseph ; entrepreneur ; 3 expertises ; 0 expertises en tant que tiers-expert ; 3 collaborations
#                                     name  totalCollab        column       id  \
# 0                      Taboureur, Pierre            1    architecte  xpr0250
# 1                    Blanchard, Jean-Luc            1    architecte  xpr0024
# 2  Bellanger, Guillaume François Gabriel            1  entrepreneur  xpr0016
#
#   age
# 0  50
# 1
# 2
# Chasteau, Jean François ; entrepreneur ; 7 expertises ; 1 expertises en tant que tiers-expert ; 6 collaborations
#                              name  totalCollab        column       id age
# 0               Taboureur, Pierre            1    architecte  xpr0250  50
# 1            Dumont, Jean Charles            1  entrepreneur  xpr0104  58
# 2                    Lemit, Louis            1    architecte  xpr0176  41
# 3              Villetard, Etienne            1  entrepreneur  xpr0261  60
# 4  Poulain, Jean Baptiste Martial            1    architecte  xpr0228  51
# 5               Bleve, Jean Louis            1    architecte  xpr0026  59
# 6         Dosmond, Léonard Pierre            1    architecte  xpr0095  35
# 7      Duboiscerf, Sébastien Jean            1  entrepreneur  xpr0101  73
# Clavareau, Jean Pierre ; architecte ; 6 expertises ; 0 expertises en tant que tiers-expert ; 6 collaborations
#                                          name  totalCollab        column  \
# 0                  Duboiscerf, Sébastien Jean            2  entrepreneur
# 1                             Ducret, Nicolas            1    architecte
# 2  Regnard De Barentin, Bernard Jean Baptiste            1  entrepreneur
# 3              Poulain, Jean Baptiste Martial            1    architecte
# 4                           Taboureur, Pierre            1    architecte
#
#         id age
# 0  xpr0101  73
# 1  xpr0102  59
# 2  xpr0235  47
# 3  xpr0228  51
# 4  xpr0250  50
# D'herbelot, Francois-Charles ; architecte ; 2 expertises ; 0 expertises en tant que tiers-expert ; 2 collaborations
#                              name  totalCollab      column       id age
# 0  Poulain, Jean Baptiste Martial            1  architecte  xpr0228  51
# 1                 Ducret, Nicolas            1  architecte  xpr0102  59
# Danjan, Pierre Alexandre ; architecte ; 11 expertises ; 0 expertises en tant que tiers-expert ; 10 collaborations
#                               name  totalCollab        column       id age
# 0             Jacob, Jean François            1  entrepreneur  xpr0143  51
# 1                    Petit, Pierre            4  entrepreneur  xpr0215  42
# 2             Dumont, Jean Charles            1  entrepreneur  xpr0104  58
# 3               Villetard, Etienne            1  entrepreneur  xpr0261  60
# 4  Boullant, Jean Baptiste Vincent            1    architecte  xpr0033  47
# 5              Egresset, Guillaume            1  entrepreneur  xpr0106  75
# 6                Taboureur, Pierre            1    architecte  xpr0250  50
# 7             Bouchu, Paul Antoine            1    architecte  xpr0031  46
# Dauvergne, Nicolas Rémy Gabriel ; architecte ; 8 expertises ; 1 expertises en tant que tiers-expert ; 3 collaborations
#                          name  totalCollab        column       id age
# 0        Mangin, Jean Charles            1    architecte  xpr0187  37
# 1  Duboiscerf, Sébastien Jean            1  entrepreneur  xpr0101  73
# 2      Capron, Charles Martin            1  entrepreneur  xpr0044  56
# De Varenne, Claude Estienne ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 0 collaborations
# Empty DataFrame
# Columns: []
# Index: []
# De Villers, Eustache Robert ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 collaborations
# Empty DataFrame
# Columns: []
# Index: []
# De Vonges, Michel ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 collaborations
# Empty DataFrame
# Columns: []
# Index: []
# Delespine, Louis Jules ; architecte ; 23 expertises ; 0 expertises en tant que tiers-expert ; 8 collaborations
#                               name  totalCollab        column       id age
# 0             Dumont, Jean Charles            3  entrepreneur  xpr0104  58
# 1               Villetard, Etienne            1  entrepreneur  xpr0261  60
# 2         Mouchelet, Georges Louis            1    architecte  xpr0199
# 3                Taboureur, Pierre            1    architecte  xpr0250  50
# 4  Boullant, Jean Baptiste Vincent            1    architecte  xpr0033  47
# 5       Gabriel, Nicolas Toussaint            1    architecte  xpr0114  47
# Desjardins, Jean Baptiste Guillaume Alexandre Georges Balthazard Auguste ; architecte ; 4 expertises ; 0 expertises en tant que tiers-expert ; 3 collaborations
#                 name  totalCollab      column       id age
# 0    Ducret, Nicolas            1  architecte  xpr0102  59
# 1  Bleve, Jean Louis            1  architecte  xpr0026  59
# 2  Taboureur, Pierre            1  architecte  xpr0250  50
# Desmaisons, Pierre ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 collaborations
# Empty DataFrame
# Columns: []
# Index: []
# Desmaisons, Jacques François ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 collaborations
# Empty DataFrame
# Columns: []
# Index: []
# Dosmond, Léonard Pierre ; architecte ; 14 expertises ; 1 expertises en tant que tiers-expert ; 9 collaborations
#                                name  totalCollab        column       id age
# 0                   Ducret, Nicolas            1    architecte  xpr0102  59
# 1              André, Jean Baptiste            1    architecte  xpr0002  51
# 2              Dumont, Jean Charles            2  entrepreneur  xpr0104  58
# 3                     Petit, Pierre            1  entrepreneur  xpr0215  42
# 4    Poulain, Jean Baptiste Martial            2    architecte  xpr0228  51
# 5           Chasteau, Jean François            1  entrepreneur  xpr0050  52
# 6                 Bleve, Jean Louis            1    architecte  xpr0026  59
# 7                Villetard, Etienne            2  entrepreneur  xpr0261  60
# 8        Duboiscerf, Sébastien Jean            2  entrepreneur  xpr0101  73
# 9                 Taboureur, Pierre            1    architecte  xpr0250  50
# 10  Boullant, Jean Baptiste Vincent            1    architecte  xpr0033  47
# Duboiscerf, Sébastien Jean ; entrepreneur ; 165 expertises ; 2 expertises en tant que tiers-expert ; 54 collaborations
#                                name  totalCollab        column       id age
# 0           Villetard, Jean Etienne            1    architecte  xpr0260
# 1   Parvy De La Renaudiere, Nicolas            1  entrepreneur  xpr0205  52
# 2     Le Camus de Mézières, Nicolas            1    architecte  xpr0043  61
# 3                Villetard, Etienne           31  entrepreneur  xpr0261  60
# 4                 Taboureur, Pierre            3    architecte  xpr0250  50
# 5              Dumont, Jean Charles            2  entrepreneur  xpr0104  58
# 6            Thevenin, Jacques-Jean            1  entrepreneur  xpr0254
# 7        Gabriel, Nicolas Toussaint            1    architecte  xpr0114  47
# 8            Clavareau, Jean Pierre            2    architecte  xpr0055  65
# 9              Bouchu, Paul Antoine            1    architecte  xpr0031  46
# 10                                             1
# 11                    Petit, Pierre            3  entrepreneur  xpr0215  42
# 12  Dauvergne, Nicolas Rémy Gabriel            1    architecte  xpr0068  38
# 13   Poulain, Jean Baptiste Martial            2    architecte  xpr0228  51
# 14          Chasteau, Jean François            1  entrepreneur  xpr0050  52
# 15                Bleve, Jean Louis            1    architecte  xpr0026  59
# 16             Jacob, Jean François            2  entrepreneur  xpr0143  51
# 17          Dosmond, Léonard Pierre            2    architecte  xpr0095  35
# 18              Egresset, Guillaume            1  entrepreneur  xpr0106  75
# 19                 Normand, Nicolas            1    architecte  xpr0203  43
# 20                  Ducret, Nicolas            1    architecte  xpr0102  59
# 21             Mangin, Jean Charles            1    architecte  xpr0187  37
# Ducret, Nicolas ; architecte ; 43 expertises ; 0 expertises en tant que tiers-expert ; 24 collaborations
#                                                  name  totalCollab  \
# 0                                   Taboureur, Pierre            5
# 1                                André, Jean Baptiste            1
# 2                             Dosmond, Léonard Pierre            1
# 3                            Lardant, Pierre François            1
# 4                            Bourgeois, Louis Silvain            1
# 5                                      Mouchet, André            1
# 6                                Dumont, Jean Charles            2
# 7   Desjardins, Jean Baptiste Guillaume Alexandre ...            1
# 8                      Poulain, Jean Baptiste Martial            2
# 9                              Clavareau, Jean Pierre            1
# 10                                   Antoine, Antoine            1
# 11                         Gabriel, Nicolas Toussaint            1
# 12                                  Bleve, Jean Louis            1
# 13                                   Normand, Nicolas            3
# 14                       D'herbelot, Francois-Charles            1
# 15                                 Villetard, Etienne            1
# 16                         Duboiscerf, Sébastien Jean            1
# 17         Regnard De Barentin, Bernard Jean Baptiste            2
#
#           column       id age
# 0     architecte  xpr0250  50
# 1     architecte  xpr0002  51
# 2     architecte  xpr0095  35
# 3   entrepreneur  xpr0155  55
# 4   entrepreneur  xpr0038  50
# 5   entrepreneur  xpr0200
# 6   entrepreneur  xpr0104  58
# 7     architecte  xpr0090  32
# 8     architecte  xpr0228  51
# 9     architecte  xpr0055  65
# 10    architecte  xpr0004  40
# 11    architecte  xpr0114  47
# 12    architecte  xpr0026  59
# 13    architecte  xpr0203  43
# 14    architecte  xpr0064
# 15  entrepreneur  xpr0261  60
# 16  entrepreneur  xpr0101  73
# 17  entrepreneur  xpr0235  47
# Dumont, Jean Charles ; entrepreneur ; 53 expertises ; 0 expertises en tant que tiers-expert ; 33 collaborations
#                               name  totalCollab        column       id age
# 0                Taboureur, Pierre            5    architecte  xpr0250  50
# 1   Poulain, Jean Baptiste Martial            5    architecte  xpr0228  51
# 2           Delespine, Louis Jules            3    architecte  xpr0085  60
# 3          Dosmond, Léonard Pierre            2    architecte  xpr0095  35
# 4                    Petit, Pierre            1  entrepreneur  xpr0215  42
# 5             Mangin, Jean Charles            3    architecte  xpr0187  37
# 6      Petit Radel, Louis François            1    architecte  xpr0216  46
# 7                  Ducret, Nicolas            2    architecte  xpr0102  59
# 8       Duboiscerf, Sébastien Jean            2  entrepreneur  xpr0101  73
# 9         Danjan, Pierre Alexandre            1    architecte  xpr0065  64
# 10         Chasteau, Jean François            1  entrepreneur  xpr0050  52
# 11                Antoine, Antoine            1    architecte  xpr0004  40
# 12      Gabriel, Nicolas Toussaint            1    architecte  xpr0114  47
# 13              Villetard, Etienne            3  entrepreneur  xpr0261  60
# 14         Villetard, Jean Etienne            1    architecte  xpr0260
# 15               Bleve, Jean Louis            1    architecte  xpr0026  59
# 16                    Siguy, Louis            1  entrepreneur  xpr0245  48
# 17        Bourgeois, Louis Silvain            1  entrepreneur  xpr0038  50
# 18            Bouchu, Paul Antoine            1    architecte  xpr0031  46
# 19                Normand, Nicolas            1    architecte  xpr0203  43
# Egresset, Guillaume ; entrepreneur ; 3 expertises ; 0 expertises en tant que tiers-expert ; 2 collaborations
#                          name  totalCollab        column       id age
# 0    Danjan, Pierre Alexandre            1    architecte  xpr0065  64
# 1  Duboiscerf, Sébastien Jean            1  entrepreneur  xpr0101  73
# Gabriel, Nicolas Toussaint ; architecte ; 14 expertises ; 0 expertises en tant que tiers-expert ; 11 collaborations
#                                     name  totalCollab        column       id  \
# 0             Duboiscerf, Sébastien Jean            1  entrepreneur  xpr0101
# 1                   Dumont, Jean Charles            1  entrepreneur  xpr0104
# 2                        Ducret, Nicolas            1    architecte  xpr0102
# 3                     Villetard, Etienne            1  entrepreneur  xpr0261
# 4                          Petit, Pierre            2  entrepreneur  xpr0215
# 5                      Taboureur, Pierre            1    architecte  xpr0250
# 6                           Siguy, Louis            1  entrepreneur  xpr0245
# 7  Vavasseur Desperriers, Louis Athanase            1  entrepreneur  xpr0258
# 8                 Delespine, Louis Jules            1    architecte  xpr0085
# 9                       Normand, Nicolas            1    architecte  xpr0203
#
#   age
# 0  73
# 1  58
# 2  59
# 3  60
# 4  42
# 5  50
# 6  48
# 7  44
# 8  60
# 9  43
# Giraud, Pierre Marie ; architecte ; 11 expertises ; 0 expertises en tant que tiers-expert ; 6 collaborations
#                                          name  totalCollab        column  \
# 0  Regnard De Barentin, Bernard Jean Baptiste            2  entrepreneur
# 1                   Le Foulon, Guillaume Elie            1  entrepreneur
# 2                        Jacob, Jean François            1  entrepreneur
# 3                           Taboureur, Pierre            2    architecte
#
#         id age
# 0  xpr0235  47
# 1  xpr0163  59
# 2  xpr0143  51
# 3  xpr0250  50
# Goulet, Nicolas ; entrepreneur ; 2 expertises ; 0 expertises en tant que tiers-expert ; 2 collaborations
#                              name  totalCollab      column       id age
# 0             Blanchard, Jean-Luc            1  architecte  xpr0024
# 1  Poulain, Jean Baptiste Martial            1  architecte  xpr0228  51
# Goupy Ii, Martin ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 collaborations
# Empty DataFrame
# Columns: []
# Index: []
# Hallet, Etienne-Sulpice ; architecte ; 9 expertises ; 1 expertises en tant que tiers-expert ; 2 collaborations
#                              name  totalCollab      column       id age
# 0  Poulain, Jean Baptiste Martial            1  architecte  xpr0228  51
# 1            Bouchu, Paul Antoine            1  architecte  xpr0031  46
# Jacob, Jean François ; entrepreneur ; 11 expertises ; 0 expertises en tant que tiers-expert ; 8 collaborations
#                              name  totalCollab        column       id age
# 0            Bouchu, Paul Antoine            1    architecte  xpr0031  46
# 1        Danjan, Pierre Alexandre            1    architecte  xpr0065  64
# 2      Duboiscerf, Sébastien Jean            2  entrepreneur  xpr0101  73
# 3               Taboureur, Pierre            1    architecte  xpr0250  50
# 4  Poulain, Jean Baptiste Martial            1    architecte  xpr0228  51
# 5            Giraud, Pierre Marie            1    architecte  xpr0122  52
# 6   Le Camus de Mézières, Nicolas            1    architecte  xpr0043  61
# Jacob, François ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 collaborations
#                      name  totalCollab      column       id age
# 0  Porquet, Claude Joseph            1  architecte  xpr0226  64
# Lardant, Pierre François ; entrepreneur ; 2 expertises ; 0 expertises en tant que tiers-expert ; 2 collaborations
#                              name  totalCollab      column       id age
# 0  Poulain, Jean Baptiste Martial            1  architecte  xpr0228  51
# 1                 Ducret, Nicolas            1  architecte  xpr0102  59
# 2               Taboureur, Pierre            1  architecte  xpr0250  50
# Le brun, Charles François ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 0 collaborations
# Empty DataFrame
# Columns: []
# Index: []
# Le Foulon, Guillaume Elie ; entrepreneur ; 5 expertises ; 0 expertises en tant que tiers-expert ; 5 collaborations
#                    name  totalCollab        column       id age
# 0      Normand, Nicolas            1    architecte  xpr0203  43
# 1  Giraud, Pierre Marie            1    architecte  xpr0122  52
# 2          Siguy, Louis            1  entrepreneur  xpr0245  48
# 3     Taboureur, Pierre            1    architecte  xpr0250  50
# 4    Villetard, Etienne            1  entrepreneur  xpr0261  60
# Le Roux, Jean ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 collaborations
#                 name  totalCollab      column       id age
# 0  Taboureur, Pierre            1  architecte  xpr0250  50
# Lemit, Louis ; architecte ; 3 expertises ; 0 expertises en tant que tiers-expert ; 1 collaborations
#                       name  totalCollab        column       id age
# 0  Chasteau, Jean François            1  entrepreneur  xpr0050  52
# Mangin, Jean Charles ; architecte ; 36 expertises ; 0 expertises en tant que tiers-expert ; 12 collaborations
#                               name  totalCollab        column       id age
# 0                Bleve, Jean Louis            2    architecte  xpr0026  59
# 1               Angot, Jean Pierre            1  entrepreneur  xpr0003  47
# 2             Dumont, Jean Charles            3  entrepreneur  xpr0104  58
# 3                Taboureur, Pierre            1    architecte  xpr0250  50
# 4  Dauvergne, Nicolas Rémy Gabriel            1    architecte  xpr0068  38
# 5   Poulain, Jean Baptiste Martial            2    architecte  xpr0228  51
# 6             Bouchu, Paul Antoine            1    architecte  xpr0031  46
# 7                    Petit, Pierre            1  entrepreneur  xpr0215  42
# 8               Villetard, Etienne            1  entrepreneur  xpr0261  60
# 9       Duboiscerf, Sébastien Jean            1  entrepreneur  xpr0101  73
# Mouchelet, Georges Louis ; architecte ; 4 expertises ; 0 expertises en tant que tiers-expert ; 3 collaborations
#                               name  totalCollab      column       id age
# 0                 Antoine, Antoine            1  architecte  xpr0004  40
# 1  Boullant, Jean Baptiste Vincent            1  architecte  xpr0033  47
# 2           Delespine, Louis Jules            1  architecte  xpr0085  60
# Mouchet, André ; entrepreneur ; 8 expertises ; 0 expertises en tant que tiers-expert ; 4 collaborations
#                              name  totalCollab      column       id age
# 0                 Ducret, Nicolas            1  architecte  xpr0102  59
# 1  Poulain, Jean Baptiste Martial            1  architecte  xpr0228  51
# 2               Taboureur, Pierre            2  architecte  xpr0250  50
# Neveu, Michel ; entrepreneur ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 collaborations
# Empty DataFrame
# Columns: []
# Index: []
# Normand, Nicolas ; architecte ; 17 expertises ; 0 expertises en tant que tiers-expert ; 13 collaborations
#                               name  totalCollab        column       id age
# 0   Poulain, Jean Baptiste Martial            1    architecte  xpr0228  51
# 1                    Petit, Pierre            1  entrepreneur  xpr0215  42
# 2             Bouchu, Paul Antoine            1    architecte  xpr0031  46
# 3                    Aubert, André            1  entrepreneur  xpr0007  41
# 4    Le Camus de Mézières, Nicolas            1    architecte  xpr0043  61
# 5                Taboureur, Pierre            1    architecte  xpr0250  50
# 6        Le Foulon, Guillaume Elie            1  entrepreneur  xpr0163  59
# 7                  Ducret, Nicolas            3    architecte  xpr0102  59
# 8       Duboiscerf, Sébastien Jean            1  entrepreneur  xpr0101  73
# 9             Dumont, Jean Charles            1  entrepreneur  xpr0104  58
# 10      Gabriel, Nicolas Toussaint            1    architecte  xpr0114  47
# Parvy De La Renaudiere, Nicolas ; entrepreneur ; 6 expertises ; 0 expertises en tant que tiers-expert ; 3 collaborations
#                              name  totalCollab        column       id age
# 0      Duboiscerf, Sébastien Jean            1  entrepreneur  xpr0101  73
# 1   Le Camus de Mézières, Nicolas            1    architecte  xpr0043  61
# 2  Poulain, Jean Baptiste Martial            1    architecte  xpr0228  51
# 3              Villetard, Etienne            1  entrepreneur  xpr0261  60
# Petit, Pierre ; entrepreneur ; 60 expertises ; 1 expertises en tant que tiers-expert ; 31 collaborations
#                                           name  totalCollab        column  \
# 0        Bellanger, Guillaume François Gabriel            1  entrepreneur
# 1                         Dumont, Jean Charles            1  entrepreneur
# 2                      Dosmond, Léonard Pierre            1    architecte
# 3                          Blanchard, Jean-Luc            2    architecte
# 4                     Danjan, Pierre Alexandre            4    architecte
# 5        Vavasseur Desperriers, Louis Athanase            5  entrepreneur
# 6                             Normand, Nicolas            1    architecte
# 7              Boullant, Jean Baptiste Vincent            2    architecte
# 8                   Duboiscerf, Sébastien Jean            3  entrepreneur
# 9                            Taboureur, Pierre            6    architecte
# 10                           Bleve, Jean Louis            2    architecte
# 11  Regnard De Barentin, Bernard Jean Baptiste            1  entrepreneur
# 12                  Gabriel, Nicolas Toussaint            2    architecte
# 13                          Villetard, Etienne            1  entrepreneur
# 14                          Angot, Jean Pierre            1  entrepreneur
# 15                        Mangin, Jean Charles            1    architecte
#
#          id age
# 0   xpr0016
# 1   xpr0104  58
# 2   xpr0095  35
# 3   xpr0024
# 4   xpr0065  64
# 5   xpr0258  44
# 6   xpr0203  43
# 7   xpr0033  47
# 8   xpr0101  73
# 9   xpr0250  50
# 10  xpr0026  59
# 11  xpr0235  47
# 12  xpr0114  47
# 13  xpr0261  60
# 14  xpr0003  47
# 15  xpr0187  37
# Petit Radel, Louis François ; architecte ; 11 expertises ; 0 expertises en tant que tiers-expert ; 3 collaborations
#                               name  totalCollab        column       id age
# 0             Dumont, Jean Charles            1  entrepreneur  xpr0104  58
# 1               Angot, Jean Pierre            1  entrepreneur  xpr0003  47
# 2  Boullant, Jean Baptiste Vincent            1    architecte  xpr0033  47
# Porquet, Claude Joseph ; architecte ; 2 expertises ; 0 expertises en tant que tiers-expert ; 1 collaborations
#               name  totalCollab      column       id age
# 0  Jacob, François            1  architecte  xpr0144
# Poulain, Jean Baptiste Martial ; architecte ; 46 expertises ; 0 expertises en tant que tiers-expert ; 37 collaborations
#                                           name  totalCollab        column  \
# 0                         Dumont, Jean Charles            5  entrepreneur
# 1                     Lardant, Pierre François            1  entrepreneur
# 2                      Hallet, Etienne-Sulpice            1    architecte
# 3                             Normand, Nicolas            1    architecte
# 4                 D'herbelot, Francois-Charles            1    architecte
# 5                            Taboureur, Pierre            7    architecte
# 6                              Ducret, Nicolas            2    architecte
# 7   Regnard De Barentin, Bernard Jean Baptiste            1  entrepreneur
# 8        Vavasseur Desperriers, Louis Athanase            1  entrepreneur
# 9              Parvy De La Renaudiere, Nicolas            1  entrepreneur
# 10                     Dosmond, Léonard Pierre            2    architecte
# 11                          Villetard, Etienne            2  entrepreneur
# 12                              Mouchet, André            1  entrepreneur
# 13                     Chasteau, Jean François            1  entrepreneur
# 14                             Goulet, Nicolas            1  entrepreneur
# 15                  Duboiscerf, Sébastien Jean            2  entrepreneur
# 16                        Mangin, Jean Charles            2    architecte
# 17                         Simon, René Auguste            1  entrepreneur
# 18                        Jacob, Jean François            1  entrepreneur
# 19       Bellanger, Guillaume François Gabriel            1  entrepreneur
# 20               Le Camus de Mézières, Nicolas            1    architecte
# 21                      Clavareau, Jean Pierre            1    architecte
# 22                           Bleve, Jean Louis            1    architecte
# 23             Boullant, Jean Baptiste Vincent            1    architecte
#
#          id age
# 0   xpr0104  58
# 1   xpr0155  55
# 2   xpr0137
# 3   xpr0203  43
# 4   xpr0064
# 5   xpr0250  50
# 6   xpr0102  59
# 7   xpr0235  47
# 8   xpr0258  44
# 9   xpr0205  52
# 10  xpr0095  35
# 11  xpr0261  60
# 12  xpr0200
# 13  xpr0050  52
# 14  xpr0127  41
# 15  xpr0101  73
# 16  xpr0187  37
# 17  xpr0247  74
# 18  xpr0143  51
# 19  xpr0016
# 20  xpr0043  61
# 21  xpr0055  65
# 22  xpr0026  59
# 23  xpr0033  47
# Pruneau De Montlouis, Jean Louis ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 collaborations
# Empty DataFrame
# Columns: []
# Index: []
# Regnard De Barentin, Bernard Jean Baptiste ; entrepreneur ; 8 expertises ; 0 expertises en tant que tiers-expert ; 8 collaborations
#                              name  totalCollab        column       id age
# 0            Giraud, Pierre Marie            2    architecte  xpr0122  52
# 1  Poulain, Jean Baptiste Martial            1    architecte  xpr0228  51
# 2          Clavareau, Jean Pierre            1    architecte  xpr0055  65
# 3                   Petit, Pierre            1  entrepreneur  xpr0215  42
# 4                 Ducret, Nicolas            2    architecte  xpr0102  59
# 5             Blanchard, Jean-Luc            1    architecte  xpr0024
# Roche, Honoré Jacques ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 collaborations
#                 name  totalCollab      column       id age
# 0  Taboureur, Pierre            1  architecte  xpr0250  50
# Siguy, Louis ; entrepreneur ; 6 expertises ; 0 expertises en tant que tiers-expert ; 3 collaborations
#                          name  totalCollab        column       id age
# 0        Dumont, Jean Charles            1  entrepreneur  xpr0104  58
# 1  Gabriel, Nicolas Toussaint            1    architecte  xpr0114  47
# 2   Le Foulon, Guillaume Elie            1  entrepreneur  xpr0163  59
# Simon, René Auguste ; entrepreneur ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 collaborations
#                              name  totalCollab      column       id age
# 0  Poulain, Jean Baptiste Martial            1  architecte  xpr0228  51
# Soisson, Charles Nicolas ; entrepreneur ; 1 expertises ; 0 expertises en tant que tiers-expert ; 0 collaborations
# Empty DataFrame
# Columns: []
# Index: []
# Taboureur, Pierre ; architecte ; 225 expertises ; 4 expertises en tant que tiers-expert ; 61 collaborations
#                                                  name  totalCollab  \
# 0                                Dumont, Jean Charles            5
# 1                                     Ducret, Nicolas            5
# 2                                  Angot, Jean Pierre            2
# 3                                  Villetard, Etienne            6
# 4                            Lardant, Pierre François            1
# 5                                    Antoine, Antoine            1
# 6                     Boullant, Jean Baptiste Vincent            3
# 7                      Poulain, Jean Baptiste Martial            7
# 8                          Duboiscerf, Sébastien Jean            3
# 9                          Chabouille, Médéric Joseph            1
# 10                            Chasteau, Jean François            1
# 11                               Mangin, Jean Charles            1
# 12                                      Aubert, André            2
# 13                                      Petit, Pierre            6
# 14                              Roche, Honoré Jacques            1
# 15                             Capron, Charles Martin            2
# 16                                  Bleve, Jean Louis            2
# 17                                   Normand, Nicolas            1
# 18                                      Le Roux, Jean            1
# 19                            Dosmond, Léonard Pierre            1
# 20                               Jacob, Jean François            1
# 21                                     Mouchet, André            2
# 22                         Gabriel, Nicolas Toussaint            1
# 23                           Danjan, Pierre Alexandre            1
# 24                             Delespine, Louis Jules            1
# 25                               Giraud, Pierre Marie            2
# 26                          Le Foulon, Guillaume Elie            1
# 27                             Clavareau, Jean Pierre            1
# 28  Desjardins, Jean Baptiste Guillaume Alexandre ...            1
#
#           column       id age
# 0   entrepreneur  xpr0104  58
# 1     architecte  xpr0102  59
# 2   entrepreneur  xpr0003  47
# 3   entrepreneur  xpr0261  60
# 4   entrepreneur  xpr0155  55
# 5     architecte  xpr0004  40
# 6     architecte  xpr0033  47
# 7     architecte  xpr0228  51
# 8   entrepreneur  xpr0101  73
# 9   entrepreneur  xpr0049  44
# 10  entrepreneur  xpr0050  52
# 11    architecte  xpr0187  37
# 12  entrepreneur  xpr0007  41
# 13  entrepreneur  xpr0215  42
# 14    architecte  xpr0238  44
# 15  entrepreneur  xpr0044  56
# 16    architecte  xpr0026  59
# 17    architecte  xpr0203  43
# 18    architecte  xpr0169
# 19    architecte  xpr0095  35
# 20  entrepreneur  xpr0143  51
# 21  entrepreneur  xpr0200
# 22    architecte  xpr0114  47
# 23    architecte  xpr0065  64
# 24    architecte  xpr0085  60
# 25    architecte  xpr0122  52
# 26  entrepreneur  xpr0163  59
# 27    architecte  xpr0055  65
# 28    architecte  xpr0090  32
# Terrier, Martin Marie ; architecte ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 collaborations
# Empty DataFrame
# Columns: []
# Index: []
# Thevenin, Jacques-Jean ; entrepreneur ; 3 expertises ; 0 expertises en tant que tiers-expert ; 1 collaborations
#                          name  totalCollab        column       id age
# 0  Duboiscerf, Sébastien Jean            1  entrepreneur  xpr0101  73
# Varin, Bénigne Joseph ; entrepreneur ; 0 expertises ; 0 expertises en tant que tiers-expert ; 0 collaborations
# Empty DataFrame
# Columns: []
# Index: []
# Vavasseur Desperriers, Louis Athanase ; entrepreneur ; 9 expertises ; 0 expertises en tant que tiers-expert ; 7 collaborations
#                              name  totalCollab        column       id age
# 0                   Petit, Pierre            5  entrepreneur  xpr0215  42
# 1  Poulain, Jean Baptiste Martial            1    architecte  xpr0228  51
# 2      Gabriel, Nicolas Toussaint            1    architecte  xpr0114  47
# Villetard, Jean Etienne ; architecte ; 5 expertises ; 0 expertises en tant que tiers-expert ; 4 collaborations
#                                     name  totalCollab        column       id  \
# 0             Duboiscerf, Sébastien Jean            1  entrepreneur  xpr0101
# 1                   Dumont, Jean Charles            1  entrepreneur  xpr0104
# 2  Bellanger, Guillaume François Gabriel            1  entrepreneur  xpr0016
# 3                   Bouchu, Paul Antoine            1    architecte  xpr0031
#
#   age
# 0  73
# 1  58
# 2
# 3  46
# Villetard, Etienne ; entrepreneur ; 54 expertises ; 0 expertises en tant que tiers-expert ; 50 collaborations
#                                name  totalCollab        column       id age
# 0                 Taboureur, Pierre            6    architecte  xpr0250  50
# 1        Duboiscerf, Sébastien Jean           31  entrepreneur  xpr0101  73
# 2          Danjan, Pierre Alexandre            1    architecte  xpr0065  64
# 3     Le Camus de Mézières, Nicolas            1    architecte  xpr0043  61
# 4              Dumont, Jean Charles            3  entrepreneur  xpr0104  58
# 5              André, Jean Baptiste            1    architecte  xpr0002  51
# 6    Poulain, Jean Baptiste Martial            2    architecte  xpr0228  51
# 7        Gabriel, Nicolas Toussaint            1    architecte  xpr0114  47
# 8           Chasteau, Jean François            1  entrepreneur  xpr0050  52
# 9                 Bleve, Jean Louis            2    architecte  xpr0026  59
# 10           Delespine, Louis Jules            1    architecte  xpr0085  60
# 11          Dosmond, Léonard Pierre            2    architecte  xpr0095  35
# 12                    Petit, Pierre            1  entrepreneur  xpr0215  42
# 13                  Ducret, Nicolas            1    architecte  xpr0102  59
# 14  Parvy De La Renaudiere, Nicolas            1  entrepreneur  xpr0205  52
# 15             Mangin, Jean Charles            1    architecte  xpr0187  37
# 16        Le Foulon, Guillaume Elie            1  entrepreneur  xpr0163  59
# Lefort, François (? - ?) ; architecte ; 3 expertises ; 0 expertises en tant que tiers-expert ; 2 collaborations
#                         name  totalCollab      column       id age
# 0     Lomet, Quentin (? - ?)            1  architecte  xpr0274
# 1  Jamain, Sébastien (? - ?)            1  architecte  xpr0277   0
# Lomet, Quentin (? - ?) ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 collaborations
#                        name  totalCollab      column       id age
# 0  Lefort, François (? - ?)            1  architecte  xpr0273
# Jamain, Sébastien (? - ?) ; architecte ; 1 expertises ; 0 expertises en tant que tiers-expert ; 1 collaborations
#                        name  totalCollab      column       id age
# 0  Lefort, François (? - ?)            1  architecte  xpr0273
